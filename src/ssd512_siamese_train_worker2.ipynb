# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights =  [0.0, 0.0, 0.000005] + [1.0]
Source_Only = False # True

# 'City_to_foggy0_01_resize_600_1200' # 'City_to_foggy0_02_resize_600_1200'  # 'SIM10K_to_VOC07'
# 'SIM10K'  # 'Cityscapes_foggy_beta_0_01'  # 'City_to_foggy0_02_resize_400_800'
DatasetName = 'City_to_foggy0_01_resize_400_800' # 'SIM10K_to_City_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName + '_worker2'
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

if DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_600_1200':
    resize_image_to = (600, 1200)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_600_1200':
    resize_image_to = (600, 1200)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'Cityscapes_foggy_beta_0_01':
    resize_image_to = (300, 600)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K':
    resize_image_to = (300, 600)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_VOC07':
    resize_image_to = (300, 600)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    
    
#     if Source_Only:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})
#     else:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 2966/2966 [00:00<00:00, 4645.80it/s]
# Loading source image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 11377.00it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 9960.46it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 2966/2966 [00:00<00:00, 7875.49it/s]
# Loading source labels: 100%|██████████| 493/493 [00:00<00:00, 5039.55it/s]
# Loading source image IDs: 100%|██████████| 493/493 [00:00<00:00, 11074.11it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 493/493 [00:00<00:00, 7809.24it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  2966
# Number of images in the validation dataset:	   493

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 50:
#         return 0.001
#     elif epoch < 60:
#         return 0.0001
#     else:
#         return 0.00001

# Define model callbacks.
checkpoint_path = '../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005'
# checkpoint_path = '../trained_weights/current/ssd_augm_beta_0_01_source_only'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'pool3_loss_weights_0_000005_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 120
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/120
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 786s 786ms/step - loss: 10.4439 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 11948.7189 - predictions_loss: 6.8490 - val_loss: 8.9756 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.4567
#
# Epoch 00001: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-01_loss-10.4439_val_loss-8.9756.h5
# Epoch 2/120
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 770s 770ms/step - loss: 8.2893 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 3351.7461 - predictions_loss: 4.7698 - val_loss: 8.5816 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.0950
#
# Epoch 00002: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-02_loss-8.2893_val_loss-8.5816.h5
# Epoch 3/120
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 769s 769ms/step - loss: 8.0563 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 2585.9043 - predictions_loss: 4.5872 - val_loss: 8.3730 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.9476
#
# Epoch 00003: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-03_loss-8.0563_val_loss-8.3730.h5
# Epoch 4/120
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 771s 771ms/step - loss: 7.6181 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 1902.1452 - predictions_loss: 4.2136 - val_loss: 7.8901 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5256
#
# Epoch 00004: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-04_loss-7.6181_val_loss-7.8901.h5
# Epoch 5/120
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 780s 780ms/step - loss: 7.2463 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 1613.4558 - predictions_loss: 3.9037 - val_loss: 7.9947 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6901
#
# Epoch 00005: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-05_loss-7.2463_val_loss-7.9947.h5
# Epoch 6/120
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 770s 770ms/step - loss: 7.0157 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 1341.9171 - predictions_loss: 3.7336 - val_loss: 7.5772 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3309
#
# Epoch 00006: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-06_loss-7.0157_val_loss-7.5772.h5
# Epoch 7/120
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 766s 766ms/step - loss: 6.8643 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 1268.6368 - predictions_loss: 3.6404 - val_loss: 7.7197 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5308
#
# Epoch 00007: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-07_loss-6.8643_val_loss-7.7197.h5
# Epoch 8/120
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 767s 767ms/step - loss: 6.7221 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 1126.4239 - predictions_loss: 3.5555 - val_loss: 7.5841 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4511
#
# Epoch 00008: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-08_loss-6.7221_val_loss-7.5841.h5
# Epoch 9/120
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 798s 798ms/step - loss: 6.5566 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 985.6160 - predictions_loss: 3.4463 - val_loss: 7.3954 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3173
#
# Epoch 00009: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-09_loss-6.5566_val_loss-7.3954.h5
# Epoch 10/120
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 775s 775ms/step - loss: 6.4404 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 896.2012 - predictions_loss: 3.3847 - val_loss: 7.4536 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4292
#
# Epoch 00010: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-10_loss-6.4404_val_loss-7.4536.h5
# Epoch 11/120
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 773s 773ms/step - loss: 6.3244 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 859.0154 - predictions_loss: 3.3220 - val_loss: 7.0673 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0954
#
# Epoch 00011: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-11_loss-6.3244_val_loss-7.0673.h5
# Epoch 12/120
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 767s 767ms/step - loss: 6.2022 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 777.6261 - predictions_loss: 3.2522 - val_loss: 7.0308 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1103
#
# Epoch 00012: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-12_loss-6.2022_val_loss-7.0308.h5
# Epoch 13/120
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 768s 768ms/step - loss: 6.1164 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 753.9222 - predictions_loss: 3.2173 - val_loss: 6.8175 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9473
# Epoch 00013: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-13_loss-6.1164_val_loss-6.8175.h5
# Epoch 14/120
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 765s 765ms/step - loss: 6.0444 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 702.4101 - predictions_loss: 3.1954 - val_loss: 6.9976 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1766
#
# Epoch 00014: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-14_loss-6.0444_val_loss-6.9976.h5
# Epoch 15/120
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 765s 765ms/step - loss: 5.9196 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 644.5024 - predictions_loss: 3.1194 - val_loss: 6.8519 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0789
#
# Epoch 00015: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-15_loss-5.9196_val_loss-6.8519.h5
# Epoch 16/120
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 5.8921 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 620.3623 - predictions_loss: 3.1393 - val_loss: 6.7605 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0344
#
# Epoch 00016: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-16_loss-5.8921_val_loss-6.7605.h5
# Epoch 17/120
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 762s 762ms/step - loss: 5.7936 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 575.0752 - predictions_loss: 3.0876 - val_loss: 6.6742 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9940
#
# Epoch 00017: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-17_loss-5.7936_val_loss-6.6742.h5
# Epoch 18/120
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 764s 764ms/step - loss: 5.6875 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 546.7729 - predictions_loss: 3.0273 - val_loss: 6.6756 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0407
#
# Epoch 00018: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-18_loss-5.6875_val_loss-6.6756.h5
# Epoch 19/120
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 764s 764ms/step - loss: 5.6597 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 524.2787 - predictions_loss: 3.0443 - val_loss: 6.6072 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0160
#
# Epoch 00019: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-19_loss-5.6597_val_loss-6.6072.h5
# Epoch 20/120
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 762s 762ms/step - loss: 5.5852 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 479.6267 - predictions_loss: 3.0132 - val_loss: 6.5476 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9994
#
# Epoch 00020: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-20_loss-5.5852_val_loss-6.5476.h5
# Epoch 21/120
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 765s 765ms/step - loss: 5.5153 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 481.4581 - predictions_loss: 2.9857 - val_loss: 6.5294 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0231
#
# Epoch 00021: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-21_loss-5.5153_val_loss-6.5294.h5
# Epoch 22/120
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 5.4685 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 443.5531 - predictions_loss: 2.9806 - val_loss: 6.4075 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9421
#
# Epoch 00022: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-22_loss-5.4685_val_loss-6.4075.h5
# Epoch 23/120
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 5.3840 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 441.9606 - predictions_loss: 2.9365 - val_loss: 6.5084 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0832
#
# Epoch 00023: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-23_loss-5.3840_val_loss-6.5084.h5
# Epoch 24/120
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 762s 762ms/step - loss: 5.3499 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 412.1581 - predictions_loss: 2.9423 - val_loss: 6.2865 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9005
#
# Epoch 00024: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-24_loss-5.3499_val_loss-6.2865.h5
# Epoch 25/120
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 5.2876 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 395.2918 - predictions_loss: 2.9189 - val_loss: 6.5939 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2463
#
# Epoch 00025: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-25_loss-5.2876_val_loss-6.5939.h5
# Epoch 26/120
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 771s 771ms/step - loss: 5.1817 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 394.8227 - predictions_loss: 2.8511 - val_loss: 6.4744 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1645
# Epoch 00026: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-26_loss-5.1817_val_loss-6.4744.h5
# Epoch 27/120
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 764s 764ms/step - loss: 5.1614 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 375.0694 - predictions_loss: 2.8682 - val_loss: 6.4892 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2161
#
# Epoch 00027: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-27_loss-5.1614_val_loss-6.4892.h5
# Epoch 28/120
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 768s 768ms/step - loss: 5.0918 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 374.1639 - predictions_loss: 2.8349 - val_loss: 6.1938 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9566
#
# Epoch 00028: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-28_loss-5.0918_val_loss-6.1938.h5
# Epoch 29/120
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 856s 856ms/step - loss: 5.0557 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 346.5587 - predictions_loss: 2.8342 - val_loss: 6.0590 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8568
#
# Epoch 00029: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-29_loss-5.0557_val_loss-6.0590.h5
# Epoch 30/120
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 5.0007 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 341.5989 - predictions_loss: 2.8140 - val_loss: 6.1783 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0102
#
# Epoch 00030: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-30_loss-5.0007_val_loss-6.1783.h5
# Epoch 31/120
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 827s 827ms/step - loss: 4.9469 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 344.9540 - predictions_loss: 2.7941 - val_loss: 6.3988 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2644
#
# Epoch 00031: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-31_loss-4.9469_val_loss-6.3988.h5
# Epoch 32/120
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 764s 764ms/step - loss: 4.9207 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 317.8876 - predictions_loss: 2.8012 - val_loss: 6.0477 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9462
#
# Epoch 00032: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-32_loss-4.9207_val_loss-6.0477.h5
# Epoch 33/120
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 820s 820ms/step - loss: 4.8022 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 315.9412 - predictions_loss: 2.7155 - val_loss: 6.1707 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1017
#
# Epoch 00033: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-33_loss-4.8022_val_loss-6.1707.h5
# Epoch 34/120
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 843s 843ms/step - loss: 4.8050 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 310.4643 - predictions_loss: 2.7501 - val_loss: 5.9775 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9398
#
# Epoch 00034: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-34_loss-4.8050_val_loss-5.9775.h5
# Epoch 35/120
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 871s 871ms/step - loss: 4.7630 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 294.7027 - predictions_loss: 2.7392 - val_loss: 6.0245 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0176
#
# Epoch 00035: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-35_loss-4.7630_val_loss-6.0245.h5
# Epoch 36/120
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 916s 916ms/step - loss: 4.7220 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 281.5196 - predictions_loss: 2.7287 - val_loss: 6.2588 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2819
#
# Epoch 00036: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-36_loss-4.7220_val_loss-6.2588.h5
# Epoch 37/120
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 899s 899ms/step - loss: 4.6856 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 294.3477 - predictions_loss: 2.7220 - val_loss: 5.8963 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9489
#
# Epoch 00037: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-37_loss-4.6856_val_loss-5.8963.h5
# Epoch 38/120
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 923s 923ms/step - loss: 4.6216 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 289.9498 - predictions_loss: 2.6873 - val_loss: 5.7668 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8483
#
# Epoch 00038: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-38_loss-4.6216_val_loss-5.7668.h5
# Epoch 39/120
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 888s 888ms/step - loss: 4.5803 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 281.3098 - predictions_loss: 2.6743 - val_loss: 5.6276 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7369
# Epoch 00039: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-39_loss-4.5803_val_loss-5.6276.h5
# Epoch 40/120
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 874s 874ms/step - loss: 4.5789 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 268.6613 - predictions_loss: 2.7007 - val_loss: 5.8044 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9410
#
# Epoch 00040: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-40_loss-4.5789_val_loss-5.8044.h5
# Epoch 41/120
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 871s 871ms/step - loss: 4.5359 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 258.6326 - predictions_loss: 2.6849 - val_loss: 6.0188 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1824
#
# Epoch 00041: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-41_loss-4.5359_val_loss-6.0188.h5
# Epoch 42/120
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 923s 923ms/step - loss: 4.4414 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 265.3350 - predictions_loss: 2.6169 - val_loss: 5.6992 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8892
#
# Epoch 00042: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-42_loss-4.4414_val_loss-5.6992.h5
# Epoch 43/120
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 846s 846ms/step - loss: 4.4354 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 263.2709 - predictions_loss: 2.6372 - val_loss: 5.9769 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1929
#
# Epoch 00043: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-43_loss-4.4354_val_loss-5.9769.h5
# Epoch 44/120
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 855s 855ms/step - loss: 4.4062 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 251.2743 - predictions_loss: 2.6336 - val_loss: 5.5757 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8169
#
# Epoch 00044: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-44_loss-4.4062_val_loss-5.5757.h5
# Epoch 45/120
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 813s 813ms/step - loss: 4.3640 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 244.5280 - predictions_loss: 2.6163 - val_loss: 5.9220 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1878
#
# Epoch 00045: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-45_loss-4.3640_val_loss-5.9220.h5
# Epoch 46/120
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 768s 768ms/step - loss: 4.3463 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 252.0146 - predictions_loss: 2.6229 - val_loss: 5.8223 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1121
#
# Epoch 00046: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-46_loss-4.3463_val_loss-5.8223.h5
# Epoch 47/120
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 886s 886ms/step - loss: 4.3139 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 242.8417 - predictions_loss: 2.6143 - val_loss: 5.5724 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8857
#
# Epoch 00047: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-47_loss-4.3139_val_loss-5.5724.h5
# Epoch 48/120
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 909s 909ms/step - loss: 4.2498 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 241.7533 - predictions_loss: 2.5734 - val_loss: 5.7181 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0543
#
# Epoch 00048: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-48_loss-4.2498_val_loss-5.7181.h5
# Epoch 49/120
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 876s 876ms/step - loss: 4.2583 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 239.7271 - predictions_loss: 2.6046 - val_loss: 5.6463 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0052
#
# Epoch 00049: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-49_loss-4.2583_val_loss-5.6463.h5
# Epoch 50/120
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 4.2081 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 240.1704 - predictions_loss: 2.5768 - val_loss: 5.3007 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6816
#
# Epoch 00050: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-50_loss-4.2081_val_loss-5.3007.h5
# Epoch 51/120
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 768s 768ms/step - loss: 4.0324 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 211.3734 - predictions_loss: 2.4137 - val_loss: 5.2931 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6768
#
# Epoch 00051: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-51_loss-4.0324_val_loss-5.2931.h5
# Epoch 52/120
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 837s 837ms/step - loss: 3.9715 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 222.8090 - predictions_loss: 2.3555 - val_loss: 5.3320 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7185
# Epoch 00052: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-52_loss-3.9715_val_loss-5.3320.h5
# Epoch 53/120
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 892s 892ms/step - loss: 3.9567 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 231.6517 - predictions_loss: 2.3434 - val_loss: 5.3463 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7355
#
# Epoch 00053: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-53_loss-3.9567_val_loss-5.3463.h5
# Epoch 54/120
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 875s 875ms/step - loss: 3.9685 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 244.2470 - predictions_loss: 2.3578 - val_loss: 5.3993 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7913
#
# Epoch 00054: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-54_loss-3.9685_val_loss-5.3993.h5
# Epoch 55/120
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 929s 929ms/step - loss: 3.9327 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 247.6762 - predictions_loss: 2.3247 - val_loss: 5.4264 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8210
#
# Epoch 00055: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-55_loss-3.9327_val_loss-5.4264.h5
# Epoch 56/120
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 890s 890ms/step - loss: 3.9493 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 249.8326 - predictions_loss: 2.3440 - val_loss: 5.3877 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7850
#
# Epoch 00056: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-56_loss-3.9493_val_loss-5.3877.h5
# Epoch 57/120
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 860s 860ms/step - loss: 3.9027 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 251.7450 - predictions_loss: 2.3001 - val_loss: 5.5013 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9013
#
# Epoch 00057: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-57_loss-3.9027_val_loss-5.5013.h5
# Epoch 58/120
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 829s 829ms/step - loss: 3.8875 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 255.3993 - predictions_loss: 2.2876 - val_loss: 5.4034 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8061
#
# Epoch 00058: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-58_loss-3.8875_val_loss-5.4034.h5
# Epoch 59/120
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 894s 894ms/step - loss: 3.8706 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 264.4922 - predictions_loss: 2.2734 - val_loss: 5.4116 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8171
#
# Epoch 00059: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-59_loss-3.8706_val_loss-5.4116.h5
# Epoch 60/120
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 888s 888ms/step - loss: 3.8736 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 266.1584 - predictions_loss: 2.2790 - val_loss: 5.3848 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7929
#
# Epoch 00060: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-60_loss-3.8736_val_loss-5.3848.h5
# Epoch 61/120
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 893s 893ms/step - loss: 3.8852 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 269.4590 - predictions_loss: 2.2933 - val_loss: 5.4681 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8789
#
# Epoch 00061: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-61_loss-3.8852_val_loss-5.4681.h5
# Epoch 62/120
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 893s 893ms/step - loss: 3.8931 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 267.1224 - predictions_loss: 2.3039 - val_loss: 5.4448 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8583
#
# Epoch 00062: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-62_loss-3.8931_val_loss-5.4448.h5
# Epoch 63/120
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 891s 891ms/step - loss: 3.8626 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 268.1009 - predictions_loss: 2.2760 - val_loss: 5.5124 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9286
#
# Epoch 00063: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-63_loss-3.8626_val_loss-5.5124.h5
# Epoch 64/120
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 848s 848ms/step - loss: 3.8309 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 266.9192 - predictions_loss: 2.2470 - val_loss: 5.4113 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8301
#
# Epoch 00064: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-64_loss-3.8309_val_loss-5.4113.h5
# Epoch 65/120
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 812s 812ms/step - loss: 3.8372 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 277.3971 - predictions_loss: 2.2559 - val_loss: 5.4191 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8405
# Epoch 00065: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-65_loss-3.8372_val_loss-5.4191.h5
# Epoch 66/120
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 896s 896ms/step - loss: 3.7954 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 273.0130 - predictions_loss: 2.2167 - val_loss: 5.3865 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8106
#
# Epoch 00066: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-66_loss-3.7954_val_loss-5.3865.h5
# Epoch 67/120
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 3.8345 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 283.3809 - predictions_loss: 2.2584 - val_loss: 5.4243 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8510
#
# Epoch 00067: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-67_loss-3.8345_val_loss-5.4243.h5
# Epoch 68/120
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 3.8208 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 279.4273 - predictions_loss: 2.2474 - val_loss: 5.5260 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9553
#
# Epoch 00068: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-68_loss-3.8208_val_loss-5.5260.h5
# Epoch 69/120
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 980s 980ms/step - loss: 3.8307 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 281.3254 - predictions_loss: 2.2599 - val_loss: 5.4781 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9100
#
# Epoch 00069: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-69_loss-3.8307_val_loss-5.4781.h5
# Epoch 70/120
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 863s 863ms/step - loss: 3.8018 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 284.7829 - predictions_loss: 2.2335 - val_loss: 5.4394 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8739
#
# Epoch 00070: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-70_loss-3.8018_val_loss-5.4394.h5
# Epoch 71/120
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 765s 765ms/step - loss: 3.7822 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 286.8741 - predictions_loss: 2.2154 - val_loss: 5.4522 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8870
#
# Epoch 00071: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-71_loss-3.7822_val_loss-5.4522.h5
# Epoch 72/120
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 869s 869ms/step - loss: 3.7948 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 278.1520 - predictions_loss: 2.2283 - val_loss: 5.4747 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9098
#
# Epoch 00072: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-72_loss-3.7948_val_loss-5.4747.h5
# Epoch 73/120
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 784s 784ms/step - loss: 3.8226 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 285.8267 - predictions_loss: 2.2563 - val_loss: 5.4429 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8782
#
# Epoch 00073: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-73_loss-3.8226_val_loss-5.4429.h5
# Epoch 74/120
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 837s 837ms/step - loss: 3.8007 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 279.8073 - predictions_loss: 2.2348 - val_loss: 5.4546 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8902
#
# Epoch 00074: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-74_loss-3.8007_val_loss-5.4546.h5
# Epoch 75/120
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
# ...
# Epoch 86/120
#
# Epoch 00086: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 877s 877ms/step - loss: 3.7581 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 283.6015 - predictions_loss: 2.1952 - val_loss: 5.4838 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9225
#
# Epoch 00086: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-86_loss-3.7581_val_loss-5.4838.h5
# Epoch 87/120
#
# Epoch 00087: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 3.7904 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 287.5420 - predictions_loss: 2.2278 - val_loss: 5.4673 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9063
#
# Epoch 00087: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-87_loss-3.7904_val_loss-5.4673.h5
# Epoch 88/120
#
# Epoch 00088: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 916s 916ms/step - loss: 3.7974 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 286.7566 - predictions_loss: 2.2351 - val_loss: 5.4787 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9179
#
# Epoch 00088: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-88_loss-3.7974_val_loss-5.4787.h5
# Epoch 89/120
#
# Epoch 00089: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 883s 883ms/step - loss: 3.7807 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 287.5401 - predictions_loss: 2.2186 - val_loss: 5.4445 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8840
#
# Epoch 00089: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-89_loss-3.7807_val_loss-5.4445.h5
# Epoch 90/120
#
# Epoch 00090: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 845s 845ms/step - loss: 3.7583 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 292.4858 - predictions_loss: 2.1964 - val_loss: 5.4792 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9190
#
# Epoch 00090: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-90_loss-3.7583_val_loss-5.4792.h5
# Epoch 91/120
#
# Epoch 00091: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 820s 820ms/step - loss: 3.7921 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 283.7263 - predictions_loss: 2.2305 - val_loss: 5.4332 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8732
# Epoch 00091: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-91_loss-3.7921_val_loss-5.4332.h5
# Epoch 92/120
#
# Epoch 00092: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 769s 769ms/step - loss: 3.7743 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 291.5671 - predictions_loss: 2.2129 - val_loss: 5.4666 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9068
#
# Epoch 00092: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-92_loss-3.7743_val_loss-5.4666.h5
# Epoch 93/120
#
# Epoch 00093: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 830s 830ms/step - loss: 3.7785 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 289.7129 - predictions_loss: 2.2175 - val_loss: 5.4223 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8628
#
# Epoch 00093: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-93_loss-3.7785_val_loss-5.4223.h5
# Epoch 94/120
#
# Epoch 00094: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 862s 862ms/step - loss: 3.7603 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 285.9899 - predictions_loss: 2.1995 - val_loss: 5.4556 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8963
#
# Epoch 00094: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-94_loss-3.7603_val_loss-5.4556.h5
# Epoch 95/120
#
# Epoch 00095: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 866s 866ms/step - loss: 3.7859 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 287.4788 - predictions_loss: 2.2254 - val_loss: 5.4674 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9084
#
# Epoch 00095: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-95_loss-3.7859_val_loss-5.4674.h5
# Epoch 96/120
#
# Epoch 00096: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 879s 879ms/step - loss: 3.7642 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 281.3598 - predictions_loss: 2.2040 - val_loss: 5.4362 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8775
#
# Epoch 00096: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-96_loss-3.7642_val_loss-5.4362.h5
# Epoch 97/120
#
# Epoch 00097: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 861s 861ms/step - loss: 3.7929 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 294.7520 - predictions_loss: 2.2329 - val_loss: 5.4311 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8727
#
# Epoch 00097: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-97_loss-3.7929_val_loss-5.4311.h5
# Epoch 98/120
#
# Epoch 00098: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 769s 769ms/step - loss: 3.7663 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 291.9736 - predictions_loss: 2.2065 - val_loss: 5.4339 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8757
#
# Epoch 00098: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-98_loss-3.7663_val_loss-5.4339.h5
# Epoch 99/120
#
# Epoch 00099: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 834s 834ms/step - loss: 3.7759 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 284.4876 - predictions_loss: 2.2165 - val_loss: 5.4358 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8779
#
# Epoch 00099: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-99_loss-3.7759_val_loss-5.4358.h5
# Epoch 100/120
#
# Epoch 00100: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 890s 890ms/step - loss: 3.7813 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 290.0298 - predictions_loss: 2.2220 - val_loss: 5.3947 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8370
#
# Epoch 00100: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-100_loss-3.7813_val_loss-5.3947.h5
# Epoch 101/120
#
# Epoch 00101: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 881s 881ms/step - loss: 3.7844 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 294.1486 - predictions_loss: 2.2254 - val_loss: 5.4446 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8872
#
# Epoch 00101: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-101_loss-3.7844_val_loss-5.4446.h5
# Epoch 102/120
#
# Epoch 00102: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 3.7612 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 294.2781 - predictions_loss: 2.2025 - val_loss: 5.4331 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8759
#
# Epoch 00102: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005/epoch-102_loss-3.7612_val_loss-5.4331.h5
# Epoch 103/120
#
# Epoch 00103: LearningRateScheduler setting learning rate to 1e-05.
#  796/1000 [======================>.......] - ETA: 2:28 - loss: 3.7838 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 293.2360 - predictions_loss: 2.2252
# -----------------------------------------------------
# KeyboardInterrupt   Traceback (most recent call last)
# <ipython-input-6-ea67b764e796> in <module>()
#       9                               validation_data=val_generator,
#      10                               validation_steps=ceil(val_dataset_size/batch_size),
# ---> 11                               initial_epoch=initial_epoch)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 5
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
