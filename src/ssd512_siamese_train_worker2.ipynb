# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights =  [0.0, 0.0, 0.0] + [1.0]

# 'City_to_foggy0_01_resize_600_1200' # 'City_to_foggy0_02_resize_600_1200'  # 'SIM10K_to_VOC07'
# 'SIM10K_to_VOC07_resize_400_800'# 'City_to_foggy0_01_resize_400_800' # 'SIM10K_to_City_resize_400_800'
DatasetName = 'SIM10K_to_VOC12_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName #  + '_worker2'
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    
    
#     if Source_Only:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})
#     else:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 10000/10000 [00:02<00:00, 4230.54it/s]
# Loading source image IDs: 100%|██████████| 10000/10000 [00:00<00:00, 10048.09it/s]
# Loading target image IDs: 100%|██████████| 621/621 [00:00<00:00, 11057.13it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 10000/10000 [00:01<00:00, 7280.82it/s]
# Loading source labels: 100%|██████████| 608/608 [00:00<00:00, 4972.13it/s]
# Loading source image IDs: 100%|██████████| 608/608 [00:00<00:00, 11628.53it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 608/608 [00:00<00:00, 8159.37it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	 10000
# Number of images in the validation dataset:	   608

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 50:
#         return 0.001
#     elif epoch < 60:
#         return 0.0001
#     else:
#         return 0.00001

# Define model callbacks.
checkpoint_path = '../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2'
# checkpoint_path = '../trained_weights/current/ssd_augm_beta_0_01_source_only'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'source_only_run2_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 120
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/120
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 739s 739ms/step - loss: 8.4311 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 5.1413 - val_loss: 8.0868 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8112
#
# Epoch 00001: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-01_loss-8.4304_val_loss-8.0868.h5
# Epoch 2/120
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 724s 724ms/step - loss: 6.6596 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3981 - val_loss: 8.1920 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.9445
#
# Epoch 00002: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-02_loss-6.6596_val_loss-8.1920.h5
# Epoch 3/120
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 723s 723ms/step - loss: 6.6058 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3838 - val_loss: 8.0142 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8185
#
# Epoch 00003: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-03_loss-6.6059_val_loss-8.0142.h5
# Epoch 4/120
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 749s 749ms/step - loss: 6.1227 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9533 - val_loss: 7.9056 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7625
#
# Epoch 00004: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-04_loss-6.1225_val_loss-7.9056.h5
# Epoch 5/120
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 730s 730ms/step - loss: 5.8314 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7142 - val_loss: 7.8714 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7802
#
# Epoch 00005: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-05_loss-5.8315_val_loss-7.8714.h5
# Epoch 6/120
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 738s 738ms/step - loss: 5.6993 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6337 - val_loss: 7.6840 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6438
#
# Epoch 00006: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-06_loss-5.6989_val_loss-7.6840.h5
# Epoch 7/120
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 736s 736ms/step - loss: 5.4612 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4465 - val_loss: 7.6594 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6698
#
# Epoch 00007: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-07_loss-5.4612_val_loss-7.6594.h5
# Epoch 8/120
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 733s 733ms/step - loss: 5.3504 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3854 - val_loss: 7.3335 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3932
#
# Epoch 00008: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-08_loss-5.3506_val_loss-7.3335.h5
# Epoch 9/120
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 726s 726ms/step - loss: 5.2603 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3443 - val_loss: 7.5303 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6385
#
# Epoch 00009: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-09_loss-5.2605_val_loss-7.5303.h5
# Epoch 10/120
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 726s 726ms/step - loss: 5.0791 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2115 - val_loss: 7.4843 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6405
#
# Epoch 00010: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-10_loss-5.0791_val_loss-7.4843.h5
# Epoch 11/120
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 725s 725ms/step - loss: 5.0109 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1903 - val_loss: 7.5885 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7912
#
# Epoch 00011: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-11_loss-5.0109_val_loss-7.5885.h5
# Epoch 12/120
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 726s 726ms/step - loss: 4.9304 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1560 - val_loss: 7.3934 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6417
#
# Epoch 00012: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-12_loss-4.9309_val_loss-7.3934.h5
# Epoch 13/120
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 4.8089 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0798 - val_loss: 7.3559 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6492
#
# Epoch 00013: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-13_loss-4.8093_val_loss-7.3559.h5
# Epoch 14/120
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 725s 725ms/step - loss: 4.7539 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0693 - val_loss: 7.2325 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5695
#
# Epoch 00014: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-14_loss-4.7538_val_loss-7.2325.h5
# Epoch 15/120
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 724s 724ms/step - loss: 4.7183 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0766 - val_loss: 7.1565 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5360
#
# Epoch 00015: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-15_loss-4.7183_val_loss-7.1565.h5
# Epoch 16/120
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 724s 724ms/step - loss: 4.5925 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9936 - val_loss: 6.9230 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3454
#
# Epoch 00016: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-16_loss-4.5924_val_loss-6.9230.h5
# Epoch 17/120
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 725s 725ms/step - loss: 4.5555 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9984 - val_loss: 7.0306 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4936
#
# Epoch 00017: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-17_loss-4.5552_val_loss-7.0306.h5
# Epoch 18/120
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 726s 726ms/step - loss: 4.5154 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9987 - val_loss: 7.2900 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7935
#
# Epoch 00018: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-18_loss-4.5153_val_loss-7.2900.h5
# Epoch 19/120
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 4.3914 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9151 - val_loss: 7.1485 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6919
#
# Epoch 00019: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-19_loss-4.3916_val_loss-7.1485.h5
# Epoch 20/120
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 727s 727ms/step - loss: 4.3555 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9183 - val_loss: 7.0956 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6779
#
# Epoch 00020: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-20_loss-4.3555_val_loss-7.0956.h5
# Epoch 21/120
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 729s 729ms/step - loss: 4.2803 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8821 - val_loss: 7.1158 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7365
#
# Epoch 00021: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-21_loss-4.2802_val_loss-7.1158.h5
# Epoch 22/120
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 731s 731ms/step - loss: 4.2482 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8877 - val_loss: 6.9460 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6041
#
# Epoch 00022: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-22_loss-4.2483_val_loss-6.9460.h5
# Epoch 23/120
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 733s 733ms/step - loss: 4.1812 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8577 - val_loss: 6.8254 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5203
#
# Epoch 00023: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-23_loss-4.1815_val_loss-6.8254.h5
# Epoch 24/120
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 735s 735ms/step - loss: 4.1244 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8373 - val_loss: 6.8698 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6007
#
# Epoch 00024: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-24_loss-4.1244_val_loss-6.8698.h5
# Epoch 25/120
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 730s 730ms/step - loss: 4.0868 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8352 - val_loss: 6.8627 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6289
#
# Epoch 00025: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-25_loss-4.0867_val_loss-6.8627.h5
# Epoch 26/120
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 732s 732ms/step - loss: 4.0247 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8081 - val_loss: 6.6287 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4291
#
# Epoch 00026: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-26_loss-4.0242_val_loss-6.6287.h5
# Epoch 27/120
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 738s 738ms/step - loss: 3.9504 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7677 - val_loss: 6.7315 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5658
#
# Epoch 00027: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-27_loss-3.9507_val_loss-6.7315.h5
# Epoch 28/120
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 734s 734ms/step - loss: 3.9745 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8249 - val_loss: 6.5100 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3765
#
# Epoch 00028: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-28_loss-3.9741_val_loss-6.5100.h5
# Epoch 29/120
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 731s 731ms/step - loss: 3.8707 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7533 - val_loss: 6.6769 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5760
#
# Epoch 00029: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-29_loss-3.8705_val_loss-6.6769.h5
# Epoch 30/120
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 735s 735ms/step - loss: 3.8112 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7264 - val_loss: 6.4977 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4288
#
# Epoch 00030: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-30_loss-3.8114_val_loss-6.4977.h5
# Epoch 31/120
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 733s 733ms/step - loss: 3.7876 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7344 - val_loss: 6.6964 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6589
#
# Epoch 00031: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-31_loss-3.7875_val_loss-6.6964.h5
# Epoch 32/120
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 731s 731ms/step - loss: 3.7570 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7346 - val_loss: 6.8309 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8235
#
# Epoch 00032: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-32_loss-3.7569_val_loss-6.8309.h5
# Epoch 33/120
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 3.7223 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7297 - val_loss: 6.6726 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6949
#
# Epoch 00033: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-33_loss-3.7217_val_loss-6.6726.h5
# Epoch 34/120
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 730s 730ms/step - loss: 3.7005 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7373 - val_loss: 6.4850 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5360
#
# Epoch 00034: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-34_loss-3.7008_val_loss-6.4850.h5
# Epoch 35/120
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 730s 730ms/step - loss: 3.6417 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7068 - val_loss: 6.3995 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4788
#
# Epoch 00035: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-35_loss-3.6415_val_loss-6.3995.h5
# Epoch 36/120
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 730s 730ms/step - loss: 3.5892 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6827 - val_loss: 6.2821 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3897
#
# Epoch 00036: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-36_loss-3.5889_val_loss-6.2821.h5
# Epoch 37/120
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 3.5521 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6737 - val_loss: 6.5663 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7015
#
# Epoch 00037: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-37_loss-3.5521_val_loss-6.5663.h5
# Epoch 38/120
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 3.5149 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6638 - val_loss: 6.5200 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6824
#
# Epoch 00038: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-38_loss-3.5146_val_loss-6.5200.h5
# Epoch 39/120
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 733s 733ms/step - loss: 3.4716 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6471 - val_loss: 6.4211 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6100
#
# Epoch 00039: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-39_loss-3.4710_val_loss-6.4211.h5
# Epoch 40/120
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 732s 732ms/step - loss: 3.4757 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6776 - val_loss: 6.6300 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8448
#
# Epoch 00040: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-40_loss-3.4757_val_loss-6.6300.h5
# Epoch 41/120
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 733s 733ms/step - loss: 3.4035 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6311 - val_loss: 6.7108 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.9512
#
# Epoch 00041: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-41_loss-3.4036_val_loss-6.7108.h5
# Epoch 42/120
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 3.3987 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6516 - val_loss: 6.5007 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7663
#
# Epoch 00042: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-42_loss-3.3987_val_loss-6.5007.h5
# Epoch 43/120
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 3.3411 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6188 - val_loss: 6.3501 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6398
#
# Epoch 00043: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-43_loss-3.3412_val_loss-6.3501.h5
# Epoch 44/120
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 3.3362 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6376 - val_loss: 6.2218 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5348
#
# Epoch 00044: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-44_loss-3.3363_val_loss-6.2218.h5
# Epoch 45/120
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 3.3261 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6508 - val_loss: 6.5302 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8664
#
# Epoch 00045: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-45_loss-3.3261_val_loss-6.5302.h5
# Epoch 46/120
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 729s 729ms/step - loss: 3.2897 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6374 - val_loss: 6.1360 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4950
#
# Epoch 00046: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-46_loss-3.2896_val_loss-6.1360.h5
# Epoch 47/120
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 736s 736ms/step - loss: 3.2256 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.5958 - val_loss: 6.4230 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8045
#
# Epoch 00047: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-47_loss-3.2256_val_loss-6.4230.h5
# Epoch 48/120
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 732s 732ms/step - loss: 3.2670 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6594 - val_loss: 6.2744 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6772
#
# Epoch 00048: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-48_loss-3.2670_val_loss-6.2744.h5
# Epoch 49/120
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 729s 729ms/step - loss: 3.2085 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6218 - val_loss: 6.7142 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.1381
#
# Epoch 00049: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-49_loss-3.2086_val_loss-6.7142.h5
# Epoch 50/120
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 732s 732ms/step - loss: 3.1324 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.5672 - val_loss: 6.1023 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5479
#
# Epoch 00050: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-50_loss-3.1320_val_loss-6.1023.h5
# Epoch 51/120
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 734s 734ms/step - loss: 2.9661 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4132 - val_loss: 6.0901 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5385
#
# Epoch 00051: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-51_loss-2.9656_val_loss-6.0901.h5
# Epoch 52/120
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 730s 730ms/step - loss: 2.9033 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3530 - val_loss: 6.1499 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6010
#
# Epoch 00052: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-52_loss-2.9034_val_loss-6.1499.h5
# Epoch 53/120
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 733s 733ms/step - loss: 2.8842 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3367 - val_loss: 6.0332 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4871
#
# Epoch 00053: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-53_loss-2.8844_val_loss-6.0332.h5
# Epoch 54/120
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 732s 732ms/step - loss: 2.8605 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3157 - val_loss: 6.0426 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4992
#
# Epoch 00054: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-54_loss-2.8605_val_loss-6.0426.h5
# Epoch 55/120
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 730s 730ms/step - loss: 2.8461 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3041 - val_loss: 6.0083 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4677
#
# Epoch 00055: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-55_loss-2.8463_val_loss-6.0083.h5
# Epoch 56/120
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 731s 731ms/step - loss: 2.8663 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3271 - val_loss: 6.0539 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5160
#
# Epoch 00056: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-56_loss-2.8666_val_loss-6.0539.h5
# Epoch 57/120
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 732s 732ms/step - loss: 2.8303 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2937 - val_loss: 6.0091 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4740
#
# Epoch 00057: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-57_loss-2.8305_val_loss-6.0091.h5
# Epoch 58/120
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 2.8320 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2982 - val_loss: 6.0337 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5013
#
# Epoch 00058: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-58_loss-2.8320_val_loss-6.0337.h5
# Epoch 59/120
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 2.8035 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2724 - val_loss: 6.0494 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5197
#
# Epoch 00059: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-59_loss-2.8033_val_loss-6.0494.h5
# Epoch 60/120
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 2.8075 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2792 - val_loss: 6.0430 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5159
#
# Epoch 00060: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-60_loss-2.8074_val_loss-6.0430.h5
# Epoch 61/120
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 728s 728ms/step - loss: 2.8196 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2940 - val_loss: 6.0846 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5603
#
# Epoch 00061: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-61_loss-2.8198_val_loss-6.0846.h5
# Epoch 62/120
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 733s 733ms/step - loss: 2.7974 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2744 - val_loss: 6.1930 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6714
#
# Epoch 00062: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-62_loss-2.7974_val_loss-6.1930.h5
# Epoch 63/120
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 733s 733ms/step - loss: 2.8009 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2806 - val_loss: 6.0393 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5204
#
# Epoch 00063: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-63_loss-2.8007_val_loss-6.0393.h5
# Epoch 64/120
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 725s 725ms/step - loss: 2.7680 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2504 - val_loss: 6.1325 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6163
#
# Epoch 00064: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-64_loss-2.7679_val_loss-6.1325.h5
# Epoch 65/120
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 725s 725ms/step - loss: 2.7627 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2479 - val_loss: 6.1227 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6091
#
# Epoch 00065: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-65_loss-2.7625_val_loss-6.1227.h5
# Epoch 66/120
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 730s 730ms/step - loss: 2.7657 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2535 - val_loss: 6.0921 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5812
#
# Epoch 00066: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-66_loss-2.7654_val_loss-6.0921.h5
# Epoch 67/120
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 733s 733ms/step - loss: 2.7637 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2542 - val_loss: 6.1313 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6231
#
# Epoch 00067: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-67_loss-2.7635_val_loss-6.1313.h5
# Epoch 68/120
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 732s 732ms/step - loss: 2.7849 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2780 - val_loss: 6.0871 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5816
#
# Epoch 00068: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-68_loss-2.7850_val_loss-6.0871.h5
# Epoch 69/120
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 730s 730ms/step - loss: 2.7683 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2641 - val_loss: 6.2410 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7381
#
# Epoch 00069: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-69_loss-2.7685_val_loss-6.2410.h5
# Epoch 70/120
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 737s 737ms/step - loss: 2.7727 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2711 - val_loss: 6.0144 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5142
#
# Epoch 00070: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-70_loss-2.7728_val_loss-6.0144.h5
# Epoch 71/120
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 737s 737ms/step - loss: 2.7374 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2374 - val_loss: 6.0446 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5447
#
# Epoch 00071: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-71_loss-2.7373_val_loss-6.0446.h5
# Epoch 72/120
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 733s 733ms/step - loss: 2.7526 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2528 - val_loss: 6.0341 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5345
#
# Epoch 00072: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-72_loss-2.7525_val_loss-6.0341.h5
# Epoch 73/120
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 727s 727ms/step - loss: 2.7390 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2395 - val_loss: 6.0711 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5717
#
# Epoch 00073: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-73_loss-2.7392_val_loss-6.0711.h5
# Epoch 74/120
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 722s 722ms/step - loss: 2.7254 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2262 - val_loss: 6.0458 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5466
#
# Epoch 00074: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-74_loss-2.7255_val_loss-6.0458.h5
# Epoch 75/120
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 722s 722ms/step - loss: 2.7407 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2417 - val_loss: 6.0768 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5780
#
# Epoch 00075: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-75_loss-2.7409_val_loss-6.0768.h5
# Epoch 76/120
#
# Epoch 00076: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 722s 722ms/step - loss: 2.7299 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2312 - val_loss: 6.0931 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5945
#
# ...
#
# Epoch 00094: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-94_loss-2.7134_val_loss-6.1094.h5
# Epoch 95/120
#
# Epoch 00095: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 747s 747ms/step - loss: 2.7114 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2177 - val_loss: 6.0670 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5735
#
# Epoch 00095: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-95_loss-2.7113_val_loss-6.0670.h5
# Epoch 96/120
#
# Epoch 00096: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 2.7150 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2215 - val_loss: 6.0822 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5890
#
# Epoch 00096: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-96_loss-2.7153_val_loss-6.0822.h5
# Epoch 97/120
#
# Epoch 00097: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 2.7187 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2256 - val_loss: 6.0967 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6037
#
# Epoch 00097: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-97_loss-2.7185_val_loss-6.0967.h5
# Epoch 98/120
#
# Epoch 00098: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 729s 729ms/step - loss: 2.7126 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2197 - val_loss: 6.1121 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6193
#
# Epoch 00098: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-98_loss-2.7125_val_loss-6.1121.h5
# Epoch 99/120
#
# Epoch 00099: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 723s 723ms/step - loss: 2.7099 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2172 - val_loss: 6.1208 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6283
#
# Epoch 00099: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-99_loss-2.7098_val_loss-6.1208.h5
# Epoch 100/120
#
# Epoch 00100: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 723s 723ms/step - loss: 2.7157 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2234 - val_loss: 6.0823 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5901
#
# Epoch 00100: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-100_loss-2.7159_val_loss-6.0823.h5
# Epoch 101/120
#
# Epoch 00101: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 722s 722ms/step - loss: 2.7348 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2427 - val_loss: 6.0580 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5661
#
# Epoch 00101: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-101_loss-2.7343_val_loss-6.0580.h5
# Epoch 102/120
#
# Epoch 00102: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 733s 733ms/step - loss: 2.7159 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2240 - val_loss: 6.0850 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5933
#
# Epoch 00102: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-102_loss-2.7156_val_loss-6.0850.h5
# Epoch 103/120
#
# Epoch 00103: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 741s 741ms/step - loss: 2.7281 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2366 - val_loss: 6.1465 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6551
#
# Epoch 00103: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-103_loss-2.7281_val_loss-6.1465.h5
# Epoch 104/120
#
# Epoch 00104: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 741s 741ms/step - loss: 2.7084 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2171 - val_loss: 6.0984 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6072
#
# Epoch 00104: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-104_loss-2.7076_val_loss-6.0984.h5
# Epoch 105/120
#
# Epoch 00105: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 736s 736ms/step - loss: 2.7117 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2207 - val_loss: 6.1107 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6199
#
# Epoch 00105: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-105_loss-2.7118_val_loss-6.1107.h5
# Epoch 106/120
#
# Epoch 00106: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 732s 732ms/step - loss: 2.7093 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2186 - val_loss: 6.1162 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6255
#
# Epoch 00106: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-106_loss-2.7089_val_loss-6.1162.h5
# Epoch 107/120
#
# Epoch 00107: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 737s 737ms/step - loss: 2.7192 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2287 - val_loss: 6.1076 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6172
#
# Epoch 00107: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-107_loss-2.7193_val_loss-6.1076.h5
# Epoch 108/120
#
# Epoch 00108: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 734s 734ms/step - loss: 2.7207 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2305 - val_loss: 6.1157 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6256
#
# Epoch 00108: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-108_loss-2.7211_val_loss-6.1157.h5
# Epoch 109/120
#
# Epoch 00109: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 735s 735ms/step - loss: 2.7370 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2471 - val_loss: 6.1347 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6449
#
# Epoch 00109: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-109_loss-2.7373_val_loss-6.1347.h5
# Epoch 110/120
#
# Epoch 00110: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 737s 737ms/step - loss: 2.7115 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2218 - val_loss: 6.1465 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6569
#
# Epoch 00110: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-110_loss-2.7116_val_loss-6.1465.h5
# Epoch 111/120
#
# Epoch 00111: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 732s 732ms/step - loss: 2.7173 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2279 - val_loss: 6.1323 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6430
#
# Epoch 00111: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2/epoch-111_loss-2.7175_val_loss-6.1323.h5
# Epoch 112/120
#
# Epoch 00112: LearningRateScheduler setting learning rate to 1e-05.
#  601/1000 [=================>............] - ETA: 4:43 - loss: 2.6860 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.1967
# -----------------------------------------------------
# KeyboardInterrupt   Traceback (most recent call last)
# <ipython-input-6-ea67b764e796> in <module>()
#       9                               validation_data=val_generator,
#      10                               validation_steps=ceil(val_dataset_size/batch_size),
# ---> 11                               initial_epoch=initial_epoch)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 5
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
