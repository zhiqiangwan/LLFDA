# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese_align_high_layers import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator_align_high_layers import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 4 #  8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [0.000005, 0.0] + [1.0]

# 'City_to_foggy0_01_resize_600_1200' # 'City_to_foggy0_02_resize_600_1200'  # 'SIM10K_to_VOC07'
# 'SIM10K'  # 'Cityscapes_foggy_beta_0_01'  #  'City_to_foggy0_02_resize_400_800'
# 'SIM10K_to_VOC07_resize_400_800'# 'SIM10K_to_City_resize_400_800'
DatasetName = 'City_to_foggy0_01_resize_400_800' # 'SIM10K_to_VOC12_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'contrastive_loss1': ssd_loss.compute_distance_loss,
                                             'contrastive_loss2': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'contrastive_loss1': loss_weights[0],
                                'contrastive_loss2': loss_weights[1],
                                'predictions': loss_weights[2]})    

else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 2966/2966 [00:00<00:00, 5182.53it/s]
# Loading source image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 11890.19it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 11583.78it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 2966/2966 [00:00<00:00, 8584.13it/s]
# Loading source labels: 100%|██████████| 493/493 [00:00<00:00, 4726.88it/s]
# Loading source image IDs: 100%|██████████| 493/493 [00:00<00:00, 10326.26it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 493/493 [00:00<00:00, 7858.86it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  2966
# Number of images in the validation dataset:	   493

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 50:
#         return 0.001
#     elif epoch < 60:
#         return 0.0001
#     else:
#         return 0.00001

# Define model callbacks.
checkpoint_path = '../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1'
# checkpoint_path = '../trained_weights/current/ssd_augm_beta_0_01_source_only'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'conv1_1_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 100 #  120
steps_per_epoch = 2000 #  1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 2000/2000 [==============================] - 964s 482ms/step - loss: 10.4633 - contrastive_loss1_loss: 3082.8002 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 6.8437 - val_loss: 9.1208 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 5.5459
#
# Epoch 00001: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-01_loss-10.4633_val_loss-9.1208.h5
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 2000/2000 [==============================] - 957s 478ms/step - loss: 8.1988 - contrastive_loss1_loss: 2042.0712 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 4.6454 - val_loss: 8.5589 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 5.0471
#
# Epoch 00002: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-02_loss-8.1988_val_loss-8.5589.h5
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 478ms/step - loss: 8.0721 - contrastive_loss1_loss: 1779.9188 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 4.6091 - val_loss: 8.2388 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.8426
#
# Epoch 00003: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-03_loss-8.0721_val_loss-8.2388.h5
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 478ms/step - loss: 7.5396 - contrastive_loss1_loss: 1705.4300 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 4.1919 - val_loss: 7.9678 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.6847
#
# Epoch 00004: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-04_loss-7.5396_val_loss-7.9678.h5
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 477ms/step - loss: 7.2227 - contrastive_loss1_loss: 1626.5854 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.9865 - val_loss: 7.9312 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.7576
#
# Epoch 00005: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-05_loss-7.2227_val_loss-7.9312.h5
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 956s 478ms/step - loss: 6.9710 - contrastive_loss1_loss: 1572.6969 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.8421 - val_loss: 7.9259 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.8568
#
# Epoch 00006: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-06_loss-6.9710_val_loss-7.9259.h5
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 478ms/step - loss: 6.7013 - contrastive_loss1_loss: 1530.2116 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.6753 - val_loss: 7.2603 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2922
#
# Epoch 00007: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-07_loss-6.7013_val_loss-7.2603.h5
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 477ms/step - loss: 6.5131 - contrastive_loss1_loss: 1439.8671 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.5865 - val_loss: 7.3116 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.4405
#
# Epoch 00008: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-08_loss-6.5131_val_loss-7.3116.h5
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 478ms/step - loss: 6.3382 - contrastive_loss1_loss: 1412.4349 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.5069 - val_loss: 7.1260 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3478
#
# Epoch 00009: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-09_loss-6.3382_val_loss-7.1260.h5
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 477ms/step - loss: 6.2127 - contrastive_loss1_loss: 1350.4678 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.4725 - val_loss: 7.2098 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5203
#
# Epoch 00010: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-10_loss-6.2127_val_loss-7.2098.h5
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 6.0704 - contrastive_loss1_loss: 1375.2142 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.4168 - val_loss: 6.9942 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3895
#
# Epoch 00011: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-11_loss-6.0704_val_loss-6.9942.h5
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 5.9329 - contrastive_loss1_loss: 1291.3088 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.3629 - val_loss: 6.7473 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2243
#
# Epoch 00012: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-12_loss-5.9329_val_loss-6.7473.h5
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 5.8076 - contrastive_loss1_loss: 1302.2617 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.3172 - val_loss: 6.7505 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3061
#
# Epoch 00013: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-13_loss-5.8076_val_loss-6.7505.h5
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 477ms/step - loss: 5.6842 - contrastive_loss1_loss: 1302.6027 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.2707 - val_loss: 6.5813 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2113
#
# Epoch 00014: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-14_loss-5.6842_val_loss-6.5813.h5
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 477ms/step - loss: 5.5722 - contrastive_loss1_loss: 1262.3096 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.2320 - val_loss: 6.3292 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0310
#
# Epoch 00015: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-15_loss-5.5722_val_loss-6.3292.h5
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 5.4859 - contrastive_loss1_loss: 1200.8540 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.2167 - val_loss: 6.2057 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9770
#
# Epoch 00016: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-16_loss-5.4859_val_loss-6.2057.h5
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 5.3894 - contrastive_loss1_loss: 1217.6730 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.1877 - val_loss: 6.4217 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2591
#
# Epoch 00017: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-17_loss-5.3894_val_loss-6.4217.h5
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 5.3011 - contrastive_loss1_loss: 1186.8159 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.1643 - val_loss: 6.2962 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1968
#
# Epoch 00018: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-18_loss-5.3011_val_loss-6.2962.h5
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 5.1648 - contrastive_loss1_loss: 1178.1540 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.0901 - val_loss: 6.0764 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0379
#
# Epoch 00019: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-19_loss-5.1648_val_loss-6.0764.h5
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 477ms/step - loss: 5.0657 - contrastive_loss1_loss: 1154.1985 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.0507 - val_loss: 5.9401 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9599
#
# Epoch 00020: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-20_loss-5.0657_val_loss-5.9401.h5
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 5.0260 - contrastive_loss1_loss: 1139.8249 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.0679 - val_loss: 6.0586 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1340
#
# Epoch 00021: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-21_loss-5.0260_val_loss-6.0586.h5
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 4.9861 - contrastive_loss1_loss: 1134.9890 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.0818 - val_loss: 6.2112 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3386
#
# Epoch 00022: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-22_loss-4.9861_val_loss-6.2112.h5
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 477ms/step - loss: 4.9233 - contrastive_loss1_loss: 1097.1536 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.0710 - val_loss: 5.9130 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0918
#
# Epoch 00023: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-23_loss-4.9233_val_loss-5.9130.h5
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 477ms/step - loss: 4.7851 - contrastive_loss1_loss: 1106.4605 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.9833 - val_loss: 5.6818 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9103
#
# Epoch 00024: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-24_loss-4.7851_val_loss-5.6818.h5
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 477ms/step - loss: 4.7855 - contrastive_loss1_loss: 1100.4689 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.0318 - val_loss: 5.6572 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9319
#
# Epoch 00025: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-25_loss-4.7855_val_loss-5.6572.h5
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 4.7380 - contrastive_loss1_loss: 1086.6805 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.0298 - val_loss: 5.6956 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0150
#
# Epoch 00026: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-26_loss-4.7380_val_loss-5.6956.h5
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 4.6310 - contrastive_loss1_loss: 1090.1542 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.9669 - val_loss: 5.8290 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1918
#
# Epoch 00027: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-27_loss-4.6310_val_loss-5.8290.h5
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 4.5665 - contrastive_loss1_loss: 1082.1810 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.9446 - val_loss: 5.6890 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0934
#
# Epoch 00028: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-28_loss-4.5665_val_loss-5.6890.h5
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 4.4713 - contrastive_loss1_loss: 1075.1674 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8902 - val_loss: 5.8181 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2621
#
# Epoch 00029: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-29_loss-4.4713_val_loss-5.8181.h5
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 4.4767 - contrastive_loss1_loss: 1015.9737 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.9341 - val_loss: 5.8315 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3128
#
# Epoch 00030: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-30_loss-4.4767_val_loss-5.8315.h5
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 956s 478ms/step - loss: 4.3942 - contrastive_loss1_loss: 1064.6203 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8886 - val_loss: 5.5013 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0192
# Epoch 00031: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-31_loss-4.3942_val_loss-5.5013.h5
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 4.4004 - contrastive_loss1_loss: 1051.9710 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.9299 - val_loss: 5.9055 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.4568
#
# Epoch 00032: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-32_loss-4.4004_val_loss-5.9055.h5
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 4.3423 - contrastive_loss1_loss: 1062.3536 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.9048 - val_loss: 5.5732 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1571
#
# Epoch 00033: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-33_loss-4.3423_val_loss-5.5732.h5
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 4.2654 - contrastive_loss1_loss: 1032.9790 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8604 - val_loss: 5.5217 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1375
#
# Epoch 00034: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-34_loss-4.2654_val_loss-5.5217.h5
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 4.2428 - contrastive_loss1_loss: 1069.4823 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8688 - val_loss: 5.4997 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1465
#
# Epoch 00035: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-35_loss-4.2428_val_loss-5.4997.h5
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 477ms/step - loss: 4.1978 - contrastive_loss1_loss: 1033.9518 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8539 - val_loss: 5.6778 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3536
#
# Epoch 00036: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-36_loss-4.1978_val_loss-5.6778.h5
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 955s 477ms/step - loss: 4.2044 - contrastive_loss1_loss: 1011.2728 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8891 - val_loss: 5.8923 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5960
#
# Epoch 00037: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-37_loss-4.2044_val_loss-5.8923.h5
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 4.1263 - contrastive_loss1_loss: 1022.3875 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8381 - val_loss: 5.6199 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3499
#
# Epoch 00038: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-38_loss-4.1263_val_loss-5.6199.h5
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 956s 478ms/step - loss: 4.1208 - contrastive_loss1_loss: 982.7538 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8589 - val_loss: 5.1874 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9430
#
# Epoch 00039: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-39_loss-4.1208_val_loss-5.1874.h5
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 953s 477ms/step - loss: 4.0602 - contrastive_loss1_loss: 993.6481 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8232 - val_loss: 5.1400 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9204
#
# Epoch 00040: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-40_loss-4.0602_val_loss-5.1400.h5
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 953s 477ms/step - loss: 4.0140 - contrastive_loss1_loss: 994.3916 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8011 - val_loss: 5.3254 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1294
#
# Epoch 00041: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-41_loss-4.0140_val_loss-5.3254.h5
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 953s 477ms/step - loss: 4.0193 - contrastive_loss1_loss: 1014.4786 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8292 - val_loss: 5.7285 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5546
#
# Epoch 00042: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-42_loss-4.0193_val_loss-5.7285.h5
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 953s 477ms/step - loss: 4.0180 - contrastive_loss1_loss: 1006.8731 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8492 - val_loss: 5.0480 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8945
#
# Epoch 00043: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-43_loss-4.0180_val_loss-5.0480.h5
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.9917 - contrastive_loss1_loss: 1033.6784 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8435 - val_loss: 5.3834 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2500
#
# Epoch 00044: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-44_loss-3.9917_val_loss-5.3834.h5
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 953s 477ms/step - loss: 3.8955 - contrastive_loss1_loss: 1004.2748 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7672 - val_loss: 5.6332 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5199
#
# Epoch 00045: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-45_loss-3.8955_val_loss-5.6332.h5
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.8922 - contrastive_loss1_loss: 1012.6431 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7833 - val_loss: 5.3190 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2246
#
# Epoch 00046: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-46_loss-3.8922_val_loss-5.3190.h5
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.8484 - contrastive_loss1_loss: 979.8385 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7582 - val_loss: 5.3702 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2939
#
# Epoch 00047: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-47_loss-3.8484_val_loss-5.3702.h5
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.8484 - contrastive_loss1_loss: 1005.2317 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7753 - val_loss: 5.2277 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1679
#
# Epoch 00048: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-48_loss-3.8484_val_loss-5.2277.h5
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.8207 - contrastive_loss1_loss: 981.3532 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7643 - val_loss: 5.1048 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0614
#
# Epoch 00049: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-49_loss-3.8207_val_loss-5.1048.h5
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.7727 - contrastive_loss1_loss: 983.4547 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7324 - val_loss: 5.1792 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1515
#
# Epoch 00050: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-50_loss-3.7727_val_loss-5.1792.h5
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.5140 - contrastive_loss1_loss: 920.3706 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.4834 - val_loss: 4.8044 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7800
#
# Epoch 00051: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-51_loss-3.5140_val_loss-4.8044.h5
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.4319 - contrastive_loss1_loss: 850.2968 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.4049 - val_loss: 4.8869 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8657
#
# Epoch 00052: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-52_loss-3.4319_val_loss-4.8869.h5
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.3996 - contrastive_loss1_loss: 847.2237 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3758 - val_loss: 4.9779 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9600
#
# Epoch 00053: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-53_loss-3.3996_val_loss-4.9779.h5
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.3848 - contrastive_loss1_loss: 832.0778 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3643 - val_loss: 4.8758 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8609
#
# Epoch 00054: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-54_loss-3.3848_val_loss-4.8758.h5
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.3896 - contrastive_loss1_loss: 864.1922 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3720 - val_loss: 4.9427 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9310
#
# Epoch 00055: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-55_loss-3.3896_val_loss-4.9427.h5
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.3495 - contrastive_loss1_loss: 858.2080 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3351 - val_loss: 4.9914 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9828
#
# Epoch 00056: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-56_loss-3.3495_val_loss-4.9914.h5
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.3313 - contrastive_loss1_loss: 860.5535 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3199 - val_loss: 4.9320 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9266
#
# Epoch 00057: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-57_loss-3.3313_val_loss-4.9320.h5
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 955s 477ms/step - loss: 3.3238 - contrastive_loss1_loss: 831.7168 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3158 - val_loss: 4.8700 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8676
#
# Epoch 00058: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-58_loss-3.3238_val_loss-4.8700.h5
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 955s 478ms/step - loss: 3.3447 - contrastive_loss1_loss: 843.4878 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3396 - val_loss: 4.9419 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9426
#
# Epoch 00059: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-59_loss-3.3447_val_loss-4.9419.h5
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 956s 478ms/step - loss: 3.3071 - contrastive_loss1_loss: 839.3501 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3051 - val_loss: 5.0247 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0284
#
# Epoch 00060: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-60_loss-3.3071_val_loss-5.0247.h5
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 957s 478ms/step - loss: 3.2922 - contrastive_loss1_loss: 843.3446 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2932 - val_loss: 4.8943 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9010
#
# Epoch 00061: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-61_loss-3.2922_val_loss-4.8943.h5
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 956s 478ms/step - loss: 3.3118 - contrastive_loss1_loss: 829.3013 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3158 - val_loss: 4.9613 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9710
# Epoch 00062: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-62_loss-3.3118_val_loss-4.9613.h5
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 957s 478ms/step - loss: 3.2682 - contrastive_loss1_loss: 825.2590 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2752 - val_loss: 4.9481 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9607
#
# Epoch 00063: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-63_loss-3.2682_val_loss-4.9481.h5
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 958s 479ms/step - loss: 3.2420 - contrastive_loss1_loss: 838.7351 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2519 - val_loss: 4.9622 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9779
#
# Epoch 00064: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-64_loss-3.2420_val_loss-4.9622.h5
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 957s 478ms/step - loss: 3.2576 - contrastive_loss1_loss: 829.0667 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2705 - val_loss: 4.9463 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9648
#
# Epoch 00065: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-65_loss-3.2576_val_loss-4.9463.h5
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 956s 478ms/step - loss: 3.2618 - contrastive_loss1_loss: 830.6416 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2776 - val_loss: 5.0563 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0777
#
# Epoch 00066: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-66_loss-3.2618_val_loss-5.0563.h5
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 957s 478ms/step - loss: 3.2700 - contrastive_loss1_loss: 783.6784 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2890 - val_loss: 5.0598 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0841
#
# Epoch 00067: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-67_loss-3.2700_val_loss-5.0598.h5
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 957s 478ms/step - loss: 3.2606 - contrastive_loss1_loss: 799.9300 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2824 - val_loss: 5.1592 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1864
#
# Epoch 00068: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-68_loss-3.2606_val_loss-5.1592.h5
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 957s 478ms/step - loss: 3.2597 - contrastive_loss1_loss: 794.7087 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2844 - val_loss: 4.9944 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0244
#
# Epoch 00069: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-69_loss-3.2597_val_loss-4.9944.h5
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 2000/2000 [==============================] - 957s 478ms/step - loss: 3.2526 - contrastive_loss1_loss: 816.6842 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2799 - val_loss: 5.0627 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0955
#
# Epoch 00070: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-70_loss-3.2526_val_loss-5.0627.h5
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 2000/2000 [==============================] - 956s 478ms/step - loss: 3.2383 - contrastive_loss1_loss: 802.7203 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2673 - val_loss: 5.0357 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0688
#
# Epoch 00071: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-71_loss-3.2383_val_loss-5.0357.h5
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 2000/2000 [==============================] - 959s 480ms/step - loss: 3.1995 - contrastive_loss1_loss: 798.7087 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2288 - val_loss: 5.0312 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0646
#
# Epoch 00072: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-72_loss-3.1995_val_loss-5.0312.h5
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 2000/2000 [==============================] - 956s 478ms/step - loss: 3.2015 - contrastive_loss1_loss: 795.4632 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2311 - val_loss: 4.9926 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0263
#
# Epoch 00073: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-73_loss-3.2015_val_loss-4.9926.h5
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 2000/2000 [==============================] - 955s 478ms/step - loss: 3.2150 - contrastive_loss1_loss: 793.4185 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2449 - val_loss: 5.0049 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0389
#
# Epoch 00074: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-74_loss-3.2150_val_loss-5.0049.h5
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
# 2000/2000 [==============================] - 956s 478ms/step - loss: 3.1990 - contrastive_loss1_loss: 792.5585 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2292 - val_loss: 4.9538 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9881
#
# Epoch 00075: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-75_loss-3.1990_val_loss-4.9538.h5
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler setting learning rate to 1e-05.
# 2000/2000 [==============================] - 956s 478ms/step - loss: 3.2133 - contrastive_loss1_loss: 780.0477 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2439 - val_loss: 4.9606 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9952
#
# Epoch 00076: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-76_loss-3.2133_val_loss-4.9606.h5
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler setting learning rate to 1e-05.
# 2000/2000 [==============================] - 956s 478ms/step - loss: 3.1858 - contrastive_loss1_loss: 803.3135 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2165 - val_loss: 4.9792 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0141
#
# Epoch 00077: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-77_loss-3.1858_val_loss-4.9792.h5
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler setting learning rate to 1e-05.
# 2000/2000 [==============================] - 956s 478ms/step - loss: 3.1995 - contrastive_loss1_loss: 790.1218 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2306 - val_loss: 4.9812 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0164
#
# Epoch 00078: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-78_loss-3.1995_val_loss-4.9812.h5
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler setting learning rate to 1e-05.
# 2000/2000 [==============================] - 954s 477ms/step - loss: 3.2111 - contrastive_loss1_loss: 803.2275 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2425 - val_loss: 5.0212 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0567
#
# Epoch 00079: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv1_1/epoch-79_loss-3.2111_val_loss-5.0212.h5
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler setting learning rate to 1e-05.
#    9/2000 [..............................] - ETA: 15:18 - loss: 3.1127 - contrastive_loss1_loss: 614.5636 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.1451
# ---------------------------------------------------
# KeyboardInterrupt Traceback (most recent call last)
# <ipython-input-6-1f47b0b27e5e> in <module>()
#       9                               validation_data=val_generator,
#      10                               validation_steps=ceil(val_dataset_size/batch_size),
# ---> 11                               initial_epoch=initial_epoch)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
