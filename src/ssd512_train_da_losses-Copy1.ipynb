# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.da_ssd512_other_loss_metrics import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [0.0005, 0.0005, 0.0] + [1.0]

# 'SIM10K_to_VOC12_resize_400_800' # 'City_to_foggy0_01_resize_400_800' 
DatasetName =  'SIM10K_to_VOC07_resize_400_800' # 'SIM10K_to_City_resize_400_800'  #   # 
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

# Define model callbacks.
checkpoint_path = '../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005'
# checkpoint_path = '../trained_weights/denug'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)
    
if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    
    
#     if Source_Only:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})
#     else:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')
# Out:
# da_loss_metric is MMD

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 10000/10000 [00:02<00:00, 4579.37it/s]
# Loading source image IDs: 100%|██████████| 10000/10000 [00:00<00:00, 10253.93it/s]
# Loading target image IDs: 100%|██████████| 761/761 [00:00<00:00, 10111.30it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 10000/10000 [00:01<00:00, 7276.55it/s]
# Loading source labels: 100%|██████████| 775/775 [00:00<00:00, 4142.02it/s]
# Loading source image IDs: 100%|██████████| 775/775 [00:00<00:00, 10693.45it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 775/775 [00:00<00:00, 6625.03it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	 10000
# Number of images in the validation dataset:	   775

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 50:
#         return 0.001
#     elif epoch < 60:
#         return 0.0001
#     else:
#         return 0.00001

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'source_only_run2_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 80
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/80
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 764s 764ms/step - loss: 8.0732 - pool1_GAP_substract_loss: 4.3829 - pool2_GAP_substract_loss: 4.5753 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.7802 - val_loss: 7.5404 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2660
#
# Epoch 00001: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-01_loss-8.0738_val_loss-7.5404.h5
# Epoch 2/80
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 6.6101 - pool1_GAP_substract_loss: 4.3794 - pool2_GAP_substract_loss: 4.5548 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3455 - val_loss: 7.4451 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1993
#
# Epoch 00002: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-02_loss-6.6100_val_loss-7.4451.h5
# Epoch 3/80
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 6.5642 - pool1_GAP_substract_loss: 4.3688 - pool2_GAP_substract_loss: 4.5233 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3395 - val_loss: 7.2254 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0314
#
# Epoch 00003: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-03_loss-6.5644_val_loss-7.2254.h5
# Epoch 4/80
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 6.1032 - pool1_GAP_substract_loss: 4.3628 - pool2_GAP_substract_loss: 4.4990 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9310 - val_loss: 7.1541 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0126
#
# Epoch 00004: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-04_loss-6.1029_val_loss-7.1541.h5
# Epoch 5/80
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 5.8576 - pool1_GAP_substract_loss: 4.3661 - pool2_GAP_substract_loss: 4.4866 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7376 - val_loss: 7.0706 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9809
#
# Epoch 00005: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-05_loss-5.8575_val_loss-7.0706.h5
# Epoch 6/80
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 5.6307 - pool1_GAP_substract_loss: 4.3605 - pool2_GAP_substract_loss: 4.4752 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5623 - val_loss: 6.8358 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7975
#
# Epoch 00006: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-06_loss-5.6309_val_loss-6.8358.h5
# Epoch 7/80
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 5.4896 - pool1_GAP_substract_loss: 4.3493 - pool2_GAP_substract_loss: 4.4602 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4720 - val_loss: 6.7712 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7830
#
# Epoch 00007: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-07_loss-5.4897_val_loss-6.7712.h5
# Epoch 8/80
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 5.3152 - pool1_GAP_substract_loss: 4.3501 - pool2_GAP_substract_loss: 4.4571 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3471 - val_loss: 6.6204 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6815
#
# Epoch 00008: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-08_loss-5.3150_val_loss-6.6204.h5
# Epoch 9/80
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 5.2570 - pool1_GAP_substract_loss: 4.3428 - pool2_GAP_substract_loss: 4.4401 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3381 - val_loss: 6.5395 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6490
#
# Epoch 00009: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-09_loss-5.2578_val_loss-6.5395.h5
# Epoch 10/80
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 5.1515 - pool1_GAP_substract_loss: 4.3527 - pool2_GAP_substract_loss: 4.4425 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2805 - val_loss: 6.5034 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6605
#
# Epoch 00010: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-10_loss-5.1510_val_loss-6.5034.h5
# Epoch 11/80
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 5.0310 - pool1_GAP_substract_loss: 4.3319 - pool2_GAP_substract_loss: 4.4165 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2070 - val_loss: 6.4585 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6620
#
# Epoch 00011: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-11_loss-5.0313_val_loss-6.4585.h5
# Epoch 12/80
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 4.9537 - pool1_GAP_substract_loss: 4.3325 - pool2_GAP_substract_loss: 4.4112 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1759 - val_loss: 6.5354 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7849
#
# Epoch 00012: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-12_loss-4.9533_val_loss-6.5354.h5
# Epoch 13/80
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.8398 - pool1_GAP_substract_loss: 4.3267 - pool2_GAP_substract_loss: 4.4026 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1074 - val_loss: 6.4410 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7354
#
# Epoch 00013: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-13_loss-4.8401_val_loss-6.4410.h5
# Epoch 14/80
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.7809 - pool1_GAP_substract_loss: 4.3288 - pool2_GAP_substract_loss: 4.3950 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0931 - val_loss: 6.3156 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6537
# Epoch 00014: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-14_loss-4.7808_val_loss-6.3156.h5
# Epoch 15/80
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.6909 - pool1_GAP_substract_loss: 4.3213 - pool2_GAP_substract_loss: 4.3867 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0463 - val_loss: 6.1823 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5636
#
# Epoch 00015: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-15_loss-4.6907_val_loss-6.1823.h5
# Epoch 16/80
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.5897 - pool1_GAP_substract_loss: 4.3205 - pool2_GAP_substract_loss: 4.3775 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9877 - val_loss: 6.3970 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8205
#
# Epoch 00016: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-16_loss-4.5903_val_loss-6.3970.h5
# Epoch 17/80
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.5324 - pool1_GAP_substract_loss: 4.3149 - pool2_GAP_substract_loss: 4.3758 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9725 - val_loss: 6.1055 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5706
#
# Epoch 00017: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-17_loss-4.5322_val_loss-6.1055.h5
# Epoch 18/80
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.4991 - pool1_GAP_substract_loss: 4.3154 - pool2_GAP_substract_loss: 4.3681 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9800 - val_loss: 6.1475 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6531
#
# Epoch 00018: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-18_loss-4.4996_val_loss-6.1475.h5
# Epoch 19/80
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.4030 - pool1_GAP_substract_loss: 4.3106 - pool2_GAP_substract_loss: 4.3649 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9241 - val_loss: 6.0011 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5462
#
# Epoch 00019: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-19_loss-4.4030_val_loss-6.0011.h5
# Epoch 20/80
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.3658 - pool1_GAP_substract_loss: 4.3009 - pool2_GAP_substract_loss: 4.3482 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9261 - val_loss: 6.0055 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5895
#
# Epoch 00020: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-20_loss-4.3656_val_loss-6.0055.h5
# Epoch 21/80
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.2937 - pool1_GAP_substract_loss: 4.2997 - pool2_GAP_substract_loss: 4.3470 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8922 - val_loss: 6.0546 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6763
#
# Epoch 00021: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-21_loss-4.2939_val_loss-6.0546.h5
# Epoch 22/80
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 4.2735 - pool1_GAP_substract_loss: 4.3019 - pool2_GAP_substract_loss: 4.3450 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9095 - val_loss: 5.8205 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4795
#
# Epoch 00022: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-22_loss-4.2728_val_loss-5.8205.h5
# Epoch 23/80
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.1602 - pool1_GAP_substract_loss: 4.3023 - pool2_GAP_substract_loss: 4.3436 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8330 - val_loss: 5.8150 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5103
#
# Epoch 00023: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-23_loss-4.1598_val_loss-5.8150.h5
# Epoch 24/80
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 4.0906 - pool1_GAP_substract_loss: 4.2990 - pool2_GAP_substract_loss: 4.3363 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7999 - val_loss: 5.9334 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6651
#
# Epoch 00024: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-24_loss-4.0901_val_loss-5.9334.h5
# Epoch 25/80
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 4.0934 - pool1_GAP_substract_loss: 4.2838 - pool2_GAP_substract_loss: 4.3207 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8385 - val_loss: 5.9232 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6900
#
# Epoch 00025: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-25_loss-4.0936_val_loss-5.9232.h5
# Epoch 26/80
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 4.0371 - pool1_GAP_substract_loss: 4.2778 - pool2_GAP_substract_loss: 4.3114 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8169 - val_loss: 5.7474 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5487
#
# Epoch 00026: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-26_loss-4.0367_val_loss-5.7474.h5
# Epoch 27/80
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.9659 - pool1_GAP_substract_loss: 4.2872 - pool2_GAP_substract_loss: 4.3154 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7800 - val_loss: 5.9699 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8053
#
# Epoch 00027: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-27_loss-3.9664_val_loss-5.9699.h5
# Epoch 28/80
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.9574 - pool1_GAP_substract_loss: 4.2793 - pool2_GAP_substract_loss: 4.3094 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8049 - val_loss: 5.9416 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8098
# Epoch 00028: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-28_loss-3.9575_val_loss-5.9416.h5
# Epoch 29/80
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.9193 - pool1_GAP_substract_loss: 4.2726 - pool2_GAP_substract_loss: 4.3029 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7991 - val_loss: 5.9326 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8326
#
# Epoch 00029: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-29_loss-3.9193_val_loss-5.9326.h5
# Epoch 30/80
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.8817 - pool1_GAP_substract_loss: 4.2753 - pool2_GAP_substract_loss: 4.2997 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7934 - val_loss: 6.4570 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3887
#
# Epoch 00030: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-30_loss-3.8813_val_loss-6.4570.h5
# Epoch 31/80
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.8274 - pool1_GAP_substract_loss: 4.2732 - pool2_GAP_substract_loss: 4.2995 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7699 - val_loss: 5.5448 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5072
#
# Epoch 00031: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-31_loss-3.8270_val_loss-5.5448.h5
# Epoch 32/80
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.7198 - pool1_GAP_substract_loss: 4.2748 - pool2_GAP_substract_loss: 4.2927 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6932 - val_loss: 5.6639 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6570
#
# Epoch 00032: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-32_loss-3.7194_val_loss-5.6639.h5
# Epoch 33/80
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.7287 - pool1_GAP_substract_loss: 4.2742 - pool2_GAP_substract_loss: 4.3004 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7325 - val_loss: 5.5896 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6125
#
# Epoch 00033: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-33_loss-3.7291_val_loss-5.5896.h5
# Epoch 34/80
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.6798 - pool1_GAP_substract_loss: 4.2587 - pool2_GAP_substract_loss: 4.2802 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7129 - val_loss: 5.6393 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6912
#
# Epoch 00034: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-34_loss-3.6801_val_loss-5.6393.h5
# Epoch 35/80
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.6708 - pool1_GAP_substract_loss: 4.2655 - pool2_GAP_substract_loss: 4.2801 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7328 - val_loss: 5.7541 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8346
#
# Epoch 00035: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-35_loss-3.6711_val_loss-5.7541.h5
# Epoch 36/80
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 3.5973 - pool1_GAP_substract_loss: 4.2603 - pool2_GAP_substract_loss: 4.2752 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6874 - val_loss: 5.8688 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9770
#
# Epoch 00036: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-36_loss-3.5972_val_loss-5.8688.h5
# Epoch 37/80
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.5946 - pool1_GAP_substract_loss: 4.2671 - pool2_GAP_substract_loss: 4.2890 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7120 - val_loss: 5.6202 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7554
#
# Epoch 00037: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-37_loss-3.5951_val_loss-5.6202.h5
# Epoch 38/80
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.5318 - pool1_GAP_substract_loss: 4.2519 - pool2_GAP_substract_loss: 4.2754 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6763 - val_loss: 5.4265 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5887
#
# Epoch 00038: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-38_loss-3.5316_val_loss-5.4265.h5
# Epoch 39/80
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.5020 - pool1_GAP_substract_loss: 4.2536 - pool2_GAP_substract_loss: 4.2681 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6732 - val_loss: 5.2031 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3917
#
# Epoch 00039: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-39_loss-3.5019_val_loss-5.2031.h5
# Epoch 40/80
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 3.4579 - pool1_GAP_substract_loss: 4.2615 - pool2_GAP_substract_loss: 4.2682 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6553 - val_loss: 5.8661 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0806
#
# Epoch 00040: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-40_loss-3.4578_val_loss-5.8661.h5
# Epoch 41/80
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.4458 - pool1_GAP_substract_loss: 4.2533 - pool2_GAP_substract_loss: 4.2590 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6686 - val_loss: 5.6012 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8409
#
# Epoch 00041: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-41_loss-3.4460_val_loss-5.6012.h5
# Epoch 42/80
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.4085 - pool1_GAP_substract_loss: 4.2430 - pool2_GAP_substract_loss: 4.2474 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6562 - val_loss: 5.3268 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5911
# Epoch 00042: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-42_loss-3.4085_val_loss-5.3268.h5
# Epoch 43/80
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.3414 - pool1_GAP_substract_loss: 4.2501 - pool2_GAP_substract_loss: 4.2574 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6138 - val_loss: 5.6499 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9387
#
# Epoch 00043: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-43_loss-3.3411_val_loss-5.6499.h5
# Epoch 44/80
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 3.3179 - pool1_GAP_substract_loss: 4.2388 - pool2_GAP_substract_loss: 4.2467 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6144 - val_loss: 5.5725 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8853
#
# Epoch 00044: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-44_loss-3.3180_val_loss-5.5725.h5
# Epoch 45/80
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.3374 - pool1_GAP_substract_loss: 4.2376 - pool2_GAP_substract_loss: 4.2429 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6573 - val_loss: 5.4359 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7714
#
# Epoch 00045: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-45_loss-3.3372_val_loss-5.4359.h5
# Epoch 46/80
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 3.2639 - pool1_GAP_substract_loss: 4.2353 - pool2_GAP_substract_loss: 4.2379 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6067 - val_loss: 5.5873 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9459
#
# Epoch 00046: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-46_loss-3.2639_val_loss-5.5873.h5
# Epoch 47/80
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 3.2920 - pool1_GAP_substract_loss: 4.2371 - pool2_GAP_substract_loss: 4.2449 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6572 - val_loss: 5.4273 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8077
#
# Epoch 00047: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-47_loss-3.2921_val_loss-5.4273.h5
# Epoch 48/80
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 3.2679 - pool1_GAP_substract_loss: 4.2385 - pool2_GAP_substract_loss: 4.2405 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6550 - val_loss: 5.3948 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7965
#
# Epoch 00048: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-48_loss-3.2674_val_loss-5.3948.h5
# Epoch 49/80
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 3.2385 - pool1_GAP_substract_loss: 4.2335 - pool2_GAP_substract_loss: 4.2361 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6467 - val_loss: 6.1472 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5703
#
# Epoch 00049: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-49_loss-3.2386_val_loss-6.1472.h5
# Epoch 50/80
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.1776 - pool1_GAP_substract_loss: 4.2206 - pool2_GAP_substract_loss: 4.2298 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6068 - val_loss: 5.5160 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9601
#
# Epoch 00050: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-50_loss-3.1778_val_loss-5.5160.h5
# Epoch 51/80
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.9599 - pool1_GAP_substract_loss: 4.2353 - pool2_GAP_substract_loss: 4.2399 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4012 - val_loss: 5.1116 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5586
#
# Epoch 00051: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-51_loss-2.9599_val_loss-5.1116.h5
# Epoch 52/80
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.8904 - pool1_GAP_substract_loss: 4.2283 - pool2_GAP_substract_loss: 4.2381 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3345 - val_loss: 5.1543 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6041
#
# Epoch 00052: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-52_loss-2.8904_val_loss-5.1543.h5
# Epoch 53/80
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.8710 - pool1_GAP_substract_loss: 4.2345 - pool2_GAP_substract_loss: 4.2439 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3179 - val_loss: 5.1687 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6212
#
# Epoch 00053: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-53_loss-2.8708_val_loss-5.1687.h5
# Epoch 54/80
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.8703 - pool1_GAP_substract_loss: 4.2246 - pool2_GAP_substract_loss: 4.2347 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3200 - val_loss: 5.0671 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5224
#
# Epoch 00054: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-54_loss-2.8701_val_loss-5.0671.h5
# Epoch 55/80
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.8741 - pool1_GAP_substract_loss: 4.2313 - pool2_GAP_substract_loss: 4.2420 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3266 - val_loss: 5.0957 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5538
#
# Epoch 00055: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-55_loss-2.8740_val_loss-5.0957.h5
# Epoch 56/80
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.8462 - pool1_GAP_substract_loss: 4.2328 - pool2_GAP_substract_loss: 4.2456 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3013 - val_loss: 5.1851 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6459
# Epoch 00056: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-56_loss-2.8461_val_loss-5.1851.h5
# Epoch 57/80
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 2.8382 - pool1_GAP_substract_loss: 4.2300 - pool2_GAP_substract_loss: 4.2442 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2962 - val_loss: 5.0373 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5009
#
# Epoch 00057: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-57_loss-2.8383_val_loss-5.0373.h5
# Epoch 58/80
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.8195 - pool1_GAP_substract_loss: 4.2243 - pool2_GAP_substract_loss: 4.2387 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2802 - val_loss: 5.1687 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6350
#
# Epoch 00058: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-58_loss-2.8197_val_loss-5.1687.h5
# Epoch 59/80
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.8098 - pool1_GAP_substract_loss: 4.2257 - pool2_GAP_substract_loss: 4.2422 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2732 - val_loss: 5.1908 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6598
#
# Epoch 00059: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-59_loss-2.8098_val_loss-5.1908.h5
# Epoch 60/80
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.8299 - pool1_GAP_substract_loss: 4.2296 - pool2_GAP_substract_loss: 4.2472 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2960 - val_loss: 5.1092 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5809
#
# Epoch 00060: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-60_loss-2.8296_val_loss-5.1092.h5
# Epoch 61/80
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.8482 - pool1_GAP_substract_loss: 4.2236 - pool2_GAP_substract_loss: 4.2384 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3170 - val_loss: 5.1036 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5781
#
# Epoch 00061: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-61_loss-2.8482_val_loss-5.1036.h5
# Epoch 62/80
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.8168 - pool1_GAP_substract_loss: 4.2227 - pool2_GAP_substract_loss: 4.2422 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2883 - val_loss: 5.1283 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6054
#
# Epoch 00062: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-62_loss-2.8169_val_loss-5.1283.h5
# Epoch 63/80
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.8049 - pool1_GAP_substract_loss: 4.2383 - pool2_GAP_substract_loss: 4.2530 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2791 - val_loss: 5.3991 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8789
#
# Epoch 00063: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-63_loss-2.8051_val_loss-5.3991.h5
# Epoch 64/80
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.8175 - pool1_GAP_substract_loss: 4.2272 - pool2_GAP_substract_loss: 4.2493 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2944 - val_loss: 5.1442 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6267
#
# Epoch 00064: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-64_loss-2.8174_val_loss-5.1442.h5
# Epoch 65/80
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.7747 - pool1_GAP_substract_loss: 4.2294 - pool2_GAP_substract_loss: 4.2509 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2543 - val_loss: 5.1389 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6241
#
# Epoch 00065: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-65_loss-2.7747_val_loss-5.1389.h5
# Epoch 66/80
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.7900 - pool1_GAP_substract_loss: 4.2156 - pool2_GAP_substract_loss: 4.2428 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2723 - val_loss: 5.2094 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6973
#
# Epoch 00066: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-66_loss-2.7901_val_loss-5.2094.h5
# Epoch 67/80
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.7706 - pool1_GAP_substract_loss: 4.2310 - pool2_GAP_substract_loss: 4.2510 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2556 - val_loss: 5.1657 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6563
#
# Epoch 00067: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-67_loss-2.7704_val_loss-5.1657.h5
# Epoch 68/80
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.8066 - pool1_GAP_substract_loss: 4.2341 - pool2_GAP_substract_loss: 4.2522 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2943 - val_loss: 5.1625 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6558
#
# Epoch 00068: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-68_loss-2.8065_val_loss-5.1625.h5
# Epoch 69/80
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.7656 - pool1_GAP_substract_loss: 4.2337 - pool2_GAP_substract_loss: 4.2546 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2559 - val_loss: 5.1630 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6589
#
# Epoch 00069: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-69_loss-2.7653_val_loss-5.1630.h5
# Epoch 70/80
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.7741 - pool1_GAP_substract_loss: 4.2224 - pool2_GAP_substract_loss: 4.2430 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2671 - val_loss: 5.1604 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6589
# Epoch 00070: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-70_loss-2.7738_val_loss-5.1604.h5
# Epoch 71/80
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.7666 - pool1_GAP_substract_loss: 4.2322 - pool2_GAP_substract_loss: 4.2509 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2611 - val_loss: 5.1134 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6122
#
# Epoch 00071: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-71_loss-2.7670_val_loss-5.1134.h5
# Epoch 72/80
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.7588 - pool1_GAP_substract_loss: 4.2244 - pool2_GAP_substract_loss: 4.2423 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2535 - val_loss: 5.1306 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6297
#
# Epoch 00072: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-72_loss-2.7586_val_loss-5.1306.h5
# Epoch 73/80
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.7421 - pool1_GAP_substract_loss: 4.2253 - pool2_GAP_substract_loss: 4.2472 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2371 - val_loss: 5.1656 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6649
#
# Epoch 00073: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-73_loss-2.7422_val_loss-5.1656.h5
# Epoch 74/80
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.7460 - pool1_GAP_substract_loss: 4.2230 - pool2_GAP_substract_loss: 4.2405 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2413 - val_loss: 5.1122 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6119
#
# Epoch 00074: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-74_loss-2.7459_val_loss-5.1122.h5
# Epoch 75/80
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.7320 - pool1_GAP_substract_loss: 4.2246 - pool2_GAP_substract_loss: 4.2475 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2275 - val_loss: 5.1174 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6172
#
# Epoch 00075: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-75_loss-2.7319_val_loss-5.1174.h5
# Epoch 76/80
#
# Epoch 00076: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.7525 - pool1_GAP_substract_loss: 4.2289 - pool2_GAP_substract_loss: 4.2553 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2483 - val_loss: 5.1571 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6573
#
# Epoch 00076: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-76_loss-2.7525_val_loss-5.1571.h5
# Epoch 77/80
#
# Epoch 00077: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.7220 - pool1_GAP_substract_loss: 4.2285 - pool2_GAP_substract_loss: 4.2514 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2181 - val_loss: 5.1758 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6762
#
# Epoch 00077: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-77_loss-2.7221_val_loss-5.1758.h5
# Epoch 78/80
#
# Epoch 00078: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.7509 - pool1_GAP_substract_loss: 4.2220 - pool2_GAP_substract_loss: 4.2474 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2472 - val_loss: 5.1699 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6706
#
# Epoch 00078: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-78_loss-2.7510_val_loss-5.1699.h5
# Epoch 79/80
#
# Epoch 00079: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.7254 - pool1_GAP_substract_loss: 4.2418 - pool2_GAP_substract_loss: 4.2645 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2220 - val_loss: 5.1771 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6781
#
# Epoch 00079: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-79_loss-2.7255_val_loss-5.1771.h5
# Epoch 80/80
#
# Epoch 00080: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.7320 - pool1_GAP_substract_loss: 4.2312 - pool2_GAP_substract_loss: 4.2578 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2288 - val_loss: 5.1441 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6453
#
# Epoch 00080: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005/epoch-80_loss-2.7318_val_loss-5.1441.h5

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()
# Out:
# Image: ../../datasets/SIM10K/JPEGImages/3386267

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
# Out:
# Image: ../../datasets/SIM10K/JPEGImages/3399675
#
# Ground truth boxes:
#
# [[  1 269 160 287 165]
#  [  1 407   0 721 240]
#  [  1 401 164 411 169]
#  [  1 342 163 349 168]
#  [  1 194 159 235 165]
#  [  1 158 157 199 166]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4c88a6df60d1> in <module>()
#      47 # 5: Convert the predictions for the original image.
#      48
# ---> 49 y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)
#      50
#      51 np.set_printoptions(precision=2, suppress=True, linewidth=90)
#
# /domain_adaptation_object_detection/LLFDA_IJCAI2019/data_generator/object_detection_2d_misc_utils.py in apply_inverse_transforms(y_pred_decoded, inverse_transforms)
#      56                 for inverter in inverse_transforms[i]:
#      57                     if not (inverter is None):
# ---> 58                         y_pred_decoded_inv[i] = inverter(y_pred_decoded_inv[i])
#      59
#      60     elif isinstance(y_pred_decoded, np.ndarray):
#
# TypeError: 'list' object is not callable
