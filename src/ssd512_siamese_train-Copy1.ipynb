# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [2.0, 0.0, 0.0] + [1.0]
experiment = 'MMD_pool1_weight2'

#  
DatasetName = 'City_to_foggy0_01_resize_400_800'  #  'SIM10K_to_City_resize_400_800' # 'SIM10K_to_VOC07_resize_400_800' #   'SIM10K_to_VOC12_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

# Define model callbacks.
checkpoint_path = os.path.join('../trained_weights', DatasetName, experiment)
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)    
    
if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')
# Out:
# da_loss_metric is MMD_loss

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 2966/2966 [00:00<00:00, 4724.20it/s]
# Loading source image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 10512.30it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 10875.11it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 2966/2966 [00:00<00:00, 7299.58it/s]
# Loading source labels: 100%|██████████| 493/493 [00:00<00:00, 4615.98it/s]
# Loading source image IDs: 100%|██████████| 493/493 [00:00<00:00, 8110.45it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 493/493 [00:00<00:00, 5871.06it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  2966
# Number of images in the validation dataset:	   493

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 60:
        return 0.0001
    else:
        return 0.00001

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 70
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/70
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 796s 796ms/step - loss: 9.5931 - pool1_GAP_substract_loss: 0.1051 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 5.8446 - val_loss: 8.8224 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.2996
#
# Epoch 00001: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-01_loss-9.5931_val_loss-8.8224.h5
# Epoch 2/70
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 782s 782ms/step - loss: 8.1921 - pool1_GAP_substract_loss: 0.0735 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.5382 - val_loss: 8.1953 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7041
#
# Epoch 00002: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-02_loss-8.1921_val_loss-8.1953.h5
# Epoch 3/70
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 781s 781ms/step - loss: 7.9825 - pool1_GAP_substract_loss: 0.0711 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.3790 - val_loss: 8.0978 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6667
#
# Epoch 00003: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-03_loss-7.9825_val_loss-8.0978.h5
# Epoch 4/70
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 781s 781ms/step - loss: 7.5928 - pool1_GAP_substract_loss: 0.0687 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.0545 - val_loss: 7.9065 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5354
#
# Epoch 00004: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-04_loss-7.5928_val_loss-7.9065.h5
# Epoch 5/70
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 782s 782ms/step - loss: 7.3144 - pool1_GAP_substract_loss: 0.0664 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.8402 - val_loss: 7.7272 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4149
#
# Epoch 00005: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-05_loss-7.3144_val_loss-7.7272.h5
# Epoch 6/70
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 782s 782ms/step - loss: 7.0825 - pool1_GAP_substract_loss: 0.0658 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.6679 - val_loss: 7.5990 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3446
#
# Epoch 00006: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-06_loss-7.0825_val_loss-7.5990.h5
# Epoch 7/70
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 785s 785ms/step - loss: 6.9155 - pool1_GAP_substract_loss: 0.0639 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5620 - val_loss: 7.4670 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2695
#
# Epoch 00007: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-07_loss-6.9155_val_loss-7.4670.h5
# Epoch 8/70
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 793s 793ms/step - loss: 6.7722 - pool1_GAP_substract_loss: 0.0650 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4727 - val_loss: 7.4183 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2762
#
# Epoch 00008: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-08_loss-6.7722_val_loss-7.4183.h5
# Epoch 9/70
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 843s 843ms/step - loss: 6.6778 - pool1_GAP_substract_loss: 0.0627 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4378 - val_loss: 7.4176 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3298
#
# Epoch 00009: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-09_loss-6.6778_val_loss-7.4176.h5
# Epoch 10/70
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 869s 869ms/step - loss: 6.5854 - pool1_GAP_substract_loss: 0.0627 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3991 - val_loss: 7.3011 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2663
#
# Epoch 00010: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-10_loss-6.5854_val_loss-7.3011.h5
# Epoch 11/70
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 928s 928ms/step - loss: 6.4241 - pool1_GAP_substract_loss: 0.0631 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2895 - val_loss: 7.2579 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2753
#
# Epoch 00011: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-11_loss-6.4241_val_loss-7.2579.h5
# Epoch 12/70
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 888s 888ms/step - loss: 6.3460 - pool1_GAP_substract_loss: 0.0626 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2640 - val_loss: 7.2114 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2796
#
# Epoch 00012: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-12_loss-6.3460_val_loss-7.2114.h5
# Epoch 13/70
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 6.2316 - pool1_GAP_substract_loss: 0.0612 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2025 - val_loss: 6.9709 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0890
#
# Epoch 00013: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-13_loss-6.2316_val_loss-6.9709.h5
# Epoch 14/70
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 885s 885ms/step - loss: 6.1233 - pool1_GAP_substract_loss: 0.0607 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1446 - val_loss: 6.9479 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1147
#
# Epoch 00014: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-14_loss-6.1233_val_loss-6.9479.h5
# Epoch 15/70
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 875s 875ms/step - loss: 6.0552 - pool1_GAP_substract_loss: 0.0616 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1230 - val_loss: 6.9049 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1195
#
# Epoch 00015: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-15_loss-6.0552_val_loss-6.9049.h5
# Epoch 16/70
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 872s 872ms/step - loss: 6.0090 - pool1_GAP_substract_loss: 0.0608 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1256 - val_loss: 6.7109 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9720
#
# Epoch 00016: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-16_loss-6.0090_val_loss-6.7109.h5
# Epoch 17/70
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 889s 889ms/step - loss: 5.8966 - pool1_GAP_substract_loss: 0.0607 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0594 - val_loss: 6.7892 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0959
#
# Epoch 00017: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-17_loss-5.8966_val_loss-6.7892.h5
# Epoch 18/70
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 873s 873ms/step - loss: 5.8450 - pool1_GAP_substract_loss: 0.0603 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0536 - val_loss: 6.7060 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0572
#
# Epoch 00018: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-18_loss-5.8450_val_loss-6.7060.h5
# Epoch 19/70
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 863s 863ms/step - loss: 5.7413 - pool1_GAP_substract_loss: 0.0599 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9950 - val_loss: 6.6594 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0547
#
# Epoch 00019: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-19_loss-5.7413_val_loss-6.6594.h5
# Epoch 20/70
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 921s 921ms/step - loss: 5.7069 - pool1_GAP_substract_loss: 0.0613 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0013 - val_loss: 6.5969 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0351
#
# Epoch 00020: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-20_loss-5.7069_val_loss-6.5969.h5
# Epoch 21/70
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 920s 920ms/step - loss: 5.6521 - pool1_GAP_substract_loss: 0.0589 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9935 - val_loss: 6.5036 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9834
#
# Epoch 00021: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-21_loss-5.6521_val_loss-6.5036.h5
# Epoch 22/70
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 888s 888ms/step - loss: 5.5615 - pool1_GAP_substract_loss: 0.0586 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9449 - val_loss: 6.5358 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0567
#
# Epoch 00022: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-22_loss-5.5615_val_loss-6.5358.h5
# Epoch 23/70
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 873s 873ms/step - loss: 5.5083 - pool1_GAP_substract_loss: 0.0602 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9292 - val_loss: 6.5183 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0794
#
# Epoch 00023: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-23_loss-5.5083_val_loss-6.5183.h5
# Epoch 24/70
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 888s 888ms/step - loss: 5.4345 - pool1_GAP_substract_loss: 0.0588 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8978 - val_loss: 6.4398 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0401
#
# Epoch 00024: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-24_loss-5.4345_val_loss-6.4398.h5
# Epoch 25/70
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 887s 887ms/step - loss: 5.3760 - pool1_GAP_substract_loss: 0.0595 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8766 - val_loss: 6.3698 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0083
#
# Epoch 00025: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-25_loss-5.3760_val_loss-6.3698.h5
# Epoch 26/70
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 817s 817ms/step - loss: 5.3241 - pool1_GAP_substract_loss: 0.0601 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8613 - val_loss: 6.1728 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8489
#
# Epoch 00026: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-26_loss-5.3241_val_loss-6.1728.h5
# Epoch 27/70
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 841s 841ms/step - loss: 5.2941 - pool1_GAP_substract_loss: 0.0598 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8693 - val_loss: 6.3289 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0415
#
# Epoch 00027: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-27_loss-5.2941_val_loss-6.3289.h5
# Epoch 28/70
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 880s 880ms/step - loss: 5.1958 - pool1_GAP_substract_loss: 0.0594 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8078 - val_loss: 6.1233 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8718
#
# Epoch 00028: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-28_loss-5.1958_val_loss-6.1233.h5
# Epoch 29/70
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 861s 861ms/step - loss: 5.1561 - pool1_GAP_substract_loss: 0.0590 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8044 - val_loss: 6.2951 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0788
#
# Epoch 00029: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-29_loss-5.1561_val_loss-6.2951.h5
# Epoch 30/70
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 5.1167 - pool1_GAP_substract_loss: 0.0582 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8012 - val_loss: 6.3160 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1337
#
# Epoch 00030: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-30_loss-5.1167_val_loss-6.3160.h5
# Epoch 31/70
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 858s 858ms/step - loss: 5.0965 - pool1_GAP_substract_loss: 0.0590 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8133 - val_loss: 6.1082 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9596
#
# Epoch 00031: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-31_loss-5.0965_val_loss-6.1082.h5
# Epoch 32/70
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 5.0256 - pool1_GAP_substract_loss: 0.0581 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7775 - val_loss: 6.0026 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8870
#
# Epoch 00032: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-32_loss-5.0256_val_loss-6.0026.h5
# Epoch 33/70
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 874s 874ms/step - loss: 4.9841 - pool1_GAP_substract_loss: 0.0592 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7662 - val_loss: 6.0457 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9619
#
# Epoch 00033: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-33_loss-4.9841_val_loss-6.0457.h5
# Epoch 34/70
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 863s 863ms/step - loss: 4.8973 - pool1_GAP_substract_loss: 0.0586 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7122 - val_loss: 5.9952 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9428
#
# Epoch 00034: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-34_loss-4.8973_val_loss-5.9952.h5
# Epoch 35/70
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 871s 871ms/step - loss: 4.8562 - pool1_GAP_substract_loss: 0.0585 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7024 - val_loss: 5.9381 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9164
#
# Epoch 00035: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-35_loss-4.8562_val_loss-5.9381.h5
# Epoch 36/70
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 881s 881ms/step - loss: 4.8250 - pool1_GAP_substract_loss: 0.0586 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7014 - val_loss: 6.1339 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1422
#
# Epoch 00036: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-36_loss-4.8250_val_loss-6.1339.h5
# Epoch 37/70
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 882s 882ms/step - loss: 4.8002 - pool1_GAP_substract_loss: 0.0591 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7051 - val_loss: 5.9008 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9385
#
# Epoch 00037: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-37_loss-4.8002_val_loss-5.9008.h5
# Epoch 38/70
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 883s 883ms/step - loss: 4.7875 - pool1_GAP_substract_loss: 0.0579 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7239 - val_loss: 5.8569 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9230
#
# Epoch 00038: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-38_loss-4.7875_val_loss-5.8569.h5
# Epoch 39/70
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 908s 908ms/step - loss: 4.7533 - pool1_GAP_substract_loss: 0.0580 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7179 - val_loss: 5.9846 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0789
#
# Epoch 00039: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-39_loss-4.7533_val_loss-5.9846.h5
# Epoch 40/70
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 892s 892ms/step - loss: 4.7208 - pool1_GAP_substract_loss: 0.0592 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7105 - val_loss: 5.7463 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8676
#
# Epoch 00040: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-40_loss-4.7208_val_loss-5.7463.h5
# Epoch 41/70
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 893s 893ms/step - loss: 4.6386 - pool1_GAP_substract_loss: 0.0588 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6562 - val_loss: 5.6223 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7706
#
# Epoch 00041: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-41_loss-4.6386_val_loss-5.6223.h5
# Epoch 42/70
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 898s 898ms/step - loss: 4.6203 - pool1_GAP_substract_loss: 0.0578 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6662 - val_loss: 5.9349 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1094
#
# Epoch 00042: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-42_loss-4.6203_val_loss-5.9349.h5
# Epoch 43/70
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 877s 877ms/step - loss: 4.5409 - pool1_GAP_substract_loss: 0.0586 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6112 - val_loss: 5.7543 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9545
#
# Epoch 00043: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-43_loss-4.5409_val_loss-5.7543.h5
# Epoch 44/70
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 885s 885ms/step - loss: 4.5447 - pool1_GAP_substract_loss: 0.0590 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6398 - val_loss: 5.6347 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8601
#
# Epoch 00044: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-44_loss-4.5447_val_loss-5.6347.h5
# Epoch 45/70
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 882s 882ms/step - loss: 4.4982 - pool1_GAP_substract_loss: 0.0572 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6217 - val_loss: 5.6394 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8892
#
# Epoch 00045: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-45_loss-4.4982_val_loss-5.6394.h5
# Epoch 46/70
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 859s 859ms/step - loss: 4.4497 - pool1_GAP_substract_loss: 0.0576 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5966 - val_loss: 5.7352 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0093
#
# Epoch 00046: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-46_loss-4.4497_val_loss-5.7352.h5
# Epoch 47/70
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 907s 907ms/step - loss: 4.4539 - pool1_GAP_substract_loss: 0.0589 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6219 - val_loss: 5.5641 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8614
#
# Epoch 00047: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-47_loss-4.4539_val_loss-5.5641.h5
# Epoch 48/70
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 4.3876 - pool1_GAP_substract_loss: 0.0581 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5804 - val_loss: 5.6167 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9370
#
# Epoch 00048: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-48_loss-4.3876_val_loss-5.6167.h5
# Epoch 49/70
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 917s 917ms/step - loss: 4.3420 - pool1_GAP_substract_loss: 0.0583 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5573 - val_loss: 5.5341 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8772
#
# Epoch 00049: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-49_loss-4.3420_val_loss-5.5341.h5
# Epoch 50/70
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 880s 880ms/step - loss: 4.3203 - pool1_GAP_substract_loss: 0.0586 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5575 - val_loss: 5.5548 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9201
#
# Epoch 00050: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-50_loss-4.3203_val_loss-5.5548.h5
# Epoch 51/70
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 896s 896ms/step - loss: 4.1463 - pool1_GAP_substract_loss: 0.0575 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3984 - val_loss: 5.4030 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7712
#
# Epoch 00051: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-51_loss-4.1463_val_loss-5.4030.h5
# Epoch 52/70
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 878s 878ms/step - loss: 4.0905 - pool1_GAP_substract_loss: 0.0570 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3463 - val_loss: 5.4185 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7894
#
# Epoch 00052: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-52_loss-4.0905_val_loss-5.4185.h5
# Epoch 53/70
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 885s 885ms/step - loss: 4.0635 - pool1_GAP_substract_loss: 0.0558 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3243 - val_loss: 5.4082 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7819
#
# Epoch 00053: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-53_loss-4.0635_val_loss-5.4082.h5
# Epoch 54/70
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 885s 885ms/step - loss: 4.0216 - pool1_GAP_substract_loss: 0.0567 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2834 - val_loss: 5.3754 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7518
#
# Epoch 00054: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-54_loss-4.0216_val_loss-5.3754.h5
# Epoch 55/70
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 865s 865ms/step - loss: 4.0244 - pool1_GAP_substract_loss: 0.0576 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2871 - val_loss: 5.4544 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8335
#
# Epoch 00055: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-55_loss-4.0244_val_loss-5.4544.h5
# Epoch 56/70
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 890s 890ms/step - loss: 4.0208 - pool1_GAP_substract_loss: 0.0566 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2884 - val_loss: 5.4710 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8528
#
# Epoch 00056: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-56_loss-4.0208_val_loss-5.4710.h5
# Epoch 57/70
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 883s 883ms/step - loss: 4.0287 - pool1_GAP_substract_loss: 0.0564 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2992 - val_loss: 5.4818 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8663
#
# Epoch 00057: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-57_loss-4.0287_val_loss-5.4818.h5
# Epoch 58/70
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 876s 876ms/step - loss: 4.0065 - pool1_GAP_substract_loss: 0.0565 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2796 - val_loss: 5.4663 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8536
#
# Epoch 00058: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-58_loss-4.0065_val_loss-5.4663.h5
# Epoch 59/70
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 903s 903ms/step - loss: 4.0074 - pool1_GAP_substract_loss: 0.0551 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2861 - val_loss: 5.4357 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8257
#
# Epoch 00059: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-59_loss-4.0074_val_loss-5.4357.h5
# Epoch 60/70
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 864s 864ms/step - loss: 3.9998 - pool1_GAP_substract_loss: 0.0557 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2799 - val_loss: 5.4391 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8318
#
# Epoch 00060: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-60_loss-3.9998_val_loss-5.4391.h5
# Epoch 61/70
#
# Epoch 00061: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 875s 875ms/step - loss: 3.9904 - pool1_GAP_substract_loss: 0.0560 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2715 - val_loss: 5.3985 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7915
#
# Epoch 00061: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-61_loss-3.9904_val_loss-5.3985.h5
# Epoch 62/70
#
# Epoch 00062: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 891s 891ms/step - loss: 3.9840 - pool1_GAP_substract_loss: 0.0570 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2633 - val_loss: 5.4043 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7975
#
# Epoch 00062: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-62_loss-3.9840_val_loss-5.4043.h5
# Epoch 63/70
#
# Epoch 00063: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 873s 873ms/step - loss: 3.9678 - pool1_GAP_substract_loss: 0.0568 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2477 - val_loss: 5.4403 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8338
#
# Epoch 00063: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-63_loss-3.9678_val_loss-5.4403.h5
# Epoch 64/70
#
# Epoch 00064: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 887s 887ms/step - loss: 3.9846 - pool1_GAP_substract_loss: 0.0560 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2664 - val_loss: 5.4396 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8333
#
# Epoch 00064: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-64_loss-3.9846_val_loss-5.4396.h5
# Epoch 65/70
#
# Epoch 00065: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 877s 877ms/step - loss: 4.0024 - pool1_GAP_substract_loss: 0.0561 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2843 - val_loss: 5.4227 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8168
#
# Epoch 00065: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-65_loss-4.0024_val_loss-5.4227.h5
# Epoch 66/70
#
# Epoch 00066: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 873s 873ms/step - loss: 3.9724 - pool1_GAP_substract_loss: 0.0548 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2573 - val_loss: 5.4128 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8071
#
# Epoch 00066: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-66_loss-3.9724_val_loss-5.4128.h5
# Epoch 67/70
#
# Epoch 00067: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 896s 896ms/step - loss: 3.9958 - pool1_GAP_substract_loss: 0.0556 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2792 - val_loss: 5.4411 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8357
#
# Epoch 00067: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-67_loss-3.9958_val_loss-5.4411.h5
# Epoch 68/70
#
# Epoch 00068: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 861s 861ms/step - loss: 3.9698 - pool1_GAP_substract_loss: 0.0563 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2520 - val_loss: 5.4337 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8286
#
# Epoch 00068: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-68_loss-3.9698_val_loss-5.4337.h5
# Epoch 69/70
#
# Epoch 00069: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 793s 793ms/step - loss: 3.9830 - pool1_GAP_substract_loss: 0.0559 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2664 - val_loss: 5.4573 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8524
#
# Epoch 00069: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-69_loss-3.9830_val_loss-5.4573.h5
# Epoch 70/70
#
# Epoch 00070: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 779s 779ms/step - loss: 3.9539 - pool1_GAP_substract_loss: 0.0570 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2354 - val_loss: 5.4385 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8339
#
# Epoch 00070: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1_weight2/epoch-70_loss-3.9539_val_loss-5.4385.h5

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()
# Out:
# Image: ../../datasets/Cityscapes/JPEGImages/source_hanover_000000_046398_leftImg8bit

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
# Out:
# Image: ../../datasets/Cityscapes/JPEGImages/source_strasbourg_000000_017081_leftImg8bit
#
# Ground truth boxes:
#
# [[  3 177 145 248 172]
#  [  8 439 161 526 218]
#  [  1 250 107 288 252]
#  [  1 300 114 333 243]
#  [  1 264 106 321 260]
#  [  1 400 159 424 193]
#  [  1 325 110 370 247]
#  [  1 430 159 437 170]
#  [  1 416 159 432 194]
#  [  1 436 157 460 206]
#  [  1 455 157 470 173]
#  [  1 468 159 480 176]
#  [  1 477 154 495 176]
#  [  1 515 158 537 205]
#  [  1 534 152 566 210]
#  [  1 635 147 647 168]
#  [  1 628 158 652 204]
#  [  1 618 156 634 173]
#  [  1 500 161 505 174]
#  [  1 612 161 626 196]
#  [  1 568 143 598 228]
#  [  1 761 145 778 185]
#  [  1 751 150 763 185]
#  [  1 729 144 753 196]
#  [  1 182 162 186 172]
#  [  1 176 155 183 173]
#  [  1 363 115 405 251]
#  [  3 179 145 186 152]
#  [  3 182 157 197 170]
#  [  3 215 154 228 165]
#  [  3 219 156 232 167]
#  [  3 237 157 248 174]
#  [  3 247 155 251 177]
#  [  3 779 149 798 182]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4c88a6df60d1> in <module>()
#      47 # 5: Convert the predictions for the original image.
#      48
# ---> 49 y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)
#      50
#      51 np.set_printoptions(precision=2, suppress=True, linewidth=90)
#
# /domain_adaptation_object_detection/LLFDA_IJCAI2019/data_generator/object_detection_2d_misc_utils.py in apply_inverse_transforms(y_pred_decoded, inverse_transforms)
#      56                 for inverter in inverse_transforms[i]:
#      57                     if not (inverter is None):
# ---> 58                         y_pred_decoded_inv[i] = inverter(y_pred_decoded_inv[i])
#      59
#      60     elif isinstance(y_pred_decoded, np.ndarray):
#
# TypeError: 'list' object is not callable
