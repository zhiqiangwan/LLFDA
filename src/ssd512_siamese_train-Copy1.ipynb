# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [1.0, 1.0, 0.0] + [1.0]
experiment = 'MMD_pool1pool2_weight1'

#  
DatasetName = 'SIM10K_to_City_resize_400_800' # 'City_to_foggy0_01_resize_400_800'  # 'SIM10K_to_VOC07_resize_400_800' #   'SIM10K_to_VOC12_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

# Define model callbacks.
checkpoint_path = os.path.join('../trained_weights', DatasetName, experiment)
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)    
    
if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')
# Out:
# da_loss_metric is MMD_loss

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 10000/10000 [00:02<00:00, 4912.05it/s]
# Loading source image IDs: 100%|██████████| 10000/10000 [00:00<00:00, 10960.80it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 11718.14it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 10000/10000 [00:01<00:00, 8007.05it/s]
# Loading source labels: 100%|██████████| 479/479 [00:00<00:00, 5079.71it/s]
# Loading source image IDs: 100%|██████████| 479/479 [00:00<00:00, 11439.62it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 479/479 [00:00<00:00, 8394.08it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	 10000
# Number of images in the validation dataset:	   479

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 60:
        return 0.0001
    else:
        return 0.00001

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 70
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/70
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 834s 834ms/step - loss: 8.9836 - pool1_GAP_substract_loss: 0.1627 - pool2_GAP_substract_loss: 0.0853 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 5.4494 - val_loss: 7.9575 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6847
#
# Epoch 00001: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-01_loss-8.9845_val_loss-7.9575.h5
# Epoch 2/70
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 810s 810ms/step - loss: 6.9566 - pool1_GAP_substract_loss: 0.1422 - pool2_GAP_substract_loss: 0.0782 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4774 - val_loss: 7.7414 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4965
#
# Epoch 00002: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-02_loss-6.9570_val_loss-7.7414.h5
# Epoch 3/70
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 6.8951 - pool1_GAP_substract_loss: 0.1304 - pool2_GAP_substract_loss: 0.0728 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4722 - val_loss: 7.6360 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4419
#
# Epoch 00003: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-03_loss-6.8951_val_loss-7.6360.h5
# Epoch 4/70
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 813s 813ms/step - loss: 6.4006 - pool1_GAP_substract_loss: 0.1211 - pool2_GAP_substract_loss: 0.0690 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0425 - val_loss: 7.6017 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4599
#
# Epoch 00004: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-04_loss-6.4002_val_loss-7.6017.h5
# Epoch 5/70
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 6.1023 - pool1_GAP_substract_loss: 0.1112 - pool2_GAP_substract_loss: 0.0664 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8088 - val_loss: 7.4856 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3949
#
# Epoch 00005: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-05_loss-6.1022_val_loss-7.4856.h5
# Epoch 6/70
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 5.8669 - pool1_GAP_substract_loss: 0.1068 - pool2_GAP_substract_loss: 0.0638 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6314 - val_loss: 7.4507 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4108
#
# Epoch 00006: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-06_loss-5.8668_val_loss-7.4507.h5
# Epoch 7/70
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 5.6724 - pool1_GAP_substract_loss: 0.1041 - pool2_GAP_substract_loss: 0.0635 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4904 - val_loss: 7.3874 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3982
#
# Epoch 00007: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-07_loss-5.6720_val_loss-7.3874.h5
# Epoch 8/70
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 5.5454 - pool1_GAP_substract_loss: 0.0999 - pool2_GAP_substract_loss: 0.0621 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4192 - val_loss: 7.3053 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3654
#
# Epoch 00008: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-08_loss-5.5454_val_loss-7.3053.h5
# Epoch 9/70
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 5.3886 - pool1_GAP_substract_loss: 0.0985 - pool2_GAP_substract_loss: 0.0626 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3120 - val_loss: 7.1376 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2459
#
# Epoch 00009: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-09_loss-5.3877_val_loss-7.1376.h5
# Epoch 10/70
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 5.3173 - pool1_GAP_substract_loss: 0.0939 - pool2_GAP_substract_loss: 0.0605 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2952 - val_loss: 7.0012 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1567
#
# Epoch 00010: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-10_loss-5.3172_val_loss-7.0012.h5
# Epoch 11/70
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 5.1774 - pool1_GAP_substract_loss: 0.0917 - pool2_GAP_substract_loss: 0.0605 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2043 - val_loss: 7.1307 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3328
#
# Epoch 00011: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-11_loss-5.1774_val_loss-7.1307.h5
# Epoch 12/70
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 5.1015 - pool1_GAP_substract_loss: 0.0917 - pool2_GAP_substract_loss: 0.0618 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1730 - val_loss: 6.7463 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9937
#
# Epoch 00012: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-12_loss-5.1013_val_loss-6.7463.h5
# Epoch 13/70
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 5.0702 - pool1_GAP_substract_loss: 0.0894 - pool2_GAP_substract_loss: 0.0602 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1903 - val_loss: 6.8390 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1307
#
# Epoch 00013: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-13_loss-5.0707_val_loss-6.8390.h5
# Epoch 14/70
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 4.9336 - pool1_GAP_substract_loss: 0.0855 - pool2_GAP_substract_loss: 0.0598 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1019 - val_loss: 6.7836 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1186
#
# Epoch 00014: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-14_loss-4.9334_val_loss-6.7836.h5
# Epoch 15/70
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 4.8374 - pool1_GAP_substract_loss: 0.0856 - pool2_GAP_substract_loss: 0.0590 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0496 - val_loss: 6.7247 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1030
#
# Epoch 00015: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-15_loss-4.8375_val_loss-6.7247.h5
# Epoch 16/70
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 4.7851 - pool1_GAP_substract_loss: 0.0851 - pool2_GAP_substract_loss: 0.0592 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0403 - val_loss: 7.1448 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5648
#
# Epoch 00016: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-16_loss-4.7847_val_loss-7.1448.h5
# Epoch 17/70
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 4.7481 - pool1_GAP_substract_loss: 0.0835 - pool2_GAP_substract_loss: 0.0586 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0467 - val_loss: 6.7939 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2547
#
# Epoch 00017: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-17_loss-4.7478_val_loss-6.7939.h5
# Epoch 18/70
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 4.6523 - pool1_GAP_substract_loss: 0.0826 - pool2_GAP_substract_loss: 0.0582 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9927 - val_loss: 6.4977 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9989
#
# Epoch 00018: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-18_loss-4.6528_val_loss-6.4977.h5
# Epoch 19/70
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 4.6146 - pool1_GAP_substract_loss: 0.0817 - pool2_GAP_substract_loss: 0.0578 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9962 - val_loss: 6.4638 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0042
#
# Epoch 00019: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-19_loss-4.6144_val_loss-6.4638.h5
# Epoch 20/70
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 4.5593 - pool1_GAP_substract_loss: 0.0814 - pool2_GAP_substract_loss: 0.0576 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9801 - val_loss: 6.6196 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1986
#
# Epoch 00020: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-20_loss-4.5588_val_loss-6.6196.h5
# Epoch 21/70
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 4.4543 - pool1_GAP_substract_loss: 0.0808 - pool2_GAP_substract_loss: 0.0573 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9147 - val_loss: 7.0003 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6175
#
# Epoch 00021: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-21_loss-4.4540_val_loss-7.0003.h5
# Epoch 22/70
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 4.3924 - pool1_GAP_substract_loss: 0.0813 - pool2_GAP_substract_loss: 0.0576 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8895 - val_loss: 6.4162 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0707
#
# Epoch 00022: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-22_loss-4.3922_val_loss-6.4162.h5
# Epoch 23/70
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 813s 813ms/step - loss: 4.3361 - pool1_GAP_substract_loss: 0.0798 - pool2_GAP_substract_loss: 0.0571 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8722 - val_loss: 6.6448 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3357
#
# Epoch 00023: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-23_loss-4.3364_val_loss-6.6448.h5
# Epoch 24/70
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 811s 811ms/step - loss: 4.2557 - pool1_GAP_substract_loss: 0.0782 - pool2_GAP_substract_loss: 0.0562 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8306 - val_loss: 6.8231 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5502
#
# Epoch 00024: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-24_loss-4.2551_val_loss-6.8231.h5
# Epoch 25/70
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 811s 811ms/step - loss: 4.2229 - pool1_GAP_substract_loss: 0.0780 - pool2_GAP_substract_loss: 0.0561 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8337 - val_loss: 6.1325 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8947
#
# Epoch 00025: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-25_loss-4.2231_val_loss-6.1325.h5
# Epoch 26/70
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 4.2008 - pool1_GAP_substract_loss: 0.0787 - pool2_GAP_substract_loss: 0.0565 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8452 - val_loss: 6.1764 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9730
#
# Epoch 00026: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-26_loss-4.2010_val_loss-6.1764.h5
# Epoch 27/70
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 811s 811ms/step - loss: 4.1013 - pool1_GAP_substract_loss: 0.0769 - pool2_GAP_substract_loss: 0.0562 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7821 - val_loss: 6.2656 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0963
# Epoch 00027: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-27_loss-4.1016_val_loss-6.2656.h5
# Epoch 28/70
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 4.1277 - pool1_GAP_substract_loss: 0.0772 - pool2_GAP_substract_loss: 0.0551 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8425 - val_loss: 6.5172 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3801
#
# Epoch 00028: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-28_loss-4.1282_val_loss-6.5172.h5
# Epoch 29/70
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 4.0615 - pool1_GAP_substract_loss: 0.0774 - pool2_GAP_substract_loss: 0.0556 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8078 - val_loss: 6.0044 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8992
#
# Epoch 00029: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-29_loss-4.0615_val_loss-6.0044.h5
# Epoch 30/70
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 4.0179 - pool1_GAP_substract_loss: 0.0777 - pool2_GAP_substract_loss: 0.0556 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7956 - val_loss: 6.5733 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4998
#
# Epoch 00030: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-30_loss-4.0179_val_loss-6.5733.h5
# Epoch 31/70
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 3.9577 - pool1_GAP_substract_loss: 0.0762 - pool2_GAP_substract_loss: 0.0549 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7690 - val_loss: 6.8675 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8252
#
# Epoch 00031: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-31_loss-3.9574_val_loss-6.8675.h5
# Epoch 32/70
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 3.9400 - pool1_GAP_substract_loss: 0.0755 - pool2_GAP_substract_loss: 0.0551 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7826 - val_loss: 5.9173 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9054
#
# Epoch 00032: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-32_loss-3.9400_val_loss-5.9173.h5
# Epoch 33/70
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 3.8799 - pool1_GAP_substract_loss: 0.0765 - pool2_GAP_substract_loss: 0.0550 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7516 - val_loss: 5.8878 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9057
#
# Epoch 00033: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-33_loss-3.8795_val_loss-5.8878.h5
# Epoch 34/70
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 3.8279 - pool1_GAP_substract_loss: 0.0744 - pool2_GAP_substract_loss: 0.0542 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7320 - val_loss: 5.8560 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9031
#
# Epoch 00034: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-34_loss-3.8279_val_loss-5.8560.h5
# Epoch 35/70
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 3.8489 - pool1_GAP_substract_loss: 0.0745 - pool2_GAP_substract_loss: 0.0542 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7814 - val_loss: 6.0108 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0858
#
# Epoch 00035: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-35_loss-3.8491_val_loss-6.0108.h5
# Epoch 36/70
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 3.7691 - pool1_GAP_substract_loss: 0.0750 - pool2_GAP_substract_loss: 0.0543 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7290 - val_loss: 6.2455 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3482
#
# Epoch 00036: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-36_loss-3.7690_val_loss-6.2455.h5
# Epoch 37/70
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 3.7855 - pool1_GAP_substract_loss: 0.0767 - pool2_GAP_substract_loss: 0.0556 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7694 - val_loss: 6.3586 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4879
#
# Epoch 00037: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-37_loss-3.7853_val_loss-6.3586.h5
# Epoch 38/70
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 3.6694 - pool1_GAP_substract_loss: 0.0746 - pool2_GAP_substract_loss: 0.0554 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6824 - val_loss: 6.4982 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6543
#
# Epoch 00038: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-38_loss-3.6693_val_loss-6.4982.h5
# Epoch 39/70
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 3.7004 - pool1_GAP_substract_loss: 0.0750 - pool2_GAP_substract_loss: 0.0551 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7398 - val_loss: 6.0695 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2517
#
# Epoch 00039: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-39_loss-3.7005_val_loss-6.0695.h5
# Epoch 40/70
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 3.5654 - pool1_GAP_substract_loss: 0.0750 - pool2_GAP_substract_loss: 0.0548 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6314 - val_loss: 5.8648 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0735
#
# Epoch 00040: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-40_loss-3.5652_val_loss-5.8648.h5
# Epoch 41/70
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 3.5668 - pool1_GAP_substract_loss: 0.0752 - pool2_GAP_substract_loss: 0.0551 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6579 - val_loss: 5.7325 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9663
#
# Epoch 00041: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-41_loss-3.5666_val_loss-5.7325.h5
# Epoch 42/70
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 3.5561 - pool1_GAP_substract_loss: 0.0742 - pool2_GAP_substract_loss: 0.0541 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6741 - val_loss: 6.1941 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4523
#
# Epoch 00042: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-42_loss-3.5563_val_loss-6.1941.h5
# Epoch 43/70
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 3.5216 - pool1_GAP_substract_loss: 0.0746 - pool2_GAP_substract_loss: 0.0541 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6634 - val_loss: 6.0318 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3144
#
# Epoch 00043: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-43_loss-3.5219_val_loss-6.0318.h5
# Epoch 44/70
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 3.4872 - pool1_GAP_substract_loss: 0.0747 - pool2_GAP_substract_loss: 0.0544 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6526 - val_loss: 5.5435 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8498
#
# Epoch 00044: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-44_loss-3.4869_val_loss-5.5435.h5
# Epoch 45/70
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 3.4264 - pool1_GAP_substract_loss: 0.0736 - pool2_GAP_substract_loss: 0.0541 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6168 - val_loss: 6.3269 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6566
#
# Epoch 00045: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-45_loss-3.4262_val_loss-6.3269.h5
# Epoch 46/70
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 3.4386 - pool1_GAP_substract_loss: 0.0737 - pool2_GAP_substract_loss: 0.0544 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6516 - val_loss: 5.7455 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0976
#
# Epoch 00046: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-46_loss-3.4385_val_loss-5.7455.h5
# Epoch 47/70
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 810s 810ms/step - loss: 3.3997 - pool1_GAP_substract_loss: 0.0742 - pool2_GAP_substract_loss: 0.0539 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6350 - val_loss: 5.4775 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8521
#
# Epoch 00047: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-47_loss-3.3997_val_loss-5.4775.h5
# Epoch 48/70
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 810s 810ms/step - loss: 3.3821 - pool1_GAP_substract_loss: 0.0736 - pool2_GAP_substract_loss: 0.0542 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6398 - val_loss: 5.7503 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1459
#
# Epoch 00048: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-48_loss-3.3823_val_loss-5.7503.h5
# Epoch 49/70
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 811s 811ms/step - loss: 3.3420 - pool1_GAP_substract_loss: 0.0734 - pool2_GAP_substract_loss: 0.0533 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6220 - val_loss: 5.4514 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8686
#
# Epoch 00049: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-49_loss-3.3421_val_loss-5.4514.h5
# Epoch 50/70
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 3.3049 - pool1_GAP_substract_loss: 0.0717 - pool2_GAP_substract_loss: 0.0526 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6087 - val_loss: 5.7271 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1655
#
# Epoch 00050: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-50_loss-3.3047_val_loss-5.7271.h5
# Epoch 51/70
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 811s 811ms/step - loss: 3.1017 - pool1_GAP_substract_loss: 0.0725 - pool2_GAP_substract_loss: 0.0522 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4171 - val_loss: 5.4023 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8437
#
# Epoch 00051: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-51_loss-3.1015_val_loss-5.4023.h5
# Epoch 52/70
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 810s 810ms/step - loss: 3.0723 - pool1_GAP_substract_loss: 0.0712 - pool2_GAP_substract_loss: 0.0513 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3928 - val_loss: 5.5722 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0163
#
# Epoch 00052: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-52_loss-3.0725_val_loss-5.5722.h5
# Epoch 53/70
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 810s 810ms/step - loss: 3.0484 - pool1_GAP_substract_loss: 0.0720 - pool2_GAP_substract_loss: 0.0520 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3702 - val_loss: 5.4661 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9130
#
# Epoch 00053: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-53_loss-3.0486_val_loss-5.4661.h5
# Epoch 54/70
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 3.0302 - pool1_GAP_substract_loss: 0.0730 - pool2_GAP_substract_loss: 0.0526 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3531 - val_loss: 5.4426 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8922
# Epoch 00054: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-54_loss-3.0300_val_loss-5.4426.h5
# Epoch 55/70
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 3.0050 - pool1_GAP_substract_loss: 0.0710 - pool2_GAP_substract_loss: 0.0517 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3334 - val_loss: 5.4161 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8685
#
# Epoch 00055: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-55_loss-3.0053_val_loss-5.4161.h5
# Epoch 56/70
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 3.0119 - pool1_GAP_substract_loss: 0.0703 - pool2_GAP_substract_loss: 0.0513 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3442 - val_loss: 5.4809 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9360
#
# Epoch 00056: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-56_loss-3.0120_val_loss-5.4809.h5
# Epoch 57/70
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 2.9947 - pool1_GAP_substract_loss: 0.0698 - pool2_GAP_substract_loss: 0.0513 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3303 - val_loss: 5.6544 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1123
#
# Epoch 00057: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-57_loss-2.9946_val_loss-5.6544.h5
# Epoch 58/70
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 2.9907 - pool1_GAP_substract_loss: 0.0719 - pool2_GAP_substract_loss: 0.0525 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3258 - val_loss: 5.5465 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0071
#
# Epoch 00058: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-58_loss-2.9906_val_loss-5.5465.h5
# Epoch 59/70
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 2.9788 - pool1_GAP_substract_loss: 0.0698 - pool2_GAP_substract_loss: 0.0512 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3199 - val_loss: 5.5223 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9856
#
# Epoch 00059: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-59_loss-2.9787_val_loss-5.5223.h5
# Epoch 60/70
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 2.9853 - pool1_GAP_substract_loss: 0.0687 - pool2_GAP_substract_loss: 0.0507 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3308 - val_loss: 5.5262 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9922
#
# Epoch 00060: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-60_loss-2.9858_val_loss-5.5262.h5
# Epoch 61/70
#
# Epoch 00061: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 2.9615 - pool1_GAP_substract_loss: 0.0704 - pool2_GAP_substract_loss: 0.0515 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3059 - val_loss: 5.5563 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0227
#
# Epoch 00061: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-61_loss-2.9616_val_loss-5.5563.h5
# Epoch 62/70
#
# Epoch 00062: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 2.9681 - pool1_GAP_substract_loss: 0.0708 - pool2_GAP_substract_loss: 0.0518 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3121 - val_loss: 5.5608 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0274
#
# Epoch 00062: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-62_loss-2.9678_val_loss-5.5608.h5
# Epoch 63/70
#
# Epoch 00063: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 2.9311 - pool1_GAP_substract_loss: 0.0707 - pool2_GAP_substract_loss: 0.0512 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2761 - val_loss: 5.6001 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0670
#
# Epoch 00063: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-63_loss-2.9308_val_loss-5.6001.h5
# Epoch 64/70
#
# Epoch 00064: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 2.9382 - pool1_GAP_substract_loss: 0.0694 - pool2_GAP_substract_loss: 0.0511 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2849 - val_loss: 5.5527 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0199
#
# Epoch 00064: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-64_loss-2.9385_val_loss-5.5527.h5
# Epoch 65/70
#
# Epoch 00065: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 2.9279 - pool1_GAP_substract_loss: 0.0704 - pool2_GAP_substract_loss: 0.0518 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2732 - val_loss: 5.5723 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0397
#
# Epoch 00065: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-65_loss-2.9276_val_loss-5.5723.h5
# Epoch 66/70
#
# Epoch 00066: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 2.9523 - pool1_GAP_substract_loss: 0.0699 - pool2_GAP_substract_loss: 0.0513 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2988 - val_loss: 5.5483 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0160
#
# Epoch 00066: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-66_loss-2.9525_val_loss-5.5483.h5
# Epoch 67/70
#
# Epoch 00067: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 2.9517 - pool1_GAP_substract_loss: 0.0704 - pool2_GAP_substract_loss: 0.0515 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2978 - val_loss: 5.5401 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0081
#
# Epoch 00067: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-67_loss-2.9514_val_loss-5.5401.h5
# Epoch 68/70
#
# Epoch 00068: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 2.9442 - pool1_GAP_substract_loss: 0.0694 - pool2_GAP_substract_loss: 0.0509 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2923 - val_loss: 5.5763 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0445
#
# Epoch 00068: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-68_loss-2.9438_val_loss-5.5763.h5
# Epoch 69/70
#
# Epoch 00069: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 813s 813ms/step - loss: 2.9335 - pool1_GAP_substract_loss: 0.0701 - pool2_GAP_substract_loss: 0.0517 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2803 - val_loss: 5.5448 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0133
#
# Epoch 00069: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-69_loss-2.9339_val_loss-5.5448.h5
# Epoch 70/70
#
# Epoch 00070: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 2.9607 - pool1_GAP_substract_loss: 0.0687 - pool2_GAP_substract_loss: 0.0504 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3105 - val_loss: 5.5735 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0423
#
# Epoch 00070: saving model to ../trained_weights/SIM10K_to_City_resize_400_800/MMD_pool1pool2_weight1/epoch-70_loss-2.9607_val_loss-5.5735.h5

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()
# Out:
# Image: ../../datasets/SIM10K/JPEGImages/3390000

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
# Out:
# Image: ../../datasets/SIM10K/JPEGImages/3388484
#
# Ground truth boxes:
#
# [[  1 715 163 794 188]
#  [  1 364 184 379 198]
#  [  1 326 191 346 203]
#  [  1 303 171 333 195]
#  [  1 339 186 354 196]
#  [  1 344 182 361 194]
#  [  1 397 173 489 208]
#  [  1 487 180 515 196]
#  [  1 677 166 761 191]
#  [  1 290 190 327 209]
#  [  1 376 176 390 187]
#  [  1  17 205  95 227]
#  [  1 370 185 390 200]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4c88a6df60d1> in <module>()
#      47 # 5: Convert the predictions for the original image.
#      48
# ---> 49 y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)
#      50
#      51 np.set_printoptions(precision=2, suppress=True, linewidth=90)
#
# /domain_adaptation_object_detection/LLFDA_IJCAI2019/data_generator/object_detection_2d_misc_utils.py in apply_inverse_transforms(y_pred_decoded, inverse_transforms)
#      56                 for inverter in inverse_transforms[i]:
#      57                     if not (inverter is None):
# ---> 58                         y_pred_decoded_inv[i] = inverter(y_pred_decoded_inv[i])
#      59
#      60     elif isinstance(y_pred_decoded, np.ndarray):
#
# TypeError: 'list' object is not callable
