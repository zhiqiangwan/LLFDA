# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese_align_high_layers import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator_align_high_layers import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [0.0, 0.000005] + [1.0]

# 'City_to_foggy0_01_resize_600_1200' # 'City_to_foggy0_02_resize_600_1200'  # 'SIM10K_to_VOC07'
# 'SIM10K'  # 'Cityscapes_foggy_beta_0_01'  #  'City_to_foggy0_02_resize_400_800'
# 'SIM10K_to_VOC07_resize_400_800'# 'SIM10K_to_City_resize_400_800'
DatasetName = 'City_to_foggy0_01_resize_400_800' # 'SIM10K_to_VOC12_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName + '_worker2'
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'contrastive_loss1': ssd_loss.compute_distance_loss_source_only,
                                             'contrastive_loss2': ssd_loss.compute_distance_loss,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'contrastive_loss1': loss_weights[0],
                                'contrastive_loss2': loss_weights[1],
                                'predictions': loss_weights[2]})    

else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 2966/2966 [00:00<00:00, 5049.77it/s]
# Loading source image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 12225.50it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 12313.90it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 2966/2966 [00:00<00:00, 6892.41it/s]
# Loading source labels: 100%|██████████| 493/493 [00:00<00:00, 5002.13it/s]
# Loading source image IDs: 100%|██████████| 493/493 [00:00<00:00, 11529.75it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 493/493 [00:00<00:00, 8087.55it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  2966
# Number of images in the validation dataset:	   493

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 50:
#         return 0.001
#     elif epoch < 60:
#         return 0.0001
#     else:
#         return 0.00001

# Define model callbacks.
checkpoint_path = '../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1'
# checkpoint_path = '../trained_weights/current/ssd_augm_beta_0_01_source_only'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'conv2_1_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 100 #  120
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 864s 864ms/step - loss: 9.6854 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 14908.9034 - predictions_loss: 6.0741 - val_loss: 8.8468 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 5.3264
#
# Epoch 00001: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-01_loss-9.6854_val_loss-8.8468.h5
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 8.1790 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 4603.8246 - predictions_loss: 4.6516 - val_loss: 8.3403 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.8519
#
# Epoch 00002: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-02_loss-8.1790_val_loss-8.3403.h5
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 7.9087 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 3610.3978 - predictions_loss: 4.4327 - val_loss: 8.9140 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 5.4868
#
# Epoch 00003: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-03_loss-7.9087_val_loss-8.9140.h5
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 7.4673 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 2941.9808 - predictions_loss: 4.0558 - val_loss: 7.8952 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5289
#
# Epoch 00004: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-04_loss-7.4673_val_loss-7.8952.h5
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 7.2152 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 2627.2374 - predictions_loss: 3.8656 - val_loss: 7.7373 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.4307
#
# Epoch 00005: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-05_loss-7.2152_val_loss-7.7373.h5
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 7.0331 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 2347.4042 - predictions_loss: 3.7439 - val_loss: 7.5375 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2891
#
# Epoch 00006: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-06_loss-7.0331_val_loss-7.5375.h5
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 6.8527 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 2223.9576 - predictions_loss: 3.6218 - val_loss: 7.5014 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3102
#
# Epoch 00007: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-07_loss-6.8527_val_loss-7.5014.h5
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 6.7263 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 2100.7167 - predictions_loss: 3.5527 - val_loss: 7.4086 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2736
#
# Epoch 00008: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-08_loss-6.7263_val_loss-7.4086.h5
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 6.6193 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 2053.5904 - predictions_loss: 3.5014 - val_loss: 7.4016 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3211
#
# Epoch 00009: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-09_loss-6.6193_val_loss-7.4016.h5
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 6.4513 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1912.3128 - predictions_loss: 3.3883 - val_loss: 6.9606 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9339
#
# Epoch 00010: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-10_loss-6.4513_val_loss-6.9606.h5
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 6.3580 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1829.4446 - predictions_loss: 3.3486 - val_loss: 7.0204 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0465
#
# Epoch 00011: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-11_loss-6.3580_val_loss-7.0204.h5
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 6.2712 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1758.1438 - predictions_loss: 3.3142 - val_loss: 7.0015 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0789
#
# Epoch 00012: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-12_loss-6.2712_val_loss-7.0015.h5
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 6.1490 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1721.8053 - predictions_loss: 3.2430 - val_loss: 6.8625 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9901
#
# Epoch 00013: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-13_loss-6.1490_val_loss-6.8625.h5
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 6.0776 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1710.8382 - predictions_loss: 3.2214 - val_loss: 6.8375 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0143
#
# Epoch 00014: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-14_loss-6.0776_val_loss-6.8375.h5
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 5.9897 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1626.4998 - predictions_loss: 3.1826 - val_loss: 6.7033 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9284
#
# Epoch 00015: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-15_loss-5.9897_val_loss-6.7033.h5
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 5.8823 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1545.3243 - predictions_loss: 3.1232 - val_loss: 6.7143 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9865
#
# Epoch 00016: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-16_loss-5.8823_val_loss-6.7143.h5
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 5.8034 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1588.9557 - predictions_loss: 3.0907 - val_loss: 6.6559 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9742
#
# Epoch 00017: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-17_loss-5.8034_val_loss-6.6559.h5
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 5.7470 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1546.4756 - predictions_loss: 3.0801 - val_loss: 6.5359 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8991
#
# Epoch 00018: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-18_loss-5.7470_val_loss-6.5359.h5
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 5.6470 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1486.2772 - predictions_loss: 3.0249 - val_loss: 6.4199 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8271
#
# Epoch 00019: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-19_loss-5.6470_val_loss-6.4199.h5
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 5.6196 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1451.9520 - predictions_loss: 3.0412 - val_loss: 6.3933 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8435
#
# Epoch 00020: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-20_loss-5.6196_val_loss-6.3933.h5
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 5.5325 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1421.8866 - predictions_loss: 2.9967 - val_loss: 6.3762 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8687
#
# Epoch 00021: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-21_loss-5.5325_val_loss-6.3762.h5
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 5.4606 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1327.5205 - predictions_loss: 2.9670 - val_loss: 6.2836 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8173
#
# Epoch 00022: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-22_loss-5.4606_val_loss-6.2836.h5
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 5.3860 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1364.0291 - predictions_loss: 2.9332 - val_loss: 6.3431 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9171
#
# Epoch 00023: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-23_loss-5.3860_val_loss-6.3431.h5
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 5.3294 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1338.5876 - predictions_loss: 2.9165 - val_loss: 6.1894 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8028
#
# Epoch 00024: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-24_loss-5.3294_val_loss-6.1894.h5
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 5.2428 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1307.9733 - predictions_loss: 2.8690 - val_loss: 6.2151 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8672
#
# Epoch 00025: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-25_loss-5.2428_val_loss-6.2151.h5
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 5.2224 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1294.4732 - predictions_loss: 2.8870 - val_loss: 6.0589 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7487
#
# Epoch 00026: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-26_loss-5.2224_val_loss-6.0589.h5
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 5.1801 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1239.1045 - predictions_loss: 2.8821 - val_loss: 6.0426 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7691
#
# Epoch 00027: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-27_loss-5.1801_val_loss-6.0426.h5
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 5.0950 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1264.8089 - predictions_loss: 2.8333 - val_loss: 6.1320 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8945
#
# Epoch 00028: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-28_loss-5.0950_val_loss-6.1320.h5
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 5.0756 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1206.6464 - predictions_loss: 2.8497 - val_loss: 6.1305 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9283
#
# Epoch 00029: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-29_loss-5.0756_val_loss-6.1305.h5
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 5.0187 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1182.5464 - predictions_loss: 2.8279 - val_loss: 5.9182 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7505
#
# Epoch 00030: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-30_loss-5.0187_val_loss-5.9182.h5
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 4.9570 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1156.0094 - predictions_loss: 2.8005 - val_loss: 6.0413 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9074
# Epoch 00031: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-31_loss-4.9570_val_loss-6.0413.h5
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 853s 853ms/step - loss: 4.9078 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1144.8358 - predictions_loss: 2.7848 - val_loss: 5.8483 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7476
#
# Epoch 00032: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-32_loss-4.9078_val_loss-5.8483.h5
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 4.8313 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1124.9421 - predictions_loss: 2.7412 - val_loss: 6.0117 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9433
#
# Epoch 00033: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-33_loss-4.8313_val_loss-6.0117.h5
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 4.8269 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1131.1145 - predictions_loss: 2.7687 - val_loss: 5.7410 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7043
#
# Epoch 00034: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-34_loss-4.8269_val_loss-5.7410.h5
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 853s 853ms/step - loss: 4.7793 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1116.8177 - predictions_loss: 2.7526 - val_loss: 5.8301 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8244
#
# Epoch 00035: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-35_loss-4.7793_val_loss-5.8301.h5
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.7081 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1105.3681 - predictions_loss: 2.7118 - val_loss: 5.7154 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7396
#
# Epoch 00036: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-36_loss-4.7081_val_loss-5.7154.h5
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.6875 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1067.9686 - predictions_loss: 2.7213 - val_loss: 5.6161 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.6700
#
# Epoch 00037: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-37_loss-4.6875_val_loss-5.6161.h5
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 4.6672 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1060.5603 - predictions_loss: 2.7303 - val_loss: 5.6527 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7354
#
# Epoch 00038: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-38_loss-4.6672_val_loss-5.6527.h5
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 4.6067 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1071.5836 - predictions_loss: 2.6982 - val_loss: 5.7900 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9009
#
# Epoch 00039: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-39_loss-4.6067_val_loss-5.7900.h5
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 4.5934 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1026.6941 - predictions_loss: 2.7129 - val_loss: 5.6341 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7724
#
# Epoch 00040: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-40_loss-4.5934_val_loss-5.6341.h5
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.5419 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1074.2812 - predictions_loss: 2.6884 - val_loss: 5.5772 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7427
#
# Epoch 00041: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-41_loss-4.5419_val_loss-5.5772.h5
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.4763 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1047.8698 - predictions_loss: 2.6498 - val_loss: 5.5156 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7075
#
# Epoch 00042: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-42_loss-4.4763_val_loss-5.5156.h5
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 4.4447 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1080.7770 - predictions_loss: 2.6440 - val_loss: 5.6365 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8543
#
# Epoch 00043: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-43_loss-4.4447_val_loss-5.6365.h5
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 4.4100 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1010.6237 - predictions_loss: 2.6354 - val_loss: 5.6336 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8768
#
# Epoch 00044: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-44_loss-4.4100_val_loss-5.6336.h5
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 4.4014 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1024.6858 - predictions_loss: 2.6517 - val_loss: 5.6775 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9452
#
# Epoch 00045: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-45_loss-4.4014_val_loss-5.6775.h5
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.3651 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1020.6501 - predictions_loss: 2.6395 - val_loss: 5.6621 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9536
#
# Epoch 00046: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-46_loss-4.3651_val_loss-5.6621.h5
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.3269 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 985.5552 - predictions_loss: 2.6253 - val_loss: 5.5485 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8636
#
# Epoch 00047: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-47_loss-4.3269_val_loss-5.5485.h5
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.2642 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 980.3209 - predictions_loss: 2.5861 - val_loss: 5.7283 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0667
#
# Epoch 00048: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-48_loss-4.2642_val_loss-5.7283.h5
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 4.2660 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 1003.0694 - predictions_loss: 2.6106 - val_loss: 5.7677 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1286
#
# Epoch 00049: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-49_loss-4.2660_val_loss-5.7677.h5
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.2042 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 963.2581 - predictions_loss: 2.5713 - val_loss: 5.5783 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.9613
#
# Epoch 00050: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-50_loss-4.2042_val_loss-5.5783.h5
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 4.0197 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 887.4688 - predictions_loss: 2.3997 - val_loss: 5.2558 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.6415
#
# Epoch 00051: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-51_loss-4.0197_val_loss-5.2558.h5
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.0066 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 869.9769 - predictions_loss: 2.3894 - val_loss: 5.2929 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.6814
#
# Epoch 00052: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-52_loss-4.0066_val_loss-5.2929.h5
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 3.9699 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 872.3484 - predictions_loss: 2.3554 - val_loss: 5.2798 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.6711
#
# Epoch 00053: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-53_loss-3.9699_val_loss-5.2798.h5
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.9564 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 872.3579 - predictions_loss: 2.3446 - val_loss: 5.2970 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.6909
#
# Epoch 00054: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-54_loss-3.9564_val_loss-5.2970.h5
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.9344 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 860.5641 - predictions_loss: 2.3254 - val_loss: 5.2900 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.6866
#
# Epoch 00055: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-55_loss-3.9344_val_loss-5.2900.h5
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 3.9302 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 834.5675 - predictions_loss: 2.3240 - val_loss: 5.3137 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7131
#
# Epoch 00056: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-56_loss-3.9302_val_loss-5.3137.h5
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.9253 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 875.1335 - predictions_loss: 2.3216 - val_loss: 5.3220 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7241
#
# Epoch 00057: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-57_loss-3.9253_val_loss-5.3220.h5
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.8982 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 861.3337 - predictions_loss: 2.2973 - val_loss: 5.3658 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7705
#
# Epoch 00058: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-58_loss-3.8982_val_loss-5.3658.h5
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.9218 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 904.0179 - predictions_loss: 2.3234 - val_loss: 5.3863 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7937
#
# Epoch 00059: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-59_loss-3.9218_val_loss-5.3863.h5
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.9187 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 869.4004 - predictions_loss: 2.3231 - val_loss: 5.2782 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.6883
#
# Epoch 00060: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-60_loss-3.9187_val_loss-5.2782.h5
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 3.8860 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 857.4744 - predictions_loss: 2.2931 - val_loss: 5.3879 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8007
#
# Epoch 00061: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-61_loss-3.8860_val_loss-5.3879.h5
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.8659 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 872.8032 - predictions_loss: 2.2757 - val_loss: 5.3447 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7602
# Epoch 00062: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-62_loss-3.8659_val_loss-5.3447.h5
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.8802 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 884.5580 - predictions_loss: 2.2926 - val_loss: 5.3329 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7509
#
# Epoch 00063: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-63_loss-3.8802_val_loss-5.3329.h5
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.8581 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 866.8541 - predictions_loss: 2.2732 - val_loss: 5.4182 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8390
#
# Epoch 00064: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-64_loss-3.8581_val_loss-5.4182.h5
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.8520 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 867.0921 - predictions_loss: 2.2697 - val_loss: 5.3404 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7638
#
# Epoch 00065: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-65_loss-3.8520_val_loss-5.3404.h5
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 3.8555 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 875.7792 - predictions_loss: 2.2758 - val_loss: 5.3619 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7879
#
# Epoch 00066: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-66_loss-3.8555_val_loss-5.3619.h5
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 3.8434 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 858.3752 - predictions_loss: 2.2665 - val_loss: 5.3561 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7848
#
# Epoch 00067: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-67_loss-3.8434_val_loss-5.3561.h5
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 3.8700 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 878.1662 - predictions_loss: 2.2956 - val_loss: 5.3492 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7805
#
# Epoch 00068: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-68_loss-3.8700_val_loss-5.3492.h5
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.8625 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 852.7811 - predictions_loss: 2.2908 - val_loss: 5.4089 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8428
#
# Epoch 00069: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-69_loss-3.8625_val_loss-5.4089.h5
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 3.8312 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 875.5198 - predictions_loss: 2.2620 - val_loss: 5.3729 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8093
#
# Epoch 00070: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-70_loss-3.8312_val_loss-5.3729.h5
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.8114 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 875.2938 - predictions_loss: 2.2436 - val_loss: 5.3901 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8268
#
# Epoch 00071: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-71_loss-3.8114_val_loss-5.3901.h5
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 853s 853ms/step - loss: 3.8081 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 874.1999 - predictions_loss: 2.2406 - val_loss: 5.4020 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8390
#
# Epoch 00072: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-72_loss-3.8081_val_loss-5.4020.h5
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.8266 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 882.9937 - predictions_loss: 2.2593 - val_loss: 5.3796 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8169
#
# Epoch 00073: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-73_loss-3.8266_val_loss-5.3796.h5
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.8058 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 877.7852 - predictions_loss: 2.2388 - val_loss: 5.3932 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8307
#
# Epoch 00074: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-74_loss-3.8058_val_loss-5.3932.h5
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.8246 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 885.7000 - predictions_loss: 2.2579 - val_loss: 5.4007 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8385
#
# Epoch 00075: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-75_loss-3.8246_val_loss-5.4007.h5
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 3.8003 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 859.8045 - predictions_loss: 2.2339 - val_loss: 5.3637 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8017
#
# Epoch 00076: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-76_loss-3.8003_val_loss-5.3637.h5
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 849s 849ms/step - loss: 3.7817 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 890.7208 - predictions_loss: 2.2154 - val_loss: 5.3541 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7924
#
# Epoch 00077: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-77_loss-3.7817_val_loss-5.3541.h5
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.7713 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 862.6749 - predictions_loss: 2.2054 - val_loss: 5.3748 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8134
#
# Epoch 00078: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-78_loss-3.7713_val_loss-5.3748.h5
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 3.7701 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 862.0932 - predictions_loss: 2.2045 - val_loss: 5.4034 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8423
#
# Epoch 00079: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-79_loss-3.7701_val_loss-5.4034.h5
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 3.7981 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 875.4692 - predictions_loss: 2.2326 - val_loss: 5.3829 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8220
#
# Epoch 00080: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-80_loss-3.7981_val_loss-5.3829.h5
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.7963 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 886.6256 - predictions_loss: 2.2311 - val_loss: 5.3946 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8339
#
# Epoch 00081: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-81_loss-3.7963_val_loss-5.3946.h5
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 3.7926 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 883.8585 - predictions_loss: 2.2276 - val_loss: 5.3480 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.7876
#
# Epoch 00082: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-82_loss-3.7926_val_loss-5.3480.h5
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.7878 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 885.3564 - predictions_loss: 2.2231 - val_loss: 5.3769 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8167
#
# Epoch 00083: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-83_loss-3.7878_val_loss-5.3769.h5
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 3.7682 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 880.3665 - predictions_loss: 2.2038 - val_loss: 5.3769 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8171
#
# Epoch 00084: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-84_loss-3.7682_val_loss-5.3769.h5
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 3.8014 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 869.1393 - predictions_loss: 2.2373 - val_loss: 5.3738 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8142
#
# Epoch 00085: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-85_loss-3.8014_val_loss-5.3738.h5
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.7805 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 867.4401 - predictions_loss: 2.2167 - val_loss: 5.4287 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8693
#
# Epoch 00086: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-86_loss-3.7805_val_loss-5.4287.h5
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.7834 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 858.0031 - predictions_loss: 2.2199 - val_loss: 5.3883 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8292
#
# Epoch 00087: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-87_loss-3.7834_val_loss-5.3883.h5
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.7880 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 849.6468 - predictions_loss: 2.2248 - val_loss: 5.4007 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 3.8418
#
# Epoch 00088: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1/epoch-88_loss-3.7880_val_loss-5.4007.h5
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler setting learning rate to 1e-05.
#  885/1000 [=========================>....] - ETA: 1:34 - loss: 3.7967 - contrastive_loss1_loss: 0.0000e+00 - contrastive_loss2_loss: 881.7798 - predictions_loss: 2.2336
# ---------------------------------------------------
# KeyboardInterrupt Traceback (most recent call last)
# <ipython-input-6-d271462368e6> in <module>()
#       9                               validation_data=val_generator,
#      10                               validation_steps=ceil(val_dataset_size/batch_size),
# ---> 11                               initial_epoch=initial_epoch)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
