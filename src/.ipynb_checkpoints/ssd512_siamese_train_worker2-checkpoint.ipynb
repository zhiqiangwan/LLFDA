# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights =  [0.0, 0.0, 0.0] + [1.0]

# 'City_to_foggy0_01_resize_600_1200' # 'City_to_foggy0_02_resize_600_1200'  # 'SIM10K_to_VOC07'
# 'SIM10K_to_VOC07_resize_400_800'# 'City_to_foggy0_01_resize_400_800' # 'SIM10K_to_City_resize_400_800'
DatasetName = 'SIM10K_to_VOC12_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName #  + '_worker2'
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    
    
#     if Source_Only:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})
#     else:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 10000/10000 [00:02<00:00, 4692.77it/s]
# Loading source image IDs: 100%|██████████| 10000/10000 [00:00<00:00, 11139.73it/s]
# Loading target image IDs: 100%|██████████| 621/621 [00:00<00:00, 11631.44it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 10000/10000 [00:01<00:00, 6976.60it/s]
# Loading source labels: 100%|██████████| 608/608 [00:00<00:00, 3216.14it/s]
# Loading source image IDs: 100%|██████████| 608/608 [00:00<00:00, 4361.76it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 608/608 [00:00<00:00, 7677.09it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	 10000
# Number of images in the validation dataset:	   608

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 50:
#         return 0.001
#     elif epoch < 60:
#         return 0.0001
#     else:
#         return 0.00001

# Define model callbacks.
checkpoint_path = '../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/source_only_run2'
# checkpoint_path = '../trained_weights/current/ssd_augm_beta_0_01_source_only'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'source_only_run2_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 120
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/120
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 792s 792ms/step - loss: 11.1736 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 25965.5430 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 7.7471 - val_loss: 8.4490 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.1677
#
# Epoch 00001: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-01_loss-11.1719_val_loss-8.4490.h5
# Epoch 2/120
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 762s 762ms/step - loss: 7.3311 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 8484.4947 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.0220 - val_loss: 8.3657 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.1136
#
# Epoch 00002: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-02_loss-7.3305_val_loss-8.3657.h5
# Epoch 3/120
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 6.9941 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 7291.9165 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.7324 - val_loss: 8.1065 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.9086
#
# Epoch 00003: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-03_loss-6.9947_val_loss-8.1065.h5
# Epoch 4/120
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 761s 761ms/step - loss: 6.4262 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 5915.3737 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2258 - val_loss: 7.8234 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6794
#
# Epoch 00004: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-04_loss-6.4262_val_loss-7.8234.h5
# Epoch 5/120
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 769s 769ms/step - loss: 6.0042 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 4793.3830 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8631 - val_loss: 7.8562 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7659
#
# Epoch 00005: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-05_loss-6.0043_val_loss-7.8562.h5
# Epoch 6/120
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 768s 768ms/step - loss: 5.8474 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 4191.0741 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7622 - val_loss: 7.8825 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8439
#
# Epoch 00006: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-06_loss-5.8472_val_loss-7.8825.h5
# Epoch 7/120
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 5.6129 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 3708.5494 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5818 - val_loss: 7.6759 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6891
#
# Epoch 00007: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-07_loss-5.6132_val_loss-7.6759.h5
# Epoch 8/120
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 5.4864 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 3389.1413 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5078 - val_loss: 7.4346 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4979
#
# Epoch 00008: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-08_loss-5.4860_val_loss-7.4346.h5
# Epoch 9/120
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 5.3325 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 3140.8494 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4047 - val_loss: 7.4555 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5680
#
# Epoch 00009: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-09_loss-5.3320_val_loss-7.4555.h5
# Epoch 10/120
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 5.2153 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 2828.4450 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3379 - val_loss: 7.8495 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.0105
#
# Epoch 00010: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-10_loss-5.2147_val_loss-7.8495.h5
# Epoch 11/120
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 747s 747ms/step - loss: 5.0880 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 2653.9486 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2596 - val_loss: 7.3330 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5414
#
# Epoch 00011: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-11_loss-5.0886_val_loss-7.3330.h5
# Epoch 12/120
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 749s 749ms/step - loss: 4.9690 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 2454.4233 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1885 - val_loss: 7.4137 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6687
#
# Epoch 00012: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-12_loss-4.9690_val_loss-7.4137.h5
# Epoch 13/120
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 4.9131 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 2420.4287 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1788 - val_loss: 7.1977 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4981
#
# Epoch 00013: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-13_loss-4.9131_val_loss-7.1977.h5
# Epoch 14/120
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 4.8517 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 2220.2124 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1631 - val_loss: 7.1673 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5118
#
# Epoch 00014: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-14_loss-4.8520_val_loss-7.1673.h5
# Epoch 15/120
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 748s 748ms/step - loss: 4.7373 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 2151.5631 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0928 - val_loss: 7.0789 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4668
#
# Epoch 00015: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-15_loss-4.7370_val_loss-7.0789.h5
# Epoch 16/120
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 4.6783 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 2106.6719 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0769 - val_loss: 7.1283 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5588
#
# Epoch 00016: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-16_loss-4.6790_val_loss-7.1283.h5
# Epoch 17/120
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 4.6251 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1979.6744 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0666 - val_loss: 7.1334 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6053
#
# Epoch 00017: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-17_loss-4.6248_val_loss-7.1334.h5
# Epoch 18/120
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 4.4905 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1949.0517 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9731 - val_loss: 7.1394 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6526
#
# Epoch 00018: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-18_loss-4.4904_val_loss-7.1394.h5
# Epoch 19/120
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 745s 745ms/step - loss: 4.4376 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1924.2746 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9611 - val_loss: 6.8814 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4346
#
# Epoch 00019: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-19_loss-4.4375_val_loss-6.8814.h5
# Epoch 20/120
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 744s 744ms/step - loss: 4.4121 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1845.6038 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9756 - val_loss: 7.0468 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6389
#
# Epoch 00020: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-20_loss-4.4123_val_loss-7.0468.h5
# Epoch 21/120
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 748s 748ms/step - loss: 4.3310 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1729.8350 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9336 - val_loss: 7.0239 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6542
#
# Epoch 00021: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-21_loss-4.3307_val_loss-7.0239.h5
# Epoch 22/120
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 4.3012 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1634.9161 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9422 - val_loss: 6.8861 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5540
#
# Epoch 00022: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-22_loss-4.3009_val_loss-6.8861.h5
# Epoch 23/120
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 747s 747ms/step - loss: 4.2322 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1672.5989 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9103 - val_loss: 6.8101 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5147
#
# Epoch 00023: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-23_loss-4.2318_val_loss-6.8101.h5
# Epoch 24/120
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.1824 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1594.4131 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8971 - val_loss: 6.8279 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5689
#
# Epoch 00024: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-24_loss-4.1824_val_loss-6.8279.h5
# Epoch 25/120
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 4.0968 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1553.4341 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8479 - val_loss: 6.7677 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5443
#
# Epoch 00025: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-25_loss-4.0966_val_loss-6.7677.h5
# Epoch 26/120
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.0668 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1535.7227 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8528 - val_loss: 6.9306 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7414
#
# Epoch 00026: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-26_loss-4.0670_val_loss-6.9306.h5
# Epoch 27/120
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 758s 758ms/step - loss: 4.0512 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1528.4817 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8709 - val_loss: 6.4488 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2928
#
# Epoch 00027: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-27_loss-4.0516_val_loss-6.4488.h5
# Epoch 28/120
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 3.9378 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1391.9468 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7916 - val_loss: 6.7998 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6774
#
# Epoch 00028: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-28_loss-3.9380_val_loss-6.7998.h5
# Epoch 29/120
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 749s 749ms/step - loss: 3.9141 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1420.8880 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8009 - val_loss: 6.7246 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6348
#
# Epoch 00029: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-29_loss-3.9140_val_loss-6.7246.h5
# Epoch 30/120
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 747s 747ms/step - loss: 3.8712 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1359.1478 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7905 - val_loss: 6.6804 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6226
#
# Epoch 00030: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-30_loss-3.8712_val_loss-6.6804.h5
# Epoch 31/120
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 744s 744ms/step - loss: 3.8336 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1279.4562 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7853 - val_loss: 6.5167 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4902
#
# Epoch 00031: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-31_loss-3.8337_val_loss-6.5167.h5
# Epoch 32/120
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 747s 747ms/step - loss: 3.7659 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1354.2827 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7482 - val_loss: 6.6145 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6188
#
# Epoch 00032: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-32_loss-3.7660_val_loss-6.6145.h5
# Epoch 33/120
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 746s 746ms/step - loss: 3.7070 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1298.9196 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7201 - val_loss: 6.3360 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3708
#
# Epoch 00033: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-33_loss-3.7072_val_loss-6.3360.h5
# Epoch 34/120
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 749s 749ms/step - loss: 3.6519 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1306.4495 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6950 - val_loss: 6.7641 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8285
#
# Epoch 00034: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-34_loss-3.6517_val_loss-6.7641.h5
# Epoch 35/120
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 745s 745ms/step - loss: 3.6450 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1201.6148 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7177 - val_loss: 6.5942 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6871
#
# Epoch 00035: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-35_loss-3.6448_val_loss-6.5942.h5
# Epoch 36/120
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 745s 745ms/step - loss: 3.6735 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1222.9510 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7742 - val_loss: 6.2334 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3538
#
# Epoch 00036: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-36_loss-3.6736_val_loss-6.2334.h5
# Epoch 37/120
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 743s 743ms/step - loss: 3.5962 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1166.0050 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7246 - val_loss: 6.3524 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5004
#
# Epoch 00037: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-37_loss-3.5963_val_loss-6.3524.h5
# Epoch 38/120
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 740s 740ms/step - loss: 3.5656 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1221.6935 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7208 - val_loss: 6.2393 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4142
#
# Epoch 00038: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-38_loss-3.5662_val_loss-6.2393.h5
# Epoch 39/120
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 743s 743ms/step - loss: 3.5099 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1215.9906 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6920 - val_loss: 6.2938 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4952
#
# Epoch 00039: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-39_loss-3.5099_val_loss-6.2938.h5
# Epoch 40/120
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 749s 749ms/step - loss: 3.4930 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1189.9644 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7012 - val_loss: 6.4849 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7122
#
# Epoch 00040: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-40_loss-3.4931_val_loss-6.4849.h5
# Epoch 41/120
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 747s 747ms/step - loss: 3.4743 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1198.4731 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7079 - val_loss: 6.7196 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.9717
#
# Epoch 00041: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-41_loss-3.4741_val_loss-6.7196.h5
# Epoch 42/120
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 741s 741ms/step - loss: 3.4554 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1084.1563 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7145 - val_loss: 6.3903 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6669
#
# Epoch 00042: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-42_loss-3.4552_val_loss-6.3903.h5
# Epoch 43/120
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 739s 739ms/step - loss: 3.4384 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1152.9844 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7210 - val_loss: 6.3256 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6260
#
# Epoch 00043: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-43_loss-3.4383_val_loss-6.3256.h5
# Epoch 44/120
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 742s 742ms/step - loss: 3.3633 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1075.0453 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6700 - val_loss: 6.4862 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8104
#
# Epoch 00044: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-44_loss-3.3630_val_loss-6.4862.h5
# Epoch 45/120
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 745s 745ms/step - loss: 3.3138 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1047.6273 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6442 - val_loss: 6.0075 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3550
#
# Epoch 00045: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-45_loss-3.3138_val_loss-6.0075.h5
# Epoch 46/120
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 742s 742ms/step - loss: 3.2989 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1091.2460 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6526 - val_loss: 6.2434 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6139
#
# Epoch 00046: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-46_loss-3.2989_val_loss-6.2434.h5
# Epoch 47/120
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 749s 749ms/step - loss: 3.2672 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1080.2952 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6436 - val_loss: 6.1269 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5198
#
# Epoch 00047: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-47_loss-3.2665_val_loss-6.1269.h5
# Epoch 48/120
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 747s 747ms/step - loss: 3.2569 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 988.8422 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6560 - val_loss: 6.1661 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5808
#
# Epoch 00048: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-48_loss-3.2569_val_loss-6.1661.h5
# Epoch 49/120
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 758s 758ms/step - loss: 3.2274 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1068.7672 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6476 - val_loss: 6.3186 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7550
#
# Epoch 00049: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-49_loss-3.2275_val_loss-6.3186.h5
# Epoch 50/120
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 3.1594 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1030.8672 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6014 - val_loss: 6.3318 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7894
#
# Epoch 00050: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-50_loss-3.1591_val_loss-6.3318.h5
# Epoch 51/120
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.9807 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 1050.0775 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4346 - val_loss: 5.9166 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3771
#
# Epoch 00051: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-51_loss-2.9808_val_loss-5.9166.h5
# Epoch 52/120
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.9285 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 988.0651 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3854 - val_loss: 6.0201 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4833
#
# Epoch 00052: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-52_loss-2.9283_val_loss-6.0201.h5
# Epoch 53/120
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 749s 749ms/step - loss: 2.9142 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 982.3205 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3739 - val_loss: 5.9002 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3661
#
# Epoch 00053: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-53_loss-2.9138_val_loss-5.9002.h5
# Epoch 54/120
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.8805 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 954.4554 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3430 - val_loss: 6.0613 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5299
#
# Epoch 00054: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-54_loss-2.8807_val_loss-6.0613.h5
# Epoch 55/120
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 2.8673 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 977.0393 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3324 - val_loss: 5.9392 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4106
#
# Epoch 00055: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-55_loss-2.8676_val_loss-5.9392.h5
# Epoch 56/120
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.8696 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 981.3892 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3374 - val_loss: 5.9499 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4239
#
# Epoch 00056: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-56_loss-2.8696_val_loss-5.9499.h5
# Epoch 57/120
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 2.8285 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 988.2928 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2990 - val_loss: 5.8824 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3591
#
# Epoch 00057: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-57_loss-2.8287_val_loss-5.8824.h5
# Epoch 58/120
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 745s 745ms/step - loss: 2.8467 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 984.1652 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3199 - val_loss: 5.9610 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4405
#
# Epoch 00058: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-58_loss-2.8468_val_loss-5.9610.h5
# Epoch 59/120
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 745s 745ms/step - loss: 2.8423 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 965.8892 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3183 - val_loss: 5.9888 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4710
#
# Epoch 00059: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-59_loss-2.8422_val_loss-5.9888.h5
# Epoch 60/120
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 739s 739ms/step - loss: 2.8327 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 930.6615 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3116 - val_loss: 5.9926 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4775
#
# Epoch 00060: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-60_loss-2.8327_val_loss-5.9926.h5
# Epoch 61/120
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 740s 740ms/step - loss: 2.8231 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 952.7335 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3046 - val_loss: 6.0840 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5716
#
# Epoch 00061: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-61_loss-2.8235_val_loss-6.0840.h5
# Epoch 62/120
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 739s 739ms/step - loss: 2.8042 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 993.6331 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2882 - val_loss: 5.9902 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4805
#
# Epoch 00062: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-62_loss-2.8040_val_loss-5.9902.h5
# Epoch 63/120
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 739s 739ms/step - loss: 2.8034 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 973.9993 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2902 - val_loss: 6.0363 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5292
#
# Epoch 00063: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-63_loss-2.8035_val_loss-6.0363.h5
# Epoch 64/120
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 738s 738ms/step - loss: 2.8114 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 945.5979 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3010 - val_loss: 5.9711 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4668
#
# Epoch 00064: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-64_loss-2.8115_val_loss-5.9711.h5
# Epoch 65/120
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 739s 739ms/step - loss: 2.8025 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 942.1266 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2948 - val_loss: 6.0157 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5139
#
# Epoch 00065: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-65_loss-2.8025_val_loss-6.0157.h5
# Epoch 66/120
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 739s 739ms/step - loss: 2.7993 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 958.3913 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2941 - val_loss: 6.0461 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5470
#
# Epoch 00066: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-66_loss-2.7987_val_loss-6.0461.h5
# Epoch 67/120
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 740s 740ms/step - loss: 2.7951 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 985.6415 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2924 - val_loss: 6.0195 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5231
#
# Epoch 00067: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-67_loss-2.7954_val_loss-6.0195.h5
# Epoch 68/120
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 742s 742ms/step - loss: 2.7769 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 970.3862 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2770 - val_loss: 6.0582 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5644
#
# Epoch 00068: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-68_loss-2.7767_val_loss-6.0582.h5
# Epoch 69/120
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 739s 739ms/step - loss: 2.7649 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 958.7004 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2677 - val_loss: 6.0556 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5645
#
# Epoch 00069: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-69_loss-2.7645_val_loss-6.0556.h5
# Epoch 70/120
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 739s 739ms/step - loss: 2.7850 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 965.5109 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2904 - val_loss: 6.0233 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5349
#
# Epoch 00070: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-70_loss-2.7852_val_loss-6.0233.h5
# Epoch 71/120
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 741s 741ms/step - loss: 2.7657 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 957.0608 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2726 - val_loss: 5.9875 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4993
#
# Epoch 00071: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-71_loss-2.7656_val_loss-5.9875.h5
# Epoch 72/120
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 742s 742ms/step - loss: 2.7571 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 973.4429 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2642 - val_loss: 5.9646 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4767
#
# Epoch 00072: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-72_loss-2.7571_val_loss-5.9646.h5
# Epoch 73/120
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 741s 741ms/step - loss: 2.7716 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 936.7780 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2792 - val_loss: 5.9392 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4516
#
# Epoch 00073: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-73_loss-2.7720_val_loss-5.9392.h5
# Epoch 74/120
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 740s 740ms/step - loss: 2.7591 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 929.0587 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2670 - val_loss: 5.9808 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4934
#
# Epoch 00074: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-74_loss-2.7591_val_loss-5.9808.h5
# Epoch 75/120
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 741s 741ms/step - loss: 2.7562 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 952.7519 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2641 - val_loss: 5.9778 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4907
#
# ...
# Epoch 81/120
#
# Epoch 00081: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 747s 747ms/step - loss: 2.7573 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 937.1345 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2669 - val_loss: 6.0402 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5547
#
# Epoch 00081: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-81_loss-2.7572_val_loss-6.0402.h5
# Epoch 82/120
#
# Epoch 00082: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 746s 746ms/step - loss: 2.7563 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 950.2084 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2661 - val_loss: 5.9990 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5137
#
# Epoch 00082: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-82_loss-2.7564_val_loss-5.9990.h5
# Epoch 83/120
#
# Epoch 00083: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 749s 749ms/step - loss: 2.7441 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 922.1951 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2543 - val_loss: 6.0067 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5217
#
# Epoch 00083: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-83_loss-2.7442_val_loss-6.0067.h5
# Epoch 84/120
#
# Epoch 00084: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 748s 748ms/step - loss: 2.7588 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 928.8327 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2692 - val_loss: 6.0298 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5451
#
# Epoch 00084: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-84_loss-2.7588_val_loss-6.0298.h5
# Epoch 85/120
#
# Epoch 00085: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 2.7380 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 928.2595 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2488 - val_loss: 6.0218 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5373
#
# Epoch 00085: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-85_loss-2.7381_val_loss-6.0218.h5
# Epoch 86/120
#
# Epoch 00086: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.7581 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 931.1183 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2691 - val_loss: 6.0161 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5319
#
# Epoch 00086: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-86_loss-2.7580_val_loss-6.0161.h5
# Epoch 87/120
#
# Epoch 00087: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 758s 758ms/step - loss: 2.7712 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 934.9395 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2824 - val_loss: 5.9964 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5125
#
# Epoch 00087: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-87_loss-2.7709_val_loss-5.9964.h5
# Epoch 88/120
#
# Epoch 00088: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 758s 758ms/step - loss: 2.7432 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 946.1081 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2547 - val_loss: 6.0277 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5440
#
# Epoch 00088: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-88_loss-2.7431_val_loss-6.0277.h5
# Epoch 89/120
#
# Epoch 00089: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.7475 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 918.5682 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2593 - val_loss: 6.0085 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5251
#
# Epoch 00089: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-89_loss-2.7477_val_loss-6.0085.h5
# Epoch 90/120
#
# Epoch 00090: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 743s 743ms/step - loss: 2.7430 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 930.5038 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2551 - val_loss: 6.0355 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5524
#
# Epoch 00090: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-90_loss-2.7432_val_loss-6.0355.h5
# Epoch 91/120
#
# Epoch 00091: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 746s 746ms/step - loss: 2.7690 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 925.9996 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2813 - val_loss: 6.0233 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5404
#
# Epoch 00091: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-91_loss-2.7687_val_loss-6.0233.h5
# Epoch 92/120
#
# Epoch 00092: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 743s 743ms/step - loss: 2.7423 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 937.9164 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2549 - val_loss: 6.0174 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5348
#
# Epoch 00092: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-92_loss-2.7426_val_loss-6.0174.h5
# Epoch 93/120
#
# Epoch 00093: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 744s 744ms/step - loss: 2.7326 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 921.9152 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2454 - val_loss: 6.0312 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5488
#
# Epoch 00093: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-93_loss-2.7325_val_loss-6.0312.h5
# Epoch 94/120
#
# Epoch 00094: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 744s 744ms/step - loss: 2.7349 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 935.1364 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2480 - val_loss: 6.0552 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5731
#
# Epoch 00094: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-94_loss-2.7348_val_loss-6.0552.h5
# Epoch 95/120
#
# Epoch 00095: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 741s 741ms/step - loss: 2.7602 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 918.2605 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2737 - val_loss: 6.0418 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5599
#
# Epoch 00095: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-95_loss-2.7601_val_loss-6.0418.h5
# Epoch 96/120
#
# Epoch 00096: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 748s 748ms/step - loss: 2.7560 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 937.7107 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2696 - val_loss: 6.0414 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5598
#
# Epoch 00096: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-96_loss-2.7559_val_loss-6.0414.h5
# Epoch 97/120
#
# Epoch 00097: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 748s 748ms/step - loss: 2.7390 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 944.1616 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2529 - val_loss: 5.9935 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5122
#
# Epoch 00097: saving model to ../trained_weights/SSD512_SIM10K_to_VOC12_resize_400_800/current/pool2_loss_weights_0_000005/epoch-97_loss-2.7388_val_loss-5.9935.h5
# Epoch 98/120
#
# Epoch 00098: LearningRateScheduler setting learning rate to 1e-05.
#  428/1000 [===========>..................] - ETA: 6:58 - loss: 2.7549 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 935.6840 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2690
# -----------------------------------------------------
# KeyboardInterrupt   Traceback (most recent call last)
# <ipython-input-6-ea67b764e796> in <module>()
#       9                               validation_data=val_generator,
#      10                               validation_steps=ceil(val_dataset_size/batch_size),
# ---> 11                               initial_epoch=initial_epoch)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 5
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
