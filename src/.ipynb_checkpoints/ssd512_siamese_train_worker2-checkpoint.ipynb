# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights =  [0.0, 0.0, 0.000005] + [1.0]
Source_Only = False # True

# 'City_to_foggy0_01_resize_600_1200' # 'City_to_foggy0_02_resize_600_1200'  # 'SIM10K_to_VOC07'
# 'SIM10K'  # 'Cityscapes_foggy_beta_0_01'  # 'City_to_foggy0_02_resize_400_800'
DatasetName = 'City_to_foggy0_01_resize_400_800' # 'SIM10K_to_City_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName + '_worker2'
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

if DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_600_1200':
    resize_image_to = (600, 1200)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_600_1200':
    resize_image_to = (600, 1200)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'Cityscapes_foggy_beta_0_01':
    resize_image_to = (300, 600)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K':
    resize_image_to = (300, 600)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_VOC07':
    resize_image_to = (300, 600)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    
    
#     if Source_Only:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})
#     else:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 2966/2966 [00:00<00:00, 5052.44it/s]
# Loading source image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 9293.21it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 10676.23it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 2966/2966 [00:00<00:00, 8244.60it/s]
# Loading source labels: 100%|██████████| 493/493 [00:00<00:00, 4784.37it/s]
# Loading source image IDs: 100%|██████████| 493/493 [00:00<00:00, 10857.69it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 493/493 [00:00<00:00, 8032.79it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  2966
# Number of images in the validation dataset:	   493

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 50:
#         return 0.001
#     elif epoch < 60:
#         return 0.0001
#     else:
#         return 0.00001

# Define model callbacks.
checkpoint_path = '../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool3_loss_weights_0_000005'
# checkpoint_path = '../trained_weights/current/ssd_augm_beta_0_01_source_only'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'pool3_loss_weights_0_000005_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 120
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/120
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 794s 794ms/step - loss: 9.6020 - pool1_GAP_substract_loss: 22686.2848 - pool2_GAP_substract_loss: 19569.2911 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 5.8572 - val_loss: 8.7122 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.1960
#
# Epoch 00001: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-01_loss-9.6020_val_loss-8.7122.h5
# Epoch 2/120
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 783s 783ms/step - loss: 8.1728 - pool1_GAP_substract_loss: 13513.6546 - pool2_GAP_substract_loss: 6076.2245 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.5755 - val_loss: 8.2691 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7866
#
# Epoch 00002: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-02_loss-8.1728_val_loss-8.2691.h5
# Epoch 3/120
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 780s 780ms/step - loss: 7.9386 - pool1_GAP_substract_loss: 10345.4467 - pool2_GAP_substract_loss: 4356.2215 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.4140 - val_loss: 8.0767 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6572
#
# Epoch 00003: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-03_loss-7.9386_val_loss-8.0767.h5
# Epoch 4/120
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 779s 779ms/step - loss: 7.4928 - pool1_GAP_substract_loss: 7460.4915 - pool2_GAP_substract_loss: 3073.0702 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.0518 - val_loss: 7.6986 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3412
#
# Epoch 00004: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-04_loss-7.4928_val_loss-7.6986.h5
# Epoch 5/120
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 779s 779ms/step - loss: 7.2185 - pool1_GAP_substract_loss: 5899.8593 - pool2_GAP_substract_loss: 2574.0689 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.8490 - val_loss: 7.4329 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1359
#
# Epoch 00005: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-05_loss-7.2185_val_loss-7.4329.h5
# Epoch 6/120
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 778s 778ms/step - loss: 7.0244 - pool1_GAP_substract_loss: 4977.3456 - pool2_GAP_substract_loss: 2240.3288 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.7209 - val_loss: 7.4791 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2411
#
# Epoch 00006: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-06_loss-7.0244_val_loss-7.4791.h5
# Epoch 7/120
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 780s 780ms/step - loss: 6.8564 - pool1_GAP_substract_loss: 4159.2045 - pool2_GAP_substract_loss: 1965.2139 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.6167 - val_loss: 7.2099 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0296
#
# Epoch 00007: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-07_loss-6.8564_val_loss-7.2099.h5
# Epoch 8/120
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 779s 779ms/step - loss: 6.7336 - pool1_GAP_substract_loss: 3667.1801 - pool2_GAP_substract_loss: 1781.1987 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5541 - val_loss: 7.2642 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1399
#
# Epoch 00008: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-08_loss-6.7336_val_loss-7.2642.h5
# Epoch 9/120
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 780s 780ms/step - loss: 6.5708 - pool1_GAP_substract_loss: 3236.5492 - pool2_GAP_substract_loss: 1591.6155 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4500 - val_loss: 6.9319 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8627
#
# Epoch 00009: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-09_loss-6.5708_val_loss-6.9319.h5
# Epoch 10/120
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 780s 780ms/step - loss: 6.4644 - pool1_GAP_substract_loss: 2933.0700 - pool2_GAP_substract_loss: 1469.0696 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4003 - val_loss: 6.9477 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9320
#
# Epoch 00010: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-10_loss-6.4644_val_loss-6.9477.h5
# Epoch 11/120
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 780s 780ms/step - loss: 6.3477 - pool1_GAP_substract_loss: 2742.5893 - pool2_GAP_substract_loss: 1399.2687 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3378 - val_loss: 6.9031 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9402
#
# Epoch 00011: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-11_loss-6.3477_val_loss-6.9031.h5
# Epoch 12/120
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 780s 780ms/step - loss: 6.2263 - pool1_GAP_substract_loss: 2480.1218 - pool2_GAP_substract_loss: 1295.6864 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2703 - val_loss: 6.8632 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9515
#
# Epoch 00012: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-12_loss-6.2263_val_loss-6.8632.h5
# Epoch 13/120
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 789s 789ms/step - loss: 6.1601 - pool1_GAP_substract_loss: 2415.2873 - pool2_GAP_substract_loss: 1252.1115 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2553 - val_loss: 6.7636 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9022
# Epoch 00013: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-13_loss-6.1601_val_loss-6.7636.h5
# Epoch 14/120
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 779s 779ms/step - loss: 6.0621 - pool1_GAP_substract_loss: 2275.7667 - pool2_GAP_substract_loss: 1218.6174 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2077 - val_loss: 6.6280 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8156
#
# Epoch 00014: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-14_loss-6.0621_val_loss-6.6280.h5
# Epoch 15/120
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 779s 779ms/step - loss: 5.9942 - pool1_GAP_substract_loss: 2201.1355 - pool2_GAP_substract_loss: 1148.4600 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1890 - val_loss: 6.6207 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8562
#
# Epoch 00015: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-15_loss-5.9942_val_loss-6.6207.h5
# Epoch 16/120
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 780s 780ms/step - loss: 5.8390 - pool1_GAP_substract_loss: 2091.0255 - pool2_GAP_substract_loss: 1115.9935 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0821 - val_loss: 6.5726 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8553
#
# Epoch 00016: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-16_loss-5.8390_val_loss-6.5726.h5
# Epoch 17/120
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 779s 779ms/step - loss: 5.8569 - pool1_GAP_substract_loss: 2009.2103 - pool2_GAP_substract_loss: 1097.2867 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1469 - val_loss: 6.4461 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7744
#
# Epoch 00017: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-17_loss-5.8569_val_loss-6.4461.h5
# Epoch 18/120
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 783s 783ms/step - loss: 5.7458 - pool1_GAP_substract_loss: 1921.9686 - pool2_GAP_substract_loss: 1070.8368 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0815 - val_loss: 6.5639 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9369
#
# Epoch 00018: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-18_loss-5.7458_val_loss-6.5639.h5
# Epoch 19/120
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 779s 779ms/step - loss: 5.6687 - pool1_GAP_substract_loss: 1897.6345 - pool2_GAP_substract_loss: 1021.1687 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0490 - val_loss: 6.4963 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9130
#
# Epoch 00019: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-19_loss-5.6687_val_loss-6.4963.h5
# Epoch 20/120
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 779s 779ms/step - loss: 5.5883 - pool1_GAP_substract_loss: 1861.6562 - pool2_GAP_substract_loss: 1007.6628 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0121 - val_loss: 6.4561 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9157
#
# Epoch 00020: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-20_loss-5.5883_val_loss-6.4561.h5
# Epoch 21/120
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 780s 780ms/step - loss: 5.5238 - pool1_GAP_substract_loss: 1720.3091 - pool2_GAP_substract_loss: 927.2864 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9912 - val_loss: 6.3742 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8758
#
# Epoch 00021: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-21_loss-5.5238_val_loss-6.3742.h5
# Epoch 22/120
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 783s 783ms/step - loss: 5.4651 - pool1_GAP_substract_loss: 1733.4487 - pool2_GAP_substract_loss: 933.9582 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9740 - val_loss: 6.4696 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0124
#
# Epoch 00022: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-22_loss-5.4651_val_loss-6.4696.h5
# Epoch 23/120
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 783s 783ms/step - loss: 5.3704 - pool1_GAP_substract_loss: 1665.1718 - pool2_GAP_substract_loss: 934.8785 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9203 - val_loss: 6.3443 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9273
#
# Epoch 00023: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-23_loss-5.3704_val_loss-6.3443.h5
# Epoch 24/120
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 813s 813ms/step - loss: 5.3715 - pool1_GAP_substract_loss: 1626.1589 - pool2_GAP_substract_loss: 867.1785 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9616 - val_loss: 6.2206 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8427
#
# Epoch 00024: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-24_loss-5.3715_val_loss-6.2206.h5
# Epoch 25/120
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 782s 782ms/step - loss: 5.3049 - pool1_GAP_substract_loss: 1591.7171 - pool2_GAP_substract_loss: 878.4551 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9338 - val_loss: 6.2554 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9156
#
# Epoch 00025: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-25_loss-5.3049_val_loss-6.2554.h5
# Epoch 26/120
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 792s 792ms/step - loss: 5.2121 - pool1_GAP_substract_loss: 1589.8943 - pool2_GAP_substract_loss: 853.9719 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8790 - val_loss: 6.0465 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7443
# Epoch 00026: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-26_loss-5.2121_val_loss-6.0465.h5
# Epoch 27/120
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 5.1745 - pool1_GAP_substract_loss: 1566.7384 - pool2_GAP_substract_loss: 846.8495 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8787 - val_loss: 6.0152 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7499
#
# Epoch 00027: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-27_loss-5.1745_val_loss-6.0152.h5
# Epoch 28/120
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 800s 800ms/step - loss: 5.0962 - pool1_GAP_substract_loss: 1509.1231 - pool2_GAP_substract_loss: 825.9567 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8374 - val_loss: 6.0101 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7808
#
# Epoch 00028: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-28_loss-5.0962_val_loss-6.0101.h5
# Epoch 29/120
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 782s 782ms/step - loss: 5.0738 - pool1_GAP_substract_loss: 1485.1205 - pool2_GAP_substract_loss: 809.2039 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8507 - val_loss: 5.9883 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7943
#
# Epoch 00029: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-29_loss-5.0738_val_loss-5.9883.h5
# Epoch 30/120
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 800s 800ms/step - loss: 5.0327 - pool1_GAP_substract_loss: 1464.4206 - pool2_GAP_substract_loss: 791.7460 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8445 - val_loss: 5.9069 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7469
#
# Epoch 00030: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-30_loss-5.0327_val_loss-5.9069.h5
# Epoch 31/120
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 787s 787ms/step - loss: 4.9197 - pool1_GAP_substract_loss: 1470.8954 - pool2_GAP_substract_loss: 779.2408 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7655 - val_loss: 5.8679 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7419
#
# Epoch 00031: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-31_loss-4.9197_val_loss-5.8679.h5
# Epoch 32/120
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 790s 790ms/step - loss: 4.9174 - pool1_GAP_substract_loss: 1434.3378 - pool2_GAP_substract_loss: 785.7293 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7967 - val_loss: 5.8159 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7227
#
# Epoch 00032: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-32_loss-4.9174_val_loss-5.8159.h5
# Epoch 33/120
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 786s 786ms/step - loss: 4.8782 - pool1_GAP_substract_loss: 1399.9633 - pool2_GAP_substract_loss: 766.7723 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7902 - val_loss: 5.9581 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8969
#
# Epoch 00033: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-33_loss-4.8782_val_loss-5.9581.h5
# Epoch 34/120
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 795s 795ms/step - loss: 4.8492 - pool1_GAP_substract_loss: 1435.0972 - pool2_GAP_substract_loss: 755.3666 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7929 - val_loss: 5.7209 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6911
#
# Epoch 00034: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-34_loss-4.8492_val_loss-5.7209.h5
# Epoch 35/120
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 785s 785ms/step - loss: 4.8022 - pool1_GAP_substract_loss: 1438.7407 - pool2_GAP_substract_loss: 757.3967 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7768 - val_loss: 5.8527 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8535
#
# Epoch 00035: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-35_loss-4.8022_val_loss-5.8527.h5
# Epoch 36/120
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 812s 812ms/step - loss: 4.7197 - pool1_GAP_substract_loss: 1403.2506 - pool2_GAP_substract_loss: 758.7999 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7249 - val_loss: 5.7628 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7940
#
# Epoch 00036: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-36_loss-4.7197_val_loss-5.7628.h5
# Epoch 37/120
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 795s 795ms/step - loss: 4.6837 - pool1_GAP_substract_loss: 1351.1806 - pool2_GAP_substract_loss: 741.3518 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7192 - val_loss: 5.6466 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7072
#
# Epoch 00037: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-37_loss-4.6837_val_loss-5.6466.h5
# Epoch 38/120
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 4.6603 - pool1_GAP_substract_loss: 1336.0038 - pool2_GAP_substract_loss: 714.4404 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7249 - val_loss: 5.7293 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8185
#
# Epoch 00038: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-38_loss-4.6603_val_loss-5.7293.h5
# Epoch 39/120
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 795s 795ms/step - loss: 4.5818 - pool1_GAP_substract_loss: 1316.1638 - pool2_GAP_substract_loss: 701.5732 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6751 - val_loss: 5.7618 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8792
# Epoch 00039: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-39_loss-4.5818_val_loss-5.7618.h5
# Epoch 40/120
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 813s 813ms/step - loss: 4.5963 - pool1_GAP_substract_loss: 1355.3074 - pool2_GAP_substract_loss: 730.3521 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7171 - val_loss: 5.6639 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8085
#
# Epoch 00040: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-40_loss-4.5963_val_loss-5.6639.h5
# Epoch 41/120
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 794s 794ms/step - loss: 4.5220 - pool1_GAP_substract_loss: 1298.6771 - pool2_GAP_substract_loss: 714.5269 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6702 - val_loss: 5.5911 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7628
#
# Epoch 00041: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-41_loss-4.5220_val_loss-5.5911.h5
# Epoch 42/120
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 803s 803ms/step - loss: 4.5114 - pool1_GAP_substract_loss: 1342.7960 - pool2_GAP_substract_loss: 729.5142 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6860 - val_loss: 5.4082 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6062
#
# Epoch 00042: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-42_loss-4.5114_val_loss-5.4082.h5
# Epoch 43/120
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 829s 829ms/step - loss: 4.4840 - pool1_GAP_substract_loss: 1297.0614 - pool2_GAP_substract_loss: 679.5006 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6850 - val_loss: 5.6195 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8430
#
# Epoch 00043: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-43_loss-4.4840_val_loss-5.6195.h5
# Epoch 44/120
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 4.4088 - pool1_GAP_substract_loss: 1318.6408 - pool2_GAP_substract_loss: 692.9217 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6349 - val_loss: 5.4699 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7186
#
# Epoch 00044: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-44_loss-4.4088_val_loss-5.4699.h5
# Epoch 45/120
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 785s 785ms/step - loss: 4.4089 - pool1_GAP_substract_loss: 1347.3585 - pool2_GAP_substract_loss: 684.4582 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6596 - val_loss: 5.4606 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7337
#
# Epoch 00045: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-45_loss-4.4089_val_loss-5.4606.h5
# Epoch 46/120
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 782s 782ms/step - loss: 4.3711 - pool1_GAP_substract_loss: 1270.6054 - pool2_GAP_substract_loss: 661.7444 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6467 - val_loss: 5.5749 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8720
#
# Epoch 00046: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-46_loss-4.3711_val_loss-5.5749.h5
# Epoch 47/120
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 795s 795ms/step - loss: 4.2795 - pool1_GAP_substract_loss: 1285.3957 - pool2_GAP_substract_loss: 678.3522 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5787 - val_loss: 5.3900 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7106
#
# Epoch 00047: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-47_loss-4.2795_val_loss-5.3900.h5
# Epoch 48/120
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 784s 784ms/step - loss: 4.3167 - pool1_GAP_substract_loss: 1294.3783 - pool2_GAP_substract_loss: 663.2369 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6391 - val_loss: 5.4664 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8101
#
# Epoch 00048: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-48_loss-4.3167_val_loss-5.4664.h5
# Epoch 49/120
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 784s 784ms/step - loss: 4.2605 - pool1_GAP_substract_loss: 1238.3072 - pool2_GAP_substract_loss: 630.9745 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6062 - val_loss: 5.5600 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9262
#
# Epoch 00049: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-49_loss-4.2605_val_loss-5.5600.h5
# Epoch 50/120
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 782s 782ms/step - loss: 4.2647 - pool1_GAP_substract_loss: 1266.5207 - pool2_GAP_substract_loss: 641.2593 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6323 - val_loss: 5.4172 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8052
#
# Epoch 00050: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-50_loss-4.2647_val_loss-5.4172.h5
# Epoch 51/120
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 801s 801ms/step - loss: 4.0663 - pool1_GAP_substract_loss: 1215.7178 - pool2_GAP_substract_loss: 670.8450 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4463 - val_loss: 5.2193 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6102
#
# Epoch 00051: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-51_loss-4.0663_val_loss-5.2193.h5
# Epoch 52/120
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 3.9838 - pool1_GAP_substract_loss: 1205.9408 - pool2_GAP_substract_loss: 681.1855 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3666 - val_loss: 5.2983 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6919
# Epoch 00052: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-52_loss-3.9838_val_loss-5.2983.h5
# Epoch 53/120
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 814s 814ms/step - loss: 3.9673 - pool1_GAP_substract_loss: 1192.6083 - pool2_GAP_substract_loss: 687.3302 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3527 - val_loss: 5.2908 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6870
#
# Epoch 00053: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-53_loss-3.9673_val_loss-5.2908.h5
# Epoch 54/120
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 811s 811ms/step - loss: 3.9390 - pool1_GAP_substract_loss: 1223.4442 - pool2_GAP_substract_loss: 693.1227 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3270 - val_loss: 5.2720 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6709
#
# Epoch 00054: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-54_loss-3.9390_val_loss-5.2720.h5
# Epoch 55/120
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 800s 800ms/step - loss: 3.9684 - pool1_GAP_substract_loss: 1217.3934 - pool2_GAP_substract_loss: 707.9551 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3591 - val_loss: 5.2015 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6032
#
# Epoch 00055: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-55_loss-3.9684_val_loss-5.2015.h5
# Epoch 56/120
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 800s 800ms/step - loss: 3.9306 - pool1_GAP_substract_loss: 1163.6122 - pool2_GAP_substract_loss: 686.3075 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3244 - val_loss: 5.2831 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6874
#
# Epoch 00056: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-56_loss-3.9306_val_loss-5.2831.h5
# Epoch 57/120
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 800s 800ms/step - loss: 3.9449 - pool1_GAP_substract_loss: 1162.0373 - pool2_GAP_substract_loss: 694.5988 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3413 - val_loss: 5.3167 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7238
#
# Epoch 00057: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-57_loss-3.9449_val_loss-5.3167.h5
# Epoch 58/120
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 799s 799ms/step - loss: 3.9092 - pool1_GAP_substract_loss: 1162.9120 - pool2_GAP_substract_loss: 700.7671 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3083 - val_loss: 5.2873 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6970
#
# Epoch 00058: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-58_loss-3.9092_val_loss-5.2873.h5
# Epoch 59/120
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 817s 817ms/step - loss: 3.9210 - pool1_GAP_substract_loss: 1143.9230 - pool2_GAP_substract_loss: 688.8632 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3228 - val_loss: 5.2700 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6824
#
# Epoch 00059: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-59_loss-3.9210_val_loss-5.2700.h5
# Epoch 60/120
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 811s 811ms/step - loss: 3.9466 - pool1_GAP_substract_loss: 1123.1413 - pool2_GAP_substract_loss: 689.4347 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3512 - val_loss: 5.2952 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7102
#
# Epoch 00060: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-60_loss-3.9466_val_loss-5.2952.h5
# Epoch 61/120
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 802s 802ms/step - loss: 3.8971 - pool1_GAP_substract_loss: 1124.8158 - pool2_GAP_substract_loss: 690.1122 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3044 - val_loss: 5.2889 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7066
#
# Epoch 00061: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-61_loss-3.8971_val_loss-5.2889.h5
# Epoch 62/120
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 785s 785ms/step - loss: 3.9192 - pool1_GAP_substract_loss: 1164.9820 - pool2_GAP_substract_loss: 712.0385 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3289 - val_loss: 5.2214 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6418
#
# Epoch 00062: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-62_loss-3.9192_val_loss-5.2214.h5
# Epoch 63/120
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 785s 785ms/step - loss: 3.8569 - pool1_GAP_substract_loss: 1144.0589 - pool2_GAP_substract_loss: 717.8998 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2693 - val_loss: 5.3338 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7569
#
# Epoch 00063: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-63_loss-3.8569_val_loss-5.3338.h5
# Epoch 64/120
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 802s 802ms/step - loss: 3.8782 - pool1_GAP_substract_loss: 1142.5952 - pool2_GAP_substract_loss: 725.3842 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2932 - val_loss: 5.3181 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7438
#
# Epoch 00064: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-64_loss-3.8782_val_loss-5.3181.h5
# Epoch 65/120
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 804s 804ms/step - loss: 3.8716 - pool1_GAP_substract_loss: 1124.4102 - pool2_GAP_substract_loss: 716.3013 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2894 - val_loss: 5.2915 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7198
# Epoch 00065: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-65_loss-3.8716_val_loss-5.2915.h5
# Epoch 66/120
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
#    3/1000 [..............................] - ETA: 21:16 - loss: 3.5702 - pool1_GAP_substract_loss: 918.8124 - pool2_GAP_substract_loss: 550.6650 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9911
# /usr/local/lib/python3.5/dist-packages/keras/callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.782957). Check your callbacks.
#   % delta_t_median)
# 1000/1000 [==============================] - 814s 814ms/step - loss: 3.8613 - pool1_GAP_substract_loss: 1103.2098 - pool2_GAP_substract_loss: 709.1077 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2818 - val_loss: 5.2481 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6790
#
# Epoch 00066: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-66_loss-3.8613_val_loss-5.2481.h5
# Epoch 67/120
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 801s 801ms/step - loss: 3.8383 - pool1_GAP_substract_loss: 1097.4414 - pool2_GAP_substract_loss: 733.6098 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2614 - val_loss: 5.3507 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7842
#
# Epoch 00067: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-67_loss-3.8383_val_loss-5.3507.h5
# Epoch 68/120
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 793s 793ms/step - loss: 3.8464 - pool1_GAP_substract_loss: 1129.2432 - pool2_GAP_substract_loss: 730.7721 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2719 - val_loss: 5.3018 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7379
#
# Epoch 00068: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-68_loss-3.8464_val_loss-5.3018.h5
# Epoch 69/120
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 3.8712 - pool1_GAP_substract_loss: 1100.2862 - pool2_GAP_substract_loss: 730.8695 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2995 - val_loss: 5.3049 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7436
#
# Epoch 00069: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-69_loss-3.8712_val_loss-5.3049.h5
# Epoch 70/120
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 803s 803ms/step - loss: 3.8634 - pool1_GAP_substract_loss: 1099.7599 - pool2_GAP_substract_loss: 709.3168 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2944 - val_loss: 5.2958 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7371
#
# Epoch 00070: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-70_loss-3.8634_val_loss-5.2958.h5
# Epoch 71/120
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 3.8429 - pool1_GAP_substract_loss: 1107.7976 - pool2_GAP_substract_loss: 721.4873 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2752 - val_loss: 5.2835 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7252
#
# Epoch 00071: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-71_loss-3.8429_val_loss-5.2835.h5
# Epoch 72/120
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 800s 800ms/step - loss: 3.8297 - pool1_GAP_substract_loss: 1110.3673 - pool2_GAP_substract_loss: 735.3844 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2622 - val_loss: 5.3027 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7446
#
# Epoch 00072: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-72_loss-3.8297_val_loss-5.3027.h5
# Epoch 73/120
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 803s 803ms/step - loss: 3.8079 - pool1_GAP_substract_loss: 1093.4615 - pool2_GAP_substract_loss: 730.0312 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2408 - val_loss: 5.2839 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7260
#
# Epoch 00073: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-73_loss-3.8079_val_loss-5.2839.h5
# Epoch 74/120
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 3.8111 - pool1_GAP_substract_loss: 1108.3660 - pool2_GAP_substract_loss: 733.1565 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2441 - val_loss: 5.3157 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7581
#
# ...
# Epoch 88/120
#
# Epoch 00088: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 3.7929 - pool1_GAP_substract_loss: 1086.0867 - pool2_GAP_substract_loss: 739.5743 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2296 - val_loss: 5.3215 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7676
#
# Epoch 00088: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-88_loss-3.7929_val_loss-5.3215.h5
# Epoch 89/120
#
# Epoch 00089: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 796s 796ms/step - loss: 3.8215 - pool1_GAP_substract_loss: 1089.2256 - pool2_GAP_substract_loss: 728.9444 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2586 - val_loss: 5.3163 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7626
#
# Epoch 00089: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-89_loss-3.8215_val_loss-5.3163.h5
# Epoch 90/120
#
# Epoch 00090: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 804s 804ms/step - loss: 3.8007 - pool1_GAP_substract_loss: 1110.0585 - pool2_GAP_substract_loss: 757.3468 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2378 - val_loss: 5.3031 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7496
#
# Epoch 00090: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-90_loss-3.8007_val_loss-5.3031.h5
# Epoch 91/120
#
# Epoch 00091: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 811s 811ms/step - loss: 3.8032 - pool1_GAP_substract_loss: 1081.3253 - pool2_GAP_substract_loss: 725.4557 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2408 - val_loss: 5.2822 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7290
# Epoch 00091: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-91_loss-3.8032_val_loss-5.2822.h5
# Epoch 92/120
#
# Epoch 00092: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 794s 794ms/step - loss: 3.8250 - pool1_GAP_substract_loss: 1085.5938 - pool2_GAP_substract_loss: 724.7415 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2629 - val_loss: 5.2832 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7303
#
# Epoch 00092: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-92_loss-3.8250_val_loss-5.2832.h5
# Epoch 93/120
#
# Epoch 00093: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 799s 799ms/step - loss: 3.8067 - pool1_GAP_substract_loss: 1061.8803 - pool2_GAP_substract_loss: 727.9389 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2450 - val_loss: 5.2865 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7339
#
# Epoch 00093: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-93_loss-3.8067_val_loss-5.2865.h5
# Epoch 94/120
#
# Epoch 00094: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 797s 797ms/step - loss: 3.7945 - pool1_GAP_substract_loss: 1096.9273 - pool2_GAP_substract_loss: 733.3130 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2328 - val_loss: 5.2971 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7447
#
# Epoch 00094: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-94_loss-3.7945_val_loss-5.2971.h5
# Epoch 95/120
#
# Epoch 00095: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 778s 778ms/step - loss: 3.8212 - pool1_GAP_substract_loss: 1083.3975 - pool2_GAP_substract_loss: 750.7056 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2598 - val_loss: 5.3015 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7494
#
# Epoch 00095: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-95_loss-3.8212_val_loss-5.3015.h5
# Epoch 96/120
#
# Epoch 00096: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 792s 792ms/step - loss: 3.7856 - pool1_GAP_substract_loss: 1109.1024 - pool2_GAP_substract_loss: 744.7075 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2243 - val_loss: 5.2735 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7216
#
# Epoch 00096: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-96_loss-3.7856_val_loss-5.2735.h5
# Epoch 97/120
#
# Epoch 00097: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 797s 797ms/step - loss: 3.8048 - pool1_GAP_substract_loss: 1102.7294 - pool2_GAP_substract_loss: 750.8547 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2438 - val_loss: 5.2967 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7451
#
# Epoch 00097: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-97_loss-3.8048_val_loss-5.2967.h5
# Epoch 98/120
#
# Epoch 00098: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 3.7895 - pool1_GAP_substract_loss: 1071.8348 - pool2_GAP_substract_loss: 727.5337 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2290 - val_loss: 5.2908 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7395
#
# Epoch 00098: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-98_loss-3.7895_val_loss-5.2908.h5
# Epoch 99/120
#
# Epoch 00099: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 804s 804ms/step - loss: 3.7833 - pool1_GAP_substract_loss: 1079.5349 - pool2_GAP_substract_loss: 736.0871 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2230 - val_loss: 5.2910 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7399
#
# Epoch 00099: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-99_loss-3.7833_val_loss-5.2910.h5
# Epoch 100/120
#
# Epoch 00100: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 3.8143 - pool1_GAP_substract_loss: 1087.9121 - pool2_GAP_substract_loss: 747.4845 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2542 - val_loss: 5.2907 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7399
#
# Epoch 00100: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-100_loss-3.8143_val_loss-5.2907.h5
# Epoch 101/120
#
# Epoch 00101: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 795s 795ms/step - loss: 3.7942 - pool1_GAP_substract_loss: 1072.1179 - pool2_GAP_substract_loss: 727.5243 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2345 - val_loss: 5.3127 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7621
#
# Epoch 00101: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-101_loss-3.7942_val_loss-5.3127.h5
# Epoch 102/120
#
# Epoch 00102: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 3.7846 - pool1_GAP_substract_loss: 1089.5319 - pool2_GAP_substract_loss: 733.0533 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2250 - val_loss: 5.3285 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7782
#
# Epoch 00102: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-102_loss-3.7846_val_loss-5.3285.h5
# Epoch 103/120
#
# Epoch 00103: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 799s 799ms/step - loss: 3.8092 - pool1_GAP_substract_loss: 1098.0371 - pool2_GAP_substract_loss: 748.9399 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2498 - val_loss: 5.2962 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7462
#
# Epoch 00103: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-103_loss-3.8092_val_loss-5.2962.h5
# Epoch 104/120
#
# Epoch 00104: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 825s 825ms/step - loss: 3.7933 - pool1_GAP_substract_loss: 1095.3929 - pool2_GAP_substract_loss: 738.4991 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2342 - val_loss: 5.2875 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7376
# Epoch 00104: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool12_loss_weights_0_000005/epoch-104_loss-3.7933_val_loss-5.2875.h5
# Epoch 105/120
#
# Epoch 00105: LearningRateScheduler setting learning rate to 1e-05.
#  486/1000 [=============>................] - ETA: 6:34 - loss: 3.7820 - pool1_GAP_substract_loss: 1077.4761 - pool2_GAP_substract_loss: 752.9561 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2231
# -----------------------------------------------------
# KeyboardInterrupt   Traceback (most recent call last)
# <ipython-input-6-ea67b764e796> in <module>()
#       9                               validation_data=val_generator,
#      10                               validation_steps=ceil(val_dataset_size/batch_size),
# ---> 11                               initial_epoch=initial_epoch)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 5
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
