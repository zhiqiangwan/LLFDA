# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.da_ssd512_other_loss_metrics import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [0.0005, 0.0005, 0.0] + [1.0]

# 'SIM10K_to_VOC12_resize_400_800' # 'City_to_foggy0_01_resize_400_800' 
DatasetName =  'SIM10K_to_VOC07_resize_400_800' # 'SIM10K_to_City_resize_400_800'  #   # 
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

# Define model callbacks.
checkpoint_path = '../trained_weights/SIM10K_to_VOC07/current/mmd_0_0005'
# checkpoint_path = '../trained_weights/denug'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)
    
if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    
    
#     if Source_Only:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})
#     else:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')
# Out:
# da_loss_metric is MMD

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 10000/10000 [00:02<00:00, 4151.92it/s]
# Loading source image IDs: 100%|██████████| 10000/10000 [00:00<00:00, 11422.57it/s]
# Loading target image IDs: 100%|██████████| 761/761 [00:00<00:00, 10228.21it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 10000/10000 [00:01<00:00, 7443.03it/s]
# Loading source labels: 100%|██████████| 775/775 [00:00<00:00, 3705.81it/s]
# Loading source image IDs: 100%|██████████| 775/775 [00:00<00:00, 9692.54it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 775/775 [00:00<00:00, 7900.82it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	 10000
# Number of images in the validation dataset:	   775

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 50:
#         return 0.001
#     elif epoch < 60:
#         return 0.0001
#     else:
#         return 0.00001

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'source_only_run2_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 80
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/80
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 769s 769ms/step - loss: 14.2600 - pool1_GAP_substract_loss: 4.3823 - pool2_GAP_substract_loss: 4.5800 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 10.9459 - val_loss: 8.6047 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.3133
#
# Epoch 00001: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-01_loss-14.2601_val_loss-8.6047.h5
# Epoch 2/80
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 8.2291 - pool1_GAP_substract_loss: 4.3785 - pool2_GAP_substract_loss: 4.5530 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.9440 - val_loss: 8.2772 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.0163
#
# Epoch 00002: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-02_loss-8.2282_val_loss-8.2772.h5
# Epoch 3/80
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 8.4112 - pool1_GAP_substract_loss: 4.3716 - pool2_GAP_substract_loss: 4.5196 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 5.1679 - val_loss: 8.1180 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.9124
#
# Epoch 00003: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-03_loss-8.4115_val_loss-8.1180.h5
# Epoch 4/80
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 7.6018 - pool1_GAP_substract_loss: 4.3583 - pool2_GAP_substract_loss: 4.4899 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.4165 - val_loss: 8.0703 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.9231
#
# Epoch 00004: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-04_loss-7.6021_val_loss-8.0703.h5
# Epoch 5/80
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 7.3356 - pool1_GAP_substract_loss: 4.3643 - pool2_GAP_substract_loss: 4.4838 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.2085 - val_loss: 7.9290 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8394
#
# Epoch 00005: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-05_loss-7.3358_val_loss-7.9290.h5
# Epoch 6/80
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 7.1303 - pool1_GAP_substract_loss: 4.3539 - pool2_GAP_substract_loss: 4.4615 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.0604 - val_loss: 7.8028 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7700
#
# Epoch 00006: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-06_loss-7.1302_val_loss-7.8028.h5
# Epoch 7/80
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 7.0133 - pool1_GAP_substract_loss: 4.3415 - pool2_GAP_substract_loss: 4.4379 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.9994 - val_loss: 7.8602 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8821
#
# Epoch 00007: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-07_loss-7.0134_val_loss-7.8602.h5
# Epoch 8/80
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 6.9169 - pool1_GAP_substract_loss: 4.3397 - pool2_GAP_substract_loss: 4.4351 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.9571 - val_loss: 7.8717 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.9480
#
# Epoch 00008: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-08_loss-6.9164_val_loss-7.8717.h5
# Epoch 9/80
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 6.7584 - pool1_GAP_substract_loss: 4.3341 - pool2_GAP_substract_loss: 4.4096 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.8527 - val_loss: 7.6360 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7658
#
# Epoch 00009: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-09_loss-6.7583_val_loss-7.6360.h5
# Epoch 10/80
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 6.6614 - pool1_GAP_substract_loss: 4.3205 - pool2_GAP_substract_loss: 4.3858 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.8088 - val_loss: 7.6584 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8405
#
# Epoch 00010: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-10_loss-6.6612_val_loss-7.6584.h5
# Epoch 11/80
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 6.5582 - pool1_GAP_substract_loss: 4.3255 - pool2_GAP_substract_loss: 4.3821 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.7573 - val_loss: 7.6978 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.9311
#
# Epoch 00011: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-11_loss-6.5580_val_loss-7.6978.h5
# Epoch 12/80
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 6.4535 - pool1_GAP_substract_loss: 4.3286 - pool2_GAP_substract_loss: 4.3763 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.7035 - val_loss: 7.5418 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8258
#
# Epoch 00012: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-12_loss-6.4531_val_loss-7.5418.h5
# Epoch 13/80
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 6.3956 - pool1_GAP_substract_loss: 4.3066 - pool2_GAP_substract_loss: 4.3577 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.6957 - val_loss: 7.4239 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7574
#
# Epoch 00013: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-13_loss-6.3958_val_loss-7.4239.h5
# Epoch 14/80
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 6.3249 - pool1_GAP_substract_loss: 4.2980 - pool2_GAP_substract_loss: 4.3384 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.6739 - val_loss: 7.4612 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8429
#
# Epoch 00014: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-14_loss-6.3250_val_loss-7.4612.h5
# Epoch 15/80
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 6.2514 - pool1_GAP_substract_loss: 4.3006 - pool2_GAP_substract_loss: 4.3284 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.6483 - val_loss: 7.3591 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7882
#
# Epoch 00015: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-15_loss-6.2512_val_loss-7.3591.h5
# Epoch 16/80
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 6.1750 - pool1_GAP_substract_loss: 4.3025 - pool2_GAP_substract_loss: 4.3246 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.6189 - val_loss: 7.3249 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8008
#
# Epoch 00016: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-16_loss-6.1751_val_loss-7.3249.h5
# Epoch 17/80
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 6.0922 - pool1_GAP_substract_loss: 4.2948 - pool2_GAP_substract_loss: 4.3131 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5824 - val_loss: 7.2720 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7937
#
# Epoch 00017: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-17_loss-6.0923_val_loss-7.2720.h5
# Epoch 18/80
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 6.0642 - pool1_GAP_substract_loss: 4.2846 - pool2_GAP_substract_loss: 4.2992 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5995 - val_loss: 7.1880 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7540
#
# Epoch 00018: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-18_loss-6.0642_val_loss-7.1880.h5
# Epoch 19/80
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 5.9832 - pool1_GAP_substract_loss: 4.2843 - pool2_GAP_substract_loss: 4.2870 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5626 - val_loss: 7.1328 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7426
#
# Epoch 00019: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-19_loss-5.9835_val_loss-7.1328.h5
# Epoch 20/80
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 5.9182 - pool1_GAP_substract_loss: 4.2721 - pool2_GAP_substract_loss: 4.2645 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5409 - val_loss: 7.1107 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7631
#
# Epoch 00020: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-20_loss-5.9181_val_loss-7.1107.h5
# Epoch 21/80
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 5.9232 - pool1_GAP_substract_loss: 4.2725 - pool2_GAP_substract_loss: 4.2677 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5880 - val_loss: 7.0324 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7266
#
# Epoch 00021: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-21_loss-5.9234_val_loss-7.0324.h5
# Epoch 22/80
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 5.8477 - pool1_GAP_substract_loss: 4.2715 - pool2_GAP_substract_loss: 4.2567 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5538 - val_loss: 7.0720 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8071
#
# Epoch 00022: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-22_loss-5.8469_val_loss-7.0720.h5
# Epoch 23/80
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 5.7795 - pool1_GAP_substract_loss: 4.2605 - pool2_GAP_substract_loss: 4.2385 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5262 - val_loss: 6.9452 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7203
#
# Epoch 00023: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-23_loss-5.7793_val_loss-6.9452.h5
# Epoch 24/80
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 5.7354 - pool1_GAP_substract_loss: 4.2598 - pool2_GAP_substract_loss: 4.2297 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5216 - val_loss: 6.9517 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7660
#
# Epoch 00024: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-24_loss-5.7357_val_loss-6.9517.h5
# Epoch 25/80
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 5.6792 - pool1_GAP_substract_loss: 4.2547 - pool2_GAP_substract_loss: 4.2167 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5044 - val_loss: 6.8851 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7381
#
# Epoch 00025: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-25_loss-5.6795_val_loss-6.8851.h5
# Epoch 26/80
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 5.6180 - pool1_GAP_substract_loss: 4.2530 - pool2_GAP_substract_loss: 4.2194 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4812 - val_loss: 6.8831 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7734
#
# Epoch 00026: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-26_loss-5.6181_val_loss-6.8831.h5
# Epoch 27/80
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 5.5888 - pool1_GAP_substract_loss: 4.2520 - pool2_GAP_substract_loss: 4.2102 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4893 - val_loss: 6.7832 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7106
#
# Epoch 00027: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-27_loss-5.5883_val_loss-6.7832.h5
# Epoch 28/80
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 5.4930 - pool1_GAP_substract_loss: 4.2461 - pool2_GAP_substract_loss: 4.1908 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4303 - val_loss: 6.8281 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7920
#
# Epoch 00028: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-28_loss-5.4935_val_loss-6.8281.h5
# Epoch 29/80
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 5.5128 - pool1_GAP_substract_loss: 4.2406 - pool2_GAP_substract_loss: 4.1739 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4862 - val_loss: 6.8391 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8386
#
# Epoch 00029: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-29_loss-5.5128_val_loss-6.8391.h5
# Epoch 30/80
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 5.4429 - pool1_GAP_substract_loss: 4.2386 - pool2_GAP_substract_loss: 4.1735 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4515 - val_loss: 6.7068 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7411
#
# Epoch 00030: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-30_loss-5.4430_val_loss-6.7068.h5
# Epoch 31/80
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 5.3910 - pool1_GAP_substract_loss: 4.2396 - pool2_GAP_substract_loss: 4.1801 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4341 - val_loss: 6.6912 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7597
#
# Epoch 00031: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-31_loss-5.3903_val_loss-6.6912.h5
# Epoch 32/80
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 5.3493 - pool1_GAP_substract_loss: 4.2265 - pool2_GAP_substract_loss: 4.1554 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4262 - val_loss: 6.6375 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7397
#
# Epoch 00032: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-32_loss-5.3491_val_loss-6.6375.h5
# Epoch 33/80
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 5.3408 - pool1_GAP_substract_loss: 4.2316 - pool2_GAP_substract_loss: 4.1573 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4510 - val_loss: 6.5988 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7337
#
# Epoch 00033: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-33_loss-5.3410_val_loss-6.5988.h5
# Epoch 34/80
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 5.2851 - pool1_GAP_substract_loss: 4.2126 - pool2_GAP_substract_loss: 4.1202 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4277 - val_loss: 6.5476 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7145
#
# Epoch 00034: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-34_loss-5.2851_val_loss-6.5476.h5
# Epoch 35/80
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 5.1532 - pool1_GAP_substract_loss: 4.2147 - pool2_GAP_substract_loss: 4.1279 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3269 - val_loss: 6.6426 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8394
#
# Epoch 00035: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-35_loss-5.1530_val_loss-6.6426.h5
# Epoch 36/80
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 4.7991 - pool1_GAP_substract_loss: 4.2149 - pool2_GAP_substract_loss: 4.1342 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0016 - val_loss: 6.6926 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.9167
#
# Epoch 00036: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-36_loss-4.7990_val_loss-6.6926.h5
# Epoch 37/80
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 4.4761 - pool1_GAP_substract_loss: 4.2058 - pool2_GAP_substract_loss: 4.1281 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7038 - val_loss: 6.3570 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6047
#
# Epoch 00037: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-37_loss-4.4763_val_loss-6.3570.h5
# Epoch 38/80
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 4.2137 - pool1_GAP_substract_loss: 4.2053 - pool2_GAP_substract_loss: 4.1306 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4644 - val_loss: 6.2547 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5251
#
# Epoch 00038: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-38_loss-4.2141_val_loss-6.2547.h5
# Epoch 39/80
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 4.0543 - pool1_GAP_substract_loss: 4.2048 - pool2_GAP_substract_loss: 4.1374 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3277 - val_loss: 6.2642 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5570
#
# Epoch 00039: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-39_loss-4.0540_val_loss-6.2642.h5
# Epoch 40/80
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.9612 - pool1_GAP_substract_loss: 4.2084 - pool2_GAP_substract_loss: 4.1342 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2565 - val_loss: 6.2345 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5489
#
# Epoch 00040: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-40_loss-3.9613_val_loss-6.2345.h5
# Epoch 41/80
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.8470 - pool1_GAP_substract_loss: 4.2047 - pool2_GAP_substract_loss: 4.1316 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1638 - val_loss: 6.1399 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4759
#
# Epoch 00041: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-41_loss-3.8471_val_loss-6.1399.h5
# Epoch 42/80
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.7482 - pool1_GAP_substract_loss: 4.2051 - pool2_GAP_substract_loss: 4.1268 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0867 - val_loss: 6.1841 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5416
#
# Epoch 00042: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-42_loss-3.7478_val_loss-6.1841.h5
# Epoch 43/80
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.7424 - pool1_GAP_substract_loss: 4.1937 - pool2_GAP_substract_loss: 4.1196 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1016 - val_loss: 6.1947 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5726
#
# Epoch 00043: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-43_loss-3.7423_val_loss-6.1947.h5
# Epoch 44/80
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 3.6419 - pool1_GAP_substract_loss: 4.1975 - pool2_GAP_substract_loss: 4.1146 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0217 - val_loss: 6.2012 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5995
#
# Epoch 00044: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-44_loss-3.6421_val_loss-6.2012.h5
# Epoch 45/80
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.6034 - pool1_GAP_substract_loss: 4.1922 - pool2_GAP_substract_loss: 4.1192 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0035 - val_loss: 6.0273 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4459
#
# Epoch 00045: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-45_loss-3.6031_val_loss-6.0273.h5
# Epoch 46/80
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 3.5542 - pool1_GAP_substract_loss: 4.2014 - pool2_GAP_substract_loss: 4.1239 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9742 - val_loss: 6.1692 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6075
#
# Epoch 00046: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-46_loss-3.5542_val_loss-6.1692.h5
# Epoch 47/80
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.5166 - pool1_GAP_substract_loss: 4.1950 - pool2_GAP_substract_loss: 4.1126 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9565 - val_loss: 6.4301 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8883
#
# Epoch 00047: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-47_loss-3.5168_val_loss-6.4301.h5
# Epoch 48/80
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.4398 - pool1_GAP_substract_loss: 4.1910 - pool2_GAP_substract_loss: 4.1124 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8996 - val_loss: 5.6791 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1569
#
# Epoch 00048: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-48_loss-3.4404_val_loss-5.6791.h5
# Epoch 49/80
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.4065 - pool1_GAP_substract_loss: 4.1905 - pool2_GAP_substract_loss: 4.1055 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8855 - val_loss: 5.8046 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3010
#
# Epoch 00049: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-49_loss-3.4067_val_loss-5.8046.h5
# Epoch 50/80
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.3646 - pool1_GAP_substract_loss: 4.1798 - pool2_GAP_substract_loss: 4.0975 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8624 - val_loss: 6.0525 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5680
#
# Epoch 00050: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-50_loss-3.3646_val_loss-6.0525.h5
# Epoch 51/80
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.1422 - pool1_GAP_substract_loss: 4.1817 - pool2_GAP_substract_loss: 4.1022 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6508 - val_loss: 5.4460 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9642
#
# Epoch 00051: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-51_loss-3.1424_val_loss-5.4460.h5
# Epoch 52/80
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 752s 752ms/step - loss: 3.0483 - pool1_GAP_substract_loss: 4.1847 - pool2_GAP_substract_loss: 4.1137 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.5595 - val_loss: 5.4139 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9347
#
# Epoch 00052: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-52_loss-3.0482_val_loss-5.4139.h5
# Epoch 53/80
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 3.0072 - pool1_GAP_substract_loss: 4.1885 - pool2_GAP_substract_loss: 4.1144 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.5211 - val_loss: 5.4578 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9813
#
# Epoch 00053: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-53_loss-3.0072_val_loss-5.4578.h5
# Epoch 54/80
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.0129 - pool1_GAP_substract_loss: 4.1787 - pool2_GAP_substract_loss: 4.1107 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.5293 - val_loss: 5.4564 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9825
#
# Epoch 00054: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-54_loss-3.0131_val_loss-5.4564.h5
# Epoch 55/80
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.9787 - pool1_GAP_substract_loss: 4.1846 - pool2_GAP_substract_loss: 4.1184 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4978 - val_loss: 5.4794 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0081
#
# Epoch 00055: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-55_loss-2.9788_val_loss-5.4794.h5
# Epoch 56/80
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.9709 - pool1_GAP_substract_loss: 4.1821 - pool2_GAP_substract_loss: 4.1121 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4926 - val_loss: 5.5284 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0597
#
# Epoch 00056: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-56_loss-2.9705_val_loss-5.5284.h5
# Epoch 57/80
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.9835 - pool1_GAP_substract_loss: 4.1698 - pool2_GAP_substract_loss: 4.1030 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.5078 - val_loss: 5.4563 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9902
#
# Epoch 00057: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-57_loss-2.9833_val_loss-5.4563.h5
# Epoch 58/80
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.9910 - pool1_GAP_substract_loss: 4.1766 - pool2_GAP_substract_loss: 4.1119 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.5179 - val_loss: 5.4754 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0119
#
# Epoch 00058: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-58_loss-2.9909_val_loss-5.4754.h5
# Epoch 59/80
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.9758 - pool1_GAP_substract_loss: 4.1772 - pool2_GAP_substract_loss: 4.1125 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.5053 - val_loss: 5.4643 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0034
#
# Epoch 00059: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-59_loss-2.9761_val_loss-5.4643.h5
# Epoch 60/80
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.9445 - pool1_GAP_substract_loss: 4.1781 - pool2_GAP_substract_loss: 4.1139 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4766 - val_loss: 5.4785 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0201
#
# Epoch 00060: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-60_loss-2.9445_val_loss-5.4785.h5
# Epoch 61/80
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.9546 - pool1_GAP_substract_loss: 4.1803 - pool2_GAP_substract_loss: 4.1189 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4893 - val_loss: 5.4346 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9788
#
# Epoch 00061: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-61_loss-2.9546_val_loss-5.4346.h5
# Epoch 62/80
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 2.9307 - pool1_GAP_substract_loss: 4.1836 - pool2_GAP_substract_loss: 4.1244 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4679 - val_loss: 5.4962 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0429
#
# Epoch 00062: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-62_loss-2.9308_val_loss-5.4962.h5
# Epoch 63/80
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.9230 - pool1_GAP_substract_loss: 4.1816 - pool2_GAP_substract_loss: 4.1200 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4628 - val_loss: 5.4216 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9709
#
# Epoch 00063: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-63_loss-2.9232_val_loss-5.4216.h5
# Epoch 64/80
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 2.9114 - pool1_GAP_substract_loss: 4.1728 - pool2_GAP_substract_loss: 4.1165 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4537 - val_loss: 5.4298 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9817
#
# Epoch 00064: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-64_loss-2.9109_val_loss-5.4298.h5
# Epoch 65/80
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 2.9151 - pool1_GAP_substract_loss: 4.1808 - pool2_GAP_substract_loss: 4.1229 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4599 - val_loss: 5.4893 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0438
#
# Epoch 00065: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-65_loss-2.9154_val_loss-5.4893.h5
# Epoch 66/80
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.8947 - pool1_GAP_substract_loss: 4.1780 - pool2_GAP_substract_loss: 4.1174 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4421 - val_loss: 5.5429 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0999
#
# Epoch 00066: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-66_loss-2.8946_val_loss-5.5429.h5
# Epoch 67/80
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.8777 - pool1_GAP_substract_loss: 4.1708 - pool2_GAP_substract_loss: 4.1205 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4276 - val_loss: 5.5773 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1367
#
# Epoch 00067: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-67_loss-2.8776_val_loss-5.5773.h5
# Epoch 68/80
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.8991 - pool1_GAP_substract_loss: 4.1777 - pool2_GAP_substract_loss: 4.1233 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4516 - val_loss: 5.4618 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0239
#
# Epoch 00068: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-68_loss-2.8988_val_loss-5.4618.h5
# Epoch 69/80
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 2.8899 - pool1_GAP_substract_loss: 4.1862 - pool2_GAP_substract_loss: 4.1281 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4449 - val_loss: 5.5743 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1389
#
# Epoch 00069: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-69_loss-2.8898_val_loss-5.5743.h5
# Epoch 70/80
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.9006 - pool1_GAP_substract_loss: 4.1763 - pool2_GAP_substract_loss: 4.1206 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4581 - val_loss: 5.3927 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9598
#
# Epoch 00070: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-70_loss-2.9006_val_loss-5.3927.h5
# Epoch 71/80
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.8925 - pool1_GAP_substract_loss: 4.1864 - pool2_GAP_substract_loss: 4.1325 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4514 - val_loss: 5.4976 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0649
#
# Epoch 00071: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-71_loss-2.8927_val_loss-5.4976.h5
# Epoch 72/80
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 2.8767 - pool1_GAP_substract_loss: 4.1771 - pool2_GAP_substract_loss: 4.1214 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4359 - val_loss: 5.4784 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0460
#
# Epoch 00072: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-72_loss-2.8767_val_loss-5.4784.h5
# Epoch 73/80
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.8545 - pool1_GAP_substract_loss: 4.1811 - pool2_GAP_substract_loss: 4.1258 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4139 - val_loss: 5.5027 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0705
#
# Epoch 00073: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-73_loss-2.8540_val_loss-5.5027.h5
# Epoch 74/80
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 2.8646 - pool1_GAP_substract_loss: 4.1830 - pool2_GAP_substract_loss: 4.1270 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4243 - val_loss: 5.4613 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0294
#
# Epoch 00074: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-74_loss-2.8642_val_loss-5.4613.h5
# Epoch 75/80
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.8810 - pool1_GAP_substract_loss: 4.1776 - pool2_GAP_substract_loss: 4.1231 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4409 - val_loss: 5.4674 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0358
#
# Epoch 00075: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-75_loss-2.8808_val_loss-5.4674.h5
# Epoch 76/80
#
# Epoch 00076: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 2.8411 - pool1_GAP_substract_loss: 4.1781 - pool2_GAP_substract_loss: 4.1272 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4013 - val_loss: 5.5141 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0827
#
# Epoch 00076: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-76_loss-2.8410_val_loss-5.5141.h5
# Epoch 77/80
#
# Epoch 00077: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 2.8628 - pool1_GAP_substract_loss: 4.1777 - pool2_GAP_substract_loss: 4.1239 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4232 - val_loss: 5.5128 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0817
#
# Epoch 00077: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-77_loss-2.8631_val_loss-5.5128.h5
# Epoch 78/80
#
# Epoch 00078: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.8551 - pool1_GAP_substract_loss: 4.1716 - pool2_GAP_substract_loss: 4.1192 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4158 - val_loss: 5.5298 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0989
#
# Epoch 00078: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-78_loss-2.8554_val_loss-5.5298.h5
# Epoch 79/80
#
# Epoch 00079: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 2.8728 - pool1_GAP_substract_loss: 4.1819 - pool2_GAP_substract_loss: 4.1263 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4337 - val_loss: 5.5207 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0901
#
# Epoch 00079: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-79_loss-2.8728_val_loss-5.5207.h5
# Epoch 80/80
#
# Epoch 00080: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 2.8525 - pool1_GAP_substract_loss: 4.1684 - pool2_GAP_substract_loss: 4.1180 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.4137 - val_loss: 5.5036 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0733
#
# Epoch 00080: saving model to ../trained_weights/SIM10K_to_VOC07/current/mmd_0_001/epoch-80_loss-2.8522_val_loss-5.5036.h5

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()
# Out:
# Image: ../../datasets/SIM10K/JPEGImages/3401696

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
# Out:
# Image: ../../datasets/SIM10K/JPEGImages/3397609
#
# Ground truth boxes:
#
# [[  1 365 163 448 181]
#  [  1   0 110 248 211]
#  [  1 601 149 675 168]
#  [  1 191 133 289 190]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4c88a6df60d1> in <module>()
#      47 # 5: Convert the predictions for the original image.
#      48
# ---> 49 y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)
#      50
#      51 np.set_printoptions(precision=2, suppress=True, linewidth=90)
#
# /domain_adaptation_object_detection/LLFDA_IJCAI2019/data_generator/object_detection_2d_misc_utils.py in apply_inverse_transforms(y_pred_decoded, inverse_transforms)
#      56                 for inverter in inverse_transforms[i]:
#      57                     if not (inverter is None):
# ---> 58                         y_pred_decoded_inv[i] = inverter(y_pred_decoded_inv[i])
#      59
#      60     elif isinstance(y_pred_decoded, np.ndarray):
#
# TypeError: 'list' object is not callable
