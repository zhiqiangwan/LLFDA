# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [1.0, 1.0, 0.0] + [1.0]
experiment = 'MMD_pool1pool2_weight1'

#  
DatasetName = 'SIM10K_to_City_resize_400_800' # 'City_to_foggy0_01_resize_400_800'  # 'SIM10K_to_VOC07_resize_400_800' #   'SIM10K_to_VOC12_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

# Define model callbacks.
checkpoint_path = os.path.join('../trained_weights', DatasetName, experiment)
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)    
    
if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')
# Out:
# da_loss_metric is MMD_loss

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 2966/2966 [00:00<00:00, 4783.78it/s]
# Loading source image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 10283.56it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 10788.36it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 2966/2966 [00:00<00:00, 7457.36it/s]
# Loading source labels: 100%|██████████| 493/493 [00:00<00:00, 4721.44it/s]
# Loading source image IDs: 100%|██████████| 493/493 [00:00<00:00, 10889.25it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 493/493 [00:00<00:00, 7472.24it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  2966
# Number of images in the validation dataset:	   493

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 60:
        return 0.0001
    else:
        return 0.00001

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 70
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/70
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 1196s 1s/step - loss: 10.1773 - pool1_GAP_substract_loss: 0.1150 - pool2_GAP_substract_loss: 0.0616 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 6.4166 - val_loss: 9.0620 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.4919
#
# Epoch 00001: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-01_loss-10.1773_val_loss-9.0620.h5
# Epoch 2/70
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 826s 826ms/step - loss: 8.3438 - pool1_GAP_substract_loss: 0.0811 - pool2_GAP_substract_loss: 0.0570 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.6518 - val_loss: 8.3481 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8099
#
# Epoch 00002: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-02_loss-8.3438_val_loss-8.3481.h5
# Epoch 3/70
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 8.0753 - pool1_GAP_substract_loss: 0.0770 - pool2_GAP_substract_loss: 0.0579 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.4328 - val_loss: 8.0913 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6141
#
# Epoch 00003: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-03_loss-8.0753_val_loss-8.0913.h5
# Epoch 4/70
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 934s 934ms/step - loss: 7.6416 - pool1_GAP_substract_loss: 0.0741 - pool2_GAP_substract_loss: 0.0567 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.0641 - val_loss: 7.8105 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3940
#
# Epoch 00004: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-04_loss-7.6416_val_loss-7.8105.h5
# Epoch 5/70
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 920s 920ms/step - loss: 7.3680 - pool1_GAP_substract_loss: 0.0722 - pool2_GAP_substract_loss: 0.0550 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.8545 - val_loss: 7.7045 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3477
#
# Epoch 00005: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-05_loss-7.3680_val_loss-7.7045.h5
# Epoch 6/70
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 963s 963ms/step - loss: 7.1823 - pool1_GAP_substract_loss: 0.0719 - pool2_GAP_substract_loss: 0.0549 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.7284 - val_loss: 7.5460 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2481
#
# Epoch 00006: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-06_loss-7.1823_val_loss-7.5460.h5
# Epoch 7/70
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 950s 950ms/step - loss: 6.9819 - pool1_GAP_substract_loss: 0.0699 - pool2_GAP_substract_loss: 0.0533 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5899 - val_loss: 7.2282 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9878
#
# Epoch 00007: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-07_loss-6.9819_val_loss-7.2282.h5
# Epoch 8/70
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 939s 939ms/step - loss: 6.8279 - pool1_GAP_substract_loss: 0.0708 - pool2_GAP_substract_loss: 0.0536 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4916 - val_loss: 7.1347 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9507
#
# Epoch 00008: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-08_loss-6.8279_val_loss-7.1347.h5
# Epoch 9/70
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 934s 934ms/step - loss: 6.7086 - pool1_GAP_substract_loss: 0.0701 - pool2_GAP_substract_loss: 0.0531 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4293 - val_loss: 7.2279 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0993
#
# Epoch 00009: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-09_loss-6.7086_val_loss-7.2279.h5
# Epoch 10/70
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 922s 922ms/step - loss: 6.5777 - pool1_GAP_substract_loss: 0.0680 - pool2_GAP_substract_loss: 0.0519 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3563 - val_loss: 7.1261 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0514
#
# Epoch 00010: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-10_loss-6.5777_val_loss-7.1261.h5
# Epoch 11/70
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 903s 903ms/step - loss: 6.4733 - pool1_GAP_substract_loss: 0.0676 - pool2_GAP_substract_loss: 0.0512 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3067 - val_loss: 6.8908 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8692
#
# Epoch 00011: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-11_loss-6.4733_val_loss-6.8908.h5
# Epoch 12/70
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 928s 928ms/step - loss: 6.3824 - pool1_GAP_substract_loss: 0.0668 - pool2_GAP_substract_loss: 0.0510 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2692 - val_loss: 6.7438 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7741
#
# Epoch 00012: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-12_loss-6.3824_val_loss-6.7438.h5
# Epoch 13/70
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 913s 913ms/step - loss: 6.3025 - pool1_GAP_substract_loss: 0.0667 - pool2_GAP_substract_loss: 0.0501 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2416 - val_loss: 6.8906 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9717
#
# Epoch 00013: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-13_loss-6.3025_val_loss-6.8906.h5
# Epoch 14/70
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 907s 907ms/step - loss: 6.1946 - pool1_GAP_substract_loss: 0.0666 - pool2_GAP_substract_loss: 0.0501 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1841 - val_loss: 6.7114 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8420
#
# Epoch 00014: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-14_loss-6.1946_val_loss-6.7114.h5
# Epoch 15/70
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 927s 927ms/step - loss: 6.1198 - pool1_GAP_substract_loss: 0.0662 - pool2_GAP_substract_loss: 0.0498 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1592 - val_loss: 6.5649 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7441
#
# Epoch 00015: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-15_loss-6.1198_val_loss-6.5649.h5
# Epoch 16/70
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 6.0394 - pool1_GAP_substract_loss: 0.0659 - pool2_GAP_substract_loss: 0.0494 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1274 - val_loss: 6.3950 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6218
#
# Epoch 00016: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-16_loss-6.0394_val_loss-6.3950.h5
# Epoch 17/70
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 935s 935ms/step - loss: 5.9399 - pool1_GAP_substract_loss: 0.0669 - pool2_GAP_substract_loss: 0.0504 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0730 - val_loss: 6.5820 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8556
#
# Epoch 00017: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-17_loss-5.9399_val_loss-6.5820.h5
# Epoch 18/70
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 5.8980 - pool1_GAP_substract_loss: 0.0657 - pool2_GAP_substract_loss: 0.0494 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0794 - val_loss: 6.4020 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7208
#
# Epoch 00018: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-18_loss-5.8980_val_loss-6.4020.h5
# Epoch 19/70
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 894s 894ms/step - loss: 5.8090 - pool1_GAP_substract_loss: 0.0656 - pool2_GAP_substract_loss: 0.0493 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0354 - val_loss: 6.4482 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8114
#
# Epoch 00019: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-19_loss-5.8090_val_loss-6.4482.h5
# Epoch 20/70
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 5.7332 - pool1_GAP_substract_loss: 0.0652 - pool2_GAP_substract_loss: 0.0489 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0043 - val_loss: 6.2611 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6677
#
# Epoch 00020: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-20_loss-5.7332_val_loss-6.2611.h5
# Epoch 21/70
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 910s 910ms/step - loss: 5.6819 - pool1_GAP_substract_loss: 0.0657 - pool2_GAP_substract_loss: 0.0493 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9951 - val_loss: 6.6225 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0717
#
# Epoch 00021: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-21_loss-5.6819_val_loss-6.6225.h5
# Epoch 22/70
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 917s 917ms/step - loss: 5.5874 - pool1_GAP_substract_loss: 0.0650 - pool2_GAP_substract_loss: 0.0490 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9435 - val_loss: 6.1858 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6766
#
# Epoch 00022: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-22_loss-5.5874_val_loss-6.1858.h5
# Epoch 23/70
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 916s 916ms/step - loss: 5.5194 - pool1_GAP_substract_loss: 0.0647 - pool2_GAP_substract_loss: 0.0488 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9175 - val_loss: 6.0878 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6194
#
# Epoch 00023: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-23_loss-5.5194_val_loss-6.0878.h5
# Epoch 24/70
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 907s 907ms/step - loss: 5.5024 - pool1_GAP_substract_loss: 0.0646 - pool2_GAP_substract_loss: 0.0485 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9410 - val_loss: 6.1859 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7571
#
# Epoch 00024: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-24_loss-5.5024_val_loss-6.1859.h5
# Epoch 25/70
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 888s 888ms/step - loss: 5.3881 - pool1_GAP_substract_loss: 0.0650 - pool2_GAP_substract_loss: 0.0484 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8657 - val_loss: 6.1953 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8055
#
# Epoch 00025: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-25_loss-5.3881_val_loss-6.1953.h5
# Epoch 26/70
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 900s 900ms/step - loss: 5.3806 - pool1_GAP_substract_loss: 0.0640 - pool2_GAP_substract_loss: 0.0480 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8982 - val_loss: 6.0122 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6607
#
# Epoch 00026: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-26_loss-5.3806_val_loss-6.0122.h5
# Epoch 27/70
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 897s 897ms/step - loss: 5.2824 - pool1_GAP_substract_loss: 0.0653 - pool2_GAP_substract_loss: 0.0489 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8354 - val_loss: 5.9235 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6092
#
# Epoch 00027: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-27_loss-5.2824_val_loss-5.9235.h5
# Epoch 28/70
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 881s 881ms/step - loss: 5.2594 - pool1_GAP_substract_loss: 0.0631 - pool2_GAP_substract_loss: 0.0473 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8532 - val_loss: 5.8814 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6036
#
# Epoch 00028: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-28_loss-5.2594_val_loss-5.8814.h5
# Epoch 29/70
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 908s 908ms/step - loss: 5.1572 - pool1_GAP_substract_loss: 0.0638 - pool2_GAP_substract_loss: 0.0478 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7859 - val_loss: 5.9066 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6646
#
# Epoch 00029: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-29_loss-5.1572_val_loss-5.9066.h5
# Epoch 30/70
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 902s 902ms/step - loss: 5.1416 - pool1_GAP_substract_loss: 0.0645 - pool2_GAP_substract_loss: 0.0483 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8045 - val_loss: 5.8232 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6162
#
# Epoch 00030: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-30_loss-5.1416_val_loss-5.8232.h5
# Epoch 31/70
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 890s 890ms/step - loss: 5.0951 - pool1_GAP_substract_loss: 0.0628 - pool2_GAP_substract_loss: 0.0475 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7951 - val_loss: 5.7975 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6246
#
# Epoch 00031: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-31_loss-5.0951_val_loss-5.7975.h5
# Epoch 32/70
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 5.0353 - pool1_GAP_substract_loss: 0.0632 - pool2_GAP_substract_loss: 0.0473 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7689 - val_loss: 5.7184 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5790
#
# Epoch 00032: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-32_loss-5.0353_val_loss-5.7184.h5
# Epoch 33/70
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 907s 907ms/step - loss: 5.0137 - pool1_GAP_substract_loss: 0.0637 - pool2_GAP_substract_loss: 0.0474 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7798 - val_loss: 5.7515 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6447
#
# Epoch 00033: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-33_loss-5.0137_val_loss-5.7515.h5
# Epoch 34/70
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 909s 909ms/step - loss: 4.9670 - pool1_GAP_substract_loss: 0.0633 - pool2_GAP_substract_loss: 0.0476 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7655 - val_loss: 5.6406 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5658
#
# Epoch 00034: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-34_loss-4.9670_val_loss-5.6406.h5
# Epoch 35/70
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 894s 894ms/step - loss: 4.9133 - pool1_GAP_substract_loss: 0.0633 - pool2_GAP_substract_loss: 0.0472 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7436 - val_loss: 5.7061 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6623
#
# Epoch 00035: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-35_loss-4.9133_val_loss-5.7061.h5
# Epoch 36/70
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 900s 900ms/step - loss: 4.8804 - pool1_GAP_substract_loss: 0.0650 - pool2_GAP_substract_loss: 0.0483 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7387 - val_loss: 5.5090 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4957
#
# Epoch 00036: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-36_loss-4.8804_val_loss-5.5090.h5
# Epoch 37/70
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 915s 915ms/step - loss: 4.7925 - pool1_GAP_substract_loss: 0.0647 - pool2_GAP_substract_loss: 0.0482 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6814 - val_loss: 5.5842 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6007
#
# Epoch 00037: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-37_loss-4.7925_val_loss-5.5842.h5
# Epoch 38/70
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 917s 917ms/step - loss: 4.8159 - pool1_GAP_substract_loss: 0.0630 - pool2_GAP_substract_loss: 0.0469 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7372 - val_loss: 5.5758 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6213
#
# Epoch 00038: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-38_loss-4.8159_val_loss-5.5758.h5
# Epoch 39/70
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 915s 915ms/step - loss: 4.7297 - pool1_GAP_substract_loss: 0.0637 - pool2_GAP_substract_loss: 0.0474 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6788 - val_loss: 5.4703 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5444
#
# Epoch 00039: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-39_loss-4.7297_val_loss-5.4703.h5
# Epoch 40/70
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 947s 947ms/step - loss: 4.7140 - pool1_GAP_substract_loss: 0.0635 - pool2_GAP_substract_loss: 0.0476 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6912 - val_loss: 5.5455 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6474
#
# Epoch 00040: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-40_loss-4.7140_val_loss-5.5455.h5
# Epoch 41/70
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 940s 940ms/step - loss: 4.6476 - pool1_GAP_substract_loss: 0.0627 - pool2_GAP_substract_loss: 0.0471 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6536 - val_loss: 5.5384 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6676
#
# Epoch 00041: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-41_loss-4.6476_val_loss-5.5384.h5
# Epoch 42/70
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 953s 953ms/step - loss: 4.6068 - pool1_GAP_substract_loss: 0.0638 - pool2_GAP_substract_loss: 0.0477 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6383 - val_loss: 5.4659 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6221
#
# Epoch 00042: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-42_loss-4.6068_val_loss-5.4659.h5
# Epoch 43/70
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 951s 951ms/step - loss: 4.5950 - pool1_GAP_substract_loss: 0.0633 - pool2_GAP_substract_loss: 0.0472 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6540 - val_loss: 5.3774 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5597
#
# Epoch 00043: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-43_loss-4.5950_val_loss-5.3774.h5
# Epoch 44/70
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 980s 980ms/step - loss: 4.5568 - pool1_GAP_substract_loss: 0.0631 - pool2_GAP_substract_loss: 0.0468 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6422 - val_loss: 5.3474 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5553
#
# Epoch 00044: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-44_loss-4.5568_val_loss-5.3474.h5
# Epoch 45/70
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 938s 938ms/step - loss: 4.4896 - pool1_GAP_substract_loss: 0.0635 - pool2_GAP_substract_loss: 0.0471 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5997 - val_loss: 5.3959 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6291
#
# Epoch 00045: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-45_loss-4.4896_val_loss-5.3959.h5
# Epoch 46/70
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 918s 918ms/step - loss: 4.4999 - pool1_GAP_substract_loss: 0.0631 - pool2_GAP_substract_loss: 0.0469 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6355 - val_loss: 5.4803 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7379
#
# Epoch 00046: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-46_loss-4.4999_val_loss-5.4803.h5
# Epoch 47/70
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 4.4617 - pool1_GAP_substract_loss: 0.0635 - pool2_GAP_substract_loss: 0.0472 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6208 - val_loss: 5.3593 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6408
#
# Epoch 00047: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-47_loss-4.4617_val_loss-5.3593.h5
# Epoch 48/70
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 913s 913ms/step - loss: 4.4290 - pool1_GAP_substract_loss: 0.0633 - pool2_GAP_substract_loss: 0.0475 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6118 - val_loss: 5.3501 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6551
#
# Epoch 00048: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-48_loss-4.4290_val_loss-5.3501.h5
# Epoch 49/70
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 909s 909ms/step - loss: 4.3769 - pool1_GAP_substract_loss: 0.0627 - pool2_GAP_substract_loss: 0.0468 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5843 - val_loss: 5.3785 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7066
#
# Epoch 00049: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-49_loss-4.3769_val_loss-5.3785.h5
# Epoch 50/70
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 934s 934ms/step - loss: 4.3440 - pool1_GAP_substract_loss: 0.0637 - pool2_GAP_substract_loss: 0.0475 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5724 - val_loss: 5.1736 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5242
#
# Epoch 00050: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-50_loss-4.3440_val_loss-5.1736.h5
# Epoch 51/70
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 939s 939ms/step - loss: 4.1641 - pool1_GAP_substract_loss: 0.0618 - pool2_GAP_substract_loss: 0.0460 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4086 - val_loss: 5.1055 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4589
#
# Epoch 00051: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-51_loss-4.1641_val_loss-5.1055.h5
# Epoch 52/70
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 927s 927ms/step - loss: 4.1069 - pool1_GAP_substract_loss: 0.0614 - pool2_GAP_substract_loss: 0.0457 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3549 - val_loss: 5.1112 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4675
#
# Epoch 00052: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-52_loss-4.1069_val_loss-5.1112.h5
# Epoch 53/70
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 898s 898ms/step - loss: 4.0948 - pool1_GAP_substract_loss: 0.0605 - pool2_GAP_substract_loss: 0.0451 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3470 - val_loss: 5.0865 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4455
#
# Epoch 00053: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-53_loss-4.0948_val_loss-5.0865.h5
# Epoch 54/70
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 905s 905ms/step - loss: 4.0609 - pool1_GAP_substract_loss: 0.0621 - pool2_GAP_substract_loss: 0.0459 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3136 - val_loss: 5.0703 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4321
#
# Epoch 00054: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-54_loss-4.0609_val_loss-5.0703.h5
# Epoch 55/70
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 875s 875ms/step - loss: 4.0672 - pool1_GAP_substract_loss: 0.0623 - pool2_GAP_substract_loss: 0.0463 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3220 - val_loss: 5.0935 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4580
#
# Epoch 00055: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-55_loss-4.0672_val_loss-5.0935.h5
# Epoch 56/70
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 870s 870ms/step - loss: 4.0498 - pool1_GAP_substract_loss: 0.0619 - pool2_GAP_substract_loss: 0.0455 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3086 - val_loss: 5.0584 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4258
#
# Epoch 00056: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-56_loss-4.0498_val_loss-5.0584.h5
# Epoch 57/70
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 882s 882ms/step - loss: 4.0400 - pool1_GAP_substract_loss: 0.0604 - pool2_GAP_substract_loss: 0.0456 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3028 - val_loss: 5.1299 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5000
#
# Epoch 00057: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-57_loss-4.0400_val_loss-5.1299.h5
# Epoch 58/70
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 878s 878ms/step - loss: 4.0160 - pool1_GAP_substract_loss: 0.0609 - pool2_GAP_substract_loss: 0.0454 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2814 - val_loss: 5.1237 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4965
#
# Epoch 00058: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-58_loss-4.0160_val_loss-5.1237.h5
# Epoch 59/70
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 880s 880ms/step - loss: 4.0429 - pool1_GAP_substract_loss: 0.0603 - pool2_GAP_substract_loss: 0.0451 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3119 - val_loss: 5.1133 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4889
#
# Epoch 00059: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-59_loss-4.0429_val_loss-5.1133.h5
# Epoch 60/70
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 889s 889ms/step - loss: 4.0286 - pool1_GAP_substract_loss: 0.0609 - pool2_GAP_substract_loss: 0.0458 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2990 - val_loss: 5.1112 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4895
#
# Epoch 00060: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-60_loss-4.0286_val_loss-5.1112.h5
# Epoch 61/70
#
# Epoch 00061: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 900s 900ms/step - loss: 4.0074 - pool1_GAP_substract_loss: 0.0619 - pool2_GAP_substract_loss: 0.0460 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2782 - val_loss: 5.0708 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4493
#
# Epoch 00061: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-61_loss-4.0074_val_loss-5.0708.h5
# Epoch 62/70
#
# Epoch 00062: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 893s 893ms/step - loss: 4.0090 - pool1_GAP_substract_loss: 0.0613 - pool2_GAP_substract_loss: 0.0455 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2810 - val_loss: 5.0561 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4349
#
# Epoch 00062: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-62_loss-4.0090_val_loss-5.0561.h5
# Epoch 63/70
#
# Epoch 00063: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 906s 906ms/step - loss: 4.0329 - pool1_GAP_substract_loss: 0.0595 - pool2_GAP_substract_loss: 0.0448 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3078 - val_loss: 5.0718 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4509
#
# Epoch 00063: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-63_loss-4.0329_val_loss-5.0718.h5
# Epoch 64/70
#
# Epoch 00064: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 907s 907ms/step - loss: 3.9839 - pool1_GAP_substract_loss: 0.0609 - pool2_GAP_substract_loss: 0.0457 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2567 - val_loss: 5.1010 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4804
#
# Epoch 00064: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-64_loss-3.9839_val_loss-5.1010.h5
# Epoch 65/70
#
# Epoch 00065: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 897s 897ms/step - loss: 3.9828 - pool1_GAP_substract_loss: 0.0610 - pool2_GAP_substract_loss: 0.0455 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2561 - val_loss: 5.1069 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4866
#
# Epoch 00065: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-65_loss-3.9828_val_loss-5.1069.h5
# Epoch 66/70
#
# Epoch 00066: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 918s 918ms/step - loss: 3.9675 - pool1_GAP_substract_loss: 0.0612 - pool2_GAP_substract_loss: 0.0460 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2403 - val_loss: 5.0900 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4699
#
# Epoch 00066: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-66_loss-3.9675_val_loss-5.0900.h5
# Epoch 67/70
#
# Epoch 00067: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 887s 887ms/step - loss: 4.0002 - pool1_GAP_substract_loss: 0.0612 - pool2_GAP_substract_loss: 0.0457 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2737 - val_loss: 5.0947 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4750
#
# Epoch 00067: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-67_loss-4.0002_val_loss-5.0947.h5
# Epoch 68/70
#
# Epoch 00068: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 883s 883ms/step - loss: 3.9715 - pool1_GAP_substract_loss: 0.0610 - pool2_GAP_substract_loss: 0.0454 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2457 - val_loss: 5.0924 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4728
#
# Epoch 00068: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-68_loss-3.9715_val_loss-5.0924.h5
# Epoch 69/70
#
# Epoch 00069: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 3.9702 - pool1_GAP_substract_loss: 0.0607 - pool2_GAP_substract_loss: 0.0452 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2451 - val_loss: 5.1156 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4963
#
# Epoch 00069: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-69_loss-3.9702_val_loss-5.1156.h5
# Epoch 70/70
#
# Epoch 00070: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 882s 882ms/step - loss: 3.9599 - pool1_GAP_substract_loss: 0.0616 - pool2_GAP_substract_loss: 0.0460 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2334 - val_loss: 5.0944 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4754
#
# Epoch 00070: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight1/epoch-70_loss-3.9599_val_loss-5.0944.h5

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()
# Out:
# Image: ../../datasets/Cityscapes/JPEGImages/source_strasbourg_000001_024701_leftImg8bit

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
# Out:
# Image: ../../datasets/Cityscapes/JPEGImages/source_tubingen_000068_000019_leftImg8bit
#
# Ground truth boxes:
#
# [[  2 404 152 417 179]
#  [  3 447 143 453 152]
#  [  3   3 121  49 225]
#  [  3 565 148 691 261]
#  [  3 622 141 798 329]
#  [  8 343 146 361 197]
#  [  8 350 164 368 197]
#  [  8 409 164 414 183]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4c88a6df60d1> in <module>()
#      47 # 5: Convert the predictions for the original image.
#      48
# ---> 49 y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)
#      50
#      51 np.set_printoptions(precision=2, suppress=True, linewidth=90)
#
# /domain_adaptation_object_detection/LLFDA_IJCAI2019/data_generator/object_detection_2d_misc_utils.py in apply_inverse_transforms(y_pred_decoded, inverse_transforms)
#      56                 for inverter in inverse_transforms[i]:
#      57                     if not (inverter is None):
# ---> 58                         y_pred_decoded_inv[i] = inverter(y_pred_decoded_inv[i])
#      59
#      60     elif isinstance(y_pred_decoded, np.ndarray):
#
# TypeError: 'list' object is not callable
