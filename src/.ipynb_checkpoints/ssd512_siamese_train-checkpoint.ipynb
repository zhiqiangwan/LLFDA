# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [10.0, 10.0, 0.0] + [1.0]
experiment = 'MMD_pool1pool2_weight10'

#  
DatasetName = 'SIM10K_to_City_resize_400_800' # 'City_to_foggy0_01_resize_400_800'  # 'SIM10K_to_VOC07_resize_400_800' #   'SIM10K_to_VOC12_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

# Define model callbacks.
checkpoint_path = os.path.join('../trained_weights', DatasetName, experiment)
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)    
    
if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')
# Out:
# da_loss_metric is MMD_loss

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 2966/2966 [00:00<00:00, 4873.92it/s]
# Loading source image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 11318.68it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 11089.93it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 2966/2966 [00:00<00:00, 7993.73it/s]
# Loading source labels: 100%|██████████| 493/493 [00:00<00:00, 4542.99it/s]
# Loading source image IDs: 100%|██████████| 493/493 [00:00<00:00, 10998.66it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 493/493 [00:00<00:00, 8105.87it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  2966
# Number of images in the validation dataset:	   493

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 60:
        return 0.0001
    else:
        return 0.00001

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 70
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/70
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 1178s 1s/step - loss: 10.6940 - pool1_GAP_substract_loss: 0.0746 - pool2_GAP_substract_loss: 0.0500 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 5.9117 - val_loss: 8.7073 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.1843
#
# Epoch 00001: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-01_loss-10.6940_val_loss-8.7073.h5
# Epoch 2/70
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 863s 863ms/step - loss: 9.2233 - pool1_GAP_substract_loss: 0.0618 - pool2_GAP_substract_loss: 0.0478 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.6216 - val_loss: 8.2605 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7678
#
# Epoch 00002: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-02_loss-9.2233_val_loss-8.2605.h5
# Epoch 3/70
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 983s 983ms/step - loss: 9.0687 - pool1_GAP_substract_loss: 0.0618 - pool2_GAP_substract_loss: 0.0496 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.4929 - val_loss: 8.3951 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.9593
#
# Epoch 00003: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-03_loss-9.0687_val_loss-8.3951.h5
# Epoch 4/70
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1664s 2s/step - loss: 8.5718 - pool1_GAP_substract_loss: 0.0576 - pool2_GAP_substract_loss: 0.0479 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.1122 - val_loss: 7.7147 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3367
#
# Epoch 00004: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-04_loss-8.5718_val_loss-7.7147.h5
# Epoch 5/70
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1541s 2s/step - loss: 8.2940 - pool1_GAP_substract_loss: 0.0553 - pool2_GAP_substract_loss: 0.0477 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.9168 - val_loss: 7.5857 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2646
#
# Epoch 00005: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-05_loss-8.2940_val_loss-7.5857.h5
# Epoch 6/70
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1501s 2s/step - loss: 8.1104 - pool1_GAP_substract_loss: 0.0553 - pool2_GAP_substract_loss: 0.0480 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.7863 - val_loss: 7.4510 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1860
#
# Epoch 00006: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-06_loss-8.1104_val_loss-7.4510.h5
# Epoch 7/70
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 925s 925ms/step - loss: 7.8973 - pool1_GAP_substract_loss: 0.0534 - pool2_GAP_substract_loss: 0.0467 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.6608 - val_loss: 7.4797 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2702
#
# Epoch 00007: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-07_loss-7.8973_val_loss-7.4797.h5
# Epoch 8/70
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1449s 1s/step - loss: 7.7039 - pool1_GAP_substract_loss: 0.0532 - pool2_GAP_substract_loss: 0.0469 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5230 - val_loss: 7.2300 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0750
#
# Epoch 00008: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-08_loss-7.7039_val_loss-7.2300.h5
# Epoch 9/70
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1403s 1s/step - loss: 7.6014 - pool1_GAP_substract_loss: 0.0527 - pool2_GAP_substract_loss: 0.0458 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4905 - val_loss: 7.0699 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9684
#
# Epoch 00009: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-09_loss-7.6014_val_loss-7.0699.h5
# Epoch 10/70
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1009s 1s/step - loss: 7.4843 - pool1_GAP_substract_loss: 0.0518 - pool2_GAP_substract_loss: 0.0448 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4453 - val_loss: 6.8365 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7873
#
# Epoch 00010: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-10_loss-7.4843_val_loss-6.8365.h5
# Epoch 11/70
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1050s 1s/step - loss: 7.3554 - pool1_GAP_substract_loss: 0.0514 - pool2_GAP_substract_loss: 0.0442 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3776 - val_loss: 6.8317 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8339
#
# Epoch 00011: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-11_loss-7.3554_val_loss-6.8317.h5
# Epoch 12/70
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 982s 982ms/step - loss: 7.2820 - pool1_GAP_substract_loss: 0.0507 - pool2_GAP_substract_loss: 0.0431 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3736 - val_loss: 7.0799 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1324
#
# Epoch 00012: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-12_loss-7.2820_val_loss-7.0799.h5
# Epoch 13/70
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1005s 1s/step - loss: 7.1473 - pool1_GAP_substract_loss: 0.0520 - pool2_GAP_substract_loss: 0.0440 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2668 - val_loss: 6.6705 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7722
#
# Epoch 00013: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-13_loss-7.1473_val_loss-6.6705.h5
# Epoch 14/70
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1035s 1s/step - loss: 7.0729 - pool1_GAP_substract_loss: 0.0506 - pool2_GAP_substract_loss: 0.0429 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2659 - val_loss: 6.5403 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6902
#
# Epoch 00014: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-14_loss-7.0729_val_loss-6.5403.h5
# Epoch 15/70
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1001s 1s/step - loss: 6.9482 - pool1_GAP_substract_loss: 0.0495 - pool2_GAP_substract_loss: 0.0420 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2089 - val_loss: 6.6296 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8268
#
# Epoch 00015: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-15_loss-6.9482_val_loss-6.6296.h5
# Epoch 16/70
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 951s 951ms/step - loss: 6.8476 - pool1_GAP_substract_loss: 0.0486 - pool2_GAP_substract_loss: 0.0413 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1708 - val_loss: 6.3913 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6349
#
# Epoch 00016: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-16_loss-6.8476_val_loss-6.3913.h5
# Epoch 17/70
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 994s 994ms/step - loss: 6.7967 - pool1_GAP_substract_loss: 0.0488 - pool2_GAP_substract_loss: 0.0411 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1664 - val_loss: 6.2698 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5583
#
# Epoch 00017: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-17_loss-6.7967_val_loss-6.2698.h5
# Epoch 18/70
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 979s 979ms/step - loss: 6.7104 - pool1_GAP_substract_loss: 0.0497 - pool2_GAP_substract_loss: 0.0415 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1116 - val_loss: 6.3431 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6759
#
# Epoch 00018: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-18_loss-6.7104_val_loss-6.3431.h5
# Epoch 19/70
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 976s 976ms/step - loss: 6.6415 - pool1_GAP_substract_loss: 0.0492 - pool2_GAP_substract_loss: 0.0414 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0914 - val_loss: 6.3477 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7238
#
# Epoch 00019: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-19_loss-6.6415_val_loss-6.3477.h5
# Epoch 20/70
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 983s 983ms/step - loss: 6.5701 - pool1_GAP_substract_loss: 0.0495 - pool2_GAP_substract_loss: 0.0411 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0627 - val_loss: 6.3021 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7203
#
# Epoch 00020: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-20_loss-6.5701_val_loss-6.3021.h5
# Epoch 21/70
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 6.4695 - pool1_GAP_substract_loss: 0.0487 - pool2_GAP_substract_loss: 0.0406 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0175 - val_loss: 6.3061 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7660
#
# Epoch 00021: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-21_loss-6.4695_val_loss-6.3061.h5
# Epoch 22/70
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 974s 974ms/step - loss: 6.4558 - pool1_GAP_substract_loss: 0.0497 - pool2_GAP_substract_loss: 0.0409 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0317 - val_loss: 6.1775 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6779
#
# Epoch 00022: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-22_loss-6.4558_val_loss-6.1775.h5
# Epoch 23/70
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 961s 961ms/step - loss: 6.3686 - pool1_GAP_substract_loss: 0.0497 - pool2_GAP_substract_loss: 0.0411 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9820 - val_loss: 6.0221 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5620
#
# Epoch 00023: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-23_loss-6.3686_val_loss-6.0221.h5
# Epoch 24/70
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 940s 940ms/step - loss: 6.3412 - pool1_GAP_substract_loss: 0.0493 - pool2_GAP_substract_loss: 0.0409 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0003 - val_loss: 5.9988 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5774
#
# Epoch 00024: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-24_loss-6.3412_val_loss-5.9988.h5
# Epoch 25/70
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 955s 955ms/step - loss: 6.2254 - pool1_GAP_substract_loss: 0.0484 - pool2_GAP_substract_loss: 0.0400 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9414 - val_loss: 5.9901 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6069
#
# Epoch 00025: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-25_loss-6.2254_val_loss-5.9901.h5
# Epoch 26/70
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 993s 993ms/step - loss: 6.1569 - pool1_GAP_substract_loss: 0.0487 - pool2_GAP_substract_loss: 0.0402 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9049 - val_loss: 5.9497 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6038
#
# Epoch 00026: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-26_loss-6.1569_val_loss-5.9497.h5
# Epoch 27/70
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 900s 900ms/step - loss: 6.1155 - pool1_GAP_substract_loss: 0.0495 - pool2_GAP_substract_loss: 0.0404 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8904 - val_loss: 5.9813 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6719
#
# Epoch 00027: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-27_loss-6.1155_val_loss-5.9813.h5
# Epoch 28/70
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 903s 903ms/step - loss: 6.0581 - pool1_GAP_substract_loss: 0.0485 - pool2_GAP_substract_loss: 0.0399 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8846 - val_loss: 5.8448 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5711
#
# Epoch 00028: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-28_loss-6.0581_val_loss-5.8448.h5
# Epoch 29/70
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 893s 893ms/step - loss: 6.0354 - pool1_GAP_substract_loss: 0.0480 - pool2_GAP_substract_loss: 0.0394 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9077 - val_loss: 5.6992 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4602
#
# Epoch 00029: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-29_loss-6.0354_val_loss-5.6992.h5
# Epoch 30/70
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 971s 971ms/step - loss: 5.9840 - pool1_GAP_substract_loss: 0.0482 - pool2_GAP_substract_loss: 0.0395 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8865 - val_loss: 5.8484 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6434
#
# Epoch 00030: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-30_loss-5.9840_val_loss-5.8484.h5
# Epoch 31/70
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 991s 991ms/step - loss: 5.8874 - pool1_GAP_substract_loss: 0.0488 - pool2_GAP_substract_loss: 0.0399 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8140 - val_loss: 5.8272 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6557
#
# Epoch 00031: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-31_loss-5.8874_val_loss-5.8272.h5
# Epoch 32/70
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 896s 896ms/step - loss: 5.8692 - pool1_GAP_substract_loss: 0.0483 - pool2_GAP_substract_loss: 0.0395 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8377 - val_loss: 5.6939 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5549
#
# Epoch 00032: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-32_loss-5.8692_val_loss-5.6939.h5
# Epoch 33/70
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 943s 943ms/step - loss: 5.8205 - pool1_GAP_substract_loss: 0.0468 - pool2_GAP_substract_loss: 0.0386 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8457 - val_loss: 5.6558 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5486
#
# Epoch 00033: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-33_loss-5.8205_val_loss-5.6558.h5
# Epoch 34/70
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 989s 989ms/step - loss: 5.7776 - pool1_GAP_substract_loss: 0.0483 - pool2_GAP_substract_loss: 0.0392 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8128 - val_loss: 5.6347 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5586
#
# Epoch 00034: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-34_loss-5.7776_val_loss-5.6347.h5
# Epoch 35/70
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1053s 1s/step - loss: 5.7457 - pool1_GAP_substract_loss: 0.0478 - pool2_GAP_substract_loss: 0.0392 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8165 - val_loss: 5.7388 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6933
#
# Epoch 00035: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-35_loss-5.7457_val_loss-5.7388.h5
# Epoch 36/70
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1077s 1s/step - loss: 5.6922 - pool1_GAP_substract_loss: 0.0487 - pool2_GAP_substract_loss: 0.0397 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7797 - val_loss: 5.4549 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4389
#
# Epoch 00036: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-36_loss-5.6922_val_loss-5.4549.h5
# Epoch 37/70
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 909s 909ms/step - loss: 5.6214 - pool1_GAP_substract_loss: 0.0484 - pool2_GAP_substract_loss: 0.0397 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7408 - val_loss: 5.4356 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4489
#
# Epoch 00037: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-37_loss-5.6214_val_loss-5.4356.h5
# Epoch 38/70
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1023s 1s/step - loss: 5.5989 - pool1_GAP_substract_loss: 0.0472 - pool2_GAP_substract_loss: 0.0384 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7730 - val_loss: 5.4211 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4628
#
# Epoch 00038: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-38_loss-5.5989_val_loss-5.4211.h5
# Epoch 39/70
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 912s 912ms/step - loss: 5.5355 - pool1_GAP_substract_loss: 0.0478 - pool2_GAP_substract_loss: 0.0390 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7251 - val_loss: 5.3834 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4532
#
# Epoch 00039: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-39_loss-5.5355_val_loss-5.3834.h5
# Epoch 40/70
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1093s 1s/step - loss: 5.5252 - pool1_GAP_substract_loss: 0.0480 - pool2_GAP_substract_loss: 0.0391 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7401 - val_loss: 5.3849 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4818
#
# Epoch 00040: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-40_loss-5.5252_val_loss-5.3849.h5
# Epoch 41/70
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 973s 973ms/step - loss: 5.4715 - pool1_GAP_substract_loss: 0.0482 - pool2_GAP_substract_loss: 0.0392 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7098 - val_loss: 5.4379 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5616
#
# Epoch 00041: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-41_loss-5.4715_val_loss-5.4379.h5
# Epoch 42/70
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 996s 996ms/step - loss: 5.4642 - pool1_GAP_substract_loss: 0.0480 - pool2_GAP_substract_loss: 0.0388 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7349 - val_loss: 5.3691 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5186
#
# Epoch 00042: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-42_loss-5.4642_val_loss-5.3691.h5
# Epoch 43/70
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 980s 980ms/step - loss: 5.3753 - pool1_GAP_substract_loss: 0.0468 - pool2_GAP_substract_loss: 0.0384 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6876 - val_loss: 5.3168 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4918
#
# Epoch 00043: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-43_loss-5.3753_val_loss-5.3168.h5
# Epoch 44/70
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 996s 996ms/step - loss: 5.3709 - pool1_GAP_substract_loss: 0.0477 - pool2_GAP_substract_loss: 0.0389 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6944 - val_loss: 5.3351 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5352
#
# Epoch 00044: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-44_loss-5.3709_val_loss-5.3351.h5
# Epoch 45/70
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1001s 1s/step - loss: 5.3041 - pool1_GAP_substract_loss: 0.0472 - pool2_GAP_substract_loss: 0.0385 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6619 - val_loss: 5.3421 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5667
#
# Epoch 00045: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-45_loss-5.3041_val_loss-5.3421.h5
# Epoch 46/70
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 990s 990ms/step - loss: 5.2965 - pool1_GAP_substract_loss: 0.0478 - pool2_GAP_substract_loss: 0.0387 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6702 - val_loss: 5.3724 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6206
#
# Epoch 00046: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-46_loss-5.2965_val_loss-5.3724.h5
# Epoch 47/70
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 894s 894ms/step - loss: 5.2491 - pool1_GAP_substract_loss: 0.0474 - pool2_GAP_substract_loss: 0.0384 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6533 - val_loss: 5.2180 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4897
#
# Epoch 00047: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-47_loss-5.2491_val_loss-5.2180.h5
# Epoch 48/70
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 5.2407 - pool1_GAP_substract_loss: 0.0482 - pool2_GAP_substract_loss: 0.0389 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6553 - val_loss: 5.2265 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5211
#
# Epoch 00048: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-48_loss-5.2407_val_loss-5.2265.h5
# Epoch 49/70
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 904s 904ms/step - loss: 5.2117 - pool1_GAP_substract_loss: 0.0483 - pool2_GAP_substract_loss: 0.0390 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6459 - val_loss: 5.1032 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4201
#
# Epoch 00049: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-49_loss-5.2117_val_loss-5.1032.h5
# Epoch 50/70
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 981s 981ms/step - loss: 5.1720 - pool1_GAP_substract_loss: 0.0473 - pool2_GAP_substract_loss: 0.0382 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6466 - val_loss: 5.1460 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4847
#
# Epoch 00050: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-50_loss-5.1720_val_loss-5.1460.h5
# Epoch 51/70
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 952s 952ms/step - loss: 4.9753 - pool1_GAP_substract_loss: 0.0458 - pool2_GAP_substract_loss: 0.0378 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4813 - val_loss: 4.9781 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3197
#
# Epoch 00051: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-51_loss-4.9753_val_loss-4.9781.h5
# Epoch 52/70
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 992s 992ms/step - loss: 4.9287 - pool1_GAP_substract_loss: 0.0462 - pool2_GAP_substract_loss: 0.0381 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4305 - val_loss: 4.9752 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3196
#
# Epoch 00052: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-52_loss-4.9287_val_loss-4.9752.h5
# Epoch 53/70
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 924s 924ms/step - loss: 4.8857 - pool1_GAP_substract_loss: 0.0457 - pool2_GAP_substract_loss: 0.0376 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3999 - val_loss: 4.9778 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3249
#
# Epoch 00053: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-53_loss-4.8857_val_loss-4.9778.h5
# Epoch 54/70
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 923s 923ms/step - loss: 4.8664 - pool1_GAP_substract_loss: 0.0455 - pool2_GAP_substract_loss: 0.0376 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3863 - val_loss: 5.0182 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3681
#
# Epoch 00054: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-54_loss-4.8664_val_loss-5.0182.h5
# Epoch 55/70
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 915s 915ms/step - loss: 4.8414 - pool1_GAP_substract_loss: 0.0461 - pool2_GAP_substract_loss: 0.0379 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3548 - val_loss: 5.0088 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3614
#
# Epoch 00055: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-55_loss-4.8414_val_loss-5.0088.h5
# Epoch 56/70
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 924s 924ms/step - loss: 4.8434 - pool1_GAP_substract_loss: 0.0456 - pool2_GAP_substract_loss: 0.0375 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3684 - val_loss: 4.9576 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3130
#
# Epoch 00056: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-56_loss-4.8434_val_loss-4.9576.h5
# Epoch 57/70
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 893s 893ms/step - loss: 4.8339 - pool1_GAP_substract_loss: 0.0451 - pool2_GAP_substract_loss: 0.0374 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3675 - val_loss: 4.9662 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3243
#
# Epoch 00057: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-57_loss-4.8339_val_loss-4.9662.h5
# Epoch 58/70
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 913s 913ms/step - loss: 4.8447 - pool1_GAP_substract_loss: 0.0452 - pool2_GAP_substract_loss: 0.0374 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3801 - val_loss: 5.0127 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3735
#
# Epoch 00058: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-58_loss-4.8447_val_loss-5.0127.h5
# Epoch 59/70
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 951s 951ms/step - loss: 4.8316 - pool1_GAP_substract_loss: 0.0452 - pool2_GAP_substract_loss: 0.0371 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3725 - val_loss: 4.9893 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3528
#
# Epoch 00059: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-59_loss-4.8316_val_loss-4.9893.h5
# Epoch 60/70
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 957s 957ms/step - loss: 4.7974 - pool1_GAP_substract_loss: 0.0454 - pool2_GAP_substract_loss: 0.0373 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3368 - val_loss: 5.0035 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3697
#
# Epoch 00060: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-60_loss-4.7974_val_loss-5.0035.h5
# Epoch 61/70
#
# Epoch 00061: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 954s 954ms/step - loss: 4.8033 - pool1_GAP_substract_loss: 0.0452 - pool2_GAP_substract_loss: 0.0373 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3471 - val_loss: 4.9631 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3296
#
# Epoch 00061: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-61_loss-4.8033_val_loss-4.9631.h5
# Epoch 62/70
#
# Epoch 00062: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 922s 922ms/step - loss: 4.8092 - pool1_GAP_substract_loss: 0.0461 - pool2_GAP_substract_loss: 0.0378 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3390 - val_loss: 4.9664 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3332
#
# Epoch 00062: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-62_loss-4.8092_val_loss-4.9664.h5
# Epoch 63/70
#
# Epoch 00063: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 931s 931ms/step - loss: 4.7980 - pool1_GAP_substract_loss: 0.0452 - pool2_GAP_substract_loss: 0.0373 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3413 - val_loss: 4.9672 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3342
#
# Epoch 00063: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-63_loss-4.7980_val_loss-4.9672.h5
# Epoch 64/70
#
# Epoch 00064: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 925s 925ms/step - loss: 4.8033 - pool1_GAP_substract_loss: 0.0451 - pool2_GAP_substract_loss: 0.0371 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3510 - val_loss: 4.9990 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3663
#
# Epoch 00064: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-64_loss-4.8033_val_loss-4.9990.h5
# Epoch 65/70
#
# Epoch 00065: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 867s 867ms/step - loss: 4.8073 - pool1_GAP_substract_loss: 0.0449 - pool2_GAP_substract_loss: 0.0371 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3570 - val_loss: 4.9871 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3547
#
# Epoch 00065: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-65_loss-4.8073_val_loss-4.9871.h5
# Epoch 66/70
#
# Epoch 00066: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 876s 876ms/step - loss: 4.8015 - pool1_GAP_substract_loss: 0.0435 - pool2_GAP_substract_loss: 0.0364 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3725 - val_loss: 4.9574 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3253
#
# Epoch 00066: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-66_loss-4.8015_val_loss-4.9574.h5
# Epoch 67/70
#
# Epoch 00067: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 878s 878ms/step - loss: 4.7885 - pool1_GAP_substract_loss: 0.0450 - pool2_GAP_substract_loss: 0.0374 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3341 - val_loss: 4.9833 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3515
#
# Epoch 00067: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-67_loss-4.7885_val_loss-4.9833.h5
# Epoch 68/70
#
# Epoch 00068: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 872s 872ms/step - loss: 4.7748 - pool1_GAP_substract_loss: 0.0462 - pool2_GAP_substract_loss: 0.0379 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3041 - val_loss: 4.9944 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3628
#
# Epoch 00068: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-68_loss-4.7748_val_loss-4.9944.h5
# Epoch 69/70
#
# Epoch 00069: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 871s 871ms/step - loss: 4.7786 - pool1_GAP_substract_loss: 0.0450 - pool2_GAP_substract_loss: 0.0374 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3250 - val_loss: 5.0080 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3767
#
# Epoch 00069: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-69_loss-4.7786_val_loss-5.0080.h5
# Epoch 70/70
#
# Epoch 00070: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 887s 887ms/step - loss: 4.7752 - pool1_GAP_substract_loss: 0.0451 - pool2_GAP_substract_loss: 0.0372 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3231 - val_loss: 4.9834 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3524
#
# Epoch 00070: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_pool1pool2_weight10/epoch-70_loss-4.7752_val_loss-4.9834.h5

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()
# Out:
# Image: ../../datasets/Cityscapes/JPEGImages/source_bremen_000300_000019_leftImg8bit

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
# Out:
# Image: ../../datasets/Cityscapes/JPEGImages/source_krefeld_000000_000108_leftImg8bit
#
# Ground truth boxes:
#
# [[  3 405 158 430 180]
#  [  2 388 158 391 167]
#  [  3 395 162 401 166]
#  [  3 500 164 509 179]
#  [  3 362 155 377 172]
#  [  3 364 163 372 176]
#  [  3 288 164 308 200]
#  [  3 224 162 302 212]
#  [  3 429 138 445 186]
#  [  3 435 130 495 195]
#  [  3 454 162 504 203]
#  [  8 388 162 391 168]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4c88a6df60d1> in <module>()
#      47 # 5: Convert the predictions for the original image.
#      48
# ---> 49 y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)
#      50
#      51 np.set_printoptions(precision=2, suppress=True, linewidth=90)
#
# /domain_adaptation_object_detection/LLFDA_IJCAI2019/data_generator/object_detection_2d_misc_utils.py in apply_inverse_transforms(y_pred_decoded, inverse_transforms)
#      56                 for inverter in inverse_transforms[i]:
#      57                     if not (inverter is None):
# ---> 58                         y_pred_decoded_inv[i] = inverter(y_pred_decoded_inv[i])
#      59
#      60     elif isinstance(y_pred_decoded, np.ndarray):
#
# TypeError: 'list' object is not callable
