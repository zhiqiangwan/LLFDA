# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [50.0, 0.0, 0.0] + [1.0]
experiment = 'MMD_pool1_weight50'

#  
DatasetName = 'City_to_foggy0_01_resize_400_800'  #  'SIM10K_to_City_resize_400_800' # 'SIM10K_to_VOC07_resize_400_800' #   'SIM10K_to_VOC12_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

# Define model callbacks.
checkpoint_path = os.path.join('../trained_weights', DatasetName, experiment)
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)    
    
if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')
# Out:
# da_loss_metric is MMD_loss

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 2966/2966 [00:00<00:00, 4910.42it/s]
# Loading source image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 11060.74it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 11265.01it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 2966/2966 [00:00<00:00, 8106.91it/s]
# Loading source labels: 100%|██████████| 493/493 [00:00<00:00, 4848.33it/s]
# Loading source image IDs: 100%|██████████| 493/493 [00:00<00:00, 10822.68it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 493/493 [00:00<00:00, 8147.62it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  2966
# Number of images in the validation dataset:	   493

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 60:
        return 0.0001
    else:
        return 0.00001

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 70
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/70
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 823s 823ms/step - loss: 16.7220 - pool1_GAP_substract_loss: 0.0586 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 7.3117 - val_loss: 9.9694 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 6.4213
#
# Epoch 00001: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-01_loss-16.7220_val_loss-9.9694.h5
# Epoch 2/70
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 815s 815ms/step - loss: 13.4386 - pool1_GAP_substract_loss: 0.0487 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 5.0440 - val_loss: 8.6206 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.1008
#
# Epoch 00002: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-02_loss-13.4386_val_loss-8.6206.h5
# Epoch 3/70
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 13.5008 - pool1_GAP_substract_loss: 0.0504 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.9787 - val_loss: 8.3431 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8720
#
# Epoch 00003: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-03_loss-13.5008_val_loss-8.3431.h5
# Epoch 4/70
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 790s 790ms/step - loss: 13.0747 - pool1_GAP_substract_loss: 0.0513 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.5058 - val_loss: 8.0563 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6315
#
# Epoch 00004: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-04_loss-13.0747_val_loss-8.0563.h5
# Epoch 5/70
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 791s 791ms/step - loss: 12.9151 - pool1_GAP_substract_loss: 0.0513 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.3858 - val_loss: 7.7819 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3954
#
# Epoch 00005: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-05_loss-12.9151_val_loss-7.7819.h5
# Epoch 6/70
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 797s 797ms/step - loss: 12.3746 - pool1_GAP_substract_loss: 0.0483 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.1911 - val_loss: 7.6440 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3007
#
# Epoch 00006: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-06_loss-12.3746_val_loss-7.6440.h5
# Epoch 7/70
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 792s 792ms/step - loss: 11.8010 - pool1_GAP_substract_loss: 0.0453 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.9610 - val_loss: 7.5336 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2427
#
# Epoch 00007: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-07_loss-11.8010_val_loss-7.5336.h5
# Epoch 8/70
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 804s 804ms/step - loss: 11.7616 - pool1_GAP_substract_loss: 0.0464 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.8660 - val_loss: 7.3696 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1266
#
# Epoch 00008: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-08_loss-11.7616_val_loss-7.3696.h5
# Epoch 9/70
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 11.4982 - pool1_GAP_substract_loss: 0.0453 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.7635 - val_loss: 7.2784 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0840
#
# Epoch 00009: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-09_loss-11.4982_val_loss-7.2784.h5
# Epoch 10/70
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 11.2462 - pool1_GAP_substract_loss: 0.0442 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.6691 - val_loss: 7.1577 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0129
#
# Epoch 00010: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-10_loss-11.2462_val_loss-7.1577.h5
# Epoch 11/70
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 11.1911 - pool1_GAP_substract_loss: 0.0443 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.6454 - val_loss: 7.0814 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9837
#
# Epoch 00011: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-11_loss-11.1911_val_loss-7.0814.h5
# Epoch 12/70
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 11.0116 - pool1_GAP_substract_loss: 0.0438 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5657 - val_loss: 7.0158 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9667
#
# Epoch 00012: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-12_loss-11.0116_val_loss-7.0158.h5
# Epoch 13/70
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 804s 804ms/step - loss: 10.8592 - pool1_GAP_substract_loss: 0.0434 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5039 - val_loss: 6.9072 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9058
#
# Epoch 00013: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-13_loss-10.8592_val_loss-6.9072.h5
# Epoch 14/70
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 803s 803ms/step - loss: 10.7633 - pool1_GAP_substract_loss: 0.0432 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4746 - val_loss: 6.8602 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9061
#
# Epoch 00014: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-14_loss-10.7633_val_loss-6.8602.h5
# Epoch 15/70
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 804s 804ms/step - loss: 10.6498 - pool1_GAP_substract_loss: 0.0431 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4180 - val_loss: 6.8149 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9070
#
# Epoch 00015: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-15_loss-10.6498_val_loss-6.8149.h5
# Epoch 16/70
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 803s 803ms/step - loss: 10.4851 - pool1_GAP_substract_loss: 0.0420 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4134 - val_loss: 6.6890 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8247
#
# Epoch 00016: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-16_loss-10.4851_val_loss-6.6890.h5
# Epoch 17/70
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 804s 804ms/step - loss: 10.6107 - pool1_GAP_substract_loss: 0.0440 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3786 - val_loss: 6.5863 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7636
#
# Epoch 00017: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-17_loss-10.6107_val_loss-6.5863.h5
# Epoch 18/70
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 10.4086 - pool1_GAP_substract_loss: 0.0431 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3064 - val_loss: 6.7536 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9736
#
# Epoch 00018: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-18_loss-10.4086_val_loss-6.7536.h5
# Epoch 19/70
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 10.3143 - pool1_GAP_substract_loss: 0.0427 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2990 - val_loss: 6.4038 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6656
#
# Epoch 00019: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-19_loss-10.3143_val_loss-6.4038.h5
# Epoch 20/70
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 10.2422 - pool1_GAP_substract_loss: 0.0426 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2725 - val_loss: 6.4475 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7501
#
# Epoch 00020: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-20_loss-10.2422_val_loss-6.4475.h5
# Epoch 21/70
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 810s 810ms/step - loss: 10.2015 - pool1_GAP_substract_loss: 0.0430 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2310 - val_loss: 6.3576 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6987
#
# Epoch 00021: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-21_loss-10.2015_val_loss-6.3576.h5
# Epoch 22/70
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 812s 812ms/step - loss: 10.0543 - pool1_GAP_substract_loss: 0.0421 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2194 - val_loss: 6.3565 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7376
#
# Epoch 00022: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-22_loss-10.0543_val_loss-6.3565.h5
# Epoch 23/70
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 813s 813ms/step - loss: 9.9224 - pool1_GAP_substract_loss: 0.0415 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1781 - val_loss: 6.3703 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7900
#
# Epoch 00023: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-23_loss-9.9224_val_loss-6.3703.h5
# Epoch 24/70
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 9.9860 - pool1_GAP_substract_loss: 0.0430 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1358 - val_loss: 6.2237 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6804
#
# Epoch 00024: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-24_loss-9.9860_val_loss-6.2237.h5
# Epoch 25/70
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 832s 832ms/step - loss: 9.7955 - pool1_GAP_substract_loss: 0.0416 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1228 - val_loss: 6.2174 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7113
#
# Epoch 00025: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-25_loss-9.7955_val_loss-6.2174.h5
# Epoch 26/70
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 9.7291 - pool1_GAP_substract_loss: 0.0414 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1103 - val_loss: 6.1348 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6643
#
# Epoch 00026: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-26_loss-9.7291_val_loss-6.1348.h5
# Epoch 27/70
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 826s 826ms/step - loss: 9.6894 - pool1_GAP_substract_loss: 0.0413 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1130 - val_loss: 6.1652 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7295
#
# Epoch 00027: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-27_loss-9.6894_val_loss-6.1652.h5
# Epoch 28/70
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 824s 824ms/step - loss: 9.7617 - pool1_GAP_substract_loss: 0.0426 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0890 - val_loss: 6.0682 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6652
#
# Epoch 00028: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-28_loss-9.7617_val_loss-6.0682.h5
# Epoch 29/70
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 832s 832ms/step - loss: 9.5714 - pool1_GAP_substract_loss: 0.0413 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0657 - val_loss: 6.0811 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7107
#
# Epoch 00029: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-29_loss-9.5714_val_loss-6.0811.h5
# Epoch 30/70
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 817s 817ms/step - loss: 9.5127 - pool1_GAP_substract_loss: 0.0411 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0628 - val_loss: 6.1104 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7731
#
# Epoch 00030: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-30_loss-9.5127_val_loss-6.1104.h5
# Epoch 31/70
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 826s 826ms/step - loss: 13.7131 - pool1_GAP_substract_loss: 0.0796 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3875 - val_loss: 7.2721 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8917
#
# Epoch 00031: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-31_loss-13.7131_val_loss-7.2721.h5
# Epoch 32/70
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 819s 819ms/step - loss: 12.8234 - pool1_GAP_substract_loss: 0.0709 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3588 - val_loss: 7.0233 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6488
#
# Epoch 00032: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-32_loss-12.8234_val_loss-7.0233.h5
# Epoch 33/70
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 837s 837ms/step - loss: 11.3304 - pool1_GAP_substract_loss: 0.0574 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2354 - val_loss: 6.4387 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0847
#
# Epoch 00033: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-33_loss-11.3304_val_loss-6.4387.h5
# Epoch 34/70
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 834s 834ms/step - loss: 9.9993 - pool1_GAP_substract_loss: 0.0462 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0524 - val_loss: 6.3480 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0280
#
# Epoch 00034: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-34_loss-9.9993_val_loss-6.3480.h5
# Epoch 35/70
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 840s 840ms/step - loss: 9.7609 - pool1_GAP_substract_loss: 0.0447 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9989 - val_loss: 5.9702 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6858
#
# Epoch 00035: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-35_loss-9.7609_val_loss-5.9702.h5
# Epoch 36/70
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 833s 833ms/step - loss: 9.6549 - pool1_GAP_substract_loss: 0.0441 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9850 - val_loss: 6.1001 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8487
#
# Epoch 00036: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-36_loss-9.6549_val_loss-6.1001.h5
# Epoch 37/70
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 825s 825ms/step - loss: 9.6056 - pool1_GAP_substract_loss: 0.0441 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9701 - val_loss: 5.9909 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7720
#
# Epoch 00037: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-37_loss-9.6056_val_loss-5.9909.h5
# Epoch 38/70
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 9.5194 - pool1_GAP_substract_loss: 0.0435 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9808 - val_loss: 5.8864 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6998
#
# Epoch 00038: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-38_loss-9.5194_val_loss-5.8864.h5
# Epoch 39/70
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 9.3799 - pool1_GAP_substract_loss: 0.0426 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9555 - val_loss: 6.0157 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8610
#
# Epoch 00039: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-39_loss-9.3799_val_loss-6.0157.h5
# Epoch 40/70
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 9.3643 - pool1_GAP_substract_loss: 0.0431 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9215 - val_loss: 5.8482 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7237
#
# Epoch 00040: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-40_loss-9.3643_val_loss-5.8482.h5
# Epoch 41/70
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 9.2439 - pool1_GAP_substract_loss: 0.0421 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9327 - val_loss: 5.7243 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6304
#
# Epoch 00041: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-41_loss-9.2439_val_loss-5.7243.h5
# Epoch 42/70
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 814s 814ms/step - loss: 9.1668 - pool1_GAP_substract_loss: 0.0420 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8938 - val_loss: 5.7244 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6584
#
# Epoch 00042: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-42_loss-9.1668_val_loss-5.7244.h5
# Epoch 43/70
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 9.1778 - pool1_GAP_substract_loss: 0.0425 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8878 - val_loss: 5.8401 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8020
#
# Epoch 00043: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-43_loss-9.1778_val_loss-5.8401.h5
# Epoch 44/70
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 822s 822ms/step - loss: 9.0552 - pool1_GAP_substract_loss: 0.0420 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8453 - val_loss: 5.8467 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8359
#
# Epoch 00044: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-44_loss-9.0552_val_loss-5.8467.h5
# Epoch 45/70
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 837s 837ms/step - loss: 8.9720 - pool1_GAP_substract_loss: 0.0410 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8801 - val_loss: 5.6606 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6774
#
# Epoch 00045: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-45_loss-8.9720_val_loss-5.6606.h5
# Epoch 46/70
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 814s 814ms/step - loss: 9.0742 - pool1_GAP_substract_loss: 0.0425 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8676 - val_loss: 5.5253 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5671
#
# Epoch 00046: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-46_loss-9.0742_val_loss-5.5253.h5
# Epoch 47/70
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 839s 839ms/step - loss: 8.8875 - pool1_GAP_substract_loss: 0.0410 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8543 - val_loss: 5.5414 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6088
#
# Epoch 00047: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-47_loss-8.8875_val_loss-5.5414.h5
# Epoch 48/70
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 823s 823ms/step - loss: 8.8325 - pool1_GAP_substract_loss: 0.0408 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8420 - val_loss: 5.4922 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.5845
#
# Epoch 00048: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-48_loss-8.8325_val_loss-5.4922.h5
# Epoch 49/70
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 831s 831ms/step - loss: 8.8391 - pool1_GAP_substract_loss: 0.0410 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8526 - val_loss: 5.5070 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6240
#
# Epoch 00049: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-49_loss-8.8391_val_loss-5.5070.h5
# Epoch 50/70
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 834s 834ms/step - loss: 8.7265 - pool1_GAP_substract_loss: 0.0405 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8163 - val_loss: 5.4687 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.6100
#
# Epoch 00050: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-50_loss-8.7265_val_loss-5.4687.h5
# Epoch 51/70
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 824s 824ms/step - loss: 8.3488 - pool1_GAP_substract_loss: 0.0387 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6360 - val_loss: 5.3043 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4490
#
# Epoch 00051: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-51_loss-8.3488_val_loss-5.3043.h5
# Epoch 52/70
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 825s 825ms/step - loss: 8.2712 - pool1_GAP_substract_loss: 0.0381 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6146 - val_loss: 5.2918 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4397
#
# Epoch 00052: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-52_loss-8.2712_val_loss-5.2918.h5
# Epoch 53/70
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 817s 817ms/step - loss: 8.2275 - pool1_GAP_substract_loss: 0.0380 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5877 - val_loss: 5.2737 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4249
#
# Epoch 00053: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-53_loss-8.2275_val_loss-5.2737.h5
# Epoch 54/70
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 812s 812ms/step - loss: 8.3021 - pool1_GAP_substract_loss: 0.0390 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5690 - val_loss: 5.2395 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.3939
#
# Epoch 00054: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-54_loss-8.3021_val_loss-5.2395.h5
# Epoch 55/70
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 810s 810ms/step - loss: 8.1934 - pool1_GAP_substract_loss: 0.0382 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5379 - val_loss: 5.2856 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4433
#
# Epoch 00055: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-55_loss-8.1934_val_loss-5.2856.h5
# Epoch 56/70
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 813s 813ms/step - loss: 8.2104 - pool1_GAP_substract_loss: 0.0386 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5207 - val_loss: 5.2510 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4119
#
# Epoch 00056: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-56_loss-8.2104_val_loss-5.2510.h5
# Epoch 57/70
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 816s 816ms/step - loss: 8.1722 - pool1_GAP_substract_loss: 0.0381 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5382 - val_loss: 5.2457 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4098
#
# Epoch 00057: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-57_loss-8.1722_val_loss-5.2457.h5
# Epoch 58/70
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 816s 816ms/step - loss: 8.1666 - pool1_GAP_substract_loss: 0.0380 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5418 - val_loss: 5.2691 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4364
#
# Epoch 00058: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-58_loss-8.1666_val_loss-5.2691.h5
# Epoch 59/70
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 814s 814ms/step - loss: 8.1747 - pool1_GAP_substract_loss: 0.0382 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5325 - val_loss: 5.2982 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4688
#
# Epoch 00059: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-59_loss-8.1747_val_loss-5.2982.h5
# Epoch 60/70
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 822s 822ms/step - loss: 8.1393 - pool1_GAP_substract_loss: 0.0380 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5233 - val_loss: 5.2564 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4301
#
# Epoch 00060: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-60_loss-8.1393_val_loss-5.2564.h5
# Epoch 61/70
#
# Epoch 00061: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 824s 824ms/step - loss: 8.0807 - pool1_GAP_substract_loss: 0.0376 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5033 - val_loss: 5.2358 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4098
#
# Epoch 00061: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-61_loss-8.0807_val_loss-5.2358.h5
# Epoch 62/70
#
# Epoch 00062: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 812s 812ms/step - loss: 8.1426 - pool1_GAP_substract_loss: 0.0380 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5230 - val_loss: 5.2303 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4047
#
# Epoch 00062: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-62_loss-8.1426_val_loss-5.2303.h5
# Epoch 63/70
#
# Epoch 00063: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 8.0822 - pool1_GAP_substract_loss: 0.0378 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4902 - val_loss: 5.2423 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4170
#
# Epoch 00063: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-63_loss-8.0822_val_loss-5.2423.h5
# Epoch 64/70
#
# Epoch 00064: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 814s 814ms/step - loss: 8.0945 - pool1_GAP_substract_loss: 0.0374 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5360 - val_loss: 5.2615 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4365
#
# Epoch 00064: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-64_loss-8.0945_val_loss-5.2615.h5
# Epoch 65/70
#
# Epoch 00065: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 806s 806ms/step - loss: 8.1266 - pool1_GAP_substract_loss: 0.0375 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5607 - val_loss: 5.2669 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4422
#
# Epoch 00065: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-65_loss-8.1266_val_loss-5.2669.h5
# Epoch 66/70
#
# Epoch 00066: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 8.0522 - pool1_GAP_substract_loss: 0.0373 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5033 - val_loss: 5.2279 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4036
#
# Epoch 00066: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-66_loss-8.0522_val_loss-5.2279.h5
# Epoch 67/70
#
# Epoch 00067: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 810s 810ms/step - loss: 8.1153 - pool1_GAP_substract_loss: 0.0380 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4999 - val_loss: 5.2396 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4155
#
# Epoch 00067: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-67_loss-8.1153_val_loss-5.2396.h5
# Epoch 68/70
#
# Epoch 00068: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 8.0313 - pool1_GAP_substract_loss: 0.0374 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4749 - val_loss: 5.2495 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4258
#
# Epoch 00068: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-68_loss-8.0313_val_loss-5.2495.h5
# Epoch 69/70
#
# Epoch 00069: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 8.0646 - pool1_GAP_substract_loss: 0.0375 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5060 - val_loss: 5.2726 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4492
#
# Epoch 00069: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-69_loss-8.0646_val_loss-5.2726.h5
# Epoch 70/70
#
# Epoch 00070: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 8.0536 - pool1_GAP_substract_loss: 0.0373 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5078 - val_loss: 5.2418 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.4187
#
# Epoch 00070: saving model to ../trained_weights/City_to_foggy0_01_resize_400_800/MMD_modified_sigmas_pool1_weight100/epoch-70_loss-8.0536_val_loss-5.2418.h5

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()
# Out:
# Image: ../../datasets/Cityscapes/JPEGImages/source_zurich_000045_000019_leftImg8bit

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
# Out:
# Image: ../../datasets/Cityscapes/JPEGImages/source_monchengladbach_000000_018445_leftImg8bit
#
# Ground truth boxes:
#
# [[  1 216 155 223 168]
#  [  1 237 161 240 162]
#  [  1 227 159 231 165]
#  [  1 205 162 211 167]
#  [  1 587 143 610 184]
#  [  3 559 165 570 171]
#  [  3 617 162 621 171]
#  [  8 471 162 480 175]
#  [  8 675 240 798 289]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4c88a6df60d1> in <module>()
#      47 # 5: Convert the predictions for the original image.
#      48
# ---> 49 y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)
#      50
#      51 np.set_printoptions(precision=2, suppress=True, linewidth=90)
#
# /domain_adaptation_object_detection/LLFDA_IJCAI2019/data_generator/object_detection_2d_misc_utils.py in apply_inverse_transforms(y_pred_decoded, inverse_transforms)
#      56                 for inverter in inverse_transforms[i]:
#      57                     if not (inverter is None):
# ---> 58                         y_pred_decoded_inv[i] = inverter(y_pred_decoded_inv[i])
#      59
#      60     elif isinstance(y_pred_decoded, np.ndarray):
#
# TypeError: 'list' object is not callable
