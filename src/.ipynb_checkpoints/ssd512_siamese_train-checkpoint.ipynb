# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [0.0, 0.000005, 0.0] + [1.0]
Source_Only = False

# 'City_to_foggy0_01_resize_600_1200' # 'City_to_foggy0_02_resize_600_1200'  # 'SIM10K_to_VOC07'
# 'SIM10K'  # 'Cityscapes_foggy_beta_0_01'  #  'City_to_foggy0_02_resize_400_800'
DatasetName = 'City_to_foggy0_01_resize_400_800' # 'SIM10K_to_City_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

if DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_600_1200':
    resize_image_to = (600, 1200)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_600_1200':
    resize_image_to = (600, 1200)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'Cityscapes_foggy_beta_0_01':
    resize_image_to = (300, 600)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K':
    resize_image_to = (300, 600)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_VOC07':
    resize_image_to = (300, 600)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    
    
#     if Source_Only:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})
#     else:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 2966/2966 [00:00<00:00, 4461.21it/s]
# Loading source image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 10825.99it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 10311.08it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 2966/2966 [00:00<00:00, 7105.90it/s]
# Loading source labels: 100%|██████████| 493/493 [00:00<00:00, 4514.63it/s]
# Loading source image IDs: 100%|██████████| 493/493 [00:00<00:00, 10430.38it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 493/493 [00:00<00:00, 7121.82it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  2966
# Number of images in the validation dataset:	   493

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 50:
#         return 0.001
#     elif epoch < 60:
#         return 0.0001
#     else:
#         return 0.00001

# Define model callbacks.
checkpoint_path = '../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool2_loss_weights_0_000005'
# checkpoint_path = '../trained_weights/current/ssd_augm_beta_0_01_source_only'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'pool2_loss_weights_0_000005_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 120
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/120
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 768s 768ms/step - loss: 10.7258 - pool1_GAP_substract_loss: 25865.4530 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 7.0398 - val_loss: 9.0574 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.5159
#
# Epoch 00001: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-01_loss-10.7258_val_loss-9.0574.h5
# Epoch 2/120
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 8.3965 - pool1_GAP_substract_loss: 14749.1250 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.7979 - val_loss: 8.6088 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.1004
#
# Epoch 00002: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-02_loss-8.3965_val_loss-8.6088.h5
# Epoch 3/120
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 8.0187 - pool1_GAP_substract_loss: 11475.4526 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.4843 - val_loss: 8.2224 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7769
#
# Epoch 00003: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-03_loss-8.0187_val_loss-8.2224.h5
# Epoch 4/120
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 7.5349 - pool1_GAP_substract_loss: 8547.9469 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.0777 - val_loss: 8.1211 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7374
#
# Epoch 00004: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-04_loss-7.5349_val_loss-8.1211.h5
# Epoch 5/120
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 7.2963 - pool1_GAP_substract_loss: 7035.0170 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.9077 - val_loss: 7.8542 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5310
#
# Epoch 00005: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-05_loss-7.2963_val_loss-7.8542.h5
# Epoch 6/120
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 7.1449 - pool1_GAP_substract_loss: 5841.3101 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.8221 - val_loss: 7.6042 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3399
#
# Epoch 00006: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-06_loss-7.1449_val_loss-7.6042.h5
# Epoch 7/120
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 6.9313 - pool1_GAP_substract_loss: 5174.4575 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.6701 - val_loss: 7.5597 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3532
#
# Epoch 00007: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-07_loss-6.9313_val_loss-7.5597.h5
# Epoch 8/120
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 6.7439 - pool1_GAP_substract_loss: 4558.3035 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5430 - val_loss: 7.3077 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1578
#
# Epoch 00008: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-08_loss-6.7439_val_loss-7.3077.h5
# Epoch 9/120
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 6.6613 - pool1_GAP_substract_loss: 4034.3883 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5189 - val_loss: 7.2759 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1810
#
# Epoch 00009: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-09_loss-6.6613_val_loss-7.2759.h5
# Epoch 10/120
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 6.5138 - pool1_GAP_substract_loss: 3826.0765 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4269 - val_loss: 7.0902 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0493
#
# Epoch 00010: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-10_loss-6.5138_val_loss-7.0902.h5
# Epoch 11/120
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 6.3409 - pool1_GAP_substract_loss: 3456.0619 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3093 - val_loss: 7.2354 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2475
#
# Epoch 00011: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-11_loss-6.3409_val_loss-7.2354.h5
# Epoch 12/120
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 761s 761ms/step - loss: 6.2860 - pool1_GAP_substract_loss: 3254.4668 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3076 - val_loss: 6.9753 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0388
#
# Epoch 00012: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-12_loss-6.2860_val_loss-6.9753.h5
# Epoch 13/120
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 758s 758ms/step - loss: 6.1930 - pool1_GAP_substract_loss: 3147.5944 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2661 - val_loss: 7.1121 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2261
# Epoch 00013: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-13_loss-6.1930_val_loss-7.1121.h5
# Epoch 14/120
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 758s 758ms/step - loss: 6.0538 - pool1_GAP_substract_loss: 2939.7809 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1780 - val_loss: 6.9224 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0860
#
# Epoch 00014: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-14_loss-6.0538_val_loss-6.9224.h5
# Epoch 15/120
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 5.9826 - pool1_GAP_substract_loss: 2827.1080 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1562 - val_loss: 6.8620 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0738
#
# Epoch 00015: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-15_loss-5.9826_val_loss-6.8620.h5
# Epoch 16/120
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 5.8773 - pool1_GAP_substract_loss: 2670.2043 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0994 - val_loss: 6.7578 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0168
#
# Epoch 00016: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-16_loss-5.8773_val_loss-6.7578.h5
# Epoch 17/120
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 5.8538 - pool1_GAP_substract_loss: 2468.6500 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1238 - val_loss: 6.7727 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0782
#
# Epoch 00017: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-17_loss-5.8538_val_loss-6.7727.h5
# Epoch 18/120
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 758s 758ms/step - loss: 5.7939 - pool1_GAP_substract_loss: 2388.3783 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1101 - val_loss: 6.7992 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1497
#
# Epoch 00018: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-18_loss-5.7939_val_loss-6.7992.h5
# Epoch 19/120
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 5.7125 - pool1_GAP_substract_loss: 2354.6932 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0734 - val_loss: 6.7037 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0983
#
# Epoch 00019: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-19_loss-5.7125_val_loss-6.7037.h5
# Epoch 20/120
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 758s 758ms/step - loss: 5.6269 - pool1_GAP_substract_loss: 2252.7536 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0321 - val_loss: 6.4232 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8613
#
# Epoch 00020: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-20_loss-5.6269_val_loss-6.4232.h5
# Epoch 21/120
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 760s 760ms/step - loss: 5.5398 - pool1_GAP_substract_loss: 2162.1411 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9883 - val_loss: 6.6318 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1122
#
# Epoch 00021: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-21_loss-5.5398_val_loss-6.6318.h5
# Epoch 22/120
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 761s 761ms/step - loss: 5.4441 - pool1_GAP_substract_loss: 2185.6964 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9344 - val_loss: 6.5509 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0727
#
# Epoch 00022: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-22_loss-5.4441_val_loss-6.5509.h5
# Epoch 23/120
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 759s 759ms/step - loss: 5.4023 - pool1_GAP_substract_loss: 2075.4351 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9342 - val_loss: 6.4109 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9733
#
# Epoch 00023: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-23_loss-5.4023_val_loss-6.4109.h5
# Epoch 24/120
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 842s 842ms/step - loss: 5.3746 - pool1_GAP_substract_loss: 2077.7635 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9464 - val_loss: 6.2643 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8663
#
# Epoch 00024: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-24_loss-5.3746_val_loss-6.2643.h5
# Epoch 25/120
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 759s 759ms/step - loss: 5.2920 - pool1_GAP_substract_loss: 2005.5756 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9034 - val_loss: 6.3478 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9886
#
# Epoch 00025: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-25_loss-5.2920_val_loss-6.3478.h5
# Epoch 26/120
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 795s 795ms/step - loss: 5.2529 - pool1_GAP_substract_loss: 1938.8193 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9030 - val_loss: 6.4121 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0907
# Epoch 00026: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-26_loss-5.2529_val_loss-6.4121.h5
# Epoch 27/120
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 5.1959 - pool1_GAP_substract_loss: 1929.7465 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8834 - val_loss: 6.3647 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0804
#
# Epoch 00027: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-27_loss-5.1959_val_loss-6.3647.h5
# Epoch 28/120
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 807s 807ms/step - loss: 5.0830 - pool1_GAP_substract_loss: 1846.2950 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8077 - val_loss: 6.2922 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0441
#
# Epoch 00028: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-28_loss-5.0830_val_loss-6.2922.h5
# Epoch 29/120
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 760s 760ms/step - loss: 5.1319 - pool1_GAP_substract_loss: 1846.1782 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8922 - val_loss: 6.1697 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9568
#
# Epoch 00029: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-29_loss-5.1319_val_loss-6.1697.h5
# Epoch 30/120
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 775s 775ms/step - loss: 5.0595 - pool1_GAP_substract_loss: 1828.6266 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8547 - val_loss: 6.2814 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1028
#
# Epoch 00030: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-30_loss-5.0595_val_loss-6.2814.h5
# Epoch 31/120
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 772s 772ms/step - loss: 5.0022 - pool1_GAP_substract_loss: 1855.3773 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8314 - val_loss: 6.1524 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0078
#
# Epoch 00031: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-31_loss-5.0022_val_loss-6.1524.h5
# Epoch 32/120
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 785s 785ms/step - loss: 4.9407 - pool1_GAP_substract_loss: 1788.5237 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8035 - val_loss: 6.0610 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9492
#
# Epoch 00032: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-32_loss-4.9407_val_loss-6.0610.h5
# Epoch 33/120
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 772s 772ms/step - loss: 4.9209 - pool1_GAP_substract_loss: 1740.5493 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8165 - val_loss: 5.9342 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8547
#
# Epoch 00033: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-33_loss-4.9209_val_loss-5.9342.h5
# Epoch 34/120
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 771s 771ms/step - loss: 4.8352 - pool1_GAP_substract_loss: 1763.1091 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7628 - val_loss: 6.0796 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0317
#
# Epoch 00034: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-34_loss-4.8352_val_loss-6.0796.h5
# Epoch 35/120
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 766s 766ms/step - loss: 4.8048 - pool1_GAP_substract_loss: 1733.9778 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7638 - val_loss: 5.9712 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9544
#
# Epoch 00035: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-35_loss-4.8048_val_loss-5.9712.h5
# Epoch 36/120
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 843s 843ms/step - loss: 4.8070 - pool1_GAP_substract_loss: 1732.3389 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7965 - val_loss: 5.8008 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8140
#
# Epoch 00036: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-36_loss-4.8070_val_loss-5.8008.h5
# Epoch 37/120
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 795s 795ms/step - loss: 4.6999 - pool1_GAP_substract_loss: 1664.1413 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7196 - val_loss: 6.0191 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0620
#
# Epoch 00037: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-37_loss-4.6999_val_loss-6.0191.h5
# Epoch 38/120
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 815s 815ms/step - loss: 4.6646 - pool1_GAP_substract_loss: 1650.3320 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7137 - val_loss: 5.7541 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8258
#
# Epoch 00038: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-38_loss-4.6646_val_loss-5.7541.h5
# Epoch 39/120
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 788s 788ms/step - loss: 4.6215 - pool1_GAP_substract_loss: 1626.3402 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6994 - val_loss: 5.7401 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8404
# Epoch 00039: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-39_loss-4.6215_val_loss-5.7401.h5
# Epoch 40/120
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 814s 814ms/step - loss: 4.5663 - pool1_GAP_substract_loss: 1624.2774 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6725 - val_loss: 5.7551 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8834
#
# Epoch 00040: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-40_loss-4.5663_val_loss-5.7551.h5
# Epoch 41/120
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 801s 801ms/step - loss: 4.5468 - pool1_GAP_substract_loss: 1648.0935 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6803 - val_loss: 5.6664 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8217
#
# Epoch 00041: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-41_loss-4.5468_val_loss-5.6664.h5
# Epoch 42/120
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.5269 - pool1_GAP_substract_loss: 1646.3545 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6872 - val_loss: 5.7618 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9437
#
# Epoch 00042: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-42_loss-4.5269_val_loss-5.7618.h5
# Epoch 43/120
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 888s 888ms/step - loss: 4.4423 - pool1_GAP_substract_loss: 1565.7539 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6295 - val_loss: 5.7007 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9088
#
# Epoch 00043: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-43_loss-4.4423_val_loss-5.7007.h5
# Epoch 44/120
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 833s 833ms/step - loss: 4.4022 - pool1_GAP_substract_loss: 1638.9759 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6149 - val_loss: 5.7403 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9738
#
# Epoch 00044: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-44_loss-4.4022_val_loss-5.7403.h5
# Epoch 45/120
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 768s 768ms/step - loss: 4.4169 - pool1_GAP_substract_loss: 1583.6343 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6550 - val_loss: 5.6490 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9073
#
# Epoch 00045: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-45_loss-4.4169_val_loss-5.6490.h5
# Epoch 46/120
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 4.3752 - pool1_GAP_substract_loss: 1537.6613 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6380 - val_loss: 5.5955 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8781
#
# Epoch 00046: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-46_loss-4.3752_val_loss-5.5955.h5
# Epoch 47/120
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 785s 785ms/step - loss: 4.3660 - pool1_GAP_substract_loss: 1539.2167 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6529 - val_loss: 5.6198 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9261
#
# Epoch 00047: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-47_loss-4.3660_val_loss-5.6198.h5
# Epoch 48/120
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 4.2887 - pool1_GAP_substract_loss: 1571.3739 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5989 - val_loss: 5.7401 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0696
#
# Epoch 00048: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-48_loss-4.2887_val_loss-5.7401.h5
# Epoch 49/120
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 762s 762ms/step - loss: 4.2614 - pool1_GAP_substract_loss: 1547.4618 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5945 - val_loss: 5.6214 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9735
#
# Epoch 00049: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-49_loss-4.2614_val_loss-5.6214.h5
# Epoch 50/120
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 761s 761ms/step - loss: 4.2604 - pool1_GAP_substract_loss: 1569.2299 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6157 - val_loss: 5.5747 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9489
#
# Epoch 00050: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-50_loss-4.2604_val_loss-5.5747.h5
# Epoch 51/120
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 4.0264 - pool1_GAP_substract_loss: 1566.0630 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3942 - val_loss: 5.3956 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7726
#
# Epoch 00051: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-51_loss-4.0264_val_loss-5.3956.h5
# Epoch 52/120
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 836s 836ms/step - loss: 4.0122 - pool1_GAP_substract_loss: 1495.3149 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3832 - val_loss: 5.4194 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7992
# Epoch 00052: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-52_loss-4.0122_val_loss-5.4194.h5
# Epoch 53/120
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 824s 824ms/step - loss: 3.9697 - pool1_GAP_substract_loss: 1445.9094 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3437 - val_loss: 5.4227 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8052
#
# Epoch 00053: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-53_loss-3.9697_val_loss-5.4227.h5
# Epoch 54/120
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 822s 822ms/step - loss: 3.9606 - pool1_GAP_substract_loss: 1439.3606 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3374 - val_loss: 5.3990 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7843
#
# Epoch 00054: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-54_loss-3.9606_val_loss-5.3990.h5
# Epoch 55/120
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 827s 827ms/step - loss: 3.9453 - pool1_GAP_substract_loss: 1422.1780 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3249 - val_loss: 5.4559 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8439
#
# Epoch 00055: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-55_loss-3.9453_val_loss-5.4559.h5
# Epoch 56/120
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 827s 827ms/step - loss: 3.9139 - pool1_GAP_substract_loss: 1437.8065 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2961 - val_loss: 5.4311 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8219
#
# Epoch 00056: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-56_loss-3.9139_val_loss-5.4311.h5
# Epoch 57/120
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 830s 830ms/step - loss: 3.9580 - pool1_GAP_substract_loss: 1415.1577 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3431 - val_loss: 5.4200 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8135
#
# Epoch 00057: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-57_loss-3.9580_val_loss-5.4200.h5
# Epoch 58/120
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 827s 827ms/step - loss: 3.9178 - pool1_GAP_substract_loss: 1406.5666 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3056 - val_loss: 5.4752 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8715
#
# Epoch 00058: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-58_loss-3.9178_val_loss-5.4752.h5
# Epoch 59/120
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 821s 821ms/step - loss: 3.9047 - pool1_GAP_substract_loss: 1371.3903 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2954 - val_loss: 5.4494 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8484
#
# Epoch 00059: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-59_loss-3.9047_val_loss-5.4494.h5
# Epoch 60/120
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 838s 838ms/step - loss: 3.8985 - pool1_GAP_substract_loss: 1391.6802 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2918 - val_loss: 5.4420 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8437
#
# Epoch 00060: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-60_loss-3.8985_val_loss-5.4420.h5
# Epoch 61/120
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 783s 783ms/step - loss: 3.9262 - pool1_GAP_substract_loss: 1407.6708 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3221 - val_loss: 5.3674 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.7717
#
# Epoch 00061: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-61_loss-3.9262_val_loss-5.3674.h5
# Epoch 62/120
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 779s 779ms/step - loss: 3.9112 - pool1_GAP_substract_loss: 1408.7310 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3099 - val_loss: 5.4193 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8264
#
# Epoch 00062: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-62_loss-3.9112_val_loss-5.4193.h5
# Epoch 63/120
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 767s 767ms/step - loss: 3.8753 - pool1_GAP_substract_loss: 1395.0214 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2767 - val_loss: 5.5003 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9100
#
# Epoch 00063: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-63_loss-3.8753_val_loss-5.5003.h5
# Epoch 64/120
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 813s 813ms/step - loss: 3.8805 - pool1_GAP_substract_loss: 1360.6270 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2847 - val_loss: 5.5097 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9221
#
# Epoch 00064: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-64_loss-3.8805_val_loss-5.5097.h5
# Epoch 65/120
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 840s 840ms/step - loss: 3.8705 - pool1_GAP_substract_loss: 1380.5906 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2773 - val_loss: 5.4435 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8586
#
# Epoch 00065: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-65_loss-3.8705_val_loss-5.4435.h5
# Epoch 66/120
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 825s 825ms/step - loss: 3.8545 - pool1_GAP_substract_loss: 1370.5445 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2641 - val_loss: 5.4771 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8948
#
# Epoch 00066: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-66_loss-3.8545_val_loss-5.4771.h5
# Epoch 67/120
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 819s 819ms/step - loss: 3.8435 - pool1_GAP_substract_loss: 1364.7026 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2557 - val_loss: 5.4673 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8877
#
# Epoch 00067: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-67_loss-3.8435_val_loss-5.4673.h5
# Epoch 68/120
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 832s 832ms/step - loss: 3.8408 - pool1_GAP_substract_loss: 1370.4696 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2556 - val_loss: 5.4675 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8905
#
# Epoch 00068: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-68_loss-3.8408_val_loss-5.4675.h5
# Epoch 69/120
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 802s 802ms/step - loss: 3.8490 - pool1_GAP_substract_loss: 1348.1952 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2666 - val_loss: 5.5519 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9775
#
# Epoch 00069: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-69_loss-3.8490_val_loss-5.5519.h5
# Epoch 70/120
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 805s 805ms/step - loss: 3.8612 - pool1_GAP_substract_loss: 1357.8856 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2813 - val_loss: 5.5157 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9440
#
# Epoch 00070: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-70_loss-3.8612_val_loss-5.5157.h5
# Epoch 71/120
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 810s 810ms/step - loss: 3.8347 - pool1_GAP_substract_loss: 1376.1379 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2563 - val_loss: 5.5105 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9391
#
# Epoch 00071: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-71_loss-3.8347_val_loss-5.5105.h5
# Epoch 72/120
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 829s 829ms/step - loss: 3.8133 - pool1_GAP_substract_loss: 1349.5310 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2352 - val_loss: 5.5261 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9550
#
# Epoch 00072: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-72_loss-3.8133_val_loss-5.5261.h5
# Epoch 73/120
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 808s 808ms/step - loss: 3.8423 - pool1_GAP_substract_loss: 1362.2424 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2644 - val_loss: 5.5030 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9321
#
# Epoch 00073: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-73_loss-3.8423_val_loss-5.5030.h5
# Epoch 74/120
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 825s 825ms/step - loss: 3.8265 - pool1_GAP_substract_loss: 1347.5745 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2490 - val_loss: 5.5217 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9511
#
# Epoch 00074: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-74_loss-3.8265_val_loss-5.5217.h5
# Epoch 75/120
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
# ...
# 1000/1000 [==============================] - 822s 822ms/step - loss: 3.8086 - pool1_GAP_substract_loss: 1383.7038 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2343 - val_loss: 5.4727 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9055
#
# Epoch 00087: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-87_loss-3.8086_val_loss-5.4727.h5
# Epoch 88/120
#
# Epoch 00088: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 801s 801ms/step - loss: 3.8157 - pool1_GAP_substract_loss: 1324.4841 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2420 - val_loss: 5.4870 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9200
#
# Epoch 00088: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-88_loss-3.8157_val_loss-5.4870.h5
# Epoch 89/120
#
# Epoch 00089: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 803s 803ms/step - loss: 3.7871 - pool1_GAP_substract_loss: 1361.8090 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2134 - val_loss: 5.4804 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9137
#
# Epoch 00089: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-89_loss-3.7871_val_loss-5.4804.h5
# Epoch 90/120
#
# Epoch 00090: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 832s 832ms/step - loss: 3.8063 - pool1_GAP_substract_loss: 1352.2330 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2330 - val_loss: 5.4479 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8815
# Epoch 00090: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-90_loss-3.8063_val_loss-5.4479.h5
# Epoch 91/120
#
# Epoch 00091: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 825s 825ms/step - loss: 3.8058 - pool1_GAP_substract_loss: 1361.5771 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2327 - val_loss: 5.4658 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8996
#
# Epoch 00091: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-91_loss-3.8058_val_loss-5.4658.h5
# Epoch 92/120
#
# Epoch 00092: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 814s 814ms/step - loss: 3.8203 - pool1_GAP_substract_loss: 1363.8852 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2474 - val_loss: 5.4600 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8941
#
# Epoch 00092: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-92_loss-3.8203_val_loss-5.4600.h5
# Epoch 93/120
#
# Epoch 00093: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 824s 824ms/step - loss: 3.8381 - pool1_GAP_substract_loss: 1372.2212 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2654 - val_loss: 5.4552 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8896
#
# Epoch 00093: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-93_loss-3.8381_val_loss-5.4552.h5
# Epoch 94/120
#
# Epoch 00094: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 767s 767ms/step - loss: 3.8059 - pool1_GAP_substract_loss: 1387.8227 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2334 - val_loss: 5.4913 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9259
#
# Epoch 00094: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-94_loss-3.8059_val_loss-5.4913.h5
# Epoch 95/120
#
# Epoch 00095: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 803s 803ms/step - loss: 3.7922 - pool1_GAP_substract_loss: 1340.6953 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2203 - val_loss: 5.4801 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9150
#
# Epoch 00095: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-95_loss-3.7922_val_loss-5.4801.h5
# Epoch 96/120
#
# Epoch 00096: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 801s 801ms/step - loss: 3.7921 - pool1_GAP_substract_loss: 1368.4722 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2203 - val_loss: 5.4791 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9142
#
# Epoch 00096: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-96_loss-3.7921_val_loss-5.4791.h5
# Epoch 97/120
#
# Epoch 00097: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 3.7765 - pool1_GAP_substract_loss: 1389.6889 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2049 - val_loss: 5.4749 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9103
#
# Epoch 00097: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-97_loss-3.7765_val_loss-5.4749.h5
# Epoch 98/120
#
# Epoch 00098: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 809s 809ms/step - loss: 3.7838 - pool1_GAP_substract_loss: 1347.7711 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2126 - val_loss: 5.4789 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9145
#
# Epoch 00098: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-98_loss-3.7838_val_loss-5.4789.h5
# Epoch 99/120
#
# Epoch 00099: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 838s 838ms/step - loss: 3.7942 - pool1_GAP_substract_loss: 1389.7876 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2230 - val_loss: 5.4845 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9204
#
# Epoch 00099: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-99_loss-3.7942_val_loss-5.4845.h5
# Epoch 100/120
#
# Epoch 00100: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 866s 866ms/step - loss: 3.8236 - pool1_GAP_substract_loss: 1346.7436 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2529 - val_loss: 5.4495 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.8857
#
# Epoch 00100: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-100_loss-3.8236_val_loss-5.4495.h5
# Epoch 101/120
#
# Epoch 00101: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 917s 917ms/step - loss: 3.8149 - pool1_GAP_substract_loss: 1383.4585 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2443 - val_loss: 5.4748 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9112
#
# Epoch 00101: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-101_loss-3.8149_val_loss-5.4748.h5
# Epoch 102/120
#
# Epoch 00102: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.8088 - pool1_GAP_substract_loss: 1371.1265 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2385 - val_loss: 5.4726 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9093
#
# Epoch 00102: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-102_loss-3.8088_val_loss-5.4726.h5
# Epoch 103/120
#
# Epoch 00103: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 867s 867ms/step - loss: 3.7771 - pool1_GAP_substract_loss: 1360.3566 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2072 - val_loss: 5.4704 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9074
#
# Epoch 00103: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/pool1_loss_weights_0_000005/epoch-103_loss-3.7771_val_loss-5.4704.h5
# Epoch 104/120
#
# Epoch 00104: LearningRateScheduler setting learning rate to 1e-05.
#  350/1000 [=========>....................] - ETA: 8:31 - loss: 3.8167 - pool1_GAP_substract_loss: 1388.8559 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2467
# -----------------------------------------------------
# KeyboardInterrupt   Traceback (most recent call last)
# <ipython-input-6-ea67b764e796> in <module>()
#       9                               validation_data=val_generator,
#      10                               validation_steps=ceil(val_dataset_size/batch_size),
# ---> 11                               initial_epoch=initial_epoch)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
