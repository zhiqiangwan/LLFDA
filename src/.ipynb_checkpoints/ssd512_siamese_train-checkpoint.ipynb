# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [0.0, 0.0, 0.0] + [1.0]

# 'City_to_foggy0_01_resize_600_1200' # 'City_to_foggy0_02_resize_600_1200'  # 'SIM10K_to_VOC07'
# 'SIM10K'  # 'Cityscapes_foggy_beta_0_01'  #  'City_to_foggy0_02_resize_400_800'
# 'City_to_foggy0_01_resize_400_800' # 
DatasetName = 'SIM10K_to_VOC07_resize_400_800' # 'SIM10K_to_City_resize_400_800'  # 'SIM10K_to_VOC12_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    
    
#     if Source_Only:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})
#     else:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 10000/10000 [00:02<00:00, 4321.12it/s]
# Loading source image IDs: 100%|██████████| 10000/10000 [00:00<00:00, 10057.31it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 10720.05it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 10000/10000 [00:01<00:00, 7872.58it/s]
# Loading source labels: 100%|██████████| 479/479 [00:00<00:00, 4705.22it/s]
# Loading source image IDs: 100%|██████████| 479/479 [00:00<00:00, 10923.56it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 479/479 [00:00<00:00, 7131.42it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	 10000
# Number of images in the validation dataset:	   479

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 50:
#         return 0.001
#     elif epoch < 60:
#         return 0.0001
#     else:
#         return 0.00001

# Define model callbacks.
checkpoint_path = '../trained_weights/SSD512_SIM10K_to_VOC07_resize_400_800/current/source_only_run2'
# checkpoint_path = '../trained_weights/current/ssd_augm_beta_0_01_source_only'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'source_only_run2_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 120
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/120
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 8.3077 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 5.0205 - val_loss: 7.7808 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5076
#
# Epoch 00001: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-01_loss-8.3081_val_loss-7.7808.h5
# Epoch 2/120
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 746s 746ms/step - loss: 6.7052 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4461 - val_loss: 7.6519 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4069
#
# Epoch 00002: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-02_loss-6.7045_val_loss-7.6519.h5
# Epoch 3/120
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 744s 744ms/step - loss: 6.5841 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3647 - val_loss: 7.9162 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7230
#
# Epoch 00003: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-03_loss-6.5842_val_loss-7.9162.h5
# Epoch 4/120
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 749s 749ms/step - loss: 6.1203 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9532 - val_loss: 7.6139 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4731
#
# Epoch 00004: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-04_loss-6.1200_val_loss-7.6139.h5
# Epoch 5/120
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 746s 746ms/step - loss: 5.9452 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8300 - val_loss: 7.7477 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6579
#
# Epoch 00005: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-05_loss-5.9448_val_loss-7.7477.h5
# Epoch 6/120
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 744s 744ms/step - loss: 5.6403 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5761 - val_loss: 7.6376 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5990
#
# Epoch 00006: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-06_loss-5.6402_val_loss-7.6376.h5
# Epoch 7/120
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 746s 746ms/step - loss: 5.4965 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4833 - val_loss: 7.2376 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2493
#
# Epoch 00007: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-07_loss-5.4973_val_loss-7.2376.h5
# Epoch 8/120
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 747s 747ms/step - loss: 5.3258 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3624 - val_loss: 7.3713 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4326
#
# Epoch 00008: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-08_loss-5.3260_val_loss-7.3713.h5
# Epoch 9/120
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 744s 744ms/step - loss: 5.2615 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3467 - val_loss: 7.9035 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.0126
#
# Epoch 00009: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-09_loss-5.2613_val_loss-7.9035.h5
# Epoch 10/120
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 748s 748ms/step - loss: 5.0768 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2100 - val_loss: 7.1699 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3268
#
# Epoch 00010: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-10_loss-5.0765_val_loss-7.1699.h5
# Epoch 11/120
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 749s 749ms/step - loss: 4.9797 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1602 - val_loss: 6.8852 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0892
#
# Epoch 00011: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-11_loss-4.9793_val_loss-6.8852.h5
# Epoch 12/120
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 4.9624 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1893 - val_loss: 7.3917 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6411
#
# Epoch 00012: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-12_loss-4.9625_val_loss-7.3917.h5
# Epoch 13/120
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 748s 748ms/step - loss: 4.8100 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0819 - val_loss: 7.1654 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4596
#
# Epoch 00013: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-13_loss-4.8098_val_loss-7.1654.h5
# Epoch 14/120
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 744s 744ms/step - loss: 4.7650 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0815 - val_loss: 7.0188 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3571
#
# Epoch 00014: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-14_loss-4.7654_val_loss-7.0188.h5
# Epoch 15/120
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 745s 745ms/step - loss: 4.7073 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.0671 - val_loss: 7.3113 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6926
#
# Epoch 00015: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-15_loss-4.7072_val_loss-7.3113.h5
# Epoch 16/120
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 760s 760ms/step - loss: 4.5966 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9992 - val_loss: 7.2364 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6602
#
# Epoch 00016: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-16_loss-4.5966_val_loss-7.2364.h5
# Epoch 17/120
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 4.5313 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9757 - val_loss: 6.9248 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3899
#
# Epoch 00017: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-17_loss-4.5311_val_loss-6.9248.h5
# Epoch 18/120
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 762s 762ms/step - loss: 4.4869 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9723 - val_loss: 6.7448 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2503
#
# Epoch 00018: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-18_loss-4.4871_val_loss-6.7448.h5
# Epoch 19/120
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 758s 758ms/step - loss: 4.4113 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9365 - val_loss: 6.5070 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0520
#
# Epoch 00019: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-19_loss-4.4106_val_loss-6.5070.h5
# Epoch 20/120
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 743s 743ms/step - loss: 4.3671 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.9317 - val_loss: 6.8701 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4539
#
# Epoch 00020: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-20_loss-4.3674_val_loss-6.8701.h5
# Epoch 21/120
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 742s 742ms/step - loss: 4.2837 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8867 - val_loss: 6.7932 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4153
#
# Epoch 00021: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-21_loss-4.2836_val_loss-6.7932.h5
# Epoch 22/120
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 4.2079 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8487 - val_loss: 6.4619 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1214
#
# Epoch 00022: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-22_loss-4.2084_val_loss-6.4619.h5
# Epoch 23/120
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 4.1998 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8774 - val_loss: 6.3556 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0512
#
# Epoch 00023: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-23_loss-4.1998_val_loss-6.3556.h5
# Epoch 24/120
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 4.1509 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8643 - val_loss: 6.8269 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5577
#
# Epoch 00024: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-24_loss-4.1515_val_loss-6.8269.h5
# Epoch 25/120
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 4.0909 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.8394 - val_loss: 6.5373 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3032
#
# Epoch 00025: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-25_loss-4.0906_val_loss-6.5373.h5
# Epoch 26/120
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 767s 767ms/step - loss: 3.9902 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7736 - val_loss: 6.6605 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4612
#
# Epoch 00026: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-26_loss-3.9904_val_loss-6.6605.h5
# Epoch 27/120
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 771s 771ms/step - loss: 3.9362 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7539 - val_loss: 6.3343 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1693
#
# Epoch 00027: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-27_loss-3.9359_val_loss-6.3343.h5
# Epoch 28/120
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 758s 758ms/step - loss: 3.8963 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7478 - val_loss: 6.4253 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2931
#
# Epoch 00028: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-28_loss-3.8958_val_loss-6.4253.h5
# Epoch 29/120
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 759s 759ms/step - loss: 3.8520 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7359 - val_loss: 6.5529 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4529
#
# Epoch 00029: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-29_loss-3.8520_val_loss-6.5529.h5
# Epoch 30/120
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 766s 766ms/step - loss: 3.8452 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7613 - val_loss: 6.3304 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2624
#
# Epoch 00030: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-30_loss-3.8449_val_loss-6.3304.h5
# Epoch 31/120
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 765s 765ms/step - loss: 3.7659 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7138 - val_loss: 6.6143 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5781
#
# Epoch 00031: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-31_loss-3.7655_val_loss-6.6143.h5
# Epoch 32/120
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 767s 767ms/step - loss: 3.7686 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7474 - val_loss: 6.4346 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4284
#
# Epoch 00032: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-32_loss-3.7683_val_loss-6.4346.h5
# Epoch 33/120
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 771s 771ms/step - loss: 3.7113 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7201 - val_loss: 6.2322 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2558
#
# Epoch 00033: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-33_loss-3.7113_val_loss-6.2322.h5
# Epoch 34/120
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 769s 769ms/step - loss: 3.6603 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6987 - val_loss: 6.4749 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5276
#
# Epoch 00034: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-34_loss-3.6599_val_loss-6.4749.h5
# Epoch 35/120
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 764s 764ms/step - loss: 3.6492 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7161 - val_loss: 7.0448 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.1260
#
# Epoch 00035: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-35_loss-3.6492_val_loss-7.0448.h5
# Epoch 36/120
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 765s 765ms/step - loss: 3.5795 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6744 - val_loss: 6.5314 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6403
#
# Epoch 00036: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-36_loss-3.5794_val_loss-6.5314.h5
# Epoch 37/120
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 770s 770ms/step - loss: 3.5675 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6903 - val_loss: 6.4979 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6341
#
# Epoch 00037: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-37_loss-3.5673_val_loss-6.4979.h5
# Epoch 38/120
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 771s 771ms/step - loss: 3.5555 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.7047 - val_loss: 6.2398 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4023
#
# Epoch 00038: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-38_loss-3.5556_val_loss-6.2398.h5
# Epoch 39/120
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 759s 759ms/step - loss: 3.4900 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6657 - val_loss: 6.3357 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5245
#
# Epoch 00039: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-39_loss-3.4897_val_loss-6.3357.h5
# Epoch 40/120
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 767s 767ms/step - loss: 3.4416 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6434 - val_loss: 6.3494 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5645
#
# Epoch 00040: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-40_loss-3.4419_val_loss-6.3494.h5
# Epoch 41/120
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 756s 756ms/step - loss: 3.4298 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6570 - val_loss: 6.7074 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.9470
#
# Epoch 00041: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-41_loss-3.4297_val_loss-6.7074.h5
# Epoch 42/120
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 3.3882 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6400 - val_loss: 6.1037 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3677
#
# Epoch 00042: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-42_loss-3.3883_val_loss-6.1037.h5
# Epoch 43/120
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 749s 749ms/step - loss: 3.3610 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6373 - val_loss: 5.6769 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9652
#
# Epoch 00043: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-43_loss-3.3611_val_loss-5.6769.h5
# Epoch 44/120
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.3204 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6207 - val_loss: 5.8938 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2063
#
# Epoch 00044: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-44_loss-3.3207_val_loss-5.8938.h5
# Epoch 45/120
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 759s 759ms/step - loss: 3.3256 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6497 - val_loss: 6.2102 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.5459
#
# Epoch 00045: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-45_loss-3.3254_val_loss-6.2102.h5
# Epoch 46/120
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 3.2706 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6177 - val_loss: 5.8654 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2237
#
# Epoch 00046: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-46_loss-3.2704_val_loss-5.8654.h5
# Epoch 47/120
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 765s 765ms/step - loss: 3.2639 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.6332 - val_loss: 5.9012 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2814
#
# Epoch 00047: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-47_loss-3.2634_val_loss-5.9012.h5
# Epoch 48/120
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 765s 765ms/step - loss: 3.2059 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.5970 - val_loss: 5.8414 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2435
#
# Epoch 00048: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-48_loss-3.2060_val_loss-5.8414.h5
# Epoch 49/120
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 758s 758ms/step - loss: 3.1524 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.5655 - val_loss: 6.3308 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7546
#
# Epoch 00049: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-49_loss-3.1527_val_loss-6.3308.h5
# Epoch 50/120
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 767s 767ms/step - loss: 3.1251 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.5595 - val_loss: 6.5703 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.0154
#
# Epoch 00050: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-50_loss-3.1250_val_loss-6.5703.h5
# Epoch 51/120
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 766s 766ms/step - loss: 2.9485 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3951 - val_loss: 5.8534 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3014
#
# Epoch 00051: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-51_loss-2.9484_val_loss-5.8534.h5
# Epoch 52/120
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 760s 760ms/step - loss: 2.9087 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3581 - val_loss: 5.6265 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0772
#
# Epoch 00052: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-52_loss-2.9085_val_loss-5.6265.h5
# Epoch 53/120
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 774s 774ms/step - loss: 2.8668 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3189 - val_loss: 5.5197 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9731
#
# Epoch 00053: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-53_loss-2.8671_val_loss-5.5197.h5
# Epoch 54/120
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 770s 770ms/step - loss: 2.8710 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3259 - val_loss: 5.7537 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2100
#
# Epoch 00054: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-54_loss-2.8708_val_loss-5.7537.h5
# Epoch 55/120
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 759s 759ms/step - loss: 2.8861 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3438 - val_loss: 5.7357 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1947
#
# Epoch 00055: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-55_loss-2.8856_val_loss-5.7357.h5
# Epoch 56/120
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 771s 771ms/step - loss: 2.8297 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2900 - val_loss: 5.7390 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2007
#
# Epoch 00056: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-56_loss-2.8296_val_loss-5.7390.h5
# Epoch 57/120
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 2.8528 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3159 - val_loss: 5.7101 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1745
#
# Epoch 00057: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-57_loss-2.8524_val_loss-5.7101.h5
# Epoch 58/120
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 2.8349 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.3007 - val_loss: 5.9070 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3742
#
# Epoch 00058: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-58_loss-2.8349_val_loss-5.9070.h5
# Epoch 59/120
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 776s 776ms/step - loss: 2.8294 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2979 - val_loss: 5.7786 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2485
#
# Epoch 00059: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-59_loss-2.8296_val_loss-5.7786.h5
# Epoch 60/120
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 760s 760ms/step - loss: 2.8011 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2724 - val_loss: 5.8031 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2757
#
# Epoch 00060: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-60_loss-2.8010_val_loss-5.8031.h5
# Epoch 61/120
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 767s 767ms/step - loss: 2.8215 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2955 - val_loss: 5.6416 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1169
#
# Epoch 00061: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-61_loss-2.8215_val_loss-5.6416.h5
# Epoch 62/120
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 766s 766ms/step - loss: 2.7874 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2640 - val_loss: 5.6758 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1539
#
# Epoch 00062: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-62_loss-2.7869_val_loss-5.6758.h5
# Epoch 63/120
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 757s 757ms/step - loss: 2.7621 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2414 - val_loss: 5.8557 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3364
#
# Epoch 00063: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-63_loss-2.7624_val_loss-5.8557.h5
# Epoch 64/120
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 768s 768ms/step - loss: 2.7935 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2755 - val_loss: 5.7581 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2415
#
# Epoch 00064: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-64_loss-2.7933_val_loss-5.7581.h5
# Epoch 65/120
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 751s 751ms/step - loss: 2.7821 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2669 - val_loss: 5.7222 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2083
#
# Epoch 00065: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-65_loss-2.7825_val_loss-5.7222.h5
# Epoch 66/120
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 768s 768ms/step - loss: 2.7845 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2720 - val_loss: 5.9301 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4190
#
# Epoch 00066: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-66_loss-2.7845_val_loss-5.9301.h5
# Epoch 67/120
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 2.7789 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2690 - val_loss: 5.7892 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2807
#
# Epoch 00067: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-67_loss-2.7784_val_loss-5.7892.h5
# Epoch 68/120
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 743s 743ms/step - loss: 2.7632 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2561 - val_loss: 5.9252 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4193
#
# Epoch 00068: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-68_loss-2.7634_val_loss-5.9252.h5
# Epoch 69/120
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 2.7563 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2518 - val_loss: 5.8746 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3715
#
# Epoch 00069: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-69_loss-2.7565_val_loss-5.8746.h5
# Epoch 70/120
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 769s 769ms/step - loss: 2.7518 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2499 - val_loss: 5.9191 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4186
#
# Epoch 00070: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-70_loss-2.7521_val_loss-5.9191.h5
# Epoch 71/120
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 763s 763ms/step - loss: 2.7409 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2405 - val_loss: 5.8871 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3869
#
# Epoch 00071: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-71_loss-2.7409_val_loss-5.8871.h5
# Epoch 72/120
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 778s 778ms/step - loss: 2.7265 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2264 - val_loss: 5.8605 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3606
#
# Epoch 00072: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-72_loss-2.7267_val_loss-5.8605.h5
# Epoch 73/120
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 774s 774ms/step - loss: 2.7342 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2344 - val_loss: 5.8815 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3818
#
# Epoch 00073: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-73_loss-2.7344_val_loss-5.8815.h5
# Epoch 74/120
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 771s 771ms/step - loss: 2.7243 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2247 - val_loss: 5.8727 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3732
#
# Epoch 00074: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-74_loss-2.7244_val_loss-5.8727.h5
# Epoch 75/120
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 771s 771ms/step - loss: 2.7402 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2409 - val_loss: 5.8508 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3516
#
# Epoch 00075: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-75_loss-2.7401_val_loss-5.8508.h5
# Epoch 76/120
#
# Epoch 00076: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 777s 777ms/step - loss: 2.7395 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2405 - val_loss: 5.8786 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3797
#
# Epoch 00076: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-76_loss-2.7394_val_loss-5.8786.h5
# Epoch 77/120
#
# ...
#
# Epoch 00093: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-93_loss-2.7158_val_loss-5.8760.h5
# Epoch 94/120
#
# Epoch 00094: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 758s 758ms/step - loss: 2.7105 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2163 - val_loss: 5.8624 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3683
#
# Epoch 00094: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-94_loss-2.7107_val_loss-5.8624.h5
# Epoch 95/120
#
# Epoch 00095: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 774s 774ms/step - loss: 2.7075 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2135 - val_loss: 5.8903 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3965
#
# Epoch 00095: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-95_loss-2.7076_val_loss-5.8903.h5
# Epoch 96/120
#
# Epoch 00096: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 774s 774ms/step - loss: 2.7353 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2415 - val_loss: 5.8415 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3480
#
# Epoch 00096: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-96_loss-2.7354_val_loss-5.8415.h5
# Epoch 97/120
#
# Epoch 00097: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 775s 775ms/step - loss: 2.7256 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2322 - val_loss: 5.8364 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3431
#
# Epoch 00097: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-97_loss-2.7256_val_loss-5.8364.h5
# Epoch 98/120
#
# Epoch 00098: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 776s 776ms/step - loss: 2.7121 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2189 - val_loss: 5.8356 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3425
#
# Epoch 00098: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-98_loss-2.7122_val_loss-5.8356.h5
# Epoch 99/120
#
# Epoch 00099: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 755s 755ms/step - loss: 2.7152 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2223 - val_loss: 5.8894 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3966
#
# Epoch 00099: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-99_loss-2.7153_val_loss-5.8894.h5
# Epoch 100/120
#
# Epoch 00100: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 771s 771ms/step - loss: 2.7197 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2270 - val_loss: 5.8533 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3608
#
# Epoch 00100: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-100_loss-2.7197_val_loss-5.8533.h5
# Epoch 101/120
#
# Epoch 00101: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 777s 777ms/step - loss: 2.7319 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2395 - val_loss: 5.8479 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3556
#
# Epoch 00101: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-101_loss-2.7319_val_loss-5.8479.h5
# Epoch 102/120
#
# Epoch 00102: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 750s 750ms/step - loss: 2.7021 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2100 - val_loss: 5.8292 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3372
#
# Epoch 00102: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-102_loss-2.7022_val_loss-5.8292.h5
# Epoch 103/120
#
# Epoch 00103: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 742s 742ms/step - loss: 2.7060 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2142 - val_loss: 5.8667 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3750
#
# Epoch 00103: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-103_loss-2.7061_val_loss-5.8667.h5
# Epoch 104/120
#
# Epoch 00104: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 753s 753ms/step - loss: 2.7113 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2197 - val_loss: 5.8715 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3800
#
# Epoch 00104: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-104_loss-2.7113_val_loss-5.8715.h5
# Epoch 105/120
#
# Epoch 00105: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 759s 759ms/step - loss: 2.7332 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2419 - val_loss: 5.8237 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3325
#
# Epoch 00105: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-105_loss-2.7333_val_loss-5.8237.h5
# Epoch 106/120
#
# Epoch 00106: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 772s 772ms/step - loss: 2.7092 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2182 - val_loss: 5.8135 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3226
#
# Epoch 00106: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-106_loss-2.7096_val_loss-5.8135.h5
# Epoch 107/120
#
# Epoch 00107: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 770s 770ms/step - loss: 2.7007 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2099 - val_loss: 5.8701 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3794
#
# Epoch 00107: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-107_loss-2.7007_val_loss-5.8701.h5
# Epoch 108/120
#
# Epoch 00108: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 776s 776ms/step - loss: 2.7103 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2198 - val_loss: 5.8776 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3872
#
# Epoch 00108: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-108_loss-2.7102_val_loss-5.8776.h5
# Epoch 109/120
#
# Epoch 00109: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 774s 774ms/step - loss: 2.7089 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2186 - val_loss: 5.8110 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3209
#
# Epoch 00109: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-109_loss-2.7092_val_loss-5.8110.h5
# Epoch 110/120
#
# Epoch 00110: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 778s 778ms/step - loss: 2.7210 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2310 - val_loss: 5.8511 - val_pool1_GAP_substract_loss: 0.0000e+00 - val_pool2_GAP_substract_loss: 0.0000e+00 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3612
#
# Epoch 00110: saving model to ../trained_weights/SSD512_SIM10K_to_City_resize_400_800/current/source_only_run2/epoch-110_loss-2.7209_val_loss-5.8511.h5
# Epoch 111/120
#
# Epoch 00111: LearningRateScheduler setting learning rate to 1e-05.
#  465/1000 [============>.................] - ETA: 6:36 - loss: 2.7157 - pool1_GAP_substract_loss: 0.0000e+00 - pool2_GAP_substract_loss: 0.0000e+00 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 1.2259
# -----------------------------------------------------
# KeyboardInterrupt   Traceback (most recent call last)
# <ipython-input-6-ea67b764e796> in <module>()
#       9                               validation_data=val_generator,
#      10                               validation_steps=ceil(val_dataset_size/batch_size),
# ---> 11                               initial_epoch=initial_epoch)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
