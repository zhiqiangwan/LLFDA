# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512_Siamese_align_high_layers import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator_align_high_layers import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [0.0, 0.000005] + [1.0]

# 'City_to_foggy0_01_resize_600_1200' # 'City_to_foggy0_02_resize_600_1200'  # 'SIM10K_to_VOC07'
# 'SIM10K'  # 'Cityscapes_foggy_beta_0_01'  #  'City_to_foggy0_02_resize_400_800'
# 'SIM10K_to_VOC07_resize_400_800'# 'SIM10K_to_City_resize_400_800'
DatasetName = 'City_to_foggy0_01_resize_400_800' # 'SIM10K_to_VOC12_resize_400_800'
processed_dataset_path = './processed_dataset_h5/' + DatasetName + '_worker2'
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'contrastive_loss1': ssd_loss.compute_distance_loss_source_only,
                                             'contrastive_loss2': ssd_loss.compute_distance_loss,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'contrastive_loss1': loss_weights[0],
                                'contrastive_loss2': loss_weights[1],
                                'predictions': loss_weights[2]})    

else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 2966/2966 [00:00<00:00, 3892.31it/s]
# Loading source image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 10483.67it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 9650.67it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 2966/2966 [00:00<00:00, 7627.66it/s]
# Loading source labels: 100%|██████████| 493/493 [00:00<00:00, 3724.54it/s]
# Loading source image IDs: 100%|██████████| 493/493 [00:00<00:00, 10316.62it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 493/493 [00:00<00:00, 7626.65it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  2966
# Number of images in the validation dataset:	   493

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 50:
#         return 0.001
#     elif epoch < 60:
#         return 0.0001
#     else:
#         return 0.00001

# Define model callbacks.
checkpoint_path = '../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/conv2_1'
# checkpoint_path = '../trained_weights/current/ssd_augm_beta_0_01_source_only'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'conv2_1_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 100 #  120
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 866s 866ms/step - loss: 9.6590 - contrastive_loss1_loss: 3.6482 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 6.1138 - val_loss: 9.1907 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 5.6649
#
# Epoch 00001: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-01_loss-9.6590_val_loss-9.1907.h5
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 8.1024 - contrastive_loss1_loss: 2.6287 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 4.5898 - val_loss: 8.4754 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.9812
#
# Epoch 00002: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-02_loss-8.1024_val_loss-8.4754.h5
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 7.9142 - contrastive_loss1_loss: 2.1061 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 4.4480 - val_loss: 8.3954 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.9616
#
# Epoch 00003: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-03_loss-7.9142_val_loss-8.3954.h5
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 7.4492 - contrastive_loss1_loss: 1.6864 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 4.0439 - val_loss: 8.1102 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.7367
#
# Epoch 00004: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-04_loss-7.4492_val_loss-8.1102.h5
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 886s 886ms/step - loss: 7.1901 - contrastive_loss1_loss: 1.4947 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.8447 - val_loss: 7.8544 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5401
#
# Epoch 00005: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-05_loss-7.1901_val_loss-7.8544.h5
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 860s 860ms/step - loss: 6.9778 - contrastive_loss1_loss: 1.3539 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.6912 - val_loss: 7.8800 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.6238
#
# Epoch 00006: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-06_loss-6.9778_val_loss-7.8800.h5
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1076s 1s/step - loss: 6.8146 - contrastive_loss1_loss: 1.2879 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.5856 - val_loss: 7.8890 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.6896
#
# Epoch 00007: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-07_loss-6.8146_val_loss-7.8890.h5
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 846s 846ms/step - loss: 6.6848 - contrastive_loss1_loss: 1.1975 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.5122 - val_loss: 7.7098 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5661
#
# Epoch 00008: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-08_loss-6.6848_val_loss-7.7098.h5
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 931s 931ms/step - loss: 6.5507 - contrastive_loss1_loss: 1.2444 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.4330 - val_loss: 7.6020 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5128
#
# Epoch 00009: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-09_loss-6.5507_val_loss-7.6020.h5
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 978s 978ms/step - loss: 6.4300 - contrastive_loss1_loss: 1.1706 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.3667 - val_loss: 7.3979 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3625
#
# Epoch 00010: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-10_loss-6.4300_val_loss-7.3979.h5
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 918s 918ms/step - loss: 6.3269 - contrastive_loss1_loss: 1.1024 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.3165 - val_loss: 7.4563 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.4730
#
# Epoch 00011: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-11_loss-6.3269_val_loss-7.4563.h5
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 988s 988ms/step - loss: 6.2299 - contrastive_loss1_loss: 1.1198 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.2711 - val_loss: 7.1450 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2129
#
# Epoch 00012: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-12_loss-6.2299_val_loss-7.1450.h5
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 861s 861ms/step - loss: 6.0921 - contrastive_loss1_loss: 1.0533 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.1840 - val_loss: 7.4592 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5772
#
# Epoch 00013: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-13_loss-6.0921_val_loss-7.4592.h5
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 901s 901ms/step - loss: 6.0454 - contrastive_loss1_loss: 1.0172 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.1870 - val_loss: 7.2666 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.4338
#
# Epoch 00014: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-14_loss-6.0454_val_loss-7.2666.h5
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 882s 882ms/step - loss: 5.9895 - contrastive_loss1_loss: 1.0190 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.1797 - val_loss: 7.0336 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2489
#
# Epoch 00015: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-15_loss-5.9895_val_loss-7.0336.h5
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1059s 1s/step - loss: 5.8324 - contrastive_loss1_loss: 1.0347 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.0701 - val_loss: 7.0942 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3565
#
# Epoch 00016: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-16_loss-5.8324_val_loss-7.0942.h5
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 981s 981ms/step - loss: 5.7984 - contrastive_loss1_loss: 1.0304 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.0826 - val_loss: 6.8869 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1950
#
# Epoch 00017: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-17_loss-5.7984_val_loss-6.8869.h5
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1042s 1s/step - loss: 5.7236 - contrastive_loss1_loss: 1.0357 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.0532 - val_loss: 7.0944 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.4475
#
# Epoch 00018: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-18_loss-5.7236_val_loss-7.0944.h5
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 969s 969ms/step - loss: 5.6159 - contrastive_loss1_loss: 1.0124 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.9899 - val_loss: 6.7506 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1475
#
# Epoch 00019: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-19_loss-5.6159_val_loss-6.7506.h5
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1061s 1s/step - loss: 5.5865 - contrastive_loss1_loss: 0.9567 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 3.0040 - val_loss: 6.9668 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.4068
#
# Epoch 00020: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-20_loss-5.5865_val_loss-6.9668.h5
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 980s 980ms/step - loss: 5.5254 - contrastive_loss1_loss: 1.0147 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.9854 - val_loss: 6.6970 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1788
#
# Epoch 00021: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-21_loss-5.5254_val_loss-6.6970.h5
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 951s 951ms/step - loss: 5.4738 - contrastive_loss1_loss: 0.9485 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.9752 - val_loss: 6.7848 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3073
#
# Epoch 00022: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-22_loss-5.4738_val_loss-6.7848.h5
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1020s 1s/step - loss: 5.3787 - contrastive_loss1_loss: 0.9428 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.9207 - val_loss: 6.8554 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.4185
#
# Epoch 00023: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-23_loss-5.3787_val_loss-6.8554.h5
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1047s 1s/step - loss: 5.3247 - contrastive_loss1_loss: 0.9683 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.9065 - val_loss: 6.6607 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2632
#
# Epoch 00024: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-24_loss-5.3247_val_loss-6.6607.h5
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 965s 965ms/step - loss: 5.2308 - contrastive_loss1_loss: 0.9508 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8517 - val_loss: 6.8622 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5032
#
# Epoch 00025: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-25_loss-5.2308_val_loss-6.8622.h5
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 929s 929ms/step - loss: 5.2097 - contrastive_loss1_loss: 0.9490 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8686 - val_loss: 6.4254 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1040
#
# Epoch 00026: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-26_loss-5.2097_val_loss-6.4254.h5
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1009s 1s/step - loss: 5.1495 - contrastive_loss1_loss: 0.9178 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8455 - val_loss: 6.6429 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3580
#
# Epoch 00027: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-27_loss-5.1495_val_loss-6.6429.h5
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1060s 1s/step - loss: 5.1107 - contrastive_loss1_loss: 0.8923 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8432 - val_loss: 6.5613 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3125
#
# Epoch 00028: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-28_loss-5.1107_val_loss-6.5613.h5
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1022s 1s/step - loss: 5.0460 - contrastive_loss1_loss: 0.9444 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8141 - val_loss: 6.4183 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2049
#
# Epoch 00029: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-29_loss-5.0460_val_loss-6.4183.h5
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1105s 1s/step - loss: 5.0075 - contrastive_loss1_loss: 0.9377 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.8104 - val_loss: 6.3954 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2164
#
# Epoch 00030: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-30_loss-5.0075_val_loss-6.3954.h5
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1104s 1s/step - loss: 4.9452 - contrastive_loss1_loss: 0.9050 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7822 - val_loss: 6.3806 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2354
#
# Epoch 00031: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-31_loss-4.9452_val_loss-6.3806.h5
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1024s 1s/step - loss: 4.8972 - contrastive_loss1_loss: 0.9237 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7675 - val_loss: 6.3220 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2095
#
# Epoch 00032: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-32_loss-4.8972_val_loss-6.3220.h5
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1204s 1s/step - loss: 4.8784 - contrastive_loss1_loss: 0.8697 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7812 - val_loss: 6.2784 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1981
#
# Epoch 00033: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-33_loss-4.8784_val_loss-6.2784.h5
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1142s 1s/step - loss: 4.8125 - contrastive_loss1_loss: 0.8674 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7471 - val_loss: 6.4740 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.4252
#
# Epoch 00034: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-34_loss-4.8125_val_loss-6.4740.h5
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1059s 1s/step - loss: 4.7820 - contrastive_loss1_loss: 0.8965 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7477 - val_loss: 6.2781 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2600
#
# Epoch 00035: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-35_loss-4.7820_val_loss-6.2781.h5
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1158s 1s/step - loss: 4.7255 - contrastive_loss1_loss: 0.9255 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7216 - val_loss: 6.5498 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5618
#
# Epoch 00036: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-36_loss-4.7255_val_loss-6.5498.h5
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1018s 1s/step - loss: 4.7014 - contrastive_loss1_loss: 0.8924 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.7274 - val_loss: 6.2964 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3379
#
# Epoch 00037: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-37_loss-4.7014_val_loss-6.2964.h5
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 986s 986ms/step - loss: 4.6245 - contrastive_loss1_loss: 0.8807 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.6796 - val_loss: 6.0080 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.0785
#
# Epoch 00038: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-38_loss-4.6245_val_loss-6.0080.h5
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1102s 1s/step - loss: 4.5959 - contrastive_loss1_loss: 0.9287 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.6796 - val_loss: 6.0859 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1845
#
# Epoch 00039: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-39_loss-4.5959_val_loss-6.0859.h5
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1002s 1s/step - loss: 4.5463 - contrastive_loss1_loss: 0.8927 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.6579 - val_loss: 6.1678 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2941
#
# Epoch 00040: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-40_loss-4.5463_val_loss-6.1678.h5
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1145s 1s/step - loss: 4.5235 - contrastive_loss1_loss: 0.8602 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.6625 - val_loss: 6.1896 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3429
#
# Epoch 00041: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-41_loss-4.5235_val_loss-6.1896.h5
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1044s 1s/step - loss: 4.4521 - contrastive_loss1_loss: 0.9074 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.6178 - val_loss: 6.1366 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3165
#
# Epoch 00042: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-42_loss-4.4521_val_loss-6.1366.h5
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1041s 1s/step - loss: 4.4438 - contrastive_loss1_loss: 0.8599 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.6359 - val_loss: 6.3332 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5390
#
# Epoch 00043: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-43_loss-4.4438_val_loss-6.3332.h5
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1035s 1s/step - loss: 4.3875 - contrastive_loss1_loss: 0.8558 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.6053 - val_loss: 6.7198 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.9510
#
# Epoch 00044: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-44_loss-4.3875_val_loss-6.7198.h5
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1068s 1s/step - loss: 4.3623 - contrastive_loss1_loss: 0.9135 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.6049 - val_loss: 6.2507 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.5067
#
# Epoch 00045: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-45_loss-4.3623_val_loss-6.2507.h5
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1106s 1s/step - loss: 4.3571 - contrastive_loss1_loss: 0.8689 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.6245 - val_loss: 6.1272 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.4075
#
# Epoch 00046: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-46_loss-4.3571_val_loss-6.1272.h5
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1156s 1s/step - loss: 4.3005 - contrastive_loss1_loss: 0.8556 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.5918 - val_loss: 5.9699 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2738
#
# Epoch 00047: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-47_loss-4.3005_val_loss-5.9699.h5
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1115s 1s/step - loss: 4.2661 - contrastive_loss1_loss: 0.8639 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.5807 - val_loss: 6.0691 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3963
#
# Epoch 00048: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-48_loss-4.2661_val_loss-6.0691.h5
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1135s 1s/step - loss: 4.2301 - contrastive_loss1_loss: 0.8652 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.5677 - val_loss: 5.9400 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2896
#
# Epoch 00049: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-49_loss-4.2301_val_loss-5.9400.h5
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1132s 1s/step - loss: 4.2729 - contrastive_loss1_loss: 0.8835 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.6327 - val_loss: 6.0390 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.4104
#
# Epoch 00050: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-50_loss-4.2729_val_loss-6.0390.h5
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1037s 1s/step - loss: 4.0603 - contrastive_loss1_loss: 0.8623 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.4323 - val_loss: 5.7554 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1296
#
# Epoch 00051: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-51_loss-4.0603_val_loss-5.7554.h5
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1113s 1s/step - loss: 3.9690 - contrastive_loss1_loss: 0.9102 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3437 - val_loss: 5.7698 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1467
#
# Epoch 00052: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-52_loss-3.9690_val_loss-5.7698.h5
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1077s 1s/step - loss: 3.9336 - contrastive_loss1_loss: 0.9337 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3109 - val_loss: 5.8703 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2499
#
# Epoch 00053: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-53_loss-3.9336_val_loss-5.8703.h5
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 963s 963ms/step - loss: 3.9045 - contrastive_loss1_loss: 0.9725 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2845 - val_loss: 5.7881 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1704
#
# Epoch 00054: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-54_loss-3.9045_val_loss-5.7881.h5
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1061s 1s/step - loss: 3.8937 - contrastive_loss1_loss: 0.9908 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2764 - val_loss: 5.8217 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2067
#
# Epoch 00055: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-55_loss-3.8937_val_loss-5.8217.h5
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1023s 1s/step - loss: 3.9321 - contrastive_loss1_loss: 0.9884 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3176 - val_loss: 5.7913 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1791
#
# Epoch 00056: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-56_loss-3.9321_val_loss-5.7913.h5
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1117s 1s/step - loss: 3.9276 - contrastive_loss1_loss: 0.9546 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.3158 - val_loss: 5.7728 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1633
#
# Epoch 00057: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-57_loss-3.9276_val_loss-5.7728.h5
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1054s 1s/step - loss: 3.8983 - contrastive_loss1_loss: 1.0153 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2891 - val_loss: 5.8663 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2595
#
# Epoch 00058: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-58_loss-3.8983_val_loss-5.8663.h5
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 983s 983ms/step - loss: 3.8867 - contrastive_loss1_loss: 0.9901 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2803 - val_loss: 5.8444 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2403
#
# Epoch 00059: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-59_loss-3.8867_val_loss-5.8444.h5
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 984s 984ms/step - loss: 3.8664 - contrastive_loss1_loss: 1.0084 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2626 - val_loss: 5.8120 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2107
#
# Epoch 00060: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-60_loss-3.8664_val_loss-5.8120.h5
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 984s 984ms/step - loss: 3.8820 - contrastive_loss1_loss: 0.9902 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2810 - val_loss: 5.7617 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.1630
#
# Epoch 00061: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-61_loss-3.8820_val_loss-5.7617.h5
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 938s 938ms/step - loss: 3.8590 - contrastive_loss1_loss: 0.9835 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2606 - val_loss: 5.8203 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2242
#
# Epoch 00062: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-62_loss-3.8590_val_loss-5.8203.h5
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1050s 1s/step - loss: 3.8541 - contrastive_loss1_loss: 1.0104 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2584 - val_loss: 5.8104 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2171
#
# Epoch 00063: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-63_loss-3.8541_val_loss-5.8104.h5
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1049s 1s/step - loss: 3.8639 - contrastive_loss1_loss: 0.9941 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2709 - val_loss: 5.8789 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2882
#
# Epoch 00064: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-64_loss-3.8639_val_loss-5.8789.h5
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1026s 1s/step - loss: 3.8613 - contrastive_loss1_loss: 1.0222 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2709 - val_loss: 5.8015 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2135
#
# Epoch 00065: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-65_loss-3.8613_val_loss-5.8015.h5
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1135s 1s/step - loss: 3.8294 - contrastive_loss1_loss: 1.0120 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2417 - val_loss: 5.8624 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2770
#
# Epoch 00066: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-66_loss-3.8294_val_loss-5.8624.h5
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1020s 1s/step - loss: 3.8409 - contrastive_loss1_loss: 1.0198 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2558 - val_loss: 5.8289 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2462
#
# Epoch 00067: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-67_loss-3.8409_val_loss-5.8289.h5
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1244s 1s/step - loss: 3.8532 - contrastive_loss1_loss: 1.0215 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2707 - val_loss: 5.8535 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2734
#
# Epoch 00068: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-68_loss-3.8532_val_loss-5.8535.h5
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1189s 1s/step - loss: 3.8186 - contrastive_loss1_loss: 1.0002 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2388 - val_loss: 5.8283 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2508
#
# Epoch 00069: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-69_loss-3.8186_val_loss-5.8283.h5
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 1129s 1s/step - loss: 3.8361 - contrastive_loss1_loss: 1.0158 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2589 - val_loss: 5.9528 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3780
#
# Epoch 00070: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-70_loss-3.8361_val_loss-5.9528.h5
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1042s 1s/step - loss: 3.7877 - contrastive_loss1_loss: 1.0714 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2119 - val_loss: 5.8901 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3156
#
# Epoch 00071: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-71_loss-3.7877_val_loss-5.8901.h5
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 938s 938ms/step - loss: 3.7814 - contrastive_loss1_loss: 1.0285 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2060 - val_loss: 5.9158 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3415
#
# Epoch 00072: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-72_loss-3.7814_val_loss-5.9158.h5
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1064s 1s/step - loss: 3.8235 - contrastive_loss1_loss: 1.0310 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2483 - val_loss: 5.9187 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3447
#
# Epoch 00073: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-73_loss-3.8235_val_loss-5.9187.h5
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1043s 1s/step - loss: 3.8089 - contrastive_loss1_loss: 1.0263 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2339 - val_loss: 5.9210 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3472
#
# Epoch 00074: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-74_loss-3.8089_val_loss-5.9210.h5
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1029s 1s/step - loss: 3.8041 - contrastive_loss1_loss: 1.0456 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2294 - val_loss: 5.9259 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3524
#
# Epoch 00075: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-75_loss-3.8041_val_loss-5.9259.h5
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1074s 1s/step - loss: 3.7905 - contrastive_loss1_loss: 1.0416 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2161 - val_loss: 5.8700 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2967
#
# Epoch 00076: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-76_loss-3.7905_val_loss-5.8700.h5
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1005s 1s/step - loss: 3.8119 - contrastive_loss1_loss: 1.0663 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2377 - val_loss: 5.8351 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2621
#
# Epoch 00077: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-77_loss-3.8119_val_loss-5.8351.h5
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1047s 1s/step - loss: 3.8013 - contrastive_loss1_loss: 1.0298 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2274 - val_loss: 5.8494 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2767
#
# Epoch 00078: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-78_loss-3.8013_val_loss-5.8494.h5
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1079s 1s/step - loss: 3.8028 - contrastive_loss1_loss: 1.0557 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2292 - val_loss: 5.9040 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3315
#
# Epoch 00079: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-79_loss-3.8028_val_loss-5.9040.h5
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1046s 1s/step - loss: 3.7852 - contrastive_loss1_loss: 1.0105 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2118 - val_loss: 5.8653 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2931
#
# Epoch 00080: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-80_loss-3.7852_val_loss-5.8653.h5
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1021s 1s/step - loss: 3.7906 - contrastive_loss1_loss: 1.0567 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2175 - val_loss: 5.8524 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2804
#
# Epoch 00081: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-81_loss-3.7906_val_loss-5.8524.h5
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1041s 1s/step - loss: 3.7749 - contrastive_loss1_loss: 1.0602 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2021 - val_loss: 5.8553 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2836
#
# Epoch 00082: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-82_loss-3.7749_val_loss-5.8553.h5
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 999s 999ms/step - loss: 3.8094 - contrastive_loss1_loss: 1.0296 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2368 - val_loss: 5.8925 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3211
#
# Epoch 00083: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-83_loss-3.8094_val_loss-5.8925.h5
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1122s 1s/step - loss: 3.8010 - contrastive_loss1_loss: 1.0367 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2287 - val_loss: 5.9052 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3340
#
# Epoch 00084: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-84_loss-3.8010_val_loss-5.9052.h5
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1197s 1s/step - loss: 3.7932 - contrastive_loss1_loss: 1.0302 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2211 - val_loss: 5.9137 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3429
#
# Epoch 00085: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-85_loss-3.7932_val_loss-5.9137.h5
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1149s 1s/step - loss: 3.7863 - contrastive_loss1_loss: 1.0585 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2145 - val_loss: 5.9390 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3684
#
# Epoch 00086: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-86_loss-3.7863_val_loss-5.9390.h5
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1029s 1s/step - loss: 3.7756 - contrastive_loss1_loss: 1.0729 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2041 - val_loss: 5.8979 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3276
#
# Epoch 00087: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-87_loss-3.7756_val_loss-5.8979.h5
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1113s 1s/step - loss: 3.8153 - contrastive_loss1_loss: 1.0707 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2440 - val_loss: 5.9139 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3438
#
# Epoch 00088: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-88_loss-3.8153_val_loss-5.9139.h5
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1010s 1s/step - loss: 3.7719 - contrastive_loss1_loss: 1.0778 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2009 - val_loss: 5.8879 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3181
#
# Epoch 00089: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-89_loss-3.7719_val_loss-5.8879.h5
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1196s 1s/step - loss: 3.7967 - contrastive_loss1_loss: 1.0443 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2259 - val_loss: 5.8647 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2952
#
# Epoch 00090: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-90_loss-3.7967_val_loss-5.8647.h5
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1050s 1s/step - loss: 3.7599 - contrastive_loss1_loss: 1.0105 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.1894 - val_loss: 5.8964 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3271
#
# Epoch 00091: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-91_loss-3.7599_val_loss-5.8964.h5
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1046s 1s/step - loss: 3.7860 - contrastive_loss1_loss: 1.0576 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2158 - val_loss: 5.9190 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3499
#
# Epoch 00092: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-92_loss-3.7860_val_loss-5.9190.h5
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1067s 1s/step - loss: 3.7945 - contrastive_loss1_loss: 1.0231 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2246 - val_loss: 5.8745 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3057
#
# Epoch 00093: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-93_loss-3.7945_val_loss-5.8745.h5
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1124s 1s/step - loss: 3.7649 - contrastive_loss1_loss: 1.0746 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.1952 - val_loss: 5.8866 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3181
#
# Epoch 00094: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-94_loss-3.7649_val_loss-5.8866.h5
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1134s 1s/step - loss: 3.7791 - contrastive_loss1_loss: 1.0214 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2097 - val_loss: 5.8910 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.3227
#
# Epoch 00095: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-95_loss-3.7791_val_loss-5.8910.h5
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1099s 1s/step - loss: 3.7901 - contrastive_loss1_loss: 1.0237 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2209 - val_loss: 5.8374 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2694
#
# Epoch 00096: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-96_loss-3.7901_val_loss-5.8374.h5
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1156s 1s/step - loss: 3.7862 - contrastive_loss1_loss: 1.0709 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2173 - val_loss: 5.8414 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2736
#
# Epoch 00097: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-97_loss-3.7862_val_loss-5.8414.h5
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1013s 1s/step - loss: 3.7834 - contrastive_loss1_loss: 1.0864 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2147 - val_loss: 5.8385 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2710
#
# Epoch 00098: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-98_loss-3.7834_val_loss-5.8385.h5
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1161s 1s/step - loss: 3.8006 - contrastive_loss1_loss: 1.0210 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2322 - val_loss: 5.8407 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2735
#
# Epoch 00099: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-99_loss-3.8006_val_loss-5.8407.h5
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 1037s 1s/step - loss: 3.7839 - contrastive_loss1_loss: 1.0415 - contrastive_loss2_loss: 0.0000e+00 - predictions_loss: 2.2158 - val_loss: 5.8325 - val_contrastive_loss1_loss: 0.0000e+00 - val_contrastive_loss2_loss: 0.0000e+00 - val_predictions_loss: 4.2656
#
# Epoch 00100: saving model to ../trained_weights/SSD512_City_to_foggy0_01_resize_400_800/current/fc7_loss_weights_0_001/epoch-100_loss-3.7839_val_loss-5.8325.h5

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()
# Out:
# Image: ../../datasets/Cityscapes/JPEGImages/source_ulm_000000_000019_leftImg8bit

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
# Out:
# Image: ../../datasets/Cityscapes/JPEGImages/source_strasbourg_000000_006995_leftImg8bit
#
# Ground truth boxes:
#
# [[  1 285 154 293 176]
#  [  1 137 159 145 181]
#  [  1  43 151  62 191]
#  [  1  43 148  57 192]
#  [  1  55 152  75 191]
#  [  1  20 142  39 191]
#  [  1 275 156 280 176]
#  [  1 327 144 340 178]
#  [  1 285 133 321 193]
#  [  1 399 148 409 176]
#  [  1 393 139 408 177]
#  [  2 196 133 225 181]
#  [  3 253 161 268 172]
#  [  8 185 152 243 191]]
# -----------------------------------------------------
# TypeError           Traceback (most recent call last)
# <ipython-input-10-4c88a6df60d1> in <module>()
#      47 # 5: Convert the predictions for the original image.
#      48
# ---> 49 y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)
#      50
#      51 np.set_printoptions(precision=2, suppress=True, linewidth=90)
#
# /domain_adaptation_object_detection/ssd_Siamese_inputs_not_match/data_generator/object_detection_2d_misc_utils.py in apply_inverse_transforms(y_pred_decoded, inverse_transforms)
#      56                 for inverter in inverse_transforms[i]:
#      57                     if not (inverter is None):
# ---> 58                         y_pred_decoded_inv[i] = inverter(y_pred_decoded_inv[i])
#      59
#      60     elif isinstance(y_pred_decoded, np.ndarray):
#
# TypeError: 'list' object is not callable
