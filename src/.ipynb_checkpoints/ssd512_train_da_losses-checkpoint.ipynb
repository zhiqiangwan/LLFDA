# %%
import sys
sys.path.append('../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import glob

from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.da_ssd512_other_loss_metrics import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation, SSDDataAugmentation_Siamese
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms


img_height = 512  # Height of the model input images
img_width = 512  # Width of the model input images
img_channels = 3  # Number of color channels of the model input images
mean_color = [123, 117, 104]  # Per-channel mean of images. Do not change if use any of the pre-trained weights.
# The color channel order in the original SSD is BGR,
# so we'll have the model reverse the color channel order of the input images.
swap_channels = [2, 1, 0]
# The anchor box scaling factors used in the original SSD512 for the Pascal VOC datasets
# scales_pascal =
# The anchor box scaling factors used in the original SSD512 for the MS COCO datasets
scales_coco = [0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05]
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]]  # The anchor box aspect ratios used in the original SSD512; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 128, 256, 512]  # Space between two adjacent anchor box center points for each predictor layer.
# The offsets of the first anchor box center points from the top and left borders of the image
# as a fraction of the step size for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False  # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
# The variances by which the encoded target coordinates are divided as in the original implementation
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True
Model_Build = 'New_Model'  # 'Load_Model'
Optimizer_Type = 'SGD'  # 'Adam'  #
# Different batch_size will have different prediction loss.
batch_size = 8  # Change the batch size if you like, or if you run into GPU memory issues.
# alpha_distance = 0.0001  # Coefficient for the distance between the source and target feature maps.
loss_weights = [0.0005, 0.0005, 0.0] + [1.0]

# 'SIM10K_to_City_resize_400_800'  # 
DatasetName = 'SIM10K_to_VOC12_resize_400_800' # 'City_to_foggy0_01_resize_400_800'  # 'SIM10K_to_VOC07_resize_400_800'  # 
processed_dataset_path = './processed_dataset_h5/' + DatasetName
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)

if len(glob.glob(os.path.join(processed_dataset_path, '*.h5'))):
    Dataset_Build = 'Load_Dataset'
else:
    Dataset_Build = 'New_Dataset'

# Define model callbacks.
checkpoint_path = '../trained_weights/SIM10K_to_VOC12/current/mmd_0_0005'
# checkpoint_path = '../trained_weights/denug'
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)
    
if DatasetName == 'SIM10K_to_VOC12_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2012/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2012/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2012_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1
    
elif DatasetName == 'SIM10K_to_VOC07_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'
    test_target_images_dir = '../../datasets/VOCdevkit/VOC2007/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/VOCdevkit/VOC2007/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    # The trainset of VOC which has 'car' object is used as train_target.
    train_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/train_target.txt'
    # The valset of VOC which has 'car' object is used as test.
    test_target_image_set_filename = '../../datasets/VOCdevkit/VOC2007_CAR/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car',
                   'aeroplane', 'bicycle', 'bird', 'boat',
                   'bottle', 'bus', 'cat',
                   'chair', 'cow', 'diningtable', 'dog',
                   'horse', 'motorbike', 'person', 'pottedplant',
                   'sheep', 'sofa', 'train', 'tvmonitor']
    val_include_classes = [val_classes.index(one_class) for one_class in classes[1:]]
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'SIM10K_to_City_resize_400_800':
    resize_image_to = (400, 800)
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/SIM10K/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/SIM10K/Annotations'
    test_annotation_dir = '../../datasets/val_data_for_SIM10K_to_cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/SIM10K/ImageSets/Main/trainval10k.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    test_target_image_set_filename = '../../datasets/val_data_for_SIM10K_to_cityscapes/ImageSets/Main/test.txt'

    classes = ['background', 'car']  # Our model will produce predictions for these classes.
    train_classes = ['background', 'car', 'motorbike', 'person']  # The train_source dataset contains these classes.
    train_include_classes = [train_classes.index(one_class) for one_class in classes[1:]]
    # The test_target dataset contains these classes.
    val_classes = ['background', 'car']
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_02_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/Cityscapes/JPEGImages'
    test_target_images_dir = '../../datasets/Cityscapes/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

elif DatasetName == 'City_to_foggy0_01_resize_400_800':
    resize_image_to = (400, 800)
    # Introduction of PascalVOC: https://arleyzhang.github.io/articles/1dc20586/
    # The directories that contain the images.
    train_source_images_dir = '../../datasets/Cityscapes/JPEGImages'
    train_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'
    test_target_images_dir = '../../datasets/CITYSCAPES_beta_0_01/JPEGImages'

    # The directories that contain the annotations.
    train_annotation_dir = '../../datasets/Cityscapes/Annotations'
    test_annotation_dir = '../../datasets/Cityscapes/Annotations'

    # The paths to the image sets.
    train_source_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_source.txt'
    train_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/train_target.txt'
    test_target_image_set_filename = '../../datasets/Cityscapes/ImageSets/Main/test.txt'
    # Our model will produce predictions for these classes.
    classes = ['background',
               'person', 'rider', 'car', 'truck',
               'bus', 'train', 'motorcycle', 'bicycle']
    train_classes = classes
    train_include_classes = 'all'
    val_classes = classes
    val_include_classes = 'all'
    # Number of positive classes, 8 for domain Cityscapes, 20 for Pascal VOC, 80 for MS COCO, 1 for SIM10K
    n_classes = len(classes) - 1

else:
    raise ValueError('Undefined dataset name.')
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
if Model_Build == 'New_Model':
    # 1: Build the Keras model.

    K.clear_session()  # Clear previous models from memory.

    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # (nothing gets printed in Jupyter, only if you run it standalone)
    sess = tf.Session(config=config)
    set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = ssd_512(image_size=(img_height, img_width, img_channels),
                    n_classes=n_classes,
                    mode='training',
                    l2_regularization=0.0005,
                    scales=scales,
                    aspect_ratios_per_layer=aspect_ratios,
                    two_boxes_for_ar1=two_boxes_for_ar1,
                    steps=steps,
                    offsets=offsets,
                    clip_boxes=clip_boxes,
                    variances=variances,
                    normalize_coords=normalize_coords,
                    subtract_mean=mean_color,
                    swap_channels=swap_channels)

    # 2: Load some weights into the model.

    # TODO: Set the path to the weights you want to load.
    weights_path = '../trained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

    model.load_weights(weights_path, by_name=True)

    # 3: Instantiate an optimizer and the SSD loss function and compile the model.
    #    If you want to follow the original Caffe implementation, use the preset SGD
    #    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

    if Optimizer_Type == 'SGD':
        Optimizer = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
    elif Optimizer_Type == 'Adam':
        Optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    else:
        raise ValueError('Undefined Optimizer_Type.')

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool2_GAP_substract': ssd_loss.compute_distance_loss,
                                             'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
                                             'predictions': ssd_loss.compute_loss},
                  loss_weights={'pool1_GAP_substract': loss_weights[0],
                                'pool2_GAP_substract': loss_weights[1],
                                'pool3_GAP_substract': loss_weights[2],
                                'predictions': loss_weights[3]})    
    
#     if Source_Only:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss_source_only,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})
#     else:
#         model.compile(optimizer=Optimizer, loss={'pool1_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool2_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'pool3_GAP_substract': ssd_loss.compute_distance_loss,
#                                                  'predictions': ssd_loss.compute_loss},
#                       loss_weights={'pool1_GAP_substract': loss_weights[0],
#                                     'pool2_GAP_substract': loss_weights[1],
#                                     'pool3_GAP_substract': loss_weights[2],
#                                     'predictions': loss_weights[3]})

elif Model_Build == 'Load_Model':
    # TODO: Set the path to the `.h5` file of the model to be loaded.
    model_path = '../trained_weights/VGG_ssd300_Cityscapes/epoch-23_loss-5.2110_val_loss-6.7452.h5'

    # We need to create an SSDLoss object in order to pass that to the model loader.
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    K.clear_session()  # Clear previous models from memory.

    # import tensorflow as tf
    # from keras.backend.tensorflow_backend import set_session
    #
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    # config.log_device_placement = True  # to log device placement (on which device the operation ran)
    # # (nothing gets printed in Jupyter, only if you run it standalone)
    # sess = tf.Session(config=config)
    # set_session(sess)  # set this TensorFlow session as the default session for Keras

    model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                                   'L2Normalization': L2Normalization,
                                                   'compute_loss': ssd_loss.compute_loss,
                                                   'compute_distance_loss': ssd_loss.compute_distance_loss})
else:
    raise ValueError('Undefined Model_Build. Model_Build should be New_Model  or Load_Model')
# Out:
# da_loss_metric is MMD

# %%
if Dataset_Build == 'New_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

    train_dataset = DataGenerator(dataset='train', load_images_into_memory=False, hdf5_dataset_path=None)
    val_dataset = DataGenerator(dataset='val', load_images_into_memory=False, hdf5_dataset_path=None)

    # 2: Parse the image and label lists for the training and validation datasets. This can take a while.
    # images_dirs, image_set_filenames, and annotations_dirs should have the same length
    train_dataset.parse_xml(images_dirs=[train_source_images_dir],
                            target_images_dirs=[train_target_images_dir],
                            image_set_filenames=[train_source_image_set_filename],
                            target_image_set_filenames=[train_target_image_set_filename],
                            annotations_dirs=[train_annotation_dir],
                            classes=train_classes,
                            include_classes=train_include_classes,
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[test_target_images_dir],
                          image_set_filenames=[test_target_image_set_filename],
                          annotations_dirs=[test_annotation_dir],
                          classes=val_classes,
                          include_classes=val_include_classes,
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)

    # Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
    # speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
    # option in the constructor, because in that cas the images are in memory already anyway. If you don't
    # want to create HDF5 datasets, comment out the subsequent two function calls.

    # After create these h5 files, if you have resized the input image, you need to reload these files. Otherwise,
    # the images and the labels will not change.

    train_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                      resize=resize_image_to,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)

    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

elif Dataset_Build == 'Load_Dataset':
    # 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

    # Load dataset from the created h5 file.
    train_dataset = DataGenerator(dataset='train',
                                  load_images_into_memory=False,
                                  hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_train.h5'),
                                  filenames=train_source_image_set_filename,
                                  target_filenames=train_target_image_set_filename,
                                  filenames_type='text',
                                  images_dir=train_source_images_dir,
                                  target_images_dir=train_target_images_dir)

    val_dataset = DataGenerator(dataset='val',
                                load_images_into_memory=False,
                                hdf5_dataset_path=os.path.join(processed_dataset_path, 'dataset_test.h5'),
                                filenames=test_target_image_set_filename,
                                filenames_type='text',
                                images_dir=test_target_images_dir)

else:
    raise ValueError('Undefined Dataset_Build. Dataset_Build should be New_Dataset or Load_Dataset.')
# Out:
# Loading source labels: 100%|██████████| 2966/2966 [00:00<00:00, 4399.47it/s]
# Loading source image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 10365.03it/s]
# Loading target image IDs: 100%|██████████| 2966/2966 [00:00<00:00, 10581.74it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 2966/2966 [00:00<00:00, 7885.27it/s]
# Loading source labels: 100%|██████████| 493/493 [00:00<00:00, 4402.27it/s]
# Loading source image IDs: 100%|██████████| 493/493 [00:00<00:00, 10594.23it/s]
# Loading target image IDs: 0it [00:00, ?it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 493/493 [00:00<00:00, 7581.72it/s]

# %%
# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation_Siamese(img_height=img_height,
                                                    img_width=img_width)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
# The input image and label are first processed by transformations. Then, the label will be further encoded by
# ssd_input_encoder. The encoded labels are classId and offset to each anchor box.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  2966
# Number of images in the validation dataset:	   493

# %%
def lr_schedule(epoch):
    if epoch < 2:
        return 0.0005
    elif epoch < 50:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 0.00001

# def lr_schedule(epoch):
#     if epoch < 50:
#         return 0.001
#     elif epoch < 60:
#         return 0.0001
#     else:
#         return 0.00001

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=os.path.join(checkpoint_path, 'epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'),
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=False,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)

# model_checkpoint.best to the best validation loss from the previous training
# model_checkpoint.best = 4.83704

csv_logger = CSVLogger(filename=os.path.join(checkpoint_path, 'source_only_run2_training_log.csv'),
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

TensorBoard_monitor = TensorBoard(log_dir=checkpoint_path)

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,
             TensorBoard_monitor]

# %%
initial_epoch = 0
final_epoch = 80
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/80
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 846s 846ms/step - loss: 9.4891 - pool1_GAP_substract_loss: 4.5584 - pool2_GAP_substract_loss: 4.6311 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 5.9436 - val_loss: 8.9644 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.4440
#
# Epoch 00001: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-01_loss-9.4891_val_loss-8.9644.h5
# Epoch 2/80
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0005.
# 1000/1000 [==============================] - 842s 842ms/step - loss: 8.0891 - pool1_GAP_substract_loss: 4.5430 - pool2_GAP_substract_loss: 4.6234 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.5753 - val_loss: 8.3816 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.8927
#
# Epoch 00002: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-02_loss-8.0891_val_loss-8.3816.h5
# Epoch 3/80
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 842s 842ms/step - loss: 7.8731 - pool1_GAP_substract_loss: 4.5112 - pool2_GAP_substract_loss: 4.5875 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.4051 - val_loss: 8.7464 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 5.3177
#
# Epoch 00003: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-03_loss-7.8731_val_loss-8.7464.h5
# Epoch 4/80
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 848s 848ms/step - loss: 7.4169 - pool1_GAP_substract_loss: 4.4829 - pool2_GAP_substract_loss: 4.5529 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 4.0091 - val_loss: 8.0523 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6835
#
# Epoch 00004: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-04_loss-7.4169_val_loss-8.0523.h5
# Epoch 5/80
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 7.1589 - pool1_GAP_substract_loss: 4.4722 - pool2_GAP_substract_loss: 4.5273 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.8106 - val_loss: 8.0489 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7391
#
# Epoch 00005: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-05_loss-7.1589_val_loss-8.0489.h5
# Epoch 6/80
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 6.9802 - pool1_GAP_substract_loss: 4.4722 - pool2_GAP_substract_loss: 4.5011 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.6905 - val_loss: 8.0486 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.7967
#
# Epoch 00006: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-06_loss-6.9802_val_loss-8.0486.h5
# Epoch 7/80
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 864s 864ms/step - loss: 6.8101 - pool1_GAP_substract_loss: 4.4576 - pool2_GAP_substract_loss: 4.4958 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5778 - val_loss: 7.6007 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4057
#
# Epoch 00007: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-07_loss-6.8101_val_loss-7.6007.h5
# Epoch 8/80
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 867s 867ms/step - loss: 6.6973 - pool1_GAP_substract_loss: 4.4539 - pool2_GAP_substract_loss: 4.4820 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.5212 - val_loss: 7.7989 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.6595
#
# Epoch 00008: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-08_loss-6.6973_val_loss-7.7989.h5
# Epoch 9/80
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 859s 859ms/step - loss: 6.5392 - pool1_GAP_substract_loss: 4.4525 - pool2_GAP_substract_loss: 4.4677 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.4182 - val_loss: 7.4535 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3686
#
# Epoch 00009: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-09_loss-6.5392_val_loss-7.4535.h5
# Epoch 10/80
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 853s 853ms/step - loss: 6.4377 - pool1_GAP_substract_loss: 4.4424 - pool2_GAP_substract_loss: 4.4484 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3707 - val_loss: 7.3693 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3378
#
# Epoch 00010: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-10_loss-6.4377_val_loss-7.3693.h5
# Epoch 11/80
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 860s 860ms/step - loss: 6.3440 - pool1_GAP_substract_loss: 4.4464 - pool2_GAP_substract_loss: 4.4418 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.3298 - val_loss: 7.2659 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2866
#
# Epoch 00011: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-11_loss-6.3440_val_loss-7.2659.h5
# Epoch 12/80
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 853s 853ms/step - loss: 6.2053 - pool1_GAP_substract_loss: 4.4369 - pool2_GAP_substract_loss: 4.4337 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2428 - val_loss: 7.2828 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3548
#
# Epoch 00012: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-12_loss-6.2053_val_loss-7.2828.h5
# Epoch 13/80
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 855s 855ms/step - loss: 6.1129 - pool1_GAP_substract_loss: 4.4461 - pool2_GAP_substract_loss: 4.4405 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.2010 - val_loss: 7.1254 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2472
#
# Epoch 00013: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-13_loss-6.1129_val_loss-7.1254.h5
# Epoch 14/80
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 853s 853ms/step - loss: 6.0467 - pool1_GAP_substract_loss: 4.4337 - pool2_GAP_substract_loss: 4.4185 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1843 - val_loss: 7.0594 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2302
#
# Epoch 00014: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-14_loss-6.0467_val_loss-7.0594.h5
# Epoch 15/80
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 5.9408 - pool1_GAP_substract_loss: 4.4442 - pool2_GAP_substract_loss: 4.4239 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1268 - val_loss: 7.0456 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2642
#
# Epoch 00015: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-15_loss-5.9408_val_loss-7.0456.h5
# Epoch 16/80
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 855s 855ms/step - loss: 5.8893 - pool1_GAP_substract_loss: 4.4284 - pool2_GAP_substract_loss: 4.4125 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.1225 - val_loss: 6.8695 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1349
#
# Epoch 00016: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-16_loss-5.8893_val_loss-6.8695.h5
# Epoch 17/80
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 856s 856ms/step - loss: 5.7870 - pool1_GAP_substract_loss: 4.4243 - pool2_GAP_substract_loss: 4.3991 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0667 - val_loss: 7.1759 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4872
#
# Epoch 00017: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-17_loss-5.7870_val_loss-7.1759.h5
# Epoch 18/80
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 847s 847ms/step - loss: 5.7371 - pool1_GAP_substract_loss: 4.4354 - pool2_GAP_substract_loss: 4.4051 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0620 - val_loss: 6.6762 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0322
#
# Epoch 00018: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-18_loss-5.7371_val_loss-6.6762.h5
# Epoch 19/80
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 846s 846ms/step - loss: 5.6323 - pool1_GAP_substract_loss: 4.4373 - pool2_GAP_substract_loss: 4.4052 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 3.0014 - val_loss: 6.8589 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2586
#
# Epoch 00019: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-19_loss-5.6323_val_loss-6.8589.h5
# Epoch 20/80
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 843s 843ms/step - loss: 5.5691 - pool1_GAP_substract_loss: 4.4424 - pool2_GAP_substract_loss: 4.3957 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9815 - val_loss: 6.7873 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2299
#
# Epoch 00020: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-20_loss-5.5691_val_loss-6.7873.h5
# Epoch 21/80
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 841s 841ms/step - loss: 5.5057 - pool1_GAP_substract_loss: 4.4307 - pool2_GAP_substract_loss: 4.3897 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9606 - val_loss: 6.6332 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1179
#
# Epoch 00021: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-21_loss-5.5057_val_loss-6.6332.h5
# Epoch 22/80
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 842s 842ms/step - loss: 5.4368 - pool1_GAP_substract_loss: 4.4283 - pool2_GAP_substract_loss: 4.3826 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9332 - val_loss: 6.5017 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0275
#
# Epoch 00022: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-22_loss-5.4368_val_loss-6.5017.h5
# Epoch 23/80
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 844s 844ms/step - loss: 5.3829 - pool1_GAP_substract_loss: 4.4378 - pool2_GAP_substract_loss: 4.3868 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.9200 - val_loss: 6.5470 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1129
#
# Epoch 00023: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-23_loss-5.3829_val_loss-6.5470.h5
# Epoch 24/80
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 845s 845ms/step - loss: 5.3038 - pool1_GAP_substract_loss: 4.4177 - pool2_GAP_substract_loss: 4.3756 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8807 - val_loss: 6.7822 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3875
#
# Epoch 00024: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-24_loss-5.3038_val_loss-6.7822.h5
# Epoch 25/80
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 5.2428 - pool1_GAP_substract_loss: 4.4227 - pool2_GAP_substract_loss: 4.3684 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8585 - val_loss: 6.5291 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1728
#
# Epoch 00025: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-25_loss-5.2428_val_loss-6.5291.h5
# Epoch 26/80
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 860s 860ms/step - loss: 5.2166 - pool1_GAP_substract_loss: 4.4093 - pool2_GAP_substract_loss: 4.3618 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8703 - val_loss: 6.6065 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2876
#
# Epoch 00026: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-26_loss-5.2166_val_loss-6.6065.h5
# Epoch 27/80
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 870s 870ms/step - loss: 5.1360 - pool1_GAP_substract_loss: 4.4273 - pool2_GAP_substract_loss: 4.3814 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8268 - val_loss: 6.4363 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1542
#
# Epoch 00027: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-27_loss-5.1360_val_loss-6.4363.h5
# Epoch 28/80
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 854s 854ms/step - loss: 5.0838 - pool1_GAP_substract_loss: 4.4128 - pool2_GAP_substract_loss: 4.3557 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8108 - val_loss: 6.4174 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1710
#
# Epoch 00028: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-28_loss-5.0838_val_loss-6.4174.h5
# Epoch 29/80
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 845s 845ms/step - loss: 5.0508 - pool1_GAP_substract_loss: 4.4111 - pool2_GAP_substract_loss: 4.3591 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.8132 - val_loss: 6.3807 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1694
#
# Epoch 00029: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-29_loss-5.0508_val_loss-6.3807.h5
# Epoch 30/80
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 863s 863ms/step - loss: 4.9930 - pool1_GAP_substract_loss: 4.4295 - pool2_GAP_substract_loss: 4.3723 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7900 - val_loss: 6.4175 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2405
#
# Epoch 00030: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-30_loss-4.9930_val_loss-6.4175.h5
# Epoch 31/80
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 867s 867ms/step - loss: 4.9543 - pool1_GAP_substract_loss: 4.4108 - pool2_GAP_substract_loss: 4.3583 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7852 - val_loss: 6.4383 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2946
#
# Epoch 00031: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-31_loss-4.9543_val_loss-6.4383.h5
# Epoch 32/80
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 861s 861ms/step - loss: 4.9001 - pool1_GAP_substract_loss: 4.4072 - pool2_GAP_substract_loss: 4.3559 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7638 - val_loss: 6.4505 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3394
#
# Epoch 00032: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-32_loss-4.9001_val_loss-6.4505.h5
# Epoch 33/80
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 862s 862ms/step - loss: 4.8528 - pool1_GAP_substract_loss: 4.4038 - pool2_GAP_substract_loss: 4.3556 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7489 - val_loss: 6.1164 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0373
#
# Epoch 00033: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-33_loss-4.8528_val_loss-6.1164.h5
# Epoch 34/80
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 875s 875ms/step - loss: 4.7752 - pool1_GAP_substract_loss: 4.4106 - pool2_GAP_substract_loss: 4.3545 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.7031 - val_loss: 6.2975 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2499
#
# Epoch 00034: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-34_loss-4.7752_val_loss-6.2975.h5
# Epoch 35/80
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 857s 857ms/step - loss: 4.7329 - pool1_GAP_substract_loss: 4.4123 - pool2_GAP_substract_loss: 4.3538 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6918 - val_loss: 6.4612 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4443
#
# Epoch 00035: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-35_loss-4.7329_val_loss-6.4612.h5
# Epoch 36/80
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 862s 862ms/step - loss: 4.7044 - pool1_GAP_substract_loss: 4.4147 - pool2_GAP_substract_loss: 4.3526 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6938 - val_loss: 5.9883 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0013
#
# Epoch 00036: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-36_loss-4.7044_val_loss-5.9883.h5
# Epoch 37/80
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 848s 848ms/step - loss: 4.6672 - pool1_GAP_substract_loss: 4.3999 - pool2_GAP_substract_loss: 4.3458 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6863 - val_loss: 6.1526 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1950
#
# Epoch 00037: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-37_loss-4.6672_val_loss-6.1526.h5
# Epoch 38/80
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 847s 847ms/step - loss: 4.6305 - pool1_GAP_substract_loss: 4.3900 - pool2_GAP_substract_loss: 4.3328 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6786 - val_loss: 6.0210 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0921
#
# Epoch 00038: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-38_loss-4.6305_val_loss-6.0210.h5
# Epoch 39/80
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.5908 - pool1_GAP_substract_loss: 4.3985 - pool2_GAP_substract_loss: 4.3323 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6673 - val_loss: 5.9693 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0687
#
# Epoch 00039: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-39_loss-4.5908_val_loss-5.9693.h5
# Epoch 40/80
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 844s 844ms/step - loss: 4.5373 - pool1_GAP_substract_loss: 4.4001 - pool2_GAP_substract_loss: 4.3358 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6418 - val_loss: 6.1566 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2835
#
# Epoch 00040: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-40_loss-4.5373_val_loss-6.1566.h5
# Epoch 41/80
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 841s 841ms/step - loss: 4.4977 - pool1_GAP_substract_loss: 4.3929 - pool2_GAP_substract_loss: 4.3393 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6295 - val_loss: 6.0079 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1618
#
# Epoch 00041: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-41_loss-4.4977_val_loss-6.0079.h5
# Epoch 42/80
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 862s 862ms/step - loss: 4.4529 - pool1_GAP_substract_loss: 4.3950 - pool2_GAP_substract_loss: 4.3331 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6114 - val_loss: 5.9881 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1685
#
# Epoch 00042: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-42_loss-4.4529_val_loss-5.9881.h5
# Epoch 43/80
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.4573 - pool1_GAP_substract_loss: 4.3926 - pool2_GAP_substract_loss: 4.3260 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6418 - val_loss: 5.9329 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1389
#
# Epoch 00043: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-43_loss-4.4573_val_loss-5.9329.h5
# Epoch 44/80
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 857s 857ms/step - loss: 4.3983 - pool1_GAP_substract_loss: 4.3787 - pool2_GAP_substract_loss: 4.3151 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6083 - val_loss: 6.0267 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2580
#
# Epoch 00044: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-44_loss-4.3983_val_loss-6.0267.h5
# Epoch 45/80
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 4.3851 - pool1_GAP_substract_loss: 4.3863 - pool2_GAP_substract_loss: 4.3230 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6200 - val_loss: 5.9283 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1842
#
# Epoch 00045: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-45_loss-4.3851_val_loss-5.9283.h5
# Epoch 46/80
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 847s 847ms/step - loss: 4.3463 - pool1_GAP_substract_loss: 4.3819 - pool2_GAP_substract_loss: 4.3167 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.6056 - val_loss: 5.9177 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1976
#
# Epoch 00046: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-46_loss-4.3463_val_loss-5.9177.h5
# Epoch 47/80
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 860s 860ms/step - loss: 4.3106 - pool1_GAP_substract_loss: 4.3904 - pool2_GAP_substract_loss: 4.3178 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5937 - val_loss: 6.0842 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.3876
#
# Epoch 00047: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-47_loss-4.3106_val_loss-6.0842.h5
# Epoch 48/80
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 854s 854ms/step - loss: 4.2638 - pool1_GAP_substract_loss: 4.3886 - pool2_GAP_substract_loss: 4.3279 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5703 - val_loss: 5.7698 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0967
#
# Epoch 00048: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-48_loss-4.2638_val_loss-5.7698.h5
# Epoch 49/80
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 871s 871ms/step - loss: 4.2217 - pool1_GAP_substract_loss: 4.3828 - pool2_GAP_substract_loss: 4.3295 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5511 - val_loss: 6.0974 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.4466
#
# Epoch 00049: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-49_loss-4.2217_val_loss-6.0974.h5
# Epoch 50/80
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 870s 870ms/step - loss: 4.2109 - pool1_GAP_substract_loss: 4.3805 - pool2_GAP_substract_loss: 4.3169 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.5624 - val_loss: 5.8772 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2485
#
# Epoch 00050: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-50_loss-4.2109_val_loss-5.8772.h5
# Epoch 51/80
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 875s 875ms/step - loss: 4.0391 - pool1_GAP_substract_loss: 4.3999 - pool2_GAP_substract_loss: 4.3227 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.4031 - val_loss: 5.6378 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0118
#
# Epoch 00051: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-51_loss-4.0391_val_loss-5.6378.h5
# Epoch 52/80
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 854s 854ms/step - loss: 3.9849 - pool1_GAP_substract_loss: 4.3936 - pool2_GAP_substract_loss: 4.3282 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3516 - val_loss: 5.6998 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0765
#
# Epoch 00052: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-52_loss-3.9849_val_loss-5.6998.h5
# Epoch 53/80
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 3.9643 - pool1_GAP_substract_loss: 4.3743 - pool2_GAP_substract_loss: 4.3159 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.3338 - val_loss: 5.7012 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0807
#
# Epoch 00053: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-53_loss-3.9643_val_loss-5.7012.h5
# Epoch 54/80
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 862s 862ms/step - loss: 3.9233 - pool1_GAP_substract_loss: 4.3860 - pool2_GAP_substract_loss: 4.3253 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2955 - val_loss: 5.6600 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0422
#
# Epoch 00054: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-54_loss-3.9233_val_loss-5.6600.h5
# Epoch 55/80
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 883s 883ms/step - loss: 3.9094 - pool1_GAP_substract_loss: 4.3853 - pool2_GAP_substract_loss: 4.3249 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2843 - val_loss: 5.6228 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0078
#
# Epoch 00055: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-55_loss-3.9094_val_loss-5.6228.h5
# Epoch 56/80
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 877s 877ms/step - loss: 3.8938 - pool1_GAP_substract_loss: 4.3833 - pool2_GAP_substract_loss: 4.3228 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2715 - val_loss: 5.6693 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0570
#
# Epoch 00056: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-56_loss-3.8938_val_loss-5.6693.h5
# Epoch 57/80
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 864s 864ms/step - loss: 3.8693 - pool1_GAP_substract_loss: 4.4045 - pool2_GAP_substract_loss: 4.3424 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2496 - val_loss: 5.6821 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0726
#
# Epoch 00057: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-57_loss-3.8693_val_loss-5.6821.h5
# Epoch 58/80
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 865s 865ms/step - loss: 3.9034 - pool1_GAP_substract_loss: 4.3833 - pool2_GAP_substract_loss: 4.3312 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2865 - val_loss: 5.6750 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0682
#
# Epoch 00058: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-58_loss-3.9034_val_loss-5.6750.h5
# Epoch 59/80
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 845s 845ms/step - loss: 3.8787 - pool1_GAP_substract_loss: 4.3895 - pool2_GAP_substract_loss: 4.3400 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2645 - val_loss: 5.7038 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0997
#
# Epoch 00059: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-59_loss-3.8787_val_loss-5.7038.h5
# Epoch 60/80
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 851s 851ms/step - loss: 3.8942 - pool1_GAP_substract_loss: 4.3623 - pool2_GAP_substract_loss: 4.3205 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2827 - val_loss: 5.6879 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0865
#
# Epoch 00060: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-60_loss-3.8942_val_loss-5.6879.h5
# Epoch 61/80
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 867s 867ms/step - loss: 3.8877 - pool1_GAP_substract_loss: 4.3830 - pool2_GAP_substract_loss: 4.3359 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2790 - val_loss: 5.6371 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0384
#
# Epoch 00061: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-61_loss-3.8877_val_loss-5.6371.h5
# Epoch 62/80
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 855s 855ms/step - loss: 3.8509 - pool1_GAP_substract_loss: 4.3800 - pool2_GAP_substract_loss: 4.3346 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2448 - val_loss: 5.5958 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 3.9998
#
# Epoch 00062: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-62_loss-3.8509_val_loss-5.5958.h5
# Epoch 63/80
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 3.8503 - pool1_GAP_substract_loss: 4.3781 - pool2_GAP_substract_loss: 4.3311 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2468 - val_loss: 5.6671 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0737
#
# Epoch 00063: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-63_loss-3.8503_val_loss-5.6671.h5
# Epoch 64/80
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 858s 858ms/step - loss: 3.8721 - pool1_GAP_substract_loss: 4.3870 - pool2_GAP_substract_loss: 4.3377 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2713 - val_loss: 5.6138 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0231
#
# Epoch 00064: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-64_loss-3.8721_val_loss-5.6138.h5
# Epoch 65/80
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 3.8555 - pool1_GAP_substract_loss: 4.3892 - pool2_GAP_substract_loss: 4.3417 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2573 - val_loss: 5.7595 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1714
#
# Epoch 00065: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-65_loss-3.8555_val_loss-5.7595.h5
# Epoch 66/80
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 856s 856ms/step - loss: 3.8619 - pool1_GAP_substract_loss: 4.3814 - pool2_GAP_substract_loss: 4.3366 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2665 - val_loss: 5.6774 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0920
#
# Epoch 00066: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-66_loss-3.8619_val_loss-5.6774.h5
# Epoch 67/80
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 846s 846ms/step - loss: 3.8459 - pool1_GAP_substract_loss: 4.3849 - pool2_GAP_substract_loss: 4.3432 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2531 - val_loss: 5.7939 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.2112
#
# Epoch 00067: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-67_loss-3.8459_val_loss-5.7939.h5
# Epoch 68/80
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 860s 860ms/step - loss: 3.8212 - pool1_GAP_substract_loss: 4.3950 - pool2_GAP_substract_loss: 4.3472 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2310 - val_loss: 5.7024 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1223
#
# Epoch 00068: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-68_loss-3.8212_val_loss-5.7024.h5
# Epoch 69/80
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 875s 875ms/step - loss: 3.8411 - pool1_GAP_substract_loss: 4.3762 - pool2_GAP_substract_loss: 4.3400 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2536 - val_loss: 5.7344 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1569
#
# Epoch 00069: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-69_loss-3.8411_val_loss-5.7344.h5
# Epoch 70/80
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 857s 857ms/step - loss: 3.7956 - pool1_GAP_substract_loss: 4.4003 - pool2_GAP_substract_loss: 4.3538 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2107 - val_loss: 5.6649 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0900
#
# Epoch 00070: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-70_loss-3.7956_val_loss-5.6649.h5
# Epoch 71/80
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 867s 867ms/step - loss: 3.8038 - pool1_GAP_substract_loss: 4.3919 - pool2_GAP_substract_loss: 4.3439 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2204 - val_loss: 5.6767 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1021
#
# Epoch 00071: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-71_loss-3.8038_val_loss-5.6767.h5
# Epoch 72/80
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 833s 833ms/step - loss: 3.7900 - pool1_GAP_substract_loss: 4.3815 - pool2_GAP_substract_loss: 4.3388 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2068 - val_loss: 5.6774 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1031
#
# Epoch 00072: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-72_loss-3.7900_val_loss-5.6774.h5
# Epoch 73/80
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 852s 852ms/step - loss: 3.7724 - pool1_GAP_substract_loss: 4.3940 - pool2_GAP_substract_loss: 4.3504 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1895 - val_loss: 5.6877 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1137
#
# Epoch 00073: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-73_loss-3.7724_val_loss-5.6877.h5
# Epoch 74/80
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 850s 850ms/step - loss: 3.7907 - pool1_GAP_substract_loss: 4.3920 - pool2_GAP_substract_loss: 4.3488 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2081 - val_loss: 5.6845 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1107
#
# Epoch 00074: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-74_loss-3.7907_val_loss-5.6845.h5
# Epoch 75/80
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 820s 820ms/step - loss: 3.7907 - pool1_GAP_substract_loss: 4.3867 - pool2_GAP_substract_loss: 4.3451 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2083 - val_loss: 5.7267 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.1532
#
# Epoch 00075: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-75_loss-3.7907_val_loss-5.7267.h5
# Epoch 76/80
#
# Epoch 00076: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 824s 824ms/step - loss: 3.7973 - pool1_GAP_substract_loss: 4.3821 - pool2_GAP_substract_loss: 4.3415 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.2152 - val_loss: 5.6707 - val_pool1_GAP_substract_loss: 1.0000e-04 - val_pool2_GAP_substract_loss: 1.0000e-04 - val_pool3_GAP_substract_loss: 0.0000e+00 - val_predictions_loss: 4.0975
#
# Epoch 00076: saving model to ../trained_weights/City_to_foggy/current/mmd_0_001/epoch-76_loss-3.7973_val_loss-5.6707.h5
# Epoch 77/80
#
# Epoch 00077: LearningRateScheduler setting learning rate to 1e-05.
#  133/1000 [==>...........................] - ETA: 11:25 - loss: 3.7671 - pool1_GAP_substract_loss: 4.3900 - pool2_GAP_substract_loss: 4.3441 - pool3_GAP_substract_loss: 0.0000e+00 - predictions_loss: 2.1851
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b7e216b1a5b0> in <module>()
#       9                               validation_data=val_generator,
#      10                               validation_steps=ceil(val_dataset_size/batch_size),
# ---> 11                               initial_epoch=initial_epoch)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 1: Set the generator for the val_dataset or train_dataset predictions.

predict_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

# %%
i = 1
print("Image:", batch_filenames[i])
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_images[0][i])
plt.show()
plt.figure(figsize=(20, 12))
plt.imshow(batch_images[1][i])
plt.show()

# %%
i = 0  # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# 3: Make predictions.

y_pred = model.predict(batch_images)[-1]

# Now let's decode the raw predictions in `y_pred`.

# Had we created the model in 'inference' or 'inference_fast' mode,
# then the model's final layer would be a `DecodeDetections` layer and
# `y_pred` would already contain the decoded predictions,
# but since we created the model in 'training' mode,
# the model outputs raw predictions that still need to be decoded and filtered.
# This is what the `decode_detections()` function is for.
# It does exactly what the `DecodeDetections` layer would do,
# but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).

# `decode_detections()` with default argument values follows the procedure of the original SSD implementation:
# First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes,
# then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45,
# and out of what is left after that, the top 200 highest confidence boxes are returned.
# Those settings are for precision-recall scoring purposes though.
# In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5,
# since we're only interested in the very confident predictions.

# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.35,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# We made the predictions on the resized images,
# but we'd like to visualize the outcome on the original input images,
# so we'll convert the coordinates accordingly.
# Don't worry about that opaque `apply_inverse_transforms()` function below,
# in this simple case it just applies `(* original_image_size / resized_image_size)` to the box coordinates.

# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# Finally, let's draw the predicted boxes onto the image.
# Each predicted box says its confidence next to the category name.
# The ground truth boxes are also drawn onto the image in green for comparison.

# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()

plt.figure(figsize=(20, 12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': 'green', 'alpha': 1.0})

# for box in y_pred_decoded_inv[i]:
#     xmin = box[2]
#     ymin = box[3]
#     xmax = box[4]
#     ymax = box[5]
#     color = colors[int(box[0])]
#     label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
#     current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))
#     current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor': color, 'alpha': 1.0})
